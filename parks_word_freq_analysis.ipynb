# %% [markdown]
# ## Analysis of long words and word frequency in Parks Canada BIAs
#
# ### Step 1: Load libraries and BIA project descriptions.
#
# The project descriptions will be tokenized into a list for counting word frequency.

# %%
import pandas as pd
import numpy as np

from pprint import pprint # pretty printer

import re # regular expressions

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/whitneylight/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# load the registry data (the clean project descriptions)

reg_data = pd.read_excel("data/processed/BIA_50select_edited.xlsx")
reg_data.head(3)
# Out:
#    BIA_no                                              title  \
# 0      87  Wildfire Risk Reduction at Fort Walsh National...
# 1     110             Shoreline Protection - Seawall Repairs
# 2     197  Big Island Marsh DFO Fisheries Habitat Offset ...
#
#                                          description              field_unit  \
# 0  The purpose of this project is to reduce the r...      Saskatchewan South
# 1  An armoured stone seawall, located around the ...  Southern New Brunswick
# 2  A Fisheries Act Authorization is required from...               Waterways
#
#                                                 park        lat          lon  \
# 0        Fort Walsh National Historic Site of Canada  49.573414  -109.882274
# 1  St. Andrews Blockhouse National Historic Site ...   45.07707     67.06198
# 2  Trent-Severn Waterway National Historic Site o...  44.106416   -77.231107
#
#         province contact_internal            fuia_num  ... attach_ia  \
# 0   Saskatchewan  Sherri Clifford    SSFU-2020-035-FW  ...       NaN
# 1  New Brunswick  Shirley Butland  NBSouth-2020-EIA-4  ...       NaN
# 2        Ontario      Randy Power          TS-2019-05  ...       NaN
#
#               created            modified       created_by      modified_by  \
# 0 2020-12-07 12:13:59 2021-03-01 17:16:27    Krista Cairns    Krista Cairns
# 1 2020-09-25 10:24:42 2021-02-24 15:02:33  Shirley Butland  Shirley Butland
# 2 2020-02-19 09:18:53 2021-07-27 11:54:55     Randal Power     Randal Power
#
#     id item_type                                            path lang_check  \
# 0  192      Item  sites/ImpactAssessment/Lists/DIA Tracking List         en
# 1  169      Item  sites/ImpactAssessment/Lists/DIA Tracking List         en
# 2   82      Item  sites/ImpactAssessment/Lists/DIA Tracking List         en
#
#   wordcount
# 0       149
# 1       139
# 2       155
#
# [3 rows x 30 columns]

# %%
# put the data into a list as tuple (BIA_no, description)

data = list(zip(reg_data["BIA_no"], reg_data["description"]))
pprint(data)
# Out:
# [(87,
#   'The purpose of this project is to reduce the risk of wildfire at Fort Walsh '
#   'National Historic Site by thinning pockets of fuel in two forested areas '
#   'near the fort site. The total area to be treated is 25 ha. The absence of '
#   'fire and the maturity of the forest around the fort site has resulted in '
#   'the accumulation of ladder fuels, old or dying mature trees and downed '
#   'woody material. By reducing the fuel load on site, removing trees and '
#   'administering various FireSmart techniques (stand thinning, ladder fuel '
#   'removal etc.) the impact of a wildfire on the site can be reduced. Ladder '
#   'fuels will be removed and tree limbs pruned to a height of 2m+ using '
#   'chainsaws and other various hand tools.  Dense areas will be thinned by '
#   'hand felling and deadfall will also be removed by hand. This project will '
#   'be assessed with a basic impact assessment. '),
#  (110,
#   'An armoured stone seawall, located around the perimeter of the shoreline '
#   'adjacent to the St Andrews Blockhouse National Historic Site, provides '
#   'protection against erosion from the water and wave action of the '
#   'Passamaquoddy Bay. Recent inspection of the seawall identified a number of '
#   'deficiencies that could result in potential failure of the structure and '
#   'cause erosion to the site. The Shoreline Protection – Seawall Repairs '
#   'project intends to rehabilitate the stone seawall by repairing damaged '
#   'areas along the structure. Some displaced stones will be temporary removed '
#   'to allow the necessary work to repair and raise the degraded bed. '
#   'Geotextile fabric will be installed before reinstating the stone. In other '
#   'areas, displaced stones, currently sitting on the ocean floor, will be '
#   'collected and fitted back in place. In addition, previously placed concrete '
#   'pieces will be removed and replaced with stone.\n'
#   '\n'),
#  (197,
#   'A Fisheries Act Authorization is required from DFO in relation to impacts '
#   'on fish habitat associated with dam construction projects at TSW Trenton '
#   'Dam 1 and Glen Miller Dam 3. The Authorization includes provisions for '
#   'offsetting measures.\n'
#   '\n'
#   'The construction of the Big Island causeway in the 1950’s and decreased '
#   'water flows between the island and the mainland have caused the channels to '
#   'be filled in with silt, and cattails now cover the entire area from the '
#   'island to the mainland. Parks Canada is proposing to expand on existing '
#   'fish habitat enhancements at the Big Island Marsh by constructing a new '
#   'channel and widening/deepening of 2 existing channels. Cattail marsh '
#   'vegetation will be removed to a width of 10 m and depths up to 3.0 m, in '
#   'order to ensure these areas stay open into the future. The Fisheries Offset '
#   'Plan is expected to result in the enhancement of fish habitat at the Big '
#   'Island Marsh.\n'),
#  (111,
#   'In May 2018 the Rabbit Creek Wildfire occurred in Prince Albert National '
#   'Park and spread within and outside of the park.  Heavy equipment was used '
#   'to create fire control lines and to improve ground and aerial access to '
#   'strategic areas.  In addition to the dozer lines that were put in during '
#   'the fire, heavy equipment was used along the border between the south '
#   'boundary of the park and the Cookson Community Pasture to push back the '
#   'forested edge to protect a newly repaired fence that had been damaged by '
#   'the fire.  Prince Albert National Park Fire Management takes responsibility '
#   'for the reclamation of the impacts from the heavy equipment.  The two areas '
#   'of work are the South Boundary Trail and the Elk Trail. \n'
#   '\n'
#   'Following the 2018 Rabbit Fire approximately 13.5 km of fence was replaced '
#   'on the northern boundary of the Cookson Community Pasture.  Approximately 6 '
#   'km of the fence was directly adjacent to the PANP boundary.  This area was '
#   'cleared of vegetation and has long linear berms of soil and wood that are '
#   'restricting efforts for weed control and seeding along the boundary and '
#   'also increase long term fire hazard if left in piles.  These berms will '
#   'need to be spread across the opening and a section of this area will need '
#   'to have a flat, debris free surface left to be used as a trail for off road '
#   'vehicles.\n'
#   '\n'
#   'The Elk trail was a maintained trail within the park.  A section of the Elk '
#   'Trail has been closed since 2018 due to impacts from heavy equipment during '
#   'wildfire operations.  The main area of concern is approximately 700 meters '
#   'of forest that was cleared to an average of 40 meters wide (2.8 ha) that '
#   'will be reclaimed.  As this fireguard was put in on a maintained trail, a '
#   'new trail surface will need to be developed during reclamation.  Within '
#   'this area a bridge that crossed a small stream was destroyed by heavy '
#   'equipment.  A shallow water ford crossing will be developed here.  Near '
#   'this area there is also a helipad of approximately 0.5 ha that will also be '
#   'reclaimed.  Midway from the trailhead there is a section of trail and '
#   'culvert that has washed out that will need to be repaired as well.  \n'),
#  (149,
#   'This project will involve construction of the Lake Superior National Marine '
#   'Conservation Area Discovery Centre in Nipigon, ON.  The project site is a '
#   '1.4-hectare lot at the Nipigon waterfront on the west side of Brennan '
#   'Drive.  The project will include construction of the Discovery Centre, '
#   'detached garage, parking area, outdoor interpretive elements, and '
#   'landscaping.  The Discovery Centre (approximately 1,300 square meters) will '
#   'be a single-story, multiuse building that will include exhibit space, '
#   'interpretive elements (interior and exterior), and administrative space.  '
#   'It will serve as the main hub for visitors to Lake Superior National Marine '
#   'Conservation Area and for site administration and operations.  The '
#   'construction phase of the project will involve use of heavy machinery, '
#   'excavation, backfilling, landscaping, and some vegetation removal.\n'
#   'This project will be assessed with a basic impact assessment.'),
#  (214,
#   'Yellow toadflax is a widely distributed perennial invasive plant that '
#   'reproduces by seed and extensive creeping rhizome. The plant is extremely '
#   'hardy and  has the ability to densely infest large areas and crowd out '
#   'native vegetation, making it a threat to ecological integrity in Prince '
#   'Albert National Park. Herbicide spraying of yellow toadflax has occurred in '
#   'several locations in Prince Albert National Park with limited success. '
#   'Using a biological control agent offers an additional option for control of '
#   'this species in a manner that is not nearly so labour intensive.  Prince '
#   'Albert National Park will be working with Agriculture and Agri-food Canada '
#   'to carry out trials of Rhinusa pilosa in up to three affected locations - '
#   'Prospect Point, Rabbit Cabin area and 12 Mile Meadow. Weevils will be '
#   'obtained from Agriculture and Agri-foods Canada at no charge and will be '
#   'released at the sites in late summer. '),
#  (257,
#   'Hyperabundant populations of White-tailed deer threaten the ecological '
#   'value of the varied forest communities on Hill Island and other park '
#   'islands. Intensive browsing has led to a distinct lack of understory '
#   'vegetation and changing forest composition.  Parks Canada has developed a '
#   'deer management strategy in response to these ecological impacts and is '
#   'proposing to restore the native vegetation to the area by reducing deer '
#   'numbers. The deer herd reduction will be conducted as outlined in the Hill '
#   'Island Hyperabundant Deer Management Plan (2012). The goal of the project '
#   'is to restore the integrity of the forest ecosystem on Hill Island and the '
#   'processes to protect the habitat of plant species of conservation concern '
#   '(eg Pitch pine). The deer herd reduction began in 2007 in an effort to '
#   'reduce populations to a level (4 deer per km2) that will allow for healthy '
#   'forest regeneration, and efforts continue to attain that population '
#   'density. The reduction in deer numbers will be achieved by partnering with '
#   'the Mohawks of Akwesasne to harvest White-tailed deer from the Island.  The '
#   'monitoring program will continue to track the effectiveness of the deer '
#   'reduction strategy in the recovery of the forest ecosystem. This project '
#   'will be assessed with a basic impact assessment.'),
#  (63,
#   'The project will entail the installation of approximately 330 grid-tied '
#   'photovoltaic solar panels at the site of the former Environment and Climate '
#   'Change Canada CAPMoN weather station, located within the Kejimkujik '
#   'National Park and National Historic Site frontcountry. The goal of the '
#   'project is to generate renewable electricity and contribute to the '
#   'reduction of greenhouse gases associated with the park’s operations. The '
#   'solar panels will be mounted on a racking system anchored with screw piles '
#   'or poured concrete foundations. Trenching will be required for the '
#   'installation of electrical wiring to connect the array with the existing '
#   'Nova Scotia power grid at the site. The project will be reviewed via a '
#   'Basic Impact Assessment. '),
#  (273,
#   'SaskPower is proposing to replace a pole mount transformer on an existing '
#   'wooden pole, and directionally drill 65 m to a customer supplied metering '
#   'point in SE-16-57-01 W3M within Prince Albert National Park. The project is '
#   'required to increase the capacity of the line and maintain the quality of '
#   'service to an existing customer.  Equipment that is expected to be used for '
#   'completion of the project includes: a digger truck, back-hoe, bucket truck, '
#   'directional boring equipment, and crew trucks.  access to components of the '
#   'project will make use of existing roads and trails. Surface disturbance is '
#   'expected to be minimized to the bell holes at the existing pole and '
#   'metering point.'),
#  (203,
#   'This project will involve dock work at multiple locations throughout '
#   'Thousand Islands National Park.  Specifically, work will include '
#   'installation of floating docks to replace docks that are were damaged due '
#   'to recent high water levels and to replace docks that are at the end of '
#   'their life cycle.  The new docks will be designed to accommodate higher '
#   'water levels.  Associated work includes installation of in-water/shoreline '
#   'anchoring systems and installation of boardwalks and kiosks at shore '
#   'landing points.  Replacements and/or minor location adjustments of mooring '
#   'buoy anchors may also be carried out where necessary. Dock project '
#   'locations include Adelaide Island, East Grenadier Island, Georgina Island, '
#   'Constance Island, Mulcaster Island, Milton Island, Hill Island and Stovin '
#   'Island.  Project work is planned to be commence in April 2020 and conclude '
#   'by November 2020.  This project will be assessed with a Basic Impact '
#   'Assessment.'),
#  (271,
#   ' A new culvert needs to be installed on the boundary road north of Osten '
#   'Lake Camping access on RR 205. The culvert has collapsed and completely '
#   'rusted out  and the site is currently flooded due to beaver activity and '
#   'Strathcona County culvert failure on RR 205.Currently beavers have a deep '
#   'run/washout through the boundary road making it impassable. The new culvert '
#   'will be a larger diameter (600mm) due to the sizes that are currently kept '
#   'in stock for replacements.  The old culvert was 450mm.  The work will take '
#   'place when there is no water flow through the boundary road. Three inch '
#   'minus pit run gravel will be used to fill the road base on the top and '
#   'sides of the new culvert. Strathcona County plans to repair the culvert '
#   'through RR 205.'),
#  (50,
#   'Red Bay’s 2011 management plan identified strategies to develop a menu of '
#   'visitor experience opportunities to enhance how Canadians discover, enjoy '
#   'and connect with the historic site. Site management have proposed an escape '
#   'game, developed by Fetch Quest, based on the history of the Red Bay Basque '
#   'Whaling Station. The game requires participants to complete a number of '
#   'puzzles and trivial tasks with props and equipment in order to successfully '
#   'solve the game. To facilitate the placement of some of the props, site '
#   'management is proposing a small addition to the island’s existing trail. A '
#   'board walk, approximately 5 feet in length, will extend from the existing '
#   'trail and allow participants to step off the main trail unto an 8 x '
#   '12-meter wooden platform that is placed upon a gravel bedding. '),
#  (51,
#   'The objective of this project is to complete the second phase of the '
#   'decommission and reclamation of the Redstreak wastewater lagoon. The first '
#   'phase of the project was completed in the summer and fall of 2020 when a '
#   'fence surrounding the lagoon and a large woody debris pile were removed. '
#   'Furthermore, soil samples were collected and analyzed to confirm that the '
#   'site is not contaminated and meets federal and provincial guidelines (BC '
#   'OMRR, BC CSR, CCME).\n'
#   '\n'
#   'The lagoon is adjacent to the Redstreak restoration area and is within a '
#   'subunit called the provincial block, which was harvested and thinned in '
#   '2002. The Redstreak restoration area was created as a multi-year '
#   'ecosystem-based management project where Parks Canada restored its '
#   'historical fire regime and brought back native grasses to provide better '
#   'grazing habitat by forest thinning and maintenance prescribed fire. \n'
#   '\n'
#   'In 2021, Parks Canada is targeting to complete the full decommission and '
#   'reclamation of the old wastewater lagoon site. The main objective of this '
#   'project’s second phase is to reduce the human footprint left on that site '
#   'by removing any infrastructure that remains at the lagoon and prepare the '
#   'site to start the natural revegetation phase of the reclamation.\n'),
#  (123,
#   'The cedar shingle roofing on the Watchmen accommodations cabin on Hotspring '
#   'Island is compromised and requires replacement. There is a known bat '
#   'maternity roost in the area (roughly 100m away), and bats may possibly be '
#   'using the roof, soffits, attic, etc. for roosting (unknown at this point, '
#   'physical inspection pending). The metal roofing on the Ellen Island '
#   'Operations station leaks and requires replacement. Bats have been observed '
#   'in the area in the past. Bats may possibly be using the roof, soffits, '
#   'attic, etc. for roosting (unknown at this point, physical inspection '
#   'pending). Both roofs will be redone using metal roofing. Because of the '
#   'possibility that bats may be using these cabins as a “residence”, this '
#   'project will be assessed with a Basic Impact Assessment.'),
#  (205,
#   'Grasslands National Park proposes to issue a license of occupation to graze '
#   'cattle over 8 sections in the Former Mankota Community Pasture area of the '
#   'East Block of the park. Cattle grazing has occurred in this area previously '
#   'under a grazing permit, and before acquisition by Parks Canada was used for '
#   'grazing livestock. Domestic livestock grazing is used in this area to '
#   'maintain a disturbance regime supporting habitat maintenance for species at '
#   'risk and for prairie ecosystem function. No new infrastructure will be '
#   'constructed as part of this program. Activities will include moving cattle '
#   'in and out of grazing paddocks, maintaining/repairing fences and watering '
#   'systems, and checking cattle. This project will be assessed with a basic '
#   'impact assessment. '),
#  (82,
#   'The existing main road from the South beach from the Sable Island Main '
#   'Station traverses an active tern colony (May – August).  Vehicle movements '
#   'along this corridor creates disturbance to nesting birds, and can '
#   'contribute to nest failure and chick mortality.  To reduce these impacts, '
#   'it is proposed that a seasonal, temporary crossing be developed to allow '
#   'access to the south beach from Main Station.  The proposed location is '
#   'located approximately 1.8 km east of Main Station and passes through one of '
#   'the narrowest sections of the dunes (100m long) and is currently almost '
#   'devoid of vegetation and easily navigable by SINPR vehicles. The project '
#   'will be assessed with a basic impact assessment. '),
#  (49,
#   'An impact assessment is required to address potential impacts resulting '
#   'from the repair of a Class A2 pedestrian bridge on the West Coast Trail of '
#   'Pacific Rim National Park Reserve. Bridge repairs are required to ensure '
#   'the safety of visitors and staff while traversing and maintaining the '
#   'trail. Limited ground disturbance within riparian\n'
#   'habitat will be required to upgrade the mid-span bridge support structure. '
#   'All work within the riparian zone will meet DFO measures to reduce harm to '
#   'fish, including project completion during the least-risk summer window when '
#   'the adjacent creek is expected to be completely dry. No in water works will '
#   'occur as part of this project.\n'
#   'The anticipated effects and mitigation for this scope of work are limited '
#   'and well understood, thus a Basic Impact Assessment will be undertaken.'),
#  (156,
#   'The previous Cavendish Campground Staff Room experienced a devastating fire '
#   'last fall and, as such, burned beyond repair. National park staff now '
#   'require a lunchroom, wash up area and bathroom for their daily personal '
#   'needs. Site design and drawings have been completed and the new site for '
#   'the staff room has been designated within the rehabilitated dumping station '
#   'for Cavendish Campground. \n'
#   '\n'
#   'The new staff room will be situated in the northeast corner of the former '
#   'dumping station site. It will be partially constructed on an old '
#   'agricultural field (100+ years ago) that has since grown into an old field '
#   'regenerative forest stand of White Spruce. A paved parking lot covering a '
#   'large portion of the remaining graded site is also proposed within the site '
#   'design. Services (electrical, water, sewage and communications) will be '
#   'routed into the new lunchroom and travel in corridors identified on the '
#   'site drawing. All corridors have been previously disturbed by either road '
#   'construction or electrical corridors. \n'
#   '\n'
#   'Construction is expected to begin in June 2020 and be completed by October '
#   '2020. The campground entrance was re-designed and reconstructed in 2017. It '
#   'was at this time the old dumping station was removed and the site '
#   'rehabilitated into a grass field.\n'
#   '\n'
#   'Last fall, Hurricane Dorian made landfall on PEI and devastated Cavendish '
#   'Campground felling the majority of trees in the area. Any softwood trees '
#   'remaining standing were removed due to safety reasons. Therefore, there are '
#   'almost no trees remaining in the area where the lunch room is to be '
#   'constructed. \n'
#   '\n'
#   'This work is being tendered for contract in May 2020 with work beginning in '
#   'June 2020 and expected to be completed by October 2020.\n'
#   'The history of the site was originally agricultural crops (hay, potato, '
#   'grain, clover). The project site since has been heavily landscaped to '
#   'facilitate the construction of the campground entrance and supporting '
#   'infrastructure (access roads, Grahams Lane, parking lots, walking trails). '
#   'The entrance to the campground has been majorly reconfigured at least three '
#   'times in the past 70 years as is evident in the aerial photos. All roadways '
#   'would have had major amounts of fill trucked in to build up the road '
#   'surfaces. Back ditches would have been heavily landscaped with heavy '
#   'machinery disturbing anything that was found on site. \n'
#   'The campground had an EIA completed in 2015 that encompassed developing '
#   'additional camping sites throughout the campground. Archaeological test '
#   'pits were dug and the area was assessed for cultural impacts. \n'),
#  (221,
#   'Parks Canada is proposing to construct a new facility to conduct watercraft '
#   'inspections for Aquatic Invasive Species. The inspection station will be '
#   'constructed on an existing disturbed footprint near the Park entrance gate. '
#   'The scope of work may include minor roadway work including realignment to '
#   'facilitate vehicle access to the site, site preparation work including '
#   'grading, paving, installation of a washroom facility, utility work, and '
#   'installation of an inspection building. Parks Canada will be undertaking a '
#   'Basic Impact Assessment to assess potential project-related impacts to '
#   'natural and cultural resources from this Project.\n'
#   '\n'
#   'Assessment pathway was changed from BIA to PRIA (amendment signed August '
#   '12, 2020) once the design was finalized and it was determined that the '
#   'footprint remained fully in Zone IV and did not enter Zone II.'),
#  (238,
#   'The project includes mobilizing and staging equipment at Moose Island '
#   '(fuel, heavy equipment, flooding pumps, chainsaws, etc).  Construction of '
#   'the ice bridge over the Peace River, ice depth measurements, removal of '
#   'pack ice on the north and south shore of the Peace River, the flooding of '
#   'the river until adequate ice depth is achieved.  The winter road then '
#   'continues through the forest which requires snow removal, brushing of '
#   'fallen trees/willows, removal of large rocks, tree stumps, etc.  '
#   'Coordination is required with the southern crew working at the Fort '
#   'Chipewyan Rocher River Ice crossing. Maintenance of ice bridge/winter road '
#   'is required throughout the season, brushing, plowing, grading of ice bridge '
#   'and winter road, and further ice depth measurements take place on the Peace '
#   'River and Quatre Forche.'),
#  (251,
#   'Snowmobiling is a permitted activity in designated areas of Gros Morne '
#   'National Park. A snowmobile access route that has been used by local '
#   'residents is now being proposed for public and commercial use. This route '
#   'covers 179.8 hectares and will travel for approximately 12 kilometers from '
#   'Woody Point to Trout River alongside highway Route 431 (Trout River Gulch). '
#   'Other than the placement of signage at entrance points, no construction '
#   'activities are required. In addition to this access route, a 1,541.5 '
#   'hectare snowmobile exclusion zone will be created on the northwest facing '
#   'slope of the Tablelands. Therefore there will be a significant net '
#   'reduction in areas open to snowmobiling. Most of the new snowmobile '
#   'corridor, 134.8 hectares, passes through areas designated as Zone III '
#   '(natural environment), whereas the majority of the expanded exclusion area, '
#   '1,195.3 hectares, is designated as Zone II (Wilderness).'),
#  (250,
#   'The existing culvert was originally constructed in 1957 and is in poor '
#   'condition with spalls, exposed rebar, and wide cracks. The existing culvert '
#   'is 5.5 m wide by 1.8 m high, and is a combination of concrete open footing '
#   'culvert and concrete box culvert. The proposed replacement consists of a 6 '
#   'm x 2.5 m cast-in-place concrete open footing culvert supported on steel '
#   'H-piles, on the existing alignment. The culvert will include cast-in-place '
#   'concrete wingwalls\n'
#   'supported on steel H-piles. The proposed culvert has adequate capacity to '
#   'convey the 25-year design storm and check flood without overtopping the '
#   'roadway. During the replacement, the flow will be maintained through a '
#   'temporary bypass pipe. The work has been divided into two phases: Phase 1 '
#   'in Fall 2019 involves installation of the bypass system, and Phase 2 in '
#   '2020 involves the culvert replacement. The work has been classified as a '
#   'Group C project under the MTO Class EA in which an Environmental Screening '
#   'Document has been prepared. This provincial level EA will be evaluated '
#   'against federal requirements and any gaps will be filled within the BIA.'),
#  (264,
#   'Parks Canada Fire Management Team in Waterton Lakes National Park has '
#   'proposed the implementation of a prescribed fire in the Y Camp (Wishbone) '
#   'area of the Park. The ecological objective of the fire is to reverse the '
#   'trend of aspen tree encroachment onto what was historically Fescue '
#   'Grassland and to restore the mean fire interval of 5 years to the Fescue '
#   'Grassland and Aspen Parkland Ecoregions of the Park. The Fescue Grassland '
#   'provides critical habitat for a variety of species in and outside of the '
#   'park. The burn unit is located on the east side of Lower Waterton Lake and '
#   'Waterton River, just south of Highway 6 and encompasses an area of 1,170 '
#   'ha. Fire operations would take place in the winter (pre-guard burning) and '
#   'spring (main unit burning) of 2020 before leaf out. Execution of this burn '
#   'would take place every 5 years thereafter under the same conditions to '
#   'continue with the trend of the reduction of Aspen Parkland encroachment '
#   'into the Fescue Grasslands Ecoregion.'),
#  (139,
#   'Grasslands National Park is partnering with SaskPower to remove 10 km of '
#   'overhead service line in the West Block of the park, replacing it with a '
#   'partially buried service line. The existing overhead line crosses through '
#   'prairie, while the replacement line will follow the existing public access '
#   'road. The public access road intersects a black-tailed prairie dog colony, '
#   'and work will occur on lands protected by the Emergency Order for the '
#   'Protection of the Greater Sage-Grouse (2013). The proposed project will '
#   'work towards conservation goals for the greater sage-grouse by removing '
#   'power poles in critical habitat. Tall vertical structures in critical '
#   'habitat are identified by the Recovery Strategy for this species as a '
#   'chronic disturbance that threatens their recovery and survival. This '
#   'project will be assessed with a basic impact assessment. '),
#  (112,
#   'Many decades of high-intensity browsing by deer on Sidney Island has '
#   'greatly reduced the abundance and diversity of plants in the forest '
#   'understory. The result of this pressure is that the forest on Sidney Island '
#   'has lost much of the species diversity and structural diversity it once '
#   'had: fewer tree species are able to grow into saplings to replace older '
#   'trees as they die, and the understorey has nearly disappeared. The forest '
#   'will continue on this trajectory unless effective restoration work is done. '
#   'Therefore, the objective of this project is to establish pockets of native '
#   'shrubs in the Park Reserve that would rejuvenate the forest understorey, '
#   'both where they are planted and also throughout the forest by producing '
#   'seeds. To accomplish this objective, we propose building ten small, fenced '
#   'areas (10-meter by 10-meter) that prevent deer browsing and planting native '
#   'shrubs within them. Fencing will not be permanent: the fenced areas will be '
#   'constructed to last several years (3 – 10) to give the shrubs time to '
#   'become well established, after which time the fences will be removed. The '
#   'work will occur seasonally during 2021-2023. \n'
#   'This project will be assessed with a basic impact assessment.'),
#  (126,
#   'Parks Canada is responsible for overseeing the management and maintenance '
#   'of tenanted properties, including the associated assets, within Rouge '
#   'National Urban Park. The purpose of this project is to decommission '
#   'existing residential sewage disposal systems and install new residential '
#   'sewage disposal systems (septic systems) to prevent potential risk to '
#   'ground water and human health.\n'
#   'In order to install the new systems, pits will be excavated to contain the '
#   'septic tanks and pump tanks (approximately 2.0 m below ground level). '
#   'Trenches will be excavated from the dwelling to the septic tank and from '
#   'the pump tank to the leaching bed to contain the underground pipe system, '
#   'and the area under the leaching beds will be excavated to various depths '
#   'depending on the site. Each of these excavations will be larger than the '
#   'area of the final septic system to allow room for installation. During this '
#   'work, a temporary silt fence barrier will be installed at each site when '
#   'necessary, equipment will be driven in the area around the excavations, and '
#   'topsoil will be stockpiled on site. \n'
#   'The new septic systems will be in compliance with the 2012 Ontario Building '
#   'Code, as amended. These septic systems will have an expected minimum '
#   'service life of 25 years provided trees, shrubs, and vegetation with deep '
#   'roots are controlled.\n'),
#  (171,
#   'The purpose of the project is to replace all distribution water main and '
#   'services, and sanitary sewer main and services including the septic fields '
#   'within the various sections of the Newman Sound and Malady Head Campgrounds '
#   'within in Terra Nova National Park. \n'
#   'o\tProject areas include the distribution main leaving the water treatment '
#   'plant/pump house and replacement of the existing wood stave tank, water '
#   'distribution mains and sanitary sewers in Newman Sound Campground loops H, '
#   'I, J, K, L, M and dumping station area, loops D, E, F and G as well as the '
#   'water main and fire hose boxes in loops R, F and Q.\n'
#   'o\tSeptic fields (3) will be installed in the vicinity of Loop D, E, & H '
#   'respectively.  \n'
#   'o\tProject works also include water services to kitchen shelters, '
#   'replacement of sanitary sewer services to existing washrooms and water '
#   'bottling filling stations. \n'
#   'o\tReplacement of the water distribution mains and sanitary sewer system '
#   'including 3 septic fields at Malady Head Campground. Septic fields located '
#   'near the existing trickling plant, group tenting and the day-use area '
#   'respectively.\n'),
#  (115,
#   'The recapitalization of the Junior Commissariat Officers’ Quarters, a '
#   'federally Recognized Heritage Building, is part of a series of Federal '
#   'Infrastructure Initiative projects initiated in 2015 at Butler’s Barracks '
#   'National Historic Site.  The Junior Commissariat Officers’ Quarters is '
#   'structurally unsound in certain areas, and renovations to the structure '
#   'will be substantial including the replacement of the roofing system, '
#   'stabilization and repointing of the chimneys, reconstruction of some of the '
#   'walls, improvements to drainage around the exterior of the building, and '
#   'installation and upgrading of utilities.  This project will allow Parks '
#   'Canada to explore future uses for this important heritage building. '),
#  (209,
#   'Invasive English hawthorn (Crataegus monogyna) has been identified as a key '
#   'threat to meadow plant communities on Sidney Island by Parks Canada, the '
#   'Sidney Island Community, and academic researchers. Management of English '
#   'hawthorn has been ongoing since 2008 but the English hawthorn population '
#   'has been progressively expanding into open meadows. English hawthorn shrubs '
#   'are able to aggressively resprout from untreated stumps and root fragments, '
#   'rendering traditional control methods of hand pulling or clipping '
#   'ineffective. Continued English hawthorn invasion will degrade ecosystem '
#   'health by supplanting native species and changing local environmental '
#   'conditions to favor shrubs and trees rather than meadow species. An '
#   'experimental approach is being taken to compare the efficacy of several '
#   'physical and chemical removal methods in order to determine best practices '
#   'for English hawthorn control. \n'
#   'English hawthorn shrubs will be cut down using hand saws or power tools (eg '
#   'brush cutters, chainsaws). Garlon brand herbicide will be applied directly '
#   'to the remaining stumps to control regrowth. Garlon, a triclopyr herbicide, '
#   'was selected for this trial because it specifically targets broadleaf '
#   'species, successfully controls resprouting, and has little to no long-term '
#   'effects on grasses or sedges, as has been documented in peer reviewed '
#   'academic research. Garlon will be applied in a manner so as to avoid '
#   'leaching, aerial drift, or surface runoff. The proposed use of Garlon '
#   'herbicide is consistent with Parks Canada’s Integrated Pest Management Plan '
#   'for Gulf Islands National Park Reserve. Treatment will occur on Sidney '
#   'Island during March – April and October – December 2020. \n'),
#  (39,
#   'Fundy National Park intends to initiate a vegetation management plan to '
#   'reduce the potential hazards of excessive vegetation growth (seepage caused '
#   'by deep roots, cavities created by decaying roots, erosion caused by '
#   'uprooted trees, competition from undesired vegetation, dense vegetation '
#   'obscure the ability to observe deficiencies, etc) on the Bennett Lake Dam '
#   'and the Wolfe Lake Water Retaining Structure.  If left unchecked, the '
#   'existing vegetation could pose a serious threat to the strength and '
#   'stabilize to both of these structures. The proposed vegetation management '
#   'activities will be conducted periodically during the growing season and '
#   'repeated annually. A Basic Impact Assessment is required to investigate the '
#   'potential impacts of the proposed vegetation management activities. '),
#  (138,
#   'The proposed project will see the construction of a new pedestrian bridge '
#   'across the Mersey River near Mills Falls. The new bridge will replace a '
#   'nearby existing pontoon floating bridge which was damaged during Hurricane '
#   'Dorian in September 2019. The new single span bridge will be 30.5m in '
#   'length and 1.8m wide. Cast in place concrete abutments will be established '
#   'on either bank, with a total surface area of 20m2 .  Short sections of new '
#   'trail (30m total length) will also be required on the north and south banks '
#   'to connect the bridge with the adjacent existing trail networks. This '
#   'project will be assessed with a basic impact assessment. '),
#  (113,
#   'Grasslands National Park is proposing to upgrade low-level stream crossings '
#   'in the East Block of Grasslands National Park. These crossings are located '
#   'along vehicle access routes that are maintained for local access, emergency '
#   'response, and for operational purposes. Current condition of stream '
#   'crossings will be assessed and upgrade options will be evaluated and '
#   'implemented. Rock Creek in the East Block is habitat for the plains minnow, '
#   'a species listed on Schedule 1 of the Species at Risk Act. It is possible '
#   'work will occur in a tributary to Rock Creek or in Rock Creek. This project '
#   'will be assessed with a basic impact assessment. '),
#  (277,
#   '\n'
#   'The work involves installing cofferdam structures upstream and downstream '
#   'of the lock, dewatering of the lock and approaches, removal of damaged '
#   'concrete, concrete repair, landscaping upon project completion and related '
#   'project activities such as creating staging areas and use of machinery. '
#   'Lock work to take place in the fall/winter between navigation season - '
#   'after the Thanksgiving weekend in October and prior to the Victoria Day '
#   'weekend in May.\n'
#   '\n'
#   '\n'
#   'The project is a complete replacement of the steel bridge structure, which '
#   'spans the canal, and repairs to its concrete piers which are completely out '
#   'of water. This work is also taking place in the fall/winter between '
#   'navigation season as not to interfere with navigation through Lock 42.'),
#  (210,
#   'The Crean Lake Channel, which joins the 3rd Heart Lake to Crean Lake has '
#   'periodically been a hazard to boaters due to submerged rocks, which can '
#   'damage boat props and motor legs. A partial modification was carried out by '
#   'volunteers in 2003; hazardous rocks were removed by hand and relocated to '
#   'the edge of the channel.  With lower water levels in recent years, the '
#   'channel is again a safety issue. A group of concerned lake users approached '
#   'to the park with a proposal to more permanently rectify the issue by '
#   'removing hazardous rocks and boulders using a small backhoe with a thumb '
#   'attachment working from the park barge.  Rocks would be picked out of the '
#   'boat channel and moved to the edge of the channel out of the way of passing '
#   'boats. '),
#  (266,
#   'This project will entail campground kiosk replacement in an established '
#   'campground in North Saanich within Gulf Islands National Park Reserve. Work '
#   'involves removing and replacing the structure and cement footing of the '
#   'approximately 2m x 5m structure then replacing with new footing and '
#   'structure. The new kiosk will incorporate culturally appropriate content, '
#   'selected in consultation with local Nations, and will include Coast Salish '
#   'carving(s). Equipment includes small excavator, cement mixer and hand '
#   'tools. Proposed mitigations include having local cultural workers on site '
#   'during excavation work. Work at the site is planned to occur by April 15 '
#   '2020. Kiosk replacement is planned to coincide with other campground '
#   'revitalization activities undertaken by the First Nations Program of Gulf '
#   'Islands National Park Reserve. '),
#  (144,
#   'The existing decking on the Thomas Meadow Brook bridge is degraded and at '
#   'the end of its service life. The Thomas Meadow Brook bridge forms part of '
#   'Kejimkujik National Park and National Historic Site backcountry Liberty '
#   'Lake trail, provides asset maintenance staff access to the northern portion '
#   'of the park and is essential for visitor safety purposes. \n'
#   'The proposed work involves removing the deteriorated decking from the 6.2m '
#   'x 3.7m bridge and replacement with pressure treated timbers. Replacement of '
#   'the bridge stringers or abutments is not anticipated. All construction '
#   'waste will be disposed off site. The proposed work will occur in August and '
#   'September 2020. This project will be assessed with a basic impact '
#   'assessment.\n'),
#  (247,
#   'There are two outcomes sought by this project. The first outcome seeks to '
#   'increase the number of visitor mooring buoys at Sidney Spit from 14 to 21 '
#   'in order to provide better quality visitor experience while also protecting '
#   'critical eelgrass habitat. Buoys are attached by chains to 1m cubed cement '
#   'gravity anchors set on the ocean floor). This project seeks to return the '
#   'number of visitor mooring buoys to 21 by installing 4 additional anchors on '
#   'the ocean floor and adding 7 new buoys to the existing mooring field. \n'
#   '\n'
#   'The second portion of the project seeks to improve the existing closure at '
#   'the Sidney Lagoon by adding regulatory signage and closure notices at the '
#   'entrance and replacing one special purpose buoy. The Sidney Lagoon is '
#   'classified as a Zone One- Special Preservation Area and has been closed to '
#   'the public since 2008. This project seeks to replace one missing special '
#   'purpose closure buoy at the entrance of the lagoon, and add additional '
#   'signage to ensure visitors are informed of the lagoon closure. '),
#  (235,
#   'The Wildfire Risk Reduction Project entails the selective removal, thinning '
#   'and pruning of trees using fuel management and FireSmart principles to '
#   'reduce fuel loading. Proposed treatment areas are strategically located '
#   'within the Gulf Islands National Park Reserve in order to reduce the '
#   'wildfire risk to park properties, adjacent residents and island '
#   'communities, while also providing safer work areas for firefighters in the '
#   'event of an wildland/urban interface fire. Project locations include Tumbo '
#   'Island (north edge of wetland), Saturna Island (Mt Warburton Pike summit, '
#   'parking lot area) and North Pender Island (south of Roe Lake, adjacent to '
#   'the Park Reserve boundary). Project work is proposed for mid-January to '
#   'mid-March 2020.\n'
#   'Location Latitude and Longitude are for the Pender Island site.'),
#  (161,
#   'The Parks Canada Agency (PCA) has proposed to construct a new segment of '
#   'approximately 10 km linear trail that will connect two existing trail '
#   'segments, Bob Hunter Memorial Park and Boyle’s cemetery. The trail is '
#   'intended to be multi-use and primarily aggregate surface, with boardwalk '
#   'where required in wet areas and crossings over the Little Rouge River. It '
#   'will also connect with the proposed Markham Gateway Welcome Area. Fencing '
#   'will be used to separate the trail from active farming operations. '
#   'Pedestrian road crossings will occur at Major Mackenzie, 16th Avenue, '
#   'Highway 7, 407, and 14th Avenue. Routing options around or through private '
#   'property with owner’s permission and a small capacity parking lot on Major '
#   'Mac or 16th Ave will be investigated. '),
#  (59,
#   'Grasslands National Park is proposing to install a weather station in the '
#   'West Block of the park. The station will provide real-time weather '
#   'information in an area that otherwise has little coverage, and this '
#   'information will be used to support the fire and visitor safety programs. '
#   'The station itself is 3 m tall, with a 1 m2 tripod base, requires anchors '
#   'to secure, and will also require a cattle exclusion (typically a fence) to '
#   'prevent damage from cattle. The weather station needs to be sited '
#   'strategically to avoid obstructions or other features that might bias '
#   'weather readings, but must also take into account other sensitive features '
#   'such as critical habitat for species at risk and cultural resources. This '
#   'project will be assessed with a basic impact assessment.'),
#  (160,
#   'In an effort to manage the impacts of deer browse in sensitive areas of '
#   'RNUP and to study differences in browse levels when deer are excluded from '
#   'these areas, approximately 600 metres of deer exclusion fencing will be '
#   'installed in a forested plot in RNUP. The fencing will be installed about '
#   '25 meters off of a main road and continue about 145 meters into the '
#   'interior of the forest. A City of Toronto Road Closure Permit will be '
#   'required for the duration of this project. The area surrounding the site is '
#   'a densely forested area with a healthy understory. There are few social '
#   'trails through the area that should be used as access routes where possible '
#   'to minimize disturbance.  \n'),
#  (114,
#   'Parks Canada is proposing to install four Remote Avalanche Control System '
#   '(RACS) units on Mt Whymper. Currently Parks Canada Agency performs '
#   'avalanche control by placing explosives from helicopters in starting zones '
#   'of Mt Whymper. However, control by helicopter is often limited by poor '
#   'visibility and wind in the starting zones, effecting timing and efficiency '
#   'of avalanche control, and exposing workers to challenging flying conditions '
#   'and explosives use. The rationale for RACS in these paths is to reduce '
#   'impacts to Highway 93 South, highway closure time and gains in operational '
#   'efficiency and worker safety. The total footprint for four Gazex RACS '
#   'units, including foundations, shelters and pipelines is ~230 m. A maximum '
#   'of three leveled work pads will be required per site (72 m² footprint). One '
#   'or two permanent helipads may also be required (50 m² maximum footprint). '),
#  (272,
#   'Hunters Lake is a one way trail that incorporates various landscape '
#   'features including jack pine ridges, aspen forest and aquatic ecosytems.  '
#   'During a large fire that burnt throught the area in 2018, heavy equipment '
#   'was brought in to create fire breaks and the trail sustained major damage.  '
#   'A reroute was cut around a waterbody; trees were felled and left on site '
#   'causing a public safety hazard. The project involves bringing in a heavy '
#   'duty mulcher to mulch the trees on site at the trail reroute location as '
#   'well as to the end of the trail, where regrowth is now too heavy to be mown '
#   'with traditional equipment. Aggregate (gravel) will be hauled into the site '
#   'to build up a trail tread on the reroute and any other areas that need to '
#   'be resurfaced.  A culvert will be installed at a low spot on the trail.'),
#  (260,
#   'Parks Canada proposes to remove and decommission three structures that are '
#   'no longer operationally viable, including: a horse barn, a tack shed, and a '
#   'pump house located at Kootenay Crossing in Kootenay National Park. All '
#   'materials being stored on site will also be removed. A second phase of this '
#   'project may occur and will involve the rehabilitation of the area involving '
#   'the re-contouring, reclamation and re-vegetation of the site\n'
#   '\n'
#   'The project is located 43 kilometres (km) North of the intersection of '
#   'Highway 93 and Highway 95 in the Village of Radium Hot Springs. It is on '
#   'the west side of Highway 93 South in Kootenay National Park and past Parks '
#   'Canada fire operations facilities, which are currently in use.  \n'
#   '\n'
#   'This project will reduce infrastructure no longer required in the park, '
#   'reduce operational and maintenance cost, restore the area to its natural '
#   'condition, and improve important wildlife habitat and corridors in the '
#   'Kootenay crossing area. Removal of these facilities, restoration of the '
#   'area and reduction in human use will contribute to Park’s Canada general '
#   'objective to maintain or improve ecological integrity.\n'),
#  (243,
#   'SaskPower is proposing to replace an urban power pole, transformer, and '
#   'take off equipment, then trench and lay approximately 30 metres (m) of '
#   'secondary cable to a customer owned splitter, at which point the customer '
#   'will be responsible to connections.  Ground disturbance will be limited to '
#   'the base of the pole and the short run of trenching.   The work will take '
#   'place near an existing underground cable, within a developed area and '
#   'existing roadways in NW-10-057-01 W3M, within the Waskesiu Townsite in '
#   'Prince Albert National Park (the Project).  The Project is required to '
#   'provide an additional service point near the library/recreation hall.\n'
#   '\n'
#   'Equipment that is expected to be used for completion of the Project '
#   'includes: a digger truck, back-hoe, trenching equipment, and crew trucks.  '
#   'Access to components of the Project will make use of existing roads and '
#   'trails.  Surface disturbance is expected to be minimized to the base of the '
#   'pole and 30 m of trenching.  \n'),
#  (274,
#   'In an effort to reduce road mortality and nest predation for rare turtles, '
#   'Thousand Islands National Park is planning to build a small artificial '
#   'nesting site near Polly Creek.  The site will be approximately 5m x 5m '
#   'large and 1m deep, consisting of sand and gravel surrounded by cedar logs.  '
#   'Turtles in the area are experiencing significant road mortality and are '
#   'primarily nesting on road shoulders where near complete nest predation has '
#   'been documented.  The artificial nest site should reduce the number of '
#   'turtles coming onto and alongside the road.  Materials will be brought to '
#   'the site using a small tractor and / or a motorised wheelbarrow and '
#   'construction is planned for October 10, before turtle hibernation begins. ')]

# %% [markdown]
# #### Tokenize and lowercase the words

# %%
# use list comprehension and re to tokenize the texts into words

datawords = [ (ID, re.findall("\w+", text)) for ID, text in data]
pprint(datawords)
# Out:
# [(87,
#   ['The',
#    'purpose',
#    'of',
#    'this',
#    'project',
#    'is',
#    'to',
#    'reduce',
#    'the',
#    'risk',
#    'of',
#    'wildfire',
#    'at',
#    'Fort',
#    'Walsh',
#    'National',
#    'Historic',
#    'Site',
#    'by',
#    'thinning',
#    'pockets',
#    'of',
#    'fuel',
#    'in',
#    'two',
#    'forested',
#    'areas',
#    'near',
#    'the',
#    'fort',
#    'site',
#    'The',
#    'total',
#    'area',
#    'to',
#    'be',
#    'treated',
#    'is',
#    '25',
#    'ha',
#    'The',
#    'absence',
#    'of',
#    'fire',
#    'and',
#    'the',
#    'maturity',
#    'of',
#    'the',
#    'forest',
#    'around',
#    'the',
#    'fort',
#    'site',
#    'has',
#    'resulted',
#    'in',
#    'the',
#    'accumulation',
#    'of',
#    'ladder',
#    'fuels',
#    'old',
#    'or',
#    'dying',
#    'mature',
#    'trees',
#    'and',
#    'downed',
#    'woody',
#    'material',
#    'By',
#    'reducing',
#    'the',
#    'fuel',
#    'load',
#    'on',
#    'site',
#    'removing',
#    'trees',
#    'and',
#    'administering',
#    'various',
#    'FireSmart',
#    'techniques',
#    'stand',
#    'thinning',
#    'ladder',
#    'fuel',
#    'removal',
#    'etc',
#    'the',
#    'impact',
#    'of',
#    'a',
#    'wildfire',
#    'on',
#    'the',
#    'site',
#    'can',
#    'be',
#    'reduced',
#    'Ladder',
#    'fuels',
#    'will',
#    'be',
#    'removed',
#    'and',
#    'tree',
#    'limbs',
#    'pruned',
#    'to',
#    'a',
#    'height',
#    'of',
#    '2m',
#    'using',
#    'chainsaws',
#    'and',
#    'other',
#    'various',
#    'hand',
#    'tools',
#    'Dense',
#    'areas',
#    'will',
#    'be',
#    'thinned',
#    'by',
#    'hand',
#    'felling',
#    'and',
#    'deadfall',
#    'will',
#    'also',
#    'be',
#    'removed',
#    'by',
#    'hand',
#    'This',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (110,
#   ['An',
#    'armoured',
#    'stone',
#    'seawall',
#    'located',
#    'around',
#    'the',
#    'perimeter',
#    'of',
#    'the',
#    'shoreline',
#    'adjacent',
#    'to',
#    'the',
#    'St',
#    'Andrews',
#    'Blockhouse',
#    'National',
#    'Historic',
#    'Site',
#    'provides',
#    'protection',
#    'against',
#    'erosion',
#    'from',
#    'the',
#    'water',
#    'and',
#    'wave',
#    'action',
#    'of',
#    'the',
#    'Passamaquoddy',
#    'Bay',
#    'Recent',
#    'inspection',
#    'of',
#    'the',
#    'seawall',
#    'identified',
#    'a',
#    'number',
#    'of',
#    'deficiencies',
#    'that',
#    'could',
#    'result',
#    'in',
#    'potential',
#    'failure',
#    'of',
#    'the',
#    'structure',
#    'and',
#    'cause',
#    'erosion',
#    'to',
#    'the',
#    'site',
#    'The',
#    'Shoreline',
#    'Protection',
#    'Seawall',
#    'Repairs',
#    'project',
#    'intends',
#    'to',
#    'rehabilitate',
#    'the',
#    'stone',
#    'seawall',
#    'by',
#    'repairing',
#    'damaged',
#    'areas',
#    'along',
#    'the',
#    'structure',
#    'Some',
#    'displaced',
#    'stones',
#    'will',
#    'be',
#    'temporary',
#    'removed',
#    'to',
#    'allow',
#    'the',
#    'necessary',
#    'work',
#    'to',
#    'repair',
#    'and',
#    'raise',
#    'the',
#    'degraded',
#    'bed',
#    'Geotextile',
#    'fabric',
#    'will',
#    'be',
#    'installed',
#    'before',
#    'reinstating',
#    'the',
#    'stone',
#    'In',
#    'other',
#    'areas',
#    'displaced',
#    'stones',
#    'currently',
#    'sitting',
#    'on',
#    'the',
#    'ocean',
#    'floor',
#    'will',
#    'be',
#    'collected',
#    'and',
#    'fitted',
#    'back',
#    'in',
#    'place',
#    'In',
#    'addition',
#    'previously',
#    'placed',
#    'concrete',
#    'pieces',
#    'will',
#    'be',
#    'removed',
#    'and',
#    'replaced',
#    'with',
#    'stone']),
#  (197,
#   ['A',
#    'Fisheries',
#    'Act',
#    'Authorization',
#    'is',
#    'required',
#    'from',
#    'DFO',
#    'in',
#    'relation',
#    'to',
#    'impacts',
#    'on',
#    'fish',
#    'habitat',
#    'associated',
#    'with',
#    'dam',
#    'construction',
#    'projects',
#    'at',
#    'TSW',
#    'Trenton',
#    'Dam',
#    '1',
#    'and',
#    'Glen',
#    'Miller',
#    'Dam',
#    '3',
#    'The',
#    'Authorization',
#    'includes',
#    'provisions',
#    'for',
#    'offsetting',
#    'measures',
#    'The',
#    'construction',
#    'of',
#    'the',
#    'Big',
#    'Island',
#    'causeway',
#    'in',
#    'the',
#    '1950',
#    's',
#    'and',
#    'decreased',
#    'water',
#    'flows',
#    'between',
#    'the',
#    'island',
#    'and',
#    'the',
#    'mainland',
#    'have',
#    'caused',
#    'the',
#    'channels',
#    'to',
#    'be',
#    'filled',
#    'in',
#    'with',
#    'silt',
#    'and',
#    'cattails',
#    'now',
#    'cover',
#    'the',
#    'entire',
#    'area',
#    'from',
#    'the',
#    'island',
#    'to',
#    'the',
#    'mainland',
#    'Parks',
#    'Canada',
#    'is',
#    'proposing',
#    'to',
#    'expand',
#    'on',
#    'existing',
#    'fish',
#    'habitat',
#    'enhancements',
#    'at',
#    'the',
#    'Big',
#    'Island',
#    'Marsh',
#    'by',
#    'constructing',
#    'a',
#    'new',
#    'channel',
#    'and',
#    'widening',
#    'deepening',
#    'of',
#    '2',
#    'existing',
#    'channels',
#    'Cattail',
#    'marsh',
#    'vegetation',
#    'will',
#    'be',
#    'removed',
#    'to',
#    'a',
#    'width',
#    'of',
#    '10',
#    'm',
#    'and',
#    'depths',
#    'up',
#    'to',
#    '3',
#    '0',
#    'm',
#    'in',
#    'order',
#    'to',
#    'ensure',
#    'these',
#    'areas',
#    'stay',
#    'open',
#    'into',
#    'the',
#    'future',
#    'The',
#    'Fisheries',
#    'Offset',
#    'Plan',
#    'is',
#    'expected',
#    'to',
#    'result',
#    'in',
#    'the',
#    'enhancement',
#    'of',
#    'fish',
#    'habitat',
#    'at',
#    'the',
#    'Big',
#    'Island',
#    'Marsh']),
#  (111,
#   ['In',
#    'May',
#    '2018',
#    'the',
#    'Rabbit',
#    'Creek',
#    'Wildfire',
#    'occurred',
#    'in',
#    'Prince',
#    'Albert',
#    'National',
#    'Park',
#    'and',
#    'spread',
#    'within',
#    'and',
#    'outside',
#    'of',
#    'the',
#    'park',
#    'Heavy',
#    'equipment',
#    'was',
#    'used',
#    'to',
#    'create',
#    'fire',
#    'control',
#    'lines',
#    'and',
#    'to',
#    'improve',
#    'ground',
#    'and',
#    'aerial',
#    'access',
#    'to',
#    'strategic',
#    'areas',
#    'In',
#    'addition',
#    'to',
#    'the',
#    'dozer',
#    'lines',
#    'that',
#    'were',
#    'put',
#    'in',
#    'during',
#    'the',
#    'fire',
#    'heavy',
#    'equipment',
#    'was',
#    'used',
#    'along',
#    'the',
#    'border',
#    'between',
#    'the',
#    'south',
#    'boundary',
#    'of',
#    'the',
#    'park',
#    'and',
#    'the',
#    'Cookson',
#    'Community',
#    'Pasture',
#    'to',
#    'push',
#    'back',
#    'the',
#    'forested',
#    'edge',
#    'to',
#    'protect',
#    'a',
#    'newly',
#    'repaired',
#    'fence',
#    'that',
#    'had',
#    'been',
#    'damaged',
#    'by',
#    'the',
#    'fire',
#    'Prince',
#    'Albert',
#    'National',
#    'Park',
#    'Fire',
#    'Management',
#    'takes',
#    'responsibility',
#    'for',
#    'the',
#    'reclamation',
#    'of',
#    'the',
#    'impacts',
#    'from',
#    'the',
#    'heavy',
#    'equipment',
#    'The',
#    'two',
#    'areas',
#    'of',
#    'work',
#    'are',
#    'the',
#    'South',
#    'Boundary',
#    'Trail',
#    'and',
#    'the',
#    'Elk',
#    'Trail',
#    'Following',
#    'the',
#    '2018',
#    'Rabbit',
#    'Fire',
#    'approximately',
#    '13',
#    '5',
#    'km',
#    'of',
#    'fence',
#    'was',
#    'replaced',
#    'on',
#    'the',
#    'northern',
#    'boundary',
#    'of',
#    'the',
#    'Cookson',
#    'Community',
#    'Pasture',
#    'Approximately',
#    '6',
#    'km',
#    'of',
#    'the',
#    'fence',
#    'was',
#    'directly',
#    'adjacent',
#    'to',
#    'the',
#    'PANP',
#    'boundary',
#    'This',
#    'area',
#    'was',
#    'cleared',
#    'of',
#    'vegetation',
#    'and',
#    'has',
#    'long',
#    'linear',
#    'berms',
#    'of',
#    'soil',
#    'and',
#    'wood',
#    'that',
#    'are',
#    'restricting',
#    'efforts',
#    'for',
#    'weed',
#    'control',
#    'and',
#    'seeding',
#    'along',
#    'the',
#    'boundary',
#    'and',
#    'also',
#    'increase',
#    'long',
#    'term',
#    'fire',
#    'hazard',
#    'if',
#    'left',
#    'in',
#    'piles',
#    'These',
#    'berms',
#    'will',
#    'need',
#    'to',
#    'be',
#    'spread',
#    'across',
#    'the',
#    'opening',
#    'and',
#    'a',
#    'section',
#    'of',
#    'this',
#    'area',
#    'will',
#    'need',
#    'to',
#    'have',
#    'a',
#    'flat',
#    'debris',
#    'free',
#    'surface',
#    'left',
#    'to',
#    'be',
#    'used',
#    'as',
#    'a',
#    'trail',
#    'for',
#    'off',
#    'road',
#    'vehicles',
#    'The',
#    'Elk',
#    'trail',
#    'was',
#    'a',
#    'maintained',
#    'trail',
#    'within',
#    'the',
#    'park',
#    'A',
#    'section',
#    'of',
#    'the',
#    'Elk',
#    'Trail',
#    'has',
#    'been',
#    'closed',
#    'since',
#    '2018',
#    'due',
#    'to',
#    'impacts',
#    'from',
#    'heavy',
#    'equipment',
#    'during',
#    'wildfire',
#    'operations',
#    'The',
#    'main',
#    'area',
#    'of',
#    'concern',
#    'is',
#    'approximately',
#    '700',
#    'meters',
#    'of',
#    'forest',
#    'that',
#    'was',
#    'cleared',
#    'to',
#    'an',
#    'average',
#    'of',
#    '40',
#    'meters',
#    'wide',
#    '2',
#    '8',
#    'ha',
#    'that',
#    'will',
#    'be',
#    'reclaimed',
#    'As',
#    'this',
#    'fireguard',
#    'was',
#    'put',
#    'in',
#    'on',
#    'a',
#    'maintained',
#    'trail',
#    'a',
#    'new',
#    'trail',
#    'surface',
#    'will',
#    'need',
#    'to',
#    'be',
#    'developed',
#    'during',
#    'reclamation',
#    'Within',
#    'this',
#    'area',
#    'a',
#    'bridge',
#    'that',
#    'crossed',
#    'a',
#    'small',
#    'stream',
#    'was',
#    'destroyed',
#    'by',
#    'heavy',
#    'equipment',
#    'A',
#    'shallow',
#    'water',
#    'ford',
#    'crossing',
#    'will',
#    'be',
#    'developed',
#    'here',
#    'Near',
#    'this',
#    'area',
#    'there',
#    'is',
#    'also',
#    'a',
#    'helipad',
#    'of',
#    'approximately',
#    '0',
#    '5',
#    'ha',
#    'that',
#    'will',
#    'also',
#    'be',
#    'reclaimed',
#    'Midway',
#    'from',
#    'the',
#    'trailhead',
#    'there',
#    'is',
#    'a',
#    'section',
#    'of',
#    'trail',
#    'and',
#    'culvert',
#    'that',
#    'has',
#    'washed',
#    'out',
#    'that',
#    'will',
#    'need',
#    'to',
#    'be',
#    'repaired',
#    'as',
#    'well']),
#  (149,
#   ['This',
#    'project',
#    'will',
#    'involve',
#    'construction',
#    'of',
#    'the',
#    'Lake',
#    'Superior',
#    'National',
#    'Marine',
#    'Conservation',
#    'Area',
#    'Discovery',
#    'Centre',
#    'in',
#    'Nipigon',
#    'ON',
#    'The',
#    'project',
#    'site',
#    'is',
#    'a',
#    '1',
#    '4',
#    'hectare',
#    'lot',
#    'at',
#    'the',
#    'Nipigon',
#    'waterfront',
#    'on',
#    'the',
#    'west',
#    'side',
#    'of',
#    'Brennan',
#    'Drive',
#    'The',
#    'project',
#    'will',
#    'include',
#    'construction',
#    'of',
#    'the',
#    'Discovery',
#    'Centre',
#    'detached',
#    'garage',
#    'parking',
#    'area',
#    'outdoor',
#    'interpretive',
#    'elements',
#    'and',
#    'landscaping',
#    'The',
#    'Discovery',
#    'Centre',
#    'approximately',
#    '1',
#    '300',
#    'square',
#    'meters',
#    'will',
#    'be',
#    'a',
#    'single',
#    'story',
#    'multiuse',
#    'building',
#    'that',
#    'will',
#    'include',
#    'exhibit',
#    'space',
#    'interpretive',
#    'elements',
#    'interior',
#    'and',
#    'exterior',
#    'and',
#    'administrative',
#    'space',
#    'It',
#    'will',
#    'serve',
#    'as',
#    'the',
#    'main',
#    'hub',
#    'for',
#    'visitors',
#    'to',
#    'Lake',
#    'Superior',
#    'National',
#    'Marine',
#    'Conservation',
#    'Area',
#    'and',
#    'for',
#    'site',
#    'administration',
#    'and',
#    'operations',
#    'The',
#    'construction',
#    'phase',
#    'of',
#    'the',
#    'project',
#    'will',
#    'involve',
#    'use',
#    'of',
#    'heavy',
#    'machinery',
#    'excavation',
#    'backfilling',
#    'landscaping',
#    'and',
#    'some',
#    'vegetation',
#    'removal',
#    'This',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (214,
#   ['Yellow',
#    'toadflax',
#    'is',
#    'a',
#    'widely',
#    'distributed',
#    'perennial',
#    'invasive',
#    'plant',
#    'that',
#    'reproduces',
#    'by',
#    'seed',
#    'and',
#    'extensive',
#    'creeping',
#    'rhizome',
#    'The',
#    'plant',
#    'is',
#    'extremely',
#    'hardy',
#    'and',
#    'has',
#    'the',
#    'ability',
#    'to',
#    'densely',
#    'infest',
#    'large',
#    'areas',
#    'and',
#    'crowd',
#    'out',
#    'native',
#    'vegetation',
#    'making',
#    'it',
#    'a',
#    'threat',
#    'to',
#    'ecological',
#    'integrity',
#    'in',
#    'Prince',
#    'Albert',
#    'National',
#    'Park',
#    'Herbicide',
#    'spraying',
#    'of',
#    'yellow',
#    'toadflax',
#    'has',
#    'occurred',
#    'in',
#    'several',
#    'locations',
#    'in',
#    'Prince',
#    'Albert',
#    'National',
#    'Park',
#    'with',
#    'limited',
#    'success',
#    'Using',
#    'a',
#    'biological',
#    'control',
#    'agent',
#    'offers',
#    'an',
#    'additional',
#    'option',
#    'for',
#    'control',
#    'of',
#    'this',
#    'species',
#    'in',
#    'a',
#    'manner',
#    'that',
#    'is',
#    'not',
#    'nearly',
#    'so',
#    'labour',
#    'intensive',
#    'Prince',
#    'Albert',
#    'National',
#    'Park',
#    'will',
#    'be',
#    'working',
#    'with',
#    'Agriculture',
#    'and',
#    'Agri',
#    'food',
#    'Canada',
#    'to',
#    'carry',
#    'out',
#    'trials',
#    'of',
#    'Rhinusa',
#    'pilosa',
#    'in',
#    'up',
#    'to',
#    'three',
#    'affected',
#    'locations',
#    'Prospect',
#    'Point',
#    'Rabbit',
#    'Cabin',
#    'area',
#    'and',
#    '12',
#    'Mile',
#    'Meadow',
#    'Weevils',
#    'will',
#    'be',
#    'obtained',
#    'from',
#    'Agriculture',
#    'and',
#    'Agri',
#    'foods',
#    'Canada',
#    'at',
#    'no',
#    'charge',
#    'and',
#    'will',
#    'be',
#    'released',
#    'at',
#    'the',
#    'sites',
#    'in',
#    'late',
#    'summer']),
#  (257,
#   ['Hyperabundant',
#    'populations',
#    'of',
#    'White',
#    'tailed',
#    'deer',
#    'threaten',
#    'the',
#    'ecological',
#    'value',
#    'of',
#    'the',
#    'varied',
#    'forest',
#    'communities',
#    'on',
#    'Hill',
#    'Island',
#    'and',
#    'other',
#    'park',
#    'islands',
#    'Intensive',
#    'browsing',
#    'has',
#    'led',
#    'to',
#    'a',
#    'distinct',
#    'lack',
#    'of',
#    'understory',
#    'vegetation',
#    'and',
#    'changing',
#    'forest',
#    'composition',
#    'Parks',
#    'Canada',
#    'has',
#    'developed',
#    'a',
#    'deer',
#    'management',
#    'strategy',
#    'in',
#    'response',
#    'to',
#    'these',
#    'ecological',
#    'impacts',
#    'and',
#    'is',
#    'proposing',
#    'to',
#    'restore',
#    'the',
#    'native',
#    'vegetation',
#    'to',
#    'the',
#    'area',
#    'by',
#    'reducing',
#    'deer',
#    'numbers',
#    'The',
#    'deer',
#    'herd',
#    'reduction',
#    'will',
#    'be',
#    'conducted',
#    'as',
#    'outlined',
#    'in',
#    'the',
#    'Hill',
#    'Island',
#    'Hyperabundant',
#    'Deer',
#    'Management',
#    'Plan',
#    '2012',
#    'The',
#    'goal',
#    'of',
#    'the',
#    'project',
#    'is',
#    'to',
#    'restore',
#    'the',
#    'integrity',
#    'of',
#    'the',
#    'forest',
#    'ecosystem',
#    'on',
#    'Hill',
#    'Island',
#    'and',
#    'the',
#    'processes',
#    'to',
#    'protect',
#    'the',
#    'habitat',
#    'of',
#    'plant',
#    'species',
#    'of',
#    'conservation',
#    'concern',
#    'eg',
#    'Pitch',
#    'pine',
#    'The',
#    'deer',
#    'herd',
#    'reduction',
#    'began',
#    'in',
#    '2007',
#    'in',
#    'an',
#    'effort',
#    'to',
#    'reduce',
#    'populations',
#    'to',
#    'a',
#    'level',
#    '4',
#    'deer',
#    'per',
#    'km2',
#    'that',
#    'will',
#    'allow',
#    'for',
#    'healthy',
#    'forest',
#    'regeneration',
#    'and',
#    'efforts',
#    'continue',
#    'to',
#    'attain',
#    'that',
#    'population',
#    'density',
#    'The',
#    'reduction',
#    'in',
#    'deer',
#    'numbers',
#    'will',
#    'be',
#    'achieved',
#    'by',
#    'partnering',
#    'with',
#    'the',
#    'Mohawks',
#    'of',
#    'Akwesasne',
#    'to',
#    'harvest',
#    'White',
#    'tailed',
#    'deer',
#    'from',
#    'the',
#    'Island',
#    'The',
#    'monitoring',
#    'program',
#    'will',
#    'continue',
#    'to',
#    'track',
#    'the',
#    'effectiveness',
#    'of',
#    'the',
#    'deer',
#    'reduction',
#    'strategy',
#    'in',
#    'the',
#    'recovery',
#    'of',
#    'the',
#    'forest',
#    'ecosystem',
#    'This',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (63,
#   ['The',
#    'project',
#    'will',
#    'entail',
#    'the',
#    'installation',
#    'of',
#    'approximately',
#    '330',
#    'grid',
#    'tied',
#    'photovoltaic',
#    'solar',
#    'panels',
#    'at',
#    'the',
#    'site',
#    'of',
#    'the',
#    'former',
#    'Environment',
#    'and',
#    'Climate',
#    'Change',
#    'Canada',
#    'CAPMoN',
#    'weather',
#    'station',
#    'located',
#    'within',
#    'the',
#    'Kejimkujik',
#    'National',
#    'Park',
#    'and',
#    'National',
#    'Historic',
#    'Site',
#    'frontcountry',
#    'The',
#    'goal',
#    'of',
#    'the',
#    'project',
#    'is',
#    'to',
#    'generate',
#    'renewable',
#    'electricity',
#    'and',
#    'contribute',
#    'to',
#    'the',
#    'reduction',
#    'of',
#    'greenhouse',
#    'gases',
#    'associated',
#    'with',
#    'the',
#    'park',
#    's',
#    'operations',
#    'The',
#    'solar',
#    'panels',
#    'will',
#    'be',
#    'mounted',
#    'on',
#    'a',
#    'racking',
#    'system',
#    'anchored',
#    'with',
#    'screw',
#    'piles',
#    'or',
#    'poured',
#    'concrete',
#    'foundations',
#    'Trenching',
#    'will',
#    'be',
#    'required',
#    'for',
#    'the',
#    'installation',
#    'of',
#    'electrical',
#    'wiring',
#    'to',
#    'connect',
#    'the',
#    'array',
#    'with',
#    'the',
#    'existing',
#    'Nova',
#    'Scotia',
#    'power',
#    'grid',
#    'at',
#    'the',
#    'site',
#    'The',
#    'project',
#    'will',
#    'be',
#    'reviewed',
#    'via',
#    'a',
#    'Basic',
#    'Impact',
#    'Assessment']),
#  (273,
#   ['SaskPower',
#    'is',
#    'proposing',
#    'to',
#    'replace',
#    'a',
#    'pole',
#    'mount',
#    'transformer',
#    'on',
#    'an',
#    'existing',
#    'wooden',
#    'pole',
#    'and',
#    'directionally',
#    'drill',
#    '65',
#    'm',
#    'to',
#    'a',
#    'customer',
#    'supplied',
#    'metering',
#    'point',
#    'in',
#    'SE',
#    '16',
#    '57',
#    '01',
#    'W3M',
#    'within',
#    'Prince',
#    'Albert',
#    'National',
#    'Park',
#    'The',
#    'project',
#    'is',
#    'required',
#    'to',
#    'increase',
#    'the',
#    'capacity',
#    'of',
#    'the',
#    'line',
#    'and',
#    'maintain',
#    'the',
#    'quality',
#    'of',
#    'service',
#    'to',
#    'an',
#    'existing',
#    'customer',
#    'Equipment',
#    'that',
#    'is',
#    'expected',
#    'to',
#    'be',
#    'used',
#    'for',
#    'completion',
#    'of',
#    'the',
#    'project',
#    'includes',
#    'a',
#    'digger',
#    'truck',
#    'back',
#    'hoe',
#    'bucket',
#    'truck',
#    'directional',
#    'boring',
#    'equipment',
#    'and',
#    'crew',
#    'trucks',
#    'access',
#    'to',
#    'components',
#    'of',
#    'the',
#    'project',
#    'will',
#    'make',
#    'use',
#    'of',
#    'existing',
#    'roads',
#    'and',
#    'trails',
#    'Surface',
#    'disturbance',
#    'is',
#    'expected',
#    'to',
#    'be',
#    'minimized',
#    'to',
#    'the',
#    'bell',
#    'holes',
#    'at',
#    'the',
#    'existing',
#    'pole',
#    'and',
#    'metering',
#    'point']),
#  (203,
#   ['This',
#    'project',
#    'will',
#    'involve',
#    'dock',
#    'work',
#    'at',
#    'multiple',
#    'locations',
#    'throughout',
#    'Thousand',
#    'Islands',
#    'National',
#    'Park',
#    'Specifically',
#    'work',
#    'will',
#    'include',
#    'installation',
#    'of',
#    'floating',
#    'docks',
#    'to',
#    'replace',
#    'docks',
#    'that',
#    'are',
#    'were',
#    'damaged',
#    'due',
#    'to',
#    'recent',
#    'high',
#    'water',
#    'levels',
#    'and',
#    'to',
#    'replace',
#    'docks',
#    'that',
#    'are',
#    'at',
#    'the',
#    'end',
#    'of',
#    'their',
#    'life',
#    'cycle',
#    'The',
#    'new',
#    'docks',
#    'will',
#    'be',
#    'designed',
#    'to',
#    'accommodate',
#    'higher',
#    'water',
#    'levels',
#    'Associated',
#    'work',
#    'includes',
#    'installation',
#    'of',
#    'in',
#    'water',
#    'shoreline',
#    'anchoring',
#    'systems',
#    'and',
#    'installation',
#    'of',
#    'boardwalks',
#    'and',
#    'kiosks',
#    'at',
#    'shore',
#    'landing',
#    'points',
#    'Replacements',
#    'and',
#    'or',
#    'minor',
#    'location',
#    'adjustments',
#    'of',
#    'mooring',
#    'buoy',
#    'anchors',
#    'may',
#    'also',
#    'be',
#    'carried',
#    'out',
#    'where',
#    'necessary',
#    'Dock',
#    'project',
#    'locations',
#    'include',
#    'Adelaide',
#    'Island',
#    'East',
#    'Grenadier',
#    'Island',
#    'Georgina',
#    'Island',
#    'Constance',
#    'Island',
#    'Mulcaster',
#    'Island',
#    'Milton',
#    'Island',
#    'Hill',
#    'Island',
#    'and',
#    'Stovin',
#    'Island',
#    'Project',
#    'work',
#    'is',
#    'planned',
#    'to',
#    'be',
#    'commence',
#    'in',
#    'April',
#    '2020',
#    'and',
#    'conclude',
#    'by',
#    'November',
#    '2020',
#    'This',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'Basic',
#    'Impact',
#    'Assessment']),
#  (271,
#   ['A',
#    'new',
#    'culvert',
#    'needs',
#    'to',
#    'be',
#    'installed',
#    'on',
#    'the',
#    'boundary',
#    'road',
#    'north',
#    'of',
#    'Osten',
#    'Lake',
#    'Camping',
#    'access',
#    'on',
#    'RR',
#    '205',
#    'The',
#    'culvert',
#    'has',
#    'collapsed',
#    'and',
#    'completely',
#    'rusted',
#    'out',
#    'and',
#    'the',
#    'site',
#    'is',
#    'currently',
#    'flooded',
#    'due',
#    'to',
#    'beaver',
#    'activity',
#    'and',
#    'Strathcona',
#    'County',
#    'culvert',
#    'failure',
#    'on',
#    'RR',
#    '205',
#    'Currently',
#    'beavers',
#    'have',
#    'a',
#    'deep',
#    'run',
#    'washout',
#    'through',
#    'the',
#    'boundary',
#    'road',
#    'making',
#    'it',
#    'impassable',
#    'The',
#    'new',
#    'culvert',
#    'will',
#    'be',
#    'a',
#    'larger',
#    'diameter',
#    '600mm',
#    'due',
#    'to',
#    'the',
#    'sizes',
#    'that',
#    'are',
#    'currently',
#    'kept',
#    'in',
#    'stock',
#    'for',
#    'replacements',
#    'The',
#    'old',
#    'culvert',
#    'was',
#    '450mm',
#    'The',
#    'work',
#    'will',
#    'take',
#    'place',
#    'when',
#    'there',
#    'is',
#    'no',
#    'water',
#    'flow',
#    'through',
#    'the',
#    'boundary',
#    'road',
#    'Three',
#    'inch',
#    'minus',
#    'pit',
#    'run',
#    'gravel',
#    'will',
#    'be',
#    'used',
#    'to',
#    'fill',
#    'the',
#    'road',
#    'base',
#    'on',
#    'the',
#    'top',
#    'and',
#    'sides',
#    'of',
#    'the',
#    'new',
#    'culvert',
#    'Strathcona',
#    'County',
#    'plans',
#    'to',
#    'repair',
#    'the',
#    'culvert',
#    'through',
#    'RR',
#    '205']),
#  (50,
#   ['Red',
#    'Bay',
#    's',
#    '2011',
#    'management',
#    'plan',
#    'identified',
#    'strategies',
#    'to',
#    'develop',
#    'a',
#    'menu',
#    'of',
#    'visitor',
#    'experience',
#    'opportunities',
#    'to',
#    'enhance',
#    'how',
#    'Canadians',
#    'discover',
#    'enjoy',
#    'and',
#    'connect',
#    'with',
#    'the',
#    'historic',
#    'site',
#    'Site',
#    'management',
#    'have',
#    'proposed',
#    'an',
#    'escape',
#    'game',
#    'developed',
#    'by',
#    'Fetch',
#    'Quest',
#    'based',
#    'on',
#    'the',
#    'history',
#    'of',
#    'the',
#    'Red',
#    'Bay',
#    'Basque',
#    'Whaling',
#    'Station',
#    'The',
#    'game',
#    'requires',
#    'participants',
#    'to',
#    'complete',
#    'a',
#    'number',
#    'of',
#    'puzzles',
#    'and',
#    'trivial',
#    'tasks',
#    'with',
#    'props',
#    'and',
#    'equipment',
#    'in',
#    'order',
#    'to',
#    'successfully',
#    'solve',
#    'the',
#    'game',
#    'To',
#    'facilitate',
#    'the',
#    'placement',
#    'of',
#    'some',
#    'of',
#    'the',
#    'props',
#    'site',
#    'management',
#    'is',
#    'proposing',
#    'a',
#    'small',
#    'addition',
#    'to',
#    'the',
#    'island',
#    's',
#    'existing',
#    'trail',
#    'A',
#    'board',
#    'walk',
#    'approximately',
#    '5',
#    'feet',
#    'in',
#    'length',
#    'will',
#    'extend',
#    'from',
#    'the',
#    'existing',
#    'trail',
#    'and',
#    'allow',
#    'participants',
#    'to',
#    'step',
#    'off',
#    'the',
#    'main',
#    'trail',
#    'unto',
#    'an',
#    '8',
#    'x',
#    '12',
#    'meter',
#    'wooden',
#    'platform',
#    'that',
#    'is',
#    'placed',
#    'upon',
#    'a',
#    'gravel',
#    'bedding']),
#  (51,
#   ['The',
#    'objective',
#    'of',
#    'this',
#    'project',
#    'is',
#    'to',
#    'complete',
#    'the',
#    'second',
#    'phase',
#    'of',
#    'the',
#    'decommission',
#    'and',
#    'reclamation',
#    'of',
#    'the',
#    'Redstreak',
#    'wastewater',
#    'lagoon',
#    'The',
#    'first',
#    'phase',
#    'of',
#    'the',
#    'project',
#    'was',
#    'completed',
#    'in',
#    'the',
#    'summer',
#    'and',
#    'fall',
#    'of',
#    '2020',
#    'when',
#    'a',
#    'fence',
#    'surrounding',
#    'the',
#    'lagoon',
#    'and',
#    'a',
#    'large',
#    'woody',
#    'debris',
#    'pile',
#    'were',
#    'removed',
#    'Furthermore',
#    'soil',
#    'samples',
#    'were',
#    'collected',
#    'and',
#    'analyzed',
#    'to',
#    'confirm',
#    'that',
#    'the',
#    'site',
#    'is',
#    'not',
#    'contaminated',
#    'and',
#    'meets',
#    'federal',
#    'and',
#    'provincial',
#    'guidelines',
#    'BC',
#    'OMRR',
#    'BC',
#    'CSR',
#    'CCME',
#    'The',
#    'lagoon',
#    'is',
#    'adjacent',
#    'to',
#    'the',
#    'Redstreak',
#    'restoration',
#    'area',
#    'and',
#    'is',
#    'within',
#    'a',
#    'subunit',
#    'called',
#    'the',
#    'provincial',
#    'block',
#    'which',
#    'was',
#    'harvested',
#    'and',
#    'thinned',
#    'in',
#    '2002',
#    'The',
#    'Redstreak',
#    'restoration',
#    'area',
#    'was',
#    'created',
#    'as',
#    'a',
#    'multi',
#    'year',
#    'ecosystem',
#    'based',
#    'management',
#    'project',
#    'where',
#    'Parks',
#    'Canada',
#    'restored',
#    'its',
#    'historical',
#    'fire',
#    'regime',
#    'and',
#    'brought',
#    'back',
#    'native',
#    'grasses',
#    'to',
#    'provide',
#    'better',
#    'grazing',
#    'habitat',
#    'by',
#    'forest',
#    'thinning',
#    'and',
#    'maintenance',
#    'prescribed',
#    'fire',
#    'In',
#    '2021',
#    'Parks',
#    'Canada',
#    'is',
#    'targeting',
#    'to',
#    'complete',
#    'the',
#    'full',
#    'decommission',
#    'and',
#    'reclamation',
#    'of',
#    'the',
#    'old',
#    'wastewater',
#    'lagoon',
#    'site',
#    'The',
#    'main',
#    'objective',
#    'of',
#    'this',
#    'project',
#    's',
#    'second',
#    'phase',
#    'is',
#    'to',
#    'reduce',
#    'the',
#    'human',
#    'footprint',
#    'left',
#    'on',
#    'that',
#    'site',
#    'by',
#    'removing',
#    'any',
#    'infrastructure',
#    'that',
#    'remains',
#    'at',
#    'the',
#    'lagoon',
#    'and',
#    'prepare',
#    'the',
#    'site',
#    'to',
#    'start',
#    'the',
#    'natural',
#    'revegetation',
#    'phase',
#    'of',
#    'the',
#    'reclamation']),
#  (123,
#   ['The',
#    'cedar',
#    'shingle',
#    'roofing',
#    'on',
#    'the',
#    'Watchmen',
#    'accommodations',
#    'cabin',
#    'on',
#    'Hotspring',
#    'Island',
#    'is',
#    'compromised',
#    'and',
#    'requires',
#    'replacement',
#    'There',
#    'is',
#    'a',
#    'known',
#    'bat',
#    'maternity',
#    'roost',
#    'in',
#    'the',
#    'area',
#    'roughly',
#    '100m',
#    'away',
#    'and',
#    'bats',
#    'may',
#    'possibly',
#    'be',
#    'using',
#    'the',
#    'roof',
#    'soffits',
#    'attic',
#    'etc',
#    'for',
#    'roosting',
#    'unknown',
#    'at',
#    'this',
#    'point',
#    'physical',
#    'inspection',
#    'pending',
#    'The',
#    'metal',
#    'roofing',
#    'on',
#    'the',
#    'Ellen',
#    'Island',
#    'Operations',
#    'station',
#    'leaks',
#    'and',
#    'requires',
#    'replacement',
#    'Bats',
#    'have',
#    'been',
#    'observed',
#    'in',
#    'the',
#    'area',
#    'in',
#    'the',
#    'past',
#    'Bats',
#    'may',
#    'possibly',
#    'be',
#    'using',
#    'the',
#    'roof',
#    'soffits',
#    'attic',
#    'etc',
#    'for',
#    'roosting',
#    'unknown',
#    'at',
#    'this',
#    'point',
#    'physical',
#    'inspection',
#    'pending',
#    'Both',
#    'roofs',
#    'will',
#    'be',
#    'redone',
#    'using',
#    'metal',
#    'roofing',
#    'Because',
#    'of',
#    'the',
#    'possibility',
#    'that',
#    'bats',
#    'may',
#    'be',
#    'using',
#    'these',
#    'cabins',
#    'as',
#    'a',
#    'residence',
#    'this',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'Basic',
#    'Impact',
#    'Assessment']),
#  (205,
#   ['Grasslands',
#    'National',
#    'Park',
#    'proposes',
#    'to',
#    'issue',
#    'a',
#    'license',
#    'of',
#    'occupation',
#    'to',
#    'graze',
#    'cattle',
#    'over',
#    '8',
#    'sections',
#    'in',
#    'the',
#    'Former',
#    'Mankota',
#    'Community',
#    'Pasture',
#    'area',
#    'of',
#    'the',
#    'East',
#    'Block',
#    'of',
#    'the',
#    'park',
#    'Cattle',
#    'grazing',
#    'has',
#    'occurred',
#    'in',
#    'this',
#    'area',
#    'previously',
#    'under',
#    'a',
#    'grazing',
#    'permit',
#    'and',
#    'before',
#    'acquisition',
#    'by',
#    'Parks',
#    'Canada',
#    'was',
#    'used',
#    'for',
#    'grazing',
#    'livestock',
#    'Domestic',
#    'livestock',
#    'grazing',
#    'is',
#    'used',
#    'in',
#    'this',
#    'area',
#    'to',
#    'maintain',
#    'a',
#    'disturbance',
#    'regime',
#    'supporting',
#    'habitat',
#    'maintenance',
#    'for',
#    'species',
#    'at',
#    'risk',
#    'and',
#    'for',
#    'prairie',
#    'ecosystem',
#    'function',
#    'No',
#    'new',
#    'infrastructure',
#    'will',
#    'be',
#    'constructed',
#    'as',
#    'part',
#    'of',
#    'this',
#    'program',
#    'Activities',
#    'will',
#    'include',
#    'moving',
#    'cattle',
#    'in',
#    'and',
#    'out',
#    'of',
#    'grazing',
#    'paddocks',
#    'maintaining',
#    'repairing',
#    'fences',
#    'and',
#    'watering',
#    'systems',
#    'and',
#    'checking',
#    'cattle',
#    'This',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (82,
#   ['The',
#    'existing',
#    'main',
#    'road',
#    'from',
#    'the',
#    'South',
#    'beach',
#    'from',
#    'the',
#    'Sable',
#    'Island',
#    'Main',
#    'Station',
#    'traverses',
#    'an',
#    'active',
#    'tern',
#    'colony',
#    'May',
#    'August',
#    'Vehicle',
#    'movements',
#    'along',
#    'this',
#    'corridor',
#    'creates',
#    'disturbance',
#    'to',
#    'nesting',
#    'birds',
#    'and',
#    'can',
#    'contribute',
#    'to',
#    'nest',
#    'failure',
#    'and',
#    'chick',
#    'mortality',
#    'To',
#    'reduce',
#    'these',
#    'impacts',
#    'it',
#    'is',
#    'proposed',
#    'that',
#    'a',
#    'seasonal',
#    'temporary',
#    'crossing',
#    'be',
#    'developed',
#    'to',
#    'allow',
#    'access',
#    'to',
#    'the',
#    'south',
#    'beach',
#    'from',
#    'Main',
#    'Station',
#    'The',
#    'proposed',
#    'location',
#    'is',
#    'located',
#    'approximately',
#    '1',
#    '8',
#    'km',
#    'east',
#    'of',
#    'Main',
#    'Station',
#    'and',
#    'passes',
#    'through',
#    'one',
#    'of',
#    'the',
#    'narrowest',
#    'sections',
#    'of',
#    'the',
#    'dunes',
#    '100m',
#    'long',
#    'and',
#    'is',
#    'currently',
#    'almost',
#    'devoid',
#    'of',
#    'vegetation',
#    'and',
#    'easily',
#    'navigable',
#    'by',
#    'SINPR',
#    'vehicles',
#    'The',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (49,
#   ['An',
#    'impact',
#    'assessment',
#    'is',
#    'required',
#    'to',
#    'address',
#    'potential',
#    'impacts',
#    'resulting',
#    'from',
#    'the',
#    'repair',
#    'of',
#    'a',
#    'Class',
#    'A2',
#    'pedestrian',
#    'bridge',
#    'on',
#    'the',
#    'West',
#    'Coast',
#    'Trail',
#    'of',
#    'Pacific',
#    'Rim',
#    'National',
#    'Park',
#    'Reserve',
#    'Bridge',
#    'repairs',
#    'are',
#    'required',
#    'to',
#    'ensure',
#    'the',
#    'safety',
#    'of',
#    'visitors',
#    'and',
#    'staff',
#    'while',
#    'traversing',
#    'and',
#    'maintaining',
#    'the',
#    'trail',
#    'Limited',
#    'ground',
#    'disturbance',
#    'within',
#    'riparian',
#    'habitat',
#    'will',
#    'be',
#    'required',
#    'to',
#    'upgrade',
#    'the',
#    'mid',
#    'span',
#    'bridge',
#    'support',
#    'structure',
#    'All',
#    'work',
#    'within',
#    'the',
#    'riparian',
#    'zone',
#    'will',
#    'meet',
#    'DFO',
#    'measures',
#    'to',
#    'reduce',
#    'harm',
#    'to',
#    'fish',
#    'including',
#    'project',
#    'completion',
#    'during',
#    'the',
#    'least',
#    'risk',
#    'summer',
#    'window',
#    'when',
#    'the',
#    'adjacent',
#    'creek',
#    'is',
#    'expected',
#    'to',
#    'be',
#    'completely',
#    'dry',
#    'No',
#    'in',
#    'water',
#    'works',
#    'will',
#    'occur',
#    'as',
#    'part',
#    'of',
#    'this',
#    'project',
#    'The',
#    'anticipated',
#    'effects',
#    'and',
#    'mitigation',
#    'for',
#    'this',
#    'scope',
#    'of',
#    'work',
#    'are',
#    'limited',
#    'and',
#    'well',
#    'understood',
#    'thus',
#    'a',
#    'Basic',
#    'Impact',
#    'Assessment',
#    'will',
#    'be',
#    'undertaken']),
#  (156,
#   ['The',
#    'previous',
#    'Cavendish',
#    'Campground',
#    'Staff',
#    'Room',
#    'experienced',
#    'a',
#    'devastating',
#    'fire',
#    'last',
#    'fall',
#    'and',
#    'as',
#    'such',
#    'burned',
#    'beyond',
#    'repair',
#    'National',
#    'park',
#    'staff',
#    'now',
#    'require',
#    'a',
#    'lunchroom',
#    'wash',
#    'up',
#    'area',
#    'and',
#    'bathroom',
#    'for',
#    'their',
#    'daily',
#    'personal',
#    'needs',
#    'Site',
#    'design',
#    'and',
#    'drawings',
#    'have',
#    'been',
#    'completed',
#    'and',
#    'the',
#    'new',
#    'site',
#    'for',
#    'the',
#    'staff',
#    'room',
#    'has',
#    'been',
#    'designated',
#    'within',
#    'the',
#    'rehabilitated',
#    'dumping',
#    'station',
#    'for',
#    'Cavendish',
#    'Campground',
#    'The',
#    'new',
#    'staff',
#    'room',
#    'will',
#    'be',
#    'situated',
#    'in',
#    'the',
#    'northeast',
#    'corner',
#    'of',
#    'the',
#    'former',
#    'dumping',
#    'station',
#    'site',
#    'It',
#    'will',
#    'be',
#    'partially',
#    'constructed',
#    'on',
#    'an',
#    'old',
#    'agricultural',
#    'field',
#    '100',
#    'years',
#    'ago',
#    'that',
#    'has',
#    'since',
#    'grown',
#    'into',
#    'an',
#    'old',
#    'field',
#    'regenerative',
#    'forest',
#    'stand',
#    'of',
#    'White',
#    'Spruce',
#    'A',
#    'paved',
#    'parking',
#    'lot',
#    'covering',
#    'a',
#    'large',
#    'portion',
#    'of',
#    'the',
#    'remaining',
#    'graded',
#    'site',
#    'is',
#    'also',
#    'proposed',
#    'within',
#    'the',
#    'site',
#    'design',
#    'Services',
#    'electrical',
#    'water',
#    'sewage',
#    'and',
#    'communications',
#    'will',
#    'be',
#    'routed',
#    'into',
#    'the',
#    'new',
#    'lunchroom',
#    'and',
#    'travel',
#    'in',
#    'corridors',
#    'identified',
#    'on',
#    'the',
#    'site',
#    'drawing',
#    'All',
#    'corridors',
#    'have',
#    'been',
#    'previously',
#    'disturbed',
#    'by',
#    'either',
#    'road',
#    'construction',
#    'or',
#    'electrical',
#    'corridors',
#    'Construction',
#    'is',
#    'expected',
#    'to',
#    'begin',
#    'in',
#    'June',
#    '2020',
#    'and',
#    'be',
#    'completed',
#    'by',
#    'October',
#    '2020',
#    'The',
#    'campground',
#    'entrance',
#    'was',
#    're',
#    'designed',
#    'and',
#    'reconstructed',
#    'in',
#    '2017',
#    'It',
#    'was',
#    'at',
#    'this',
#    'time',
#    'the',
#    'old',
#    'dumping',
#    'station',
#    'was',
#    'removed',
#    'and',
#    'the',
#    'site',
#    'rehabilitated',
#    'into',
#    'a',
#    'grass',
#    'field',
#    'Last',
#    'fall',
#    'Hurricane',
#    'Dorian',
#    'made',
#    'landfall',
#    'on',
#    'PEI',
#    'and',
#    'devastated',
#    'Cavendish',
#    'Campground',
#    'felling',
#    'the',
#    'majority',
#    'of',
#    'trees',
#    'in',
#    'the',
#    'area',
#    'Any',
#    'softwood',
#    'trees',
#    'remaining',
#    'standing',
#    'were',
#    'removed',
#    'due',
#    'to',
#    'safety',
#    'reasons',
#    'Therefore',
#    'there',
#    'are',
#    'almost',
#    'no',
#    'trees',
#    'remaining',
#    'in',
#    'the',
#    'area',
#    'where',
#    'the',
#    'lunch',
#    'room',
#    'is',
#    'to',
#    'be',
#    'constructed',
#    'This',
#    'work',
#    'is',
#    'being',
#    'tendered',
#    'for',
#    'contract',
#    'in',
#    'May',
#    '2020',
#    'with',
#    'work',
#    'beginning',
#    'in',
#    'June',
#    '2020',
#    'and',
#    'expected',
#    'to',
#    'be',
#    'completed',
#    'by',
#    'October',
#    '2020',
#    'The',
#    'history',
#    'of',
#    'the',
#    'site',
#    'was',
#    'originally',
#    'agricultural',
#    'crops',
#    'hay',
#    'potato',
#    'grain',
#    'clover',
#    'The',
#    'project',
#    'site',
#    'since',
#    'has',
#    'been',
#    'heavily',
#    'landscaped',
#    'to',
#    'facilitate',
#    'the',
#    'construction',
#    'of',
#    'the',
#    'campground',
#    'entrance',
#    'and',
#    'supporting',
#    'infrastructure',
#    'access',
#    'roads',
#    'Grahams',
#    'Lane',
#    'parking',
#    'lots',
#    'walking',
#    'trails',
#    'The',
#    'entrance',
#    'to',
#    'the',
#    'campground',
#    'has',
#    'been',
#    'majorly',
#    'reconfigured',
#    'at',
#    'least',
#    'three',
#    'times',
#    'in',
#    'the',
#    'past',
#    '70',
#    'years',
#    'as',
#    'is',
#    'evident',
#    'in',
#    'the',
#    'aerial',
#    'photos',
#    'All',
#    'roadways',
#    'would',
#    'have',
#    'had',
#    'major',
#    'amounts',
#    'of',
#    'fill',
#    'trucked',
#    'in',
#    'to',
#    'build',
#    'up',
#    'the',
#    'road',
#    'surfaces',
#    'Back',
#    'ditches',
#    'would',
#    'have',
#    'been',
#    'heavily',
#    'landscaped',
#    'with',
#    'heavy',
#    'machinery',
#    'disturbing',
#    'anything',
#    'that',
#    'was',
#    'found',
#    'on',
#    'site',
#    'The',
#    'campground',
#    'had',
#    'an',
#    'EIA',
#    'completed',
#    'in',
#    '2015',
#    'that',
#    'encompassed',
#    'developing',
#    'additional',
#    'camping',
#    'sites',
#    'throughout',
#    'the',
#    'campground',
#    'Archaeological',
#    'test',
#    'pits',
#    'were',
#    'dug',
#    'and',
#    'the',
#    'area',
#    'was',
#    'assessed',
#    'for',
#    'cultural',
#    'impacts']),
#  (221,
#   ['Parks',
#    'Canada',
#    'is',
#    'proposing',
#    'to',
#    'construct',
#    'a',
#    'new',
#    'facility',
#    'to',
#    'conduct',
#    'watercraft',
#    'inspections',
#    'for',
#    'Aquatic',
#    'Invasive',
#    'Species',
#    'The',
#    'inspection',
#    'station',
#    'will',
#    'be',
#    'constructed',
#    'on',
#    'an',
#    'existing',
#    'disturbed',
#    'footprint',
#    'near',
#    'the',
#    'Park',
#    'entrance',
#    'gate',
#    'The',
#    'scope',
#    'of',
#    'work',
#    'may',
#    'include',
#    'minor',
#    'roadway',
#    'work',
#    'including',
#    'realignment',
#    'to',
#    'facilitate',
#    'vehicle',
#    'access',
#    'to',
#    'the',
#    'site',
#    'site',
#    'preparation',
#    'work',
#    'including',
#    'grading',
#    'paving',
#    'installation',
#    'of',
#    'a',
#    'washroom',
#    'facility',
#    'utility',
#    'work',
#    'and',
#    'installation',
#    'of',
#    'an',
#    'inspection',
#    'building',
#    'Parks',
#    'Canada',
#    'will',
#    'be',
#    'undertaking',
#    'a',
#    'Basic',
#    'Impact',
#    'Assessment',
#    'to',
#    'assess',
#    'potential',
#    'project',
#    'related',
#    'impacts',
#    'to',
#    'natural',
#    'and',
#    'cultural',
#    'resources',
#    'from',
#    'this',
#    'Project',
#    'Assessment',
#    'pathway',
#    'was',
#    'changed',
#    'from',
#    'BIA',
#    'to',
#    'PRIA',
#    'amendment',
#    'signed',
#    'August',
#    '12',
#    '2020',
#    'once',
#    'the',
#    'design',
#    'was',
#    'finalized',
#    'and',
#    'it',
#    'was',
#    'determined',
#    'that',
#    'the',
#    'footprint',
#    'remained',
#    'fully',
#    'in',
#    'Zone',
#    'IV',
#    'and',
#    'did',
#    'not',
#    'enter',
#    'Zone',
#    'II']),
#  (238,
#   ['The',
#    'project',
#    'includes',
#    'mobilizing',
#    'and',
#    'staging',
#    'equipment',
#    'at',
#    'Moose',
#    'Island',
#    'fuel',
#    'heavy',
#    'equipment',
#    'flooding',
#    'pumps',
#    'chainsaws',
#    'etc',
#    'Construction',
#    'of',
#    'the',
#    'ice',
#    'bridge',
#    'over',
#    'the',
#    'Peace',
#    'River',
#    'ice',
#    'depth',
#    'measurements',
#    'removal',
#    'of',
#    'pack',
#    'ice',
#    'on',
#    'the',
#    'north',
#    'and',
#    'south',
#    'shore',
#    'of',
#    'the',
#    'Peace',
#    'River',
#    'the',
#    'flooding',
#    'of',
#    'the',
#    'river',
#    'until',
#    'adequate',
#    'ice',
#    'depth',
#    'is',
#    'achieved',
#    'The',
#    'winter',
#    'road',
#    'then',
#    'continues',
#    'through',
#    'the',
#    'forest',
#    'which',
#    'requires',
#    'snow',
#    'removal',
#    'brushing',
#    'of',
#    'fallen',
#    'trees',
#    'willows',
#    'removal',
#    'of',
#    'large',
#    'rocks',
#    'tree',
#    'stumps',
#    'etc',
#    'Coordination',
#    'is',
#    'required',
#    'with',
#    'the',
#    'southern',
#    'crew',
#    'working',
#    'at',
#    'the',
#    'Fort',
#    'Chipewyan',
#    'Rocher',
#    'River',
#    'Ice',
#    'crossing',
#    'Maintenance',
#    'of',
#    'ice',
#    'bridge',
#    'winter',
#    'road',
#    'is',
#    'required',
#    'throughout',
#    'the',
#    'season',
#    'brushing',
#    'plowing',
#    'grading',
#    'of',
#    'ice',
#    'bridge',
#    'and',
#    'winter',
#    'road',
#    'and',
#    'further',
#    'ice',
#    'depth',
#    'measurements',
#    'take',
#    'place',
#    'on',
#    'the',
#    'Peace',
#    'River',
#    'and',
#    'Quatre',
#    'Forche']),
#  (251,
#   ['Snowmobiling',
#    'is',
#    'a',
#    'permitted',
#    'activity',
#    'in',
#    'designated',
#    'areas',
#    'of',
#    'Gros',
#    'Morne',
#    'National',
#    'Park',
#    'A',
#    'snowmobile',
#    'access',
#    'route',
#    'that',
#    'has',
#    'been',
#    'used',
#    'by',
#    'local',
#    'residents',
#    'is',
#    'now',
#    'being',
#    'proposed',
#    'for',
#    'public',
#    'and',
#    'commercial',
#    'use',
#    'This',
#    'route',
#    'covers',
#    '179',
#    '8',
#    'hectares',
#    'and',
#    'will',
#    'travel',
#    'for',
#    'approximately',
#    '12',
#    'kilometers',
#    'from',
#    'Woody',
#    'Point',
#    'to',
#    'Trout',
#    'River',
#    'alongside',
#    'highway',
#    'Route',
#    '431',
#    'Trout',
#    'River',
#    'Gulch',
#    'Other',
#    'than',
#    'the',
#    'placement',
#    'of',
#    'signage',
#    'at',
#    'entrance',
#    'points',
#    'no',
#    'construction',
#    'activities',
#    'are',
#    'required',
#    'In',
#    'addition',
#    'to',
#    'this',
#    'access',
#    'route',
#    'a',
#    '1',
#    '541',
#    '5',
#    'hectare',
#    'snowmobile',
#    'exclusion',
#    'zone',
#    'will',
#    'be',
#    'created',
#    'on',
#    'the',
#    'northwest',
#    'facing',
#    'slope',
#    'of',
#    'the',
#    'Tablelands',
#    'Therefore',
#    'there',
#    'will',
#    'be',
#    'a',
#    'significant',
#    'net',
#    'reduction',
#    'in',
#    'areas',
#    'open',
#    'to',
#    'snowmobiling',
#    'Most',
#    'of',
#    'the',
#    'new',
#    'snowmobile',
#    'corridor',
#    '134',
#    '8',
#    'hectares',
#    'passes',
#    'through',
#    'areas',
#    'designated',
#    'as',
#    'Zone',
#    'III',
#    'natural',
#    'environment',
#    'whereas',
#    'the',
#    'majority',
#    'of',
#    'the',
#    'expanded',
#    'exclusion',
#    'area',
#    '1',
#    '195',
#    '3',
#    'hectares',
#    'is',
#    'designated',
#    'as',
#    'Zone',
#    'II',
#    'Wilderness']),
#  (250,
#   ['The',
#    'existing',
#    'culvert',
#    'was',
#    'originally',
#    'constructed',
#    'in',
#    '1957',
#    'and',
#    'is',
#    'in',
#    'poor',
#    'condition',
#    'with',
#    'spalls',
#    'exposed',
#    'rebar',
#    'and',
#    'wide',
#    'cracks',
#    'The',
#    'existing',
#    'culvert',
#    'is',
#    '5',
#    '5',
#    'm',
#    'wide',
#    'by',
#    '1',
#    '8',
#    'm',
#    'high',
#    'and',
#    'is',
#    'a',
#    'combination',
#    'of',
#    'concrete',
#    'open',
#    'footing',
#    'culvert',
#    'and',
#    'concrete',
#    'box',
#    'culvert',
#    'The',
#    'proposed',
#    'replacement',
#    'consists',
#    'of',
#    'a',
#    '6',
#    'm',
#    'x',
#    '2',
#    '5',
#    'm',
#    'cast',
#    'in',
#    'place',
#    'concrete',
#    'open',
#    'footing',
#    'culvert',
#    'supported',
#    'on',
#    'steel',
#    'H',
#    'piles',
#    'on',
#    'the',
#    'existing',
#    'alignment',
#    'The',
#    'culvert',
#    'will',
#    'include',
#    'cast',
#    'in',
#    'place',
#    'concrete',
#    'wingwalls',
#    'supported',
#    'on',
#    'steel',
#    'H',
#    'piles',
#    'The',
#    'proposed',
#    'culvert',
#    'has',
#    'adequate',
#    'capacity',
#    'to',
#    'convey',
#    'the',
#    '25',
#    'year',
#    'design',
#    'storm',
#    'and',
#    'check',
#    'flood',
#    'without',
#    'overtopping',
#    'the',
#    'roadway',
#    'During',
#    'the',
#    'replacement',
#    'the',
#    'flow',
#    'will',
#    'be',
#    'maintained',
#    'through',
#    'a',
#    'temporary',
#    'bypass',
#    'pipe',
#    'The',
#    'work',
#    'has',
#    'been',
#    'divided',
#    'into',
#    'two',
#    'phases',
#    'Phase',
#    '1',
#    'in',
#    'Fall',
#    '2019',
#    'involves',
#    'installation',
#    'of',
#    'the',
#    'bypass',
#    'system',
#    'and',
#    'Phase',
#    '2',
#    'in',
#    '2020',
#    'involves',
#    'the',
#    'culvert',
#    'replacement',
#    'The',
#    'work',
#    'has',
#    'been',
#    'classified',
#    'as',
#    'a',
#    'Group',
#    'C',
#    'project',
#    'under',
#    'the',
#    'MTO',
#    'Class',
#    'EA',
#    'in',
#    'which',
#    'an',
#    'Environmental',
#    'Screening',
#    'Document',
#    'has',
#    'been',
#    'prepared',
#    'This',
#    'provincial',
#    'level',
#    'EA',
#    'will',
#    'be',
#    'evaluated',
#    'against',
#    'federal',
#    'requirements',
#    'and',
#    'any',
#    'gaps',
#    'will',
#    'be',
#    'filled',
#    'within',
#    'the',
#    'BIA']),
#  (264,
#   ['Parks',
#    'Canada',
#    'Fire',
#    'Management',
#    'Team',
#    'in',
#    'Waterton',
#    'Lakes',
#    'National',
#    'Park',
#    'has',
#    'proposed',
#    'the',
#    'implementation',
#    'of',
#    'a',
#    'prescribed',
#    'fire',
#    'in',
#    'the',
#    'Y',
#    'Camp',
#    'Wishbone',
#    'area',
#    'of',
#    'the',
#    'Park',
#    'The',
#    'ecological',
#    'objective',
#    'of',
#    'the',
#    'fire',
#    'is',
#    'to',
#    'reverse',
#    'the',
#    'trend',
#    'of',
#    'aspen',
#    'tree',
#    'encroachment',
#    'onto',
#    'what',
#    'was',
#    'historically',
#    'Fescue',
#    'Grassland',
#    'and',
#    'to',
#    'restore',
#    'the',
#    'mean',
#    'fire',
#    'interval',
#    'of',
#    '5',
#    'years',
#    'to',
#    'the',
#    'Fescue',
#    'Grassland',
#    'and',
#    'Aspen',
#    'Parkland',
#    'Ecoregions',
#    'of',
#    'the',
#    'Park',
#    'The',
#    'Fescue',
#    'Grassland',
#    'provides',
#    'critical',
#    'habitat',
#    'for',
#    'a',
#    'variety',
#    'of',
#    'species',
#    'in',
#    'and',
#    'outside',
#    'of',
#    'the',
#    'park',
#    'The',
#    'burn',
#    'unit',
#    'is',
#    'located',
#    'on',
#    'the',
#    'east',
#    'side',
#    'of',
#    'Lower',
#    'Waterton',
#    'Lake',
#    'and',
#    'Waterton',
#    'River',
#    'just',
#    'south',
#    'of',
#    'Highway',
#    '6',
#    'and',
#    'encompasses',
#    'an',
#    'area',
#    'of',
#    '1',
#    '170',
#    'ha',
#    'Fire',
#    'operations',
#    'would',
#    'take',
#    'place',
#    'in',
#    'the',
#    'winter',
#    'pre',
#    'guard',
#    'burning',
#    'and',
#    'spring',
#    'main',
#    'unit',
#    'burning',
#    'of',
#    '2020',
#    'before',
#    'leaf',
#    'out',
#    'Execution',
#    'of',
#    'this',
#    'burn',
#    'would',
#    'take',
#    'place',
#    'every',
#    '5',
#    'years',
#    'thereafter',
#    'under',
#    'the',
#    'same',
#    'conditions',
#    'to',
#    'continue',
#    'with',
#    'the',
#    'trend',
#    'of',
#    'the',
#    'reduction',
#    'of',
#    'Aspen',
#    'Parkland',
#    'encroachment',
#    'into',
#    'the',
#    'Fescue',
#    'Grasslands',
#    'Ecoregion']),
#  (139,
#   ['Grasslands',
#    'National',
#    'Park',
#    'is',
#    'partnering',
#    'with',
#    'SaskPower',
#    'to',
#    'remove',
#    '10',
#    'km',
#    'of',
#    'overhead',
#    'service',
#    'line',
#    'in',
#    'the',
#    'West',
#    'Block',
#    'of',
#    'the',
#    'park',
#    'replacing',
#    'it',
#    'with',
#    'a',
#    'partially',
#    'buried',
#    'service',
#    'line',
#    'The',
#    'existing',
#    'overhead',
#    'line',
#    'crosses',
#    'through',
#    'prairie',
#    'while',
#    'the',
#    'replacement',
#    'line',
#    'will',
#    'follow',
#    'the',
#    'existing',
#    'public',
#    'access',
#    'road',
#    'The',
#    'public',
#    'access',
#    'road',
#    'intersects',
#    'a',
#    'black',
#    'tailed',
#    'prairie',
#    'dog',
#    'colony',
#    'and',
#    'work',
#    'will',
#    'occur',
#    'on',
#    'lands',
#    'protected',
#    'by',
#    'the',
#    'Emergency',
#    'Order',
#    'for',
#    'the',
#    'Protection',
#    'of',
#    'the',
#    'Greater',
#    'Sage',
#    'Grouse',
#    '2013',
#    'The',
#    'proposed',
#    'project',
#    'will',
#    'work',
#    'towards',
#    'conservation',
#    'goals',
#    'for',
#    'the',
#    'greater',
#    'sage',
#    'grouse',
#    'by',
#    'removing',
#    'power',
#    'poles',
#    'in',
#    'critical',
#    'habitat',
#    'Tall',
#    'vertical',
#    'structures',
#    'in',
#    'critical',
#    'habitat',
#    'are',
#    'identified',
#    'by',
#    'the',
#    'Recovery',
#    'Strategy',
#    'for',
#    'this',
#    'species',
#    'as',
#    'a',
#    'chronic',
#    'disturbance',
#    'that',
#    'threatens',
#    'their',
#    'recovery',
#    'and',
#    'survival',
#    'This',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (112,
#   ['Many',
#    'decades',
#    'of',
#    'high',
#    'intensity',
#    'browsing',
#    'by',
#    'deer',
#    'on',
#    'Sidney',
#    'Island',
#    'has',
#    'greatly',
#    'reduced',
#    'the',
#    'abundance',
#    'and',
#    'diversity',
#    'of',
#    'plants',
#    'in',
#    'the',
#    'forest',
#    'understory',
#    'The',
#    'result',
#    'of',
#    'this',
#    'pressure',
#    'is',
# ...
#    'and',
#    'adding',
#    '7',
#    'new',
#    'buoys',
#    'to',
#    'the',
#    'existing',
#    'mooring',
#    'field',
#    'The',
#    'second',
#    'portion',
#    'of',
#    'the',
#    'project',
#    'seeks',
#    'to',
#    'improve',
#    'the',
#    'existing',
#    'closure',
#    'at',
#    'the',
#    'Sidney',
#    'Lagoon',
#    'by',
#    'adding',
#    'regulatory',
#    'signage',
#    'and',
#    'closure',
#    'notices',
#    'at',
#    'the',
#    'entrance',
#    'and',
#    'replacing',
#    'one',
#    'special',
#    'purpose',
#    'buoy',
#    'The',
#    'Sidney',
#    'Lagoon',
#    'is',
#    'classified',
#    'as',
#    'a',
#    'Zone',
#    'One',
#    'Special',
#    'Preservation',
#    'Area',
#    'and',
#    'has',
#    'been',
#    'closed',
#    'to',
#    'the',
#    'public',
#    'since',
#    '2008',
#    'This',
#    'project',
#    'seeks',
#    'to',
#    'replace',
#    'one',
#    'missing',
#    'special',
#    'purpose',
#    'closure',
#    'buoy',
#    'at',
#    'the',
#    'entrance',
#    'of',
#    'the',
#    'lagoon',
#    'and',
#    'add',
#    'additional',
#    'signage',
#    'to',
#    'ensure',
#    'visitors',
#    'are',
#    'informed',
#    'of',
#    'the',
#    'lagoon',
#    'closure']),
#  (235,
#   ['The',
#    'Wildfire',
#    'Risk',
#    'Reduction',
#    'Project',
#    'entails',
#    'the',
#    'selective',
#    'removal',
#    'thinning',
#    'and',
#    'pruning',
#    'of',
#    'trees',
#    'using',
#    'fuel',
#    'management',
#    'and',
#    'FireSmart',
#    'principles',
#    'to',
#    'reduce',
#    'fuel',
#    'loading',
#    'Proposed',
#    'treatment',
#    'areas',
#    'are',
#    'strategically',
#    'located',
#    'within',
#    'the',
#    'Gulf',
#    'Islands',
#    'National',
#    'Park',
#    'Reserve',
#    'in',
#    'order',
#    'to',
#    'reduce',
#    'the',
#    'wildfire',
#    'risk',
#    'to',
#    'park',
#    'properties',
#    'adjacent',
#    'residents',
#    'and',
#    'island',
#    'communities',
#    'while',
#    'also',
#    'providing',
#    'safer',
#    'work',
#    'areas',
#    'for',
#    'firefighters',
#    'in',
#    'the',
#    'event',
#    'of',
#    'an',
#    'wildland',
#    'urban',
#    'interface',
#    'fire',
#    'Project',
#    'locations',
#    'include',
#    'Tumbo',
#    'Island',
#    'north',
#    'edge',
#    'of',
#    'wetland',
#    'Saturna',
#    'Island',
#    'Mt',
#    'Warburton',
#    'Pike',
#    'summit',
#    'parking',
#    'lot',
#    'area',
#    'and',
#    'North',
#    'Pender',
#    'Island',
#    'south',
#    'of',
#    'Roe',
#    'Lake',
#    'adjacent',
#    'to',
#    'the',
#    'Park',
#    'Reserve',
#    'boundary',
#    'Project',
#    'work',
#    'is',
#    'proposed',
#    'for',
#    'mid',
#    'January',
#    'to',
#    'mid',
#    'March',
#    '2020',
#    'Location',
#    'Latitude',
#    'and',
#    'Longitude',
#    'are',
#    'for',
#    'the',
#    'Pender',
#    'Island',
#    'site']),
#  (161,
#   ['The',
#    'Parks',
#    'Canada',
#    'Agency',
#    'PCA',
#    'has',
#    'proposed',
#    'to',
#    'construct',
#    'a',
#    'new',
#    'segment',
#    'of',
#    'approximately',
#    '10',
#    'km',
#    'linear',
#    'trail',
#    'that',
#    'will',
#    'connect',
#    'two',
#    'existing',
#    'trail',
#    'segments',
#    'Bob',
#    'Hunter',
#    'Memorial',
#    'Park',
#    'and',
#    'Boyle',
#    's',
#    'cemetery',
#    'The',
#    'trail',
#    'is',
#    'intended',
#    'to',
#    'be',
#    'multi',
#    'use',
#    'and',
#    'primarily',
#    'aggregate',
#    'surface',
#    'with',
#    'boardwalk',
#    'where',
#    'required',
#    'in',
#    'wet',
#    'areas',
#    'and',
#    'crossings',
#    'over',
#    'the',
#    'Little',
#    'Rouge',
#    'River',
#    'It',
#    'will',
#    'also',
#    'connect',
#    'with',
#    'the',
#    'proposed',
#    'Markham',
#    'Gateway',
#    'Welcome',
#    'Area',
#    'Fencing',
#    'will',
#    'be',
#    'used',
#    'to',
#    'separate',
#    'the',
#    'trail',
#    'from',
#    'active',
#    'farming',
#    'operations',
#    'Pedestrian',
#    'road',
#    'crossings',
#    'will',
#    'occur',
#    'at',
#    'Major',
#    'Mackenzie',
#    '16th',
#    'Avenue',
#    'Highway',
#    '7',
#    '407',
#    'and',
#    '14th',
#    'Avenue',
#    'Routing',
#    'options',
#    'around',
#    'or',
#    'through',
#    'private',
#    'property',
#    'with',
#    'owner',
#    's',
#    'permission',
#    'and',
#    'a',
#    'small',
#    'capacity',
#    'parking',
#    'lot',
#    'on',
#    'Major',
#    'Mac',
#    'or',
#    '16th',
#    'Ave',
#    'will',
#    'be',
#    'investigated']),
#  (59,
#   ['Grasslands',
#    'National',
#    'Park',
#    'is',
#    'proposing',
#    'to',
#    'install',
#    'a',
#    'weather',
#    'station',
#    'in',
#    'the',
#    'West',
#    'Block',
#    'of',
#    'the',
#    'park',
#    'The',
#    'station',
#    'will',
#    'provide',
#    'real',
#    'time',
#    'weather',
#    'information',
#    'in',
#    'an',
#    'area',
#    'that',
#    'otherwise',
#    'has',
#    'little',
#    'coverage',
#    'and',
#    'this',
#    'information',
#    'will',
#    'be',
#    'used',
#    'to',
#    'support',
#    'the',
#    'fire',
#    'and',
#    'visitor',
#    'safety',
#    'programs',
#    'The',
#    'station',
#    'itself',
#    'is',
#    '3',
#    'm',
#    'tall',
#    'with',
#    'a',
#    '1',
#    'm2',
#    'tripod',
#    'base',
#    'requires',
#    'anchors',
#    'to',
#    'secure',
#    'and',
#    'will',
#    'also',
#    'require',
#    'a',
#    'cattle',
#    'exclusion',
#    'typically',
#    'a',
#    'fence',
#    'to',
#    'prevent',
#    'damage',
#    'from',
#    'cattle',
#    'The',
#    'weather',
#    'station',
#    'needs',
#    'to',
#    'be',
#    'sited',
#    'strategically',
#    'to',
#    'avoid',
#    'obstructions',
#    'or',
#    'other',
#    'features',
#    'that',
#    'might',
#    'bias',
#    'weather',
#    'readings',
#    'but',
#    'must',
#    'also',
#    'take',
#    'into',
#    'account',
#    'other',
#    'sensitive',
#    'features',
#    'such',
#    'as',
#    'critical',
#    'habitat',
#    'for',
#    'species',
#    'at',
#    'risk',
#    'and',
#    'cultural',
#    'resources',
#    'This',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (160,
#   ['In',
#    'an',
#    'effort',
#    'to',
#    'manage',
#    'the',
#    'impacts',
#    'of',
#    'deer',
#    'browse',
#    'in',
#    'sensitive',
#    'areas',
#    'of',
#    'RNUP',
#    'and',
#    'to',
#    'study',
#    'differences',
#    'in',
#    'browse',
#    'levels',
#    'when',
#    'deer',
#    'are',
#    'excluded',
#    'from',
#    'these',
#    'areas',
#    'approximately',
#    '600',
#    'metres',
#    'of',
#    'deer',
#    'exclusion',
#    'fencing',
#    'will',
#    'be',
#    'installed',
#    'in',
#    'a',
#    'forested',
#    'plot',
#    'in',
#    'RNUP',
#    'The',
#    'fencing',
#    'will',
#    'be',
#    'installed',
#    'about',
#    '25',
#    'meters',
#    'off',
#    'of',
#    'a',
#    'main',
#    'road',
#    'and',
#    'continue',
#    'about',
#    '145',
#    'meters',
#    'into',
#    'the',
#    'interior',
#    'of',
#    'the',
#    'forest',
#    'A',
#    'City',
#    'of',
#    'Toronto',
#    'Road',
#    'Closure',
#    'Permit',
#    'will',
#    'be',
#    'required',
#    'for',
#    'the',
#    'duration',
#    'of',
#    'this',
#    'project',
#    'The',
#    'area',
#    'surrounding',
#    'the',
#    'site',
#    'is',
#    'a',
#    'densely',
#    'forested',
#    'area',
#    'with',
#    'a',
#    'healthy',
#    'understory',
#    'There',
#    'are',
#    'few',
#    'social',
#    'trails',
#    'through',
#    'the',
#    'area',
#    'that',
#    'should',
#    'be',
#    'used',
#    'as',
#    'access',
#    'routes',
#    'where',
#    'possible',
#    'to',
#    'minimize',
#    'disturbance']),
#  (114,
#   ['Parks',
#    'Canada',
#    'is',
#    'proposing',
#    'to',
#    'install',
#    'four',
#    'Remote',
#    'Avalanche',
#    'Control',
#    'System',
#    'RACS',
#    'units',
#    'on',
#    'Mt',
#    'Whymper',
#    'Currently',
#    'Parks',
#    'Canada',
#    'Agency',
#    'performs',
#    'avalanche',
#    'control',
#    'by',
#    'placing',
#    'explosives',
#    'from',
#    'helicopters',
#    'in',
#    'starting',
#    'zones',
#    'of',
#    'Mt',
#    'Whymper',
#    'However',
#    'control',
#    'by',
#    'helicopter',
#    'is',
#    'often',
#    'limited',
#    'by',
#    'poor',
#    'visibility',
#    'and',
#    'wind',
#    'in',
#    'the',
#    'starting',
#    'zones',
#    'effecting',
#    'timing',
#    'and',
#    'efficiency',
#    'of',
#    'avalanche',
#    'control',
#    'and',
#    'exposing',
#    'workers',
#    'to',
#    'challenging',
#    'flying',
#    'conditions',
#    'and',
#    'explosives',
#    'use',
#    'The',
#    'rationale',
#    'for',
#    'RACS',
#    'in',
#    'these',
#    'paths',
#    'is',
#    'to',
#    'reduce',
#    'impacts',
#    'to',
#    'Highway',
#    '93',
#    'South',
#    'highway',
#    'closure',
#    'time',
#    'and',
#    'gains',
#    'in',
#    'operational',
#    'efficiency',
#    'and',
#    'worker',
#    'safety',
#    'The',
#    'total',
#    'footprint',
#    'for',
#    'four',
#    'Gazex',
#    'RACS',
#    'units',
#    'including',
#    'foundations',
#    'shelters',
#    'and',
#    'pipelines',
#    'is',
#    '230',
#    'm',
#    'A',
#    'maximum',
#    'of',
#    'three',
#    'leveled',
#    'work',
#    'pads',
#    'will',
#    'be',
#    'required',
#    'per',
#    'site',
#    '72',
#    'm²',
#    'footprint',
#    'One',
#    'or',
#    'two',
#    'permanent',
#    'helipads',
#    'may',
#    'also',
#    'be',
#    'required',
#    '50',
#    'm²',
#    'maximum',
#    'footprint']),
#  (272,
#   ['Hunters',
#    'Lake',
#    'is',
#    'a',
#    'one',
#    'way',
#    'trail',
#    'that',
#    'incorporates',
#    'various',
#    'landscape',
#    'features',
#    'including',
#    'jack',
#    'pine',
#    'ridges',
#    'aspen',
#    'forest',
#    'and',
#    'aquatic',
#    'ecosytems',
#    'During',
#    'a',
#    'large',
#    'fire',
#    'that',
#    'burnt',
#    'throught',
#    'the',
#    'area',
#    'in',
#    '2018',
#    'heavy',
#    'equipment',
#    'was',
#    'brought',
#    'in',
#    'to',
#    'create',
#    'fire',
#    'breaks',
#    'and',
#    'the',
#    'trail',
#    'sustained',
#    'major',
#    'damage',
#    'A',
#    'reroute',
#    'was',
#    'cut',
#    'around',
#    'a',
#    'waterbody',
#    'trees',
#    'were',
#    'felled',
#    'and',
#    'left',
#    'on',
#    'site',
#    'causing',
#    'a',
#    'public',
#    'safety',
#    'hazard',
#    'The',
#    'project',
#    'involves',
#    'bringing',
#    'in',
#    'a',
#    'heavy',
#    'duty',
#    'mulcher',
#    'to',
#    'mulch',
#    'the',
#    'trees',
#    'on',
#    'site',
#    'at',
#    'the',
#    'trail',
#    'reroute',
#    'location',
#    'as',
#    'well',
#    'as',
#    'to',
#    'the',
#    'end',
#    'of',
#    'the',
#    'trail',
#    'where',
#    'regrowth',
#    'is',
#    'now',
#    'too',
#    'heavy',
#    'to',
#    'be',
#    'mown',
#    'with',
#    'traditional',
#    'equipment',
#    'Aggregate',
#    'gravel',
#    'will',
#    'be',
#    'hauled',
#    'into',
#    'the',
#    'site',
#    'to',
#    'build',
#    'up',
#    'a',
#    'trail',
#    'tread',
#    'on',
#    'the',
#    'reroute',
#    'and',
#    'any',
#    'other',
#    'areas',
#    'that',
#    'need',
#    'to',
#    'be',
#    'resurfaced',
#    'A',
#    'culvert',
#    'will',
#    'be',
#    'installed',
#    'at',
#    'a',
#    'low',
#    'spot',
#    'on',
#    'the',
#    'trail']),
#  (260,
#   ['Parks',
#    'Canada',
#    'proposes',
#    'to',
#    'remove',
#    'and',
#    'decommission',
#    'three',
#    'structures',
#    'that',
#    'are',
#    'no',
#    'longer',
#    'operationally',
#    'viable',
#    'including',
#    'a',
#    'horse',
#    'barn',
#    'a',
#    'tack',
#    'shed',
#    'and',
#    'a',
#    'pump',
#    'house',
#    'located',
#    'at',
#    'Kootenay',
#    'Crossing',
#    'in',
#    'Kootenay',
#    'National',
#    'Park',
#    'All',
#    'materials',
#    'being',
#    'stored',
#    'on',
#    'site',
#    'will',
#    'also',
#    'be',
#    'removed',
#    'A',
#    'second',
#    'phase',
#    'of',
#    'this',
#    'project',
#    'may',
#    'occur',
#    'and',
#    'will',
#    'involve',
#    'the',
#    'rehabilitation',
#    'of',
#    'the',
#    'area',
#    'involving',
#    'the',
#    're',
#    'contouring',
#    'reclamation',
#    'and',
#    're',
#    'vegetation',
#    'of',
#    'the',
#    'site',
#    'The',
#    'project',
#    'is',
#    'located',
#    '43',
#    'kilometres',
#    'km',
#    'North',
#    'of',
#    'the',
#    'intersection',
#    'of',
#    'Highway',
#    '93',
#    'and',
#    'Highway',
#    '95',
#    'in',
#    'the',
#    'Village',
#    'of',
#    'Radium',
#    'Hot',
#    'Springs',
#    'It',
#    'is',
#    'on',
#    'the',
#    'west',
#    'side',
#    'of',
#    'Highway',
#    '93',
#    'South',
#    'in',
#    'Kootenay',
#    'National',
#    'Park',
#    'and',
#    'past',
#    'Parks',
#    'Canada',
#    'fire',
#    'operations',
#    'facilities',
#    'which',
#    'are',
#    'currently',
#    'in',
#    'use',
#    'This',
#    'project',
#    'will',
#    'reduce',
#    'infrastructure',
#    'no',
#    'longer',
#    'required',
#    'in',
#    'the',
#    'park',
#    'reduce',
#    'operational',
#    'and',
#    'maintenance',
#    'cost',
#    'restore',
#    'the',
#    'area',
#    'to',
#    'its',
#    'natural',
#    'condition',
#    'and',
#    'improve',
#    'important',
#    'wildlife',
#    'habitat',
#    'and',
#    'corridors',
#    'in',
#    'the',
#    'Kootenay',
#    'crossing',
#    'area',
#    'Removal',
#    'of',
#    'these',
#    'facilities',
#    'restoration',
#    'of',
#    'the',
#    'area',
#    'and',
#    'reduction',
#    'in',
#    'human',
#    'use',
#    'will',
#    'contribute',
#    'to',
#    'Park',
#    's',
#    'Canada',
#    'general',
#    'objective',
#    'to',
#    'maintain',
#    'or',
#    'improve',
#    'ecological',
#    'integrity']),
#  (243,
#   ['SaskPower',
#    'is',
#    'proposing',
#    'to',
#    'replace',
#    'an',
#    'urban',
#    'power',
#    'pole',
#    'transformer',
#    'and',
#    'take',
#    'off',
#    'equipment',
#    'then',
#    'trench',
#    'and',
#    'lay',
#    'approximately',
#    '30',
#    'metres',
#    'm',
#    'of',
#    'secondary',
#    'cable',
#    'to',
#    'a',
#    'customer',
#    'owned',
#    'splitter',
#    'at',
#    'which',
#    'point',
#    'the',
#    'customer',
#    'will',
#    'be',
#    'responsible',
#    'to',
#    'connections',
#    'Ground',
#    'disturbance',
#    'will',
#    'be',
#    'limited',
#    'to',
#    'the',
#    'base',
#    'of',
#    'the',
#    'pole',
#    'and',
#    'the',
#    'short',
#    'run',
#    'of',
#    'trenching',
#    'The',
#    'work',
#    'will',
#    'take',
#    'place',
#    'near',
#    'an',
#    'existing',
#    'underground',
#    'cable',
#    'within',
#    'a',
#    'developed',
#    'area',
#    'and',
#    'existing',
#    'roadways',
#    'in',
#    'NW',
#    '10',
#    '057',
#    '01',
#    'W3M',
#    'within',
#    'the',
#    'Waskesiu',
#    'Townsite',
#    'in',
#    'Prince',
#    'Albert',
#    'National',
#    'Park',
#    'the',
#    'Project',
#    'The',
#    'Project',
#    'is',
#    'required',
#    'to',
#    'provide',
#    'an',
#    'additional',
#    'service',
#    'point',
#    'near',
#    'the',
#    'library',
#    'recreation',
#    'hall',
#    'Equipment',
#    'that',
#    'is',
#    'expected',
#    'to',
#    'be',
#    'used',
#    'for',
#    'completion',
#    'of',
#    'the',
#    'Project',
#    'includes',
#    'a',
#    'digger',
#    'truck',
#    'back',
#    'hoe',
#    'trenching',
#    'equipment',
#    'and',
#    'crew',
#    'trucks',
#    'Access',
#    'to',
#    'components',
#    'of',
#    'the',
#    'Project',
#    'will',
#    'make',
#    'use',
#    'of',
#    'existing',
#    'roads',
#    'and',
#    'trails',
#    'Surface',
#    'disturbance',
#    'is',
#    'expected',
#    'to',
#    'be',
#    'minimized',
#    'to',
#    'the',
#    'base',
#    'of',
#    'the',
#    'pole',
#    'and',
#    '30',
#    'm',
#    'of',
#    'trenching']),
#  (274,
#   ['In',
#    'an',
#    'effort',
#    'to',
#    'reduce',
#    'road',
#    'mortality',
#    'and',
#    'nest',
#    'predation',
#    'for',
#    'rare',
#    'turtles',
#    'Thousand',
#    'Islands',
#    'National',
#    'Park',
#    'is',
#    'planning',
#    'to',
#    'build',
#    'a',
#    'small',
#    'artificial',
#    'nesting',
#    'site',
#    'near',
#    'Polly',
#    'Creek',
#    'The',
#    'site',
#    'will',
#    'be',
#    'approximately',
#    '5m',
#    'x',
#    '5m',
#    'large',
#    'and',
#    '1m',
#    'deep',
#    'consisting',
#    'of',
#    'sand',
#    'and',
#    'gravel',
#    'surrounded',
#    'by',
#    'cedar',
#    'logs',
#    'Turtles',
#    'in',
#    'the',
#    'area',
#    'are',
#    'experiencing',
#    'significant',
#    'road',
#    'mortality',
#    'and',
#    'are',
#    'primarily',
#    'nesting',
#    'on',
#    'road',
#    'shoulders',
#    'where',
#    'near',
#    'complete',
#    'nest',
#    'predation',
#    'has',
#    'been',
#    'documented',
#    'The',
#    'artificial',
#    'nest',
#    'site',
#    'should',
#    'reduce',
#    'the',
#    'number',
#    'of',
#    'turtles',
#    'coming',
#    'onto',
#    'and',
#    'alongside',
#    'the',
#    'road',
#    'Materials',
#    'will',
#    'be',
#    'brought',
#    'to',
#    'the',
#    'site',
#    'using',
#    'a',
#    'small',
#    'tractor',
#    'and',
#    'or',
#    'a',
#    'motorised',
#    'wheelbarrow',
#    'and',
#    'construction',
#    'is',
#    'planned',
#    'for',
#    'October',
#    '10',
#    'before',
#    'turtle',
#    'hibernation',
#    'begins'])]

# %%
# lower case all words
datawords = [ (ID, [w.lower() for w in words]) for ID, words in datawords]
pprint(datawords)
# Out:
# [(87,
#   ['the',
#    'purpose',
#    'of',
#    'this',
#    'project',
#    'is',
#    'to',
#    'reduce',
#    'the',
#    'risk',
#    'of',
#    'wildfire',
#    'at',
#    'fort',
#    'walsh',
#    'national',
#    'historic',
#    'site',
#    'by',
#    'thinning',
#    'pockets',
#    'of',
#    'fuel',
#    'in',
#    'two',
#    'forested',
#    'areas',
#    'near',
#    'the',
#    'fort',
#    'site',
#    'the',
#    'total',
#    'area',
#    'to',
#    'be',
#    'treated',
#    'is',
#    '25',
#    'ha',
#    'the',
#    'absence',
#    'of',
#    'fire',
#    'and',
#    'the',
#    'maturity',
#    'of',
#    'the',
#    'forest',
#    'around',
#    'the',
#    'fort',
#    'site',
#    'has',
#    'resulted',
#    'in',
#    'the',
#    'accumulation',
#    'of',
#    'ladder',
#    'fuels',
#    'old',
#    'or',
#    'dying',
#    'mature',
#    'trees',
#    'and',
#    'downed',
#    'woody',
#    'material',
#    'by',
#    'reducing',
#    'the',
#    'fuel',
#    'load',
#    'on',
#    'site',
#    'removing',
#    'trees',
#    'and',
#    'administering',
#    'various',
#    'firesmart',
#    'techniques',
#    'stand',
#    'thinning',
#    'ladder',
#    'fuel',
#    'removal',
#    'etc',
#    'the',
#    'impact',
#    'of',
#    'a',
#    'wildfire',
#    'on',
#    'the',
#    'site',
#    'can',
#    'be',
#    'reduced',
#    'ladder',
#    'fuels',
#    'will',
#    'be',
#    'removed',
#    'and',
#    'tree',
#    'limbs',
#    'pruned',
#    'to',
#    'a',
#    'height',
#    'of',
#    '2m',
#    'using',
#    'chainsaws',
#    'and',
#    'other',
#    'various',
#    'hand',
#    'tools',
#    'dense',
#    'areas',
#    'will',
#    'be',
#    'thinned',
#    'by',
#    'hand',
#    'felling',
#    'and',
#    'deadfall',
#    'will',
#    'also',
#    'be',
#    'removed',
#    'by',
#    'hand',
#    'this',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (110,
#   ['an',
#    'armoured',
#    'stone',
#    'seawall',
#    'located',
#    'around',
#    'the',
#    'perimeter',
#    'of',
#    'the',
#    'shoreline',
#    'adjacent',
#    'to',
#    'the',
#    'st',
#    'andrews',
#    'blockhouse',
#    'national',
#    'historic',
#    'site',
#    'provides',
#    'protection',
#    'against',
#    'erosion',
#    'from',
#    'the',
#    'water',
#    'and',
#    'wave',
#    'action',
#    'of',
#    'the',
#    'passamaquoddy',
#    'bay',
#    'recent',
#    'inspection',
#    'of',
#    'the',
#    'seawall',
#    'identified',
#    'a',
#    'number',
#    'of',
#    'deficiencies',
#    'that',
#    'could',
#    'result',
#    'in',
#    'potential',
#    'failure',
#    'of',
#    'the',
#    'structure',
#    'and',
#    'cause',
#    'erosion',
#    'to',
#    'the',
#    'site',
#    'the',
#    'shoreline',
#    'protection',
#    'seawall',
#    'repairs',
#    'project',
#    'intends',
#    'to',
#    'rehabilitate',
#    'the',
#    'stone',
#    'seawall',
#    'by',
#    'repairing',
#    'damaged',
#    'areas',
#    'along',
#    'the',
#    'structure',
#    'some',
#    'displaced',
#    'stones',
#    'will',
#    'be',
#    'temporary',
#    'removed',
#    'to',
#    'allow',
#    'the',
#    'necessary',
#    'work',
#    'to',
#    'repair',
#    'and',
#    'raise',
#    'the',
#    'degraded',
#    'bed',
#    'geotextile',
#    'fabric',
#    'will',
#    'be',
#    'installed',
#    'before',
#    'reinstating',
#    'the',
#    'stone',
#    'in',
#    'other',
#    'areas',
#    'displaced',
#    'stones',
#    'currently',
#    'sitting',
#    'on',
#    'the',
#    'ocean',
#    'floor',
#    'will',
#    'be',
#    'collected',
#    'and',
#    'fitted',
#    'back',
#    'in',
#    'place',
#    'in',
#    'addition',
#    'previously',
#    'placed',
#    'concrete',
#    'pieces',
#    'will',
#    'be',
#    'removed',
#    'and',
#    'replaced',
#    'with',
#    'stone']),
#  (197,
#   ['a',
#    'fisheries',
#    'act',
#    'authorization',
#    'is',
#    'required',
#    'from',
#    'dfo',
#    'in',
#    'relation',
#    'to',
#    'impacts',
#    'on',
#    'fish',
#    'habitat',
#    'associated',
#    'with',
#    'dam',
#    'construction',
#    'projects',
#    'at',
#    'tsw',
#    'trenton',
#    'dam',
#    '1',
#    'and',
#    'glen',
#    'miller',
#    'dam',
#    '3',
#    'the',
#    'authorization',
#    'includes',
#    'provisions',
#    'for',
#    'offsetting',
#    'measures',
#    'the',
#    'construction',
#    'of',
#    'the',
#    'big',
#    'island',
#    'causeway',
#    'in',
#    'the',
#    '1950',
#    's',
#    'and',
#    'decreased',
#    'water',
#    'flows',
#    'between',
#    'the',
#    'island',
#    'and',
#    'the',
#    'mainland',
#    'have',
#    'caused',
#    'the',
#    'channels',
#    'to',
#    'be',
#    'filled',
#    'in',
#    'with',
#    'silt',
#    'and',
#    'cattails',
#    'now',
#    'cover',
#    'the',
#    'entire',
#    'area',
#    'from',
#    'the',
#    'island',
#    'to',
#    'the',
#    'mainland',
#    'parks',
#    'canada',
#    'is',
#    'proposing',
#    'to',
#    'expand',
#    'on',
#    'existing',
#    'fish',
#    'habitat',
#    'enhancements',
#    'at',
#    'the',
#    'big',
#    'island',
#    'marsh',
#    'by',
#    'constructing',
#    'a',
#    'new',
#    'channel',
#    'and',
#    'widening',
#    'deepening',
#    'of',
#    '2',
#    'existing',
#    'channels',
#    'cattail',
#    'marsh',
#    'vegetation',
#    'will',
#    'be',
#    'removed',
#    'to',
#    'a',
#    'width',
#    'of',
#    '10',
#    'm',
#    'and',
#    'depths',
#    'up',
#    'to',
#    '3',
#    '0',
#    'm',
#    'in',
#    'order',
#    'to',
#    'ensure',
#    'these',
#    'areas',
#    'stay',
#    'open',
#    'into',
#    'the',
#    'future',
#    'the',
#    'fisheries',
#    'offset',
#    'plan',
#    'is',
#    'expected',
#    'to',
#    'result',
#    'in',
#    'the',
#    'enhancement',
#    'of',
#    'fish',
#    'habitat',
#    'at',
#    'the',
#    'big',
#    'island',
#    'marsh']),
#  (111,
#   ['in',
#    'may',
#    '2018',
#    'the',
#    'rabbit',
#    'creek',
#    'wildfire',
#    'occurred',
#    'in',
#    'prince',
#    'albert',
#    'national',
#    'park',
#    'and',
#    'spread',
#    'within',
#    'and',
#    'outside',
#    'of',
#    'the',
#    'park',
#    'heavy',
#    'equipment',
#    'was',
#    'used',
#    'to',
#    'create',
#    'fire',
#    'control',
#    'lines',
#    'and',
#    'to',
#    'improve',
#    'ground',
#    'and',
#    'aerial',
#    'access',
#    'to',
#    'strategic',
#    'areas',
#    'in',
#    'addition',
#    'to',
#    'the',
#    'dozer',
#    'lines',
#    'that',
#    'were',
#    'put',
#    'in',
#    'during',
#    'the',
#    'fire',
#    'heavy',
#    'equipment',
#    'was',
#    'used',
#    'along',
#    'the',
#    'border',
#    'between',
#    'the',
#    'south',
#    'boundary',
#    'of',
#    'the',
#    'park',
#    'and',
#    'the',
#    'cookson',
#    'community',
#    'pasture',
#    'to',
#    'push',
#    'back',
#    'the',
#    'forested',
#    'edge',
#    'to',
#    'protect',
#    'a',
#    'newly',
#    'repaired',
#    'fence',
#    'that',
#    'had',
#    'been',
#    'damaged',
#    'by',
#    'the',
#    'fire',
#    'prince',
#    'albert',
#    'national',
#    'park',
#    'fire',
#    'management',
#    'takes',
#    'responsibility',
#    'for',
#    'the',
#    'reclamation',
#    'of',
#    'the',
#    'impacts',
#    'from',
#    'the',
#    'heavy',
#    'equipment',
#    'the',
#    'two',
#    'areas',
#    'of',
#    'work',
#    'are',
#    'the',
#    'south',
#    'boundary',
#    'trail',
#    'and',
#    'the',
#    'elk',
#    'trail',
#    'following',
#    'the',
#    '2018',
#    'rabbit',
#    'fire',
#    'approximately',
#    '13',
#    '5',
#    'km',
#    'of',
#    'fence',
#    'was',
#    'replaced',
#    'on',
#    'the',
#    'northern',
#    'boundary',
#    'of',
#    'the',
#    'cookson',
#    'community',
#    'pasture',
#    'approximately',
#    '6',
#    'km',
#    'of',
#    'the',
#    'fence',
#    'was',
#    'directly',
#    'adjacent',
#    'to',
#    'the',
#    'panp',
#    'boundary',
#    'this',
#    'area',
#    'was',
#    'cleared',
#    'of',
#    'vegetation',
#    'and',
#    'has',
#    'long',
#    'linear',
#    'berms',
#    'of',
#    'soil',
#    'and',
#    'wood',
#    'that',
#    'are',
#    'restricting',
#    'efforts',
#    'for',
#    'weed',
#    'control',
#    'and',
#    'seeding',
#    'along',
#    'the',
#    'boundary',
#    'and',
#    'also',
#    'increase',
#    'long',
#    'term',
#    'fire',
#    'hazard',
#    'if',
#    'left',
#    'in',
#    'piles',
#    'these',
#    'berms',
#    'will',
#    'need',
#    'to',
#    'be',
#    'spread',
#    'across',
#    'the',
#    'opening',
#    'and',
#    'a',
#    'section',
#    'of',
#    'this',
#    'area',
#    'will',
#    'need',
#    'to',
#    'have',
#    'a',
#    'flat',
#    'debris',
#    'free',
#    'surface',
#    'left',
#    'to',
#    'be',
#    'used',
#    'as',
#    'a',
#    'trail',
#    'for',
#    'off',
#    'road',
#    'vehicles',
#    'the',
#    'elk',
#    'trail',
#    'was',
#    'a',
#    'maintained',
#    'trail',
#    'within',
#    'the',
#    'park',
#    'a',
#    'section',
#    'of',
#    'the',
#    'elk',
#    'trail',
#    'has',
#    'been',
#    'closed',
#    'since',
#    '2018',
#    'due',
#    'to',
#    'impacts',
#    'from',
#    'heavy',
#    'equipment',
#    'during',
#    'wildfire',
#    'operations',
#    'the',
#    'main',
#    'area',
#    'of',
#    'concern',
#    'is',
#    'approximately',
#    '700',
#    'meters',
#    'of',
#    'forest',
#    'that',
#    'was',
#    'cleared',
#    'to',
#    'an',
#    'average',
#    'of',
#    '40',
#    'meters',
#    'wide',
#    '2',
#    '8',
#    'ha',
#    'that',
#    'will',
#    'be',
#    'reclaimed',
#    'as',
#    'this',
#    'fireguard',
#    'was',
#    'put',
#    'in',
#    'on',
#    'a',
#    'maintained',
#    'trail',
#    'a',
#    'new',
#    'trail',
#    'surface',
#    'will',
#    'need',
#    'to',
#    'be',
#    'developed',
#    'during',
#    'reclamation',
#    'within',
#    'this',
#    'area',
#    'a',
#    'bridge',
#    'that',
#    'crossed',
#    'a',
#    'small',
#    'stream',
#    'was',
#    'destroyed',
#    'by',
#    'heavy',
#    'equipment',
#    'a',
#    'shallow',
#    'water',
#    'ford',
#    'crossing',
#    'will',
#    'be',
#    'developed',
#    'here',
#    'near',
#    'this',
#    'area',
#    'there',
#    'is',
#    'also',
#    'a',
#    'helipad',
#    'of',
#    'approximately',
#    '0',
#    '5',
#    'ha',
#    'that',
#    'will',
#    'also',
#    'be',
#    'reclaimed',
#    'midway',
#    'from',
#    'the',
#    'trailhead',
#    'there',
#    'is',
#    'a',
#    'section',
#    'of',
#    'trail',
#    'and',
#    'culvert',
#    'that',
#    'has',
#    'washed',
#    'out',
#    'that',
#    'will',
#    'need',
#    'to',
#    'be',
#    'repaired',
#    'as',
#    'well']),
#  (149,
#   ['this',
#    'project',
#    'will',
#    'involve',
#    'construction',
#    'of',
#    'the',
#    'lake',
#    'superior',
#    'national',
#    'marine',
#    'conservation',
#    'area',
#    'discovery',
#    'centre',
#    'in',
#    'nipigon',
#    'on',
#    'the',
#    'project',
#    'site',
#    'is',
#    'a',
#    '1',
#    '4',
#    'hectare',
#    'lot',
#    'at',
#    'the',
#    'nipigon',
#    'waterfront',
#    'on',
#    'the',
#    'west',
#    'side',
#    'of',
#    'brennan',
#    'drive',
#    'the',
#    'project',
#    'will',
#    'include',
#    'construction',
#    'of',
#    'the',
#    'discovery',
#    'centre',
#    'detached',
#    'garage',
#    'parking',
#    'area',
#    'outdoor',
#    'interpretive',
#    'elements',
#    'and',
#    'landscaping',
#    'the',
#    'discovery',
#    'centre',
#    'approximately',
#    '1',
#    '300',
#    'square',
#    'meters',
#    'will',
#    'be',
#    'a',
#    'single',
#    'story',
#    'multiuse',
#    'building',
#    'that',
#    'will',
#    'include',
#    'exhibit',
#    'space',
#    'interpretive',
#    'elements',
#    'interior',
#    'and',
#    'exterior',
#    'and',
#    'administrative',
#    'space',
#    'it',
#    'will',
#    'serve',
#    'as',
#    'the',
#    'main',
#    'hub',
#    'for',
#    'visitors',
#    'to',
#    'lake',
#    'superior',
#    'national',
#    'marine',
#    'conservation',
#    'area',
#    'and',
#    'for',
#    'site',
#    'administration',
#    'and',
#    'operations',
#    'the',
#    'construction',
#    'phase',
#    'of',
#    'the',
#    'project',
#    'will',
#    'involve',
#    'use',
#    'of',
#    'heavy',
#    'machinery',
#    'excavation',
#    'backfilling',
#    'landscaping',
#    'and',
#    'some',
#    'vegetation',
#    'removal',
#    'this',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (214,
#   ['yellow',
#    'toadflax',
#    'is',
#    'a',
#    'widely',
#    'distributed',
#    'perennial',
#    'invasive',
#    'plant',
#    'that',
#    'reproduces',
#    'by',
#    'seed',
#    'and',
#    'extensive',
#    'creeping',
#    'rhizome',
#    'the',
#    'plant',
#    'is',
#    'extremely',
#    'hardy',
#    'and',
#    'has',
#    'the',
#    'ability',
#    'to',
#    'densely',
#    'infest',
#    'large',
#    'areas',
#    'and',
#    'crowd',
#    'out',
#    'native',
#    'vegetation',
#    'making',
#    'it',
#    'a',
#    'threat',
#    'to',
#    'ecological',
#    'integrity',
#    'in',
#    'prince',
#    'albert',
#    'national',
#    'park',
#    'herbicide',
#    'spraying',
#    'of',
#    'yellow',
#    'toadflax',
#    'has',
#    'occurred',
#    'in',
#    'several',
#    'locations',
#    'in',
#    'prince',
#    'albert',
#    'national',
#    'park',
#    'with',
#    'limited',
#    'success',
#    'using',
#    'a',
#    'biological',
#    'control',
#    'agent',
#    'offers',
#    'an',
#    'additional',
#    'option',
#    'for',
#    'control',
#    'of',
#    'this',
#    'species',
#    'in',
#    'a',
#    'manner',
#    'that',
#    'is',
#    'not',
#    'nearly',
#    'so',
#    'labour',
#    'intensive',
#    'prince',
#    'albert',
#    'national',
#    'park',
#    'will',
#    'be',
#    'working',
#    'with',
#    'agriculture',
#    'and',
#    'agri',
#    'food',
#    'canada',
#    'to',
#    'carry',
#    'out',
#    'trials',
#    'of',
#    'rhinusa',
#    'pilosa',
#    'in',
#    'up',
#    'to',
#    'three',
#    'affected',
#    'locations',
#    'prospect',
#    'point',
#    'rabbit',
#    'cabin',
#    'area',
#    'and',
#    '12',
#    'mile',
#    'meadow',
#    'weevils',
#    'will',
#    'be',
#    'obtained',
#    'from',
#    'agriculture',
#    'and',
#    'agri',
#    'foods',
#    'canada',
#    'at',
#    'no',
#    'charge',
#    'and',
#    'will',
#    'be',
#    'released',
#    'at',
#    'the',
#    'sites',
#    'in',
#    'late',
#    'summer']),
#  (257,
#   ['hyperabundant',
#    'populations',
#    'of',
#    'white',
#    'tailed',
#    'deer',
#    'threaten',
#    'the',
#    'ecological',
#    'value',
#    'of',
#    'the',
#    'varied',
#    'forest',
#    'communities',
#    'on',
#    'hill',
#    'island',
#    'and',
#    'other',
#    'park',
#    'islands',
#    'intensive',
#    'browsing',
#    'has',
#    'led',
#    'to',
#    'a',
#    'distinct',
#    'lack',
#    'of',
#    'understory',
#    'vegetation',
#    'and',
#    'changing',
#    'forest',
#    'composition',
#    'parks',
#    'canada',
#    'has',
#    'developed',
#    'a',
#    'deer',
#    'management',
#    'strategy',
#    'in',
#    'response',
#    'to',
#    'these',
#    'ecological',
#    'impacts',
#    'and',
#    'is',
#    'proposing',
#    'to',
#    'restore',
#    'the',
#    'native',
#    'vegetation',
#    'to',
#    'the',
#    'area',
#    'by',
#    'reducing',
#    'deer',
#    'numbers',
#    'the',
#    'deer',
#    'herd',
#    'reduction',
#    'will',
#    'be',
#    'conducted',
#    'as',
#    'outlined',
#    'in',
#    'the',
#    'hill',
#    'island',
#    'hyperabundant',
#    'deer',
#    'management',
#    'plan',
#    '2012',
#    'the',
#    'goal',
#    'of',
#    'the',
#    'project',
#    'is',
#    'to',
#    'restore',
#    'the',
#    'integrity',
#    'of',
#    'the',
#    'forest',
#    'ecosystem',
#    'on',
#    'hill',
#    'island',
#    'and',
#    'the',
#    'processes',
#    'to',
#    'protect',
#    'the',
#    'habitat',
#    'of',
#    'plant',
#    'species',
#    'of',
#    'conservation',
#    'concern',
#    'eg',
#    'pitch',
#    'pine',
#    'the',
#    'deer',
#    'herd',
#    'reduction',
#    'began',
#    'in',
#    '2007',
#    'in',
#    'an',
#    'effort',
#    'to',
#    'reduce',
#    'populations',
#    'to',
#    'a',
#    'level',
#    '4',
#    'deer',
#    'per',
#    'km2',
#    'that',
#    'will',
#    'allow',
#    'for',
#    'healthy',
#    'forest',
#    'regeneration',
#    'and',
#    'efforts',
#    'continue',
#    'to',
#    'attain',
#    'that',
#    'population',
#    'density',
#    'the',
#    'reduction',
#    'in',
#    'deer',
#    'numbers',
#    'will',
#    'be',
#    'achieved',
#    'by',
#    'partnering',
#    'with',
#    'the',
#    'mohawks',
#    'of',
#    'akwesasne',
#    'to',
#    'harvest',
#    'white',
#    'tailed',
#    'deer',
#    'from',
#    'the',
#    'island',
#    'the',
#    'monitoring',
#    'program',
#    'will',
#    'continue',
#    'to',
#    'track',
#    'the',
#    'effectiveness',
#    'of',
#    'the',
#    'deer',
#    'reduction',
#    'strategy',
#    'in',
#    'the',
#    'recovery',
#    'of',
#    'the',
#    'forest',
#    'ecosystem',
#    'this',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (63,
#   ['the',
#    'project',
#    'will',
#    'entail',
#    'the',
#    'installation',
#    'of',
#    'approximately',
#    '330',
#    'grid',
#    'tied',
#    'photovoltaic',
#    'solar',
#    'panels',
#    'at',
#    'the',
#    'site',
#    'of',
#    'the',
#    'former',
#    'environment',
#    'and',
#    'climate',
#    'change',
#    'canada',
#    'capmon',
#    'weather',
#    'station',
#    'located',
#    'within',
#    'the',
#    'kejimkujik',
#    'national',
#    'park',
#    'and',
#    'national',
#    'historic',
#    'site',
#    'frontcountry',
#    'the',
#    'goal',
#    'of',
#    'the',
#    'project',
#    'is',
#    'to',
#    'generate',
#    'renewable',
#    'electricity',
#    'and',
#    'contribute',
#    'to',
#    'the',
#    'reduction',
#    'of',
#    'greenhouse',
#    'gases',
#    'associated',
#    'with',
#    'the',
#    'park',
#    's',
#    'operations',
#    'the',
#    'solar',
#    'panels',
#    'will',
#    'be',
#    'mounted',
#    'on',
#    'a',
#    'racking',
#    'system',
#    'anchored',
#    'with',
#    'screw',
#    'piles',
#    'or',
#    'poured',
#    'concrete',
#    'foundations',
#    'trenching',
#    'will',
#    'be',
#    'required',
#    'for',
#    'the',
#    'installation',
#    'of',
#    'electrical',
#    'wiring',
#    'to',
#    'connect',
#    'the',
#    'array',
#    'with',
#    'the',
#    'existing',
#    'nova',
#    'scotia',
#    'power',
#    'grid',
#    'at',
#    'the',
#    'site',
#    'the',
#    'project',
#    'will',
#    'be',
#    'reviewed',
#    'via',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (273,
#   ['saskpower',
#    'is',
#    'proposing',
#    'to',
#    'replace',
#    'a',
#    'pole',
#    'mount',
#    'transformer',
#    'on',
#    'an',
#    'existing',
#    'wooden',
#    'pole',
#    'and',
#    'directionally',
#    'drill',
#    '65',
#    'm',
#    'to',
#    'a',
#    'customer',
#    'supplied',
#    'metering',
#    'point',
#    'in',
#    'se',
#    '16',
#    '57',
#    '01',
#    'w3m',
#    'within',
#    'prince',
#    'albert',
#    'national',
#    'park',
#    'the',
#    'project',
#    'is',
#    'required',
#    'to',
#    'increase',
#    'the',
#    'capacity',
#    'of',
#    'the',
#    'line',
#    'and',
#    'maintain',
#    'the',
#    'quality',
#    'of',
#    'service',
#    'to',
#    'an',
#    'existing',
#    'customer',
#    'equipment',
#    'that',
#    'is',
#    'expected',
#    'to',
#    'be',
#    'used',
#    'for',
#    'completion',
#    'of',
#    'the',
#    'project',
#    'includes',
#    'a',
#    'digger',
#    'truck',
#    'back',
#    'hoe',
#    'bucket',
#    'truck',
#    'directional',
#    'boring',
#    'equipment',
#    'and',
#    'crew',
#    'trucks',
#    'access',
#    'to',
#    'components',
#    'of',
#    'the',
#    'project',
#    'will',
#    'make',
#    'use',
#    'of',
#    'existing',
#    'roads',
#    'and',
#    'trails',
#    'surface',
#    'disturbance',
#    'is',
#    'expected',
#    'to',
#    'be',
#    'minimized',
#    'to',
#    'the',
#    'bell',
#    'holes',
#    'at',
#    'the',
#    'existing',
#    'pole',
#    'and',
#    'metering',
#    'point']),
#  (203,
#   ['this',
#    'project',
#    'will',
#    'involve',
#    'dock',
#    'work',
#    'at',
#    'multiple',
#    'locations',
#    'throughout',
#    'thousand',
#    'islands',
#    'national',
#    'park',
#    'specifically',
#    'work',
#    'will',
#    'include',
#    'installation',
#    'of',
#    'floating',
#    'docks',
#    'to',
#    'replace',
#    'docks',
#    'that',
#    'are',
#    'were',
#    'damaged',
#    'due',
#    'to',
#    'recent',
#    'high',
#    'water',
#    'levels',
#    'and',
#    'to',
#    'replace',
#    'docks',
#    'that',
#    'are',
#    'at',
#    'the',
#    'end',
#    'of',
#    'their',
#    'life',
#    'cycle',
#    'the',
#    'new',
#    'docks',
#    'will',
#    'be',
#    'designed',
#    'to',
#    'accommodate',
#    'higher',
#    'water',
#    'levels',
#    'associated',
#    'work',
#    'includes',
#    'installation',
#    'of',
#    'in',
#    'water',
#    'shoreline',
#    'anchoring',
#    'systems',
#    'and',
#    'installation',
#    'of',
#    'boardwalks',
#    'and',
#    'kiosks',
#    'at',
#    'shore',
#    'landing',
#    'points',
#    'replacements',
#    'and',
#    'or',
#    'minor',
#    'location',
#    'adjustments',
#    'of',
#    'mooring',
#    'buoy',
#    'anchors',
#    'may',
#    'also',
#    'be',
#    'carried',
#    'out',
#    'where',
#    'necessary',
#    'dock',
#    'project',
#    'locations',
#    'include',
#    'adelaide',
#    'island',
#    'east',
#    'grenadier',
#    'island',
#    'georgina',
#    'island',
#    'constance',
#    'island',
#    'mulcaster',
#    'island',
#    'milton',
#    'island',
#    'hill',
#    'island',
#    'and',
#    'stovin',
#    'island',
#    'project',
#    'work',
#    'is',
#    'planned',
#    'to',
#    'be',
#    'commence',
#    'in',
#    'april',
#    '2020',
#    'and',
#    'conclude',
#    'by',
#    'november',
#    '2020',
#    'this',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (271,
#   ['a',
#    'new',
#    'culvert',
#    'needs',
#    'to',
#    'be',
#    'installed',
#    'on',
#    'the',
#    'boundary',
#    'road',
#    'north',
#    'of',
#    'osten',
#    'lake',
#    'camping',
#    'access',
#    'on',
#    'rr',
#    '205',
#    'the',
#    'culvert',
#    'has',
#    'collapsed',
#    'and',
#    'completely',
#    'rusted',
#    'out',
#    'and',
#    'the',
#    'site',
#    'is',
#    'currently',
#    'flooded',
#    'due',
#    'to',
#    'beaver',
#    'activity',
#    'and',
#    'strathcona',
#    'county',
#    'culvert',
#    'failure',
#    'on',
#    'rr',
#    '205',
#    'currently',
#    'beavers',
#    'have',
#    'a',
#    'deep',
#    'run',
#    'washout',
#    'through',
#    'the',
#    'boundary',
#    'road',
#    'making',
#    'it',
#    'impassable',
#    'the',
#    'new',
#    'culvert',
#    'will',
#    'be',
#    'a',
#    'larger',
#    'diameter',
#    '600mm',
#    'due',
#    'to',
#    'the',
#    'sizes',
#    'that',
#    'are',
#    'currently',
#    'kept',
#    'in',
#    'stock',
#    'for',
#    'replacements',
#    'the',
#    'old',
#    'culvert',
#    'was',
#    '450mm',
#    'the',
#    'work',
#    'will',
#    'take',
#    'place',
#    'when',
#    'there',
#    'is',
#    'no',
#    'water',
#    'flow',
#    'through',
#    'the',
#    'boundary',
#    'road',
#    'three',
#    'inch',
#    'minus',
#    'pit',
#    'run',
#    'gravel',
#    'will',
#    'be',
#    'used',
#    'to',
#    'fill',
#    'the',
#    'road',
#    'base',
#    'on',
#    'the',
#    'top',
#    'and',
#    'sides',
#    'of',
#    'the',
#    'new',
#    'culvert',
#    'strathcona',
#    'county',
#    'plans',
#    'to',
#    'repair',
#    'the',
#    'culvert',
#    'through',
#    'rr',
#    '205']),
#  (50,
#   ['red',
#    'bay',
#    's',
#    '2011',
#    'management',
#    'plan',
#    'identified',
#    'strategies',
#    'to',
#    'develop',
#    'a',
#    'menu',
#    'of',
#    'visitor',
#    'experience',
#    'opportunities',
#    'to',
#    'enhance',
#    'how',
#    'canadians',
#    'discover',
#    'enjoy',
#    'and',
#    'connect',
#    'with',
#    'the',
#    'historic',
#    'site',
#    'site',
#    'management',
#    'have',
#    'proposed',
#    'an',
#    'escape',
#    'game',
#    'developed',
#    'by',
#    'fetch',
#    'quest',
#    'based',
#    'on',
#    'the',
#    'history',
#    'of',
#    'the',
#    'red',
#    'bay',
#    'basque',
#    'whaling',
#    'station',
#    'the',
#    'game',
#    'requires',
#    'participants',
#    'to',
#    'complete',
#    'a',
#    'number',
#    'of',
#    'puzzles',
#    'and',
#    'trivial',
#    'tasks',
#    'with',
#    'props',
#    'and',
#    'equipment',
#    'in',
#    'order',
#    'to',
#    'successfully',
#    'solve',
#    'the',
#    'game',
#    'to',
#    'facilitate',
#    'the',
#    'placement',
#    'of',
#    'some',
#    'of',
#    'the',
#    'props',
#    'site',
#    'management',
#    'is',
#    'proposing',
#    'a',
#    'small',
#    'addition',
#    'to',
#    'the',
#    'island',
#    's',
#    'existing',
#    'trail',
#    'a',
#    'board',
#    'walk',
#    'approximately',
#    '5',
#    'feet',
#    'in',
#    'length',
#    'will',
#    'extend',
#    'from',
#    'the',
#    'existing',
#    'trail',
#    'and',
#    'allow',
#    'participants',
#    'to',
#    'step',
#    'off',
#    'the',
#    'main',
#    'trail',
#    'unto',
#    'an',
#    '8',
#    'x',
#    '12',
#    'meter',
#    'wooden',
#    'platform',
#    'that',
#    'is',
#    'placed',
#    'upon',
#    'a',
#    'gravel',
#    'bedding']),
#  (51,
#   ['the',
#    'objective',
#    'of',
#    'this',
#    'project',
#    'is',
#    'to',
#    'complete',
#    'the',
#    'second',
#    'phase',
#    'of',
#    'the',
#    'decommission',
#    'and',
#    'reclamation',
#    'of',
#    'the',
#    'redstreak',
#    'wastewater',
#    'lagoon',
#    'the',
#    'first',
#    'phase',
#    'of',
#    'the',
#    'project',
#    'was',
#    'completed',
#    'in',
#    'the',
#    'summer',
#    'and',
#    'fall',
#    'of',
#    '2020',
#    'when',
#    'a',
#    'fence',
#    'surrounding',
#    'the',
#    'lagoon',
#    'and',
#    'a',
#    'large',
#    'woody',
#    'debris',
#    'pile',
#    'were',
#    'removed',
#    'furthermore',
#    'soil',
#    'samples',
#    'were',
#    'collected',
#    'and',
#    'analyzed',
#    'to',
#    'confirm',
#    'that',
#    'the',
#    'site',
#    'is',
#    'not',
#    'contaminated',
#    'and',
#    'meets',
#    'federal',
#    'and',
#    'provincial',
#    'guidelines',
#    'bc',
#    'omrr',
#    'bc',
#    'csr',
#    'ccme',
#    'the',
#    'lagoon',
#    'is',
#    'adjacent',
#    'to',
#    'the',
#    'redstreak',
#    'restoration',
#    'area',
#    'and',
#    'is',
#    'within',
#    'a',
#    'subunit',
#    'called',
#    'the',
#    'provincial',
#    'block',
#    'which',
#    'was',
#    'harvested',
#    'and',
#    'thinned',
#    'in',
#    '2002',
#    'the',
#    'redstreak',
#    'restoration',
#    'area',
#    'was',
#    'created',
#    'as',
#    'a',
#    'multi',
#    'year',
#    'ecosystem',
#    'based',
#    'management',
#    'project',
#    'where',
#    'parks',
#    'canada',
#    'restored',
#    'its',
#    'historical',
#    'fire',
#    'regime',
#    'and',
#    'brought',
#    'back',
#    'native',
#    'grasses',
#    'to',
#    'provide',
#    'better',
#    'grazing',
#    'habitat',
#    'by',
#    'forest',
#    'thinning',
#    'and',
#    'maintenance',
#    'prescribed',
#    'fire',
#    'in',
#    '2021',
#    'parks',
#    'canada',
#    'is',
#    'targeting',
#    'to',
#    'complete',
#    'the',
#    'full',
#    'decommission',
#    'and',
#    'reclamation',
#    'of',
#    'the',
#    'old',
#    'wastewater',
#    'lagoon',
#    'site',
#    'the',
#    'main',
#    'objective',
#    'of',
#    'this',
#    'project',
#    's',
#    'second',
#    'phase',
#    'is',
#    'to',
#    'reduce',
#    'the',
#    'human',
#    'footprint',
#    'left',
#    'on',
#    'that',
#    'site',
#    'by',
#    'removing',
#    'any',
#    'infrastructure',
#    'that',
#    'remains',
#    'at',
#    'the',
#    'lagoon',
#    'and',
#    'prepare',
#    'the',
#    'site',
#    'to',
#    'start',
#    'the',
#    'natural',
#    'revegetation',
#    'phase',
#    'of',
#    'the',
#    'reclamation']),
#  (123,
#   ['the',
#    'cedar',
#    'shingle',
#    'roofing',
#    'on',
#    'the',
#    'watchmen',
#    'accommodations',
#    'cabin',
#    'on',
#    'hotspring',
#    'island',
#    'is',
#    'compromised',
#    'and',
#    'requires',
#    'replacement',
#    'there',
#    'is',
#    'a',
#    'known',
#    'bat',
#    'maternity',
#    'roost',
#    'in',
#    'the',
#    'area',
#    'roughly',
#    '100m',
#    'away',
#    'and',
#    'bats',
#    'may',
#    'possibly',
#    'be',
#    'using',
#    'the',
#    'roof',
#    'soffits',
#    'attic',
#    'etc',
#    'for',
#    'roosting',
#    'unknown',
#    'at',
#    'this',
#    'point',
#    'physical',
#    'inspection',
#    'pending',
#    'the',
#    'metal',
#    'roofing',
#    'on',
#    'the',
#    'ellen',
#    'island',
#    'operations',
#    'station',
#    'leaks',
#    'and',
#    'requires',
#    'replacement',
#    'bats',
#    'have',
#    'been',
#    'observed',
#    'in',
#    'the',
#    'area',
#    'in',
#    'the',
#    'past',
#    'bats',
#    'may',
#    'possibly',
#    'be',
#    'using',
#    'the',
#    'roof',
#    'soffits',
#    'attic',
#    'etc',
#    'for',
#    'roosting',
#    'unknown',
#    'at',
#    'this',
#    'point',
#    'physical',
#    'inspection',
#    'pending',
#    'both',
#    'roofs',
#    'will',
#    'be',
#    'redone',
#    'using',
#    'metal',
#    'roofing',
#    'because',
#    'of',
#    'the',
#    'possibility',
#    'that',
#    'bats',
#    'may',
#    'be',
#    'using',
#    'these',
#    'cabins',
#    'as',
#    'a',
#    'residence',
#    'this',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (205,
#   ['grasslands',
#    'national',
#    'park',
#    'proposes',
#    'to',
#    'issue',
#    'a',
#    'license',
#    'of',
#    'occupation',
#    'to',
#    'graze',
#    'cattle',
#    'over',
#    '8',
#    'sections',
#    'in',
#    'the',
#    'former',
#    'mankota',
#    'community',
#    'pasture',
#    'area',
#    'of',
#    'the',
#    'east',
#    'block',
#    'of',
#    'the',
#    'park',
#    'cattle',
#    'grazing',
#    'has',
#    'occurred',
#    'in',
#    'this',
#    'area',
#    'previously',
#    'under',
#    'a',
#    'grazing',
#    'permit',
#    'and',
#    'before',
#    'acquisition',
#    'by',
#    'parks',
#    'canada',
#    'was',
#    'used',
#    'for',
#    'grazing',
#    'livestock',
#    'domestic',
#    'livestock',
#    'grazing',
#    'is',
#    'used',
#    'in',
#    'this',
#    'area',
#    'to',
#    'maintain',
#    'a',
#    'disturbance',
#    'regime',
#    'supporting',
#    'habitat',
#    'maintenance',
#    'for',
#    'species',
#    'at',
#    'risk',
#    'and',
#    'for',
#    'prairie',
#    'ecosystem',
#    'function',
#    'no',
#    'new',
#    'infrastructure',
#    'will',
#    'be',
#    'constructed',
#    'as',
#    'part',
#    'of',
#    'this',
#    'program',
#    'activities',
#    'will',
#    'include',
#    'moving',
#    'cattle',
#    'in',
#    'and',
#    'out',
#    'of',
#    'grazing',
#    'paddocks',
#    'maintaining',
#    'repairing',
#    'fences',
#    'and',
#    'watering',
#    'systems',
#    'and',
#    'checking',
#    'cattle',
#    'this',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (82,
#   ['the',
#    'existing',
#    'main',
#    'road',
#    'from',
#    'the',
#    'south',
#    'beach',
#    'from',
#    'the',
#    'sable',
#    'island',
#    'main',
#    'station',
#    'traverses',
#    'an',
#    'active',
#    'tern',
#    'colony',
#    'may',
#    'august',
#    'vehicle',
#    'movements',
#    'along',
#    'this',
#    'corridor',
#    'creates',
#    'disturbance',
#    'to',
#    'nesting',
#    'birds',
#    'and',
#    'can',
#    'contribute',
#    'to',
#    'nest',
#    'failure',
#    'and',
#    'chick',
#    'mortality',
#    'to',
#    'reduce',
#    'these',
#    'impacts',
#    'it',
#    'is',
#    'proposed',
#    'that',
#    'a',
#    'seasonal',
#    'temporary',
#    'crossing',
#    'be',
#    'developed',
#    'to',
#    'allow',
#    'access',
#    'to',
#    'the',
#    'south',
#    'beach',
#    'from',
#    'main',
#    'station',
#    'the',
#    'proposed',
#    'location',
#    'is',
#    'located',
#    'approximately',
#    '1',
#    '8',
#    'km',
#    'east',
#    'of',
#    'main',
#    'station',
#    'and',
#    'passes',
#    'through',
#    'one',
#    'of',
#    'the',
#    'narrowest',
#    'sections',
#    'of',
#    'the',
#    'dunes',
#    '100m',
#    'long',
#    'and',
#    'is',
#    'currently',
#    'almost',
#    'devoid',
#    'of',
#    'vegetation',
#    'and',
#    'easily',
#    'navigable',
#    'by',
#    'sinpr',
#    'vehicles',
#    'the',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (49,
#   ['an',
#    'impact',
#    'assessment',
#    'is',
#    'required',
#    'to',
#    'address',
#    'potential',
#    'impacts',
#    'resulting',
#    'from',
#    'the',
#    'repair',
#    'of',
#    'a',
#    'class',
#    'a2',
#    'pedestrian',
#    'bridge',
#    'on',
#    'the',
#    'west',
#    'coast',
#    'trail',
#    'of',
#    'pacific',
#    'rim',
#    'national',
#    'park',
#    'reserve',
#    'bridge',
#    'repairs',
#    'are',
#    'required',
#    'to',
#    'ensure',
#    'the',
#    'safety',
#    'of',
#    'visitors',
#    'and',
#    'staff',
#    'while',
#    'traversing',
#    'and',
#    'maintaining',
#    'the',
#    'trail',
#    'limited',
#    'ground',
#    'disturbance',
#    'within',
#    'riparian',
#    'habitat',
#    'will',
#    'be',
#    'required',
#    'to',
#    'upgrade',
#    'the',
#    'mid',
#    'span',
#    'bridge',
#    'support',
#    'structure',
#    'all',
#    'work',
#    'within',
#    'the',
#    'riparian',
#    'zone',
#    'will',
#    'meet',
#    'dfo',
#    'measures',
#    'to',
#    'reduce',
#    'harm',
#    'to',
#    'fish',
#    'including',
#    'project',
#    'completion',
#    'during',
#    'the',
#    'least',
#    'risk',
#    'summer',
#    'window',
#    'when',
#    'the',
#    'adjacent',
#    'creek',
#    'is',
#    'expected',
#    'to',
#    'be',
#    'completely',
#    'dry',
#    'no',
#    'in',
#    'water',
#    'works',
#    'will',
#    'occur',
#    'as',
#    'part',
#    'of',
#    'this',
#    'project',
#    'the',
#    'anticipated',
#    'effects',
#    'and',
#    'mitigation',
#    'for',
#    'this',
#    'scope',
#    'of',
#    'work',
#    'are',
#    'limited',
#    'and',
#    'well',
#    'understood',
#    'thus',
#    'a',
#    'basic',
#    'impact',
#    'assessment',
#    'will',
#    'be',
#    'undertaken']),
#  (156,
#   ['the',
#    'previous',
#    'cavendish',
#    'campground',
#    'staff',
#    'room',
#    'experienced',
#    'a',
#    'devastating',
#    'fire',
#    'last',
#    'fall',
#    'and',
#    'as',
#    'such',
#    'burned',
#    'beyond',
#    'repair',
#    'national',
#    'park',
#    'staff',
#    'now',
#    'require',
#    'a',
#    'lunchroom',
#    'wash',
#    'up',
#    'area',
#    'and',
#    'bathroom',
#    'for',
#    'their',
#    'daily',
#    'personal',
#    'needs',
#    'site',
#    'design',
#    'and',
#    'drawings',
#    'have',
#    'been',
#    'completed',
#    'and',
#    'the',
#    'new',
#    'site',
#    'for',
#    'the',
#    'staff',
#    'room',
#    'has',
#    'been',
#    'designated',
#    'within',
#    'the',
#    'rehabilitated',
#    'dumping',
#    'station',
#    'for',
#    'cavendish',
#    'campground',
#    'the',
#    'new',
#    'staff',
#    'room',
#    'will',
#    'be',
#    'situated',
#    'in',
#    'the',
#    'northeast',
#    'corner',
#    'of',
#    'the',
#    'former',
#    'dumping',
#    'station',
#    'site',
#    'it',
#    'will',
#    'be',
#    'partially',
#    'constructed',
#    'on',
#    'an',
#    'old',
#    'agricultural',
#    'field',
#    '100',
#    'years',
#    'ago',
#    'that',
#    'has',
#    'since',
#    'grown',
#    'into',
#    'an',
#    'old',
#    'field',
#    'regenerative',
#    'forest',
#    'stand',
#    'of',
#    'white',
#    'spruce',
#    'a',
#    'paved',
#    'parking',
#    'lot',
#    'covering',
#    'a',
#    'large',
#    'portion',
#    'of',
#    'the',
#    'remaining',
#    'graded',
#    'site',
#    'is',
#    'also',
#    'proposed',
#    'within',
#    'the',
#    'site',
#    'design',
#    'services',
#    'electrical',
#    'water',
#    'sewage',
#    'and',
#    'communications',
#    'will',
#    'be',
#    'routed',
#    'into',
#    'the',
#    'new',
#    'lunchroom',
#    'and',
#    'travel',
#    'in',
#    'corridors',
#    'identified',
#    'on',
#    'the',
#    'site',
#    'drawing',
#    'all',
#    'corridors',
#    'have',
#    'been',
#    'previously',
#    'disturbed',
#    'by',
#    'either',
#    'road',
#    'construction',
#    'or',
#    'electrical',
#    'corridors',
#    'construction',
#    'is',
#    'expected',
#    'to',
#    'begin',
#    'in',
#    'june',
#    '2020',
#    'and',
#    'be',
#    'completed',
#    'by',
#    'october',
#    '2020',
#    'the',
#    'campground',
#    'entrance',
#    'was',
#    're',
#    'designed',
#    'and',
#    'reconstructed',
#    'in',
#    '2017',
#    'it',
#    'was',
#    'at',
#    'this',
#    'time',
#    'the',
#    'old',
#    'dumping',
#    'station',
#    'was',
#    'removed',
#    'and',
#    'the',
#    'site',
#    'rehabilitated',
#    'into',
#    'a',
#    'grass',
#    'field',
#    'last',
#    'fall',
#    'hurricane',
#    'dorian',
#    'made',
#    'landfall',
#    'on',
#    'pei',
#    'and',
#    'devastated',
#    'cavendish',
#    'campground',
#    'felling',
#    'the',
#    'majority',
#    'of',
#    'trees',
#    'in',
#    'the',
#    'area',
#    'any',
#    'softwood',
#    'trees',
#    'remaining',
#    'standing',
#    'were',
#    'removed',
#    'due',
#    'to',
#    'safety',
#    'reasons',
#    'therefore',
#    'there',
#    'are',
#    'almost',
#    'no',
#    'trees',
#    'remaining',
#    'in',
#    'the',
#    'area',
#    'where',
#    'the',
#    'lunch',
#    'room',
#    'is',
#    'to',
#    'be',
#    'constructed',
#    'this',
#    'work',
#    'is',
#    'being',
#    'tendered',
#    'for',
#    'contract',
#    'in',
#    'may',
#    '2020',
#    'with',
#    'work',
#    'beginning',
#    'in',
#    'june',
#    '2020',
#    'and',
#    'expected',
#    'to',
#    'be',
#    'completed',
#    'by',
#    'october',
#    '2020',
#    'the',
#    'history',
#    'of',
#    'the',
#    'site',
#    'was',
#    'originally',
#    'agricultural',
#    'crops',
#    'hay',
#    'potato',
#    'grain',
#    'clover',
#    'the',
#    'project',
#    'site',
#    'since',
#    'has',
#    'been',
#    'heavily',
#    'landscaped',
#    'to',
#    'facilitate',
#    'the',
#    'construction',
#    'of',
#    'the',
#    'campground',
#    'entrance',
#    'and',
#    'supporting',
#    'infrastructure',
#    'access',
#    'roads',
#    'grahams',
#    'lane',
#    'parking',
#    'lots',
#    'walking',
#    'trails',
#    'the',
#    'entrance',
#    'to',
#    'the',
#    'campground',
#    'has',
#    'been',
#    'majorly',
#    'reconfigured',
#    'at',
#    'least',
#    'three',
#    'times',
#    'in',
#    'the',
#    'past',
#    '70',
#    'years',
#    'as',
#    'is',
#    'evident',
#    'in',
#    'the',
#    'aerial',
#    'photos',
#    'all',
#    'roadways',
#    'would',
#    'have',
#    'had',
#    'major',
#    'amounts',
#    'of',
#    'fill',
#    'trucked',
#    'in',
#    'to',
#    'build',
#    'up',
#    'the',
#    'road',
#    'surfaces',
#    'back',
#    'ditches',
#    'would',
#    'have',
#    'been',
#    'heavily',
#    'landscaped',
#    'with',
#    'heavy',
#    'machinery',
#    'disturbing',
#    'anything',
#    'that',
#    'was',
#    'found',
#    'on',
#    'site',
#    'the',
#    'campground',
#    'had',
#    'an',
#    'eia',
#    'completed',
#    'in',
#    '2015',
#    'that',
#    'encompassed',
#    'developing',
#    'additional',
#    'camping',
#    'sites',
#    'throughout',
#    'the',
#    'campground',
#    'archaeological',
#    'test',
#    'pits',
#    'were',
#    'dug',
#    'and',
#    'the',
#    'area',
#    'was',
#    'assessed',
#    'for',
#    'cultural',
#    'impacts']),
#  (221,
#   ['parks',
#    'canada',
#    'is',
#    'proposing',
#    'to',
#    'construct',
#    'a',
#    'new',
#    'facility',
#    'to',
#    'conduct',
#    'watercraft',
#    'inspections',
#    'for',
#    'aquatic',
#    'invasive',
#    'species',
#    'the',
#    'inspection',
#    'station',
#    'will',
#    'be',
#    'constructed',
#    'on',
#    'an',
#    'existing',
#    'disturbed',
#    'footprint',
#    'near',
#    'the',
#    'park',
#    'entrance',
#    'gate',
#    'the',
#    'scope',
#    'of',
#    'work',
#    'may',
#    'include',
#    'minor',
#    'roadway',
#    'work',
#    'including',
#    'realignment',
#    'to',
#    'facilitate',
#    'vehicle',
#    'access',
#    'to',
#    'the',
#    'site',
#    'site',
#    'preparation',
#    'work',
#    'including',
#    'grading',
#    'paving',
#    'installation',
#    'of',
#    'a',
#    'washroom',
#    'facility',
#    'utility',
#    'work',
#    'and',
#    'installation',
#    'of',
#    'an',
#    'inspection',
#    'building',
#    'parks',
#    'canada',
#    'will',
#    'be',
#    'undertaking',
#    'a',
#    'basic',
#    'impact',
#    'assessment',
#    'to',
#    'assess',
#    'potential',
#    'project',
#    'related',
#    'impacts',
#    'to',
#    'natural',
#    'and',
#    'cultural',
#    'resources',
#    'from',
#    'this',
#    'project',
#    'assessment',
#    'pathway',
#    'was',
#    'changed',
#    'from',
#    'bia',
#    'to',
#    'pria',
#    'amendment',
#    'signed',
#    'august',
#    '12',
#    '2020',
#    'once',
#    'the',
#    'design',
#    'was',
#    'finalized',
#    'and',
#    'it',
#    'was',
#    'determined',
#    'that',
#    'the',
#    'footprint',
#    'remained',
#    'fully',
#    'in',
#    'zone',
#    'iv',
#    'and',
#    'did',
#    'not',
#    'enter',
#    'zone',
#    'ii']),
#  (238,
#   ['the',
#    'project',
#    'includes',
#    'mobilizing',
#    'and',
#    'staging',
#    'equipment',
#    'at',
#    'moose',
#    'island',
#    'fuel',
#    'heavy',
#    'equipment',
#    'flooding',
#    'pumps',
#    'chainsaws',
#    'etc',
#    'construction',
#    'of',
#    'the',
#    'ice',
#    'bridge',
#    'over',
#    'the',
#    'peace',
#    'river',
#    'ice',
#    'depth',
#    'measurements',
#    'removal',
#    'of',
#    'pack',
#    'ice',
#    'on',
#    'the',
#    'north',
#    'and',
#    'south',
#    'shore',
#    'of',
#    'the',
#    'peace',
#    'river',
#    'the',
#    'flooding',
#    'of',
#    'the',
#    'river',
#    'until',
#    'adequate',
#    'ice',
#    'depth',
#    'is',
#    'achieved',
#    'the',
#    'winter',
#    'road',
#    'then',
#    'continues',
#    'through',
#    'the',
#    'forest',
#    'which',
#    'requires',
#    'snow',
#    'removal',
#    'brushing',
#    'of',
#    'fallen',
#    'trees',
#    'willows',
#    'removal',
#    'of',
#    'large',
#    'rocks',
#    'tree',
#    'stumps',
#    'etc',
#    'coordination',
#    'is',
#    'required',
#    'with',
#    'the',
#    'southern',
#    'crew',
#    'working',
#    'at',
#    'the',
#    'fort',
#    'chipewyan',
#    'rocher',
#    'river',
#    'ice',
#    'crossing',
#    'maintenance',
#    'of',
#    'ice',
#    'bridge',
#    'winter',
#    'road',
#    'is',
#    'required',
#    'throughout',
#    'the',
#    'season',
#    'brushing',
#    'plowing',
#    'grading',
#    'of',
#    'ice',
#    'bridge',
#    'and',
#    'winter',
#    'road',
#    'and',
#    'further',
#    'ice',
#    'depth',
#    'measurements',
#    'take',
#    'place',
#    'on',
#    'the',
#    'peace',
#    'river',
#    'and',
#    'quatre',
#    'forche']),
#  (251,
#   ['snowmobiling',
#    'is',
#    'a',
#    'permitted',
#    'activity',
#    'in',
#    'designated',
#    'areas',
#    'of',
#    'gros',
#    'morne',
#    'national',
#    'park',
#    'a',
#    'snowmobile',
#    'access',
#    'route',
#    'that',
#    'has',
#    'been',
#    'used',
#    'by',
#    'local',
#    'residents',
#    'is',
#    'now',
#    'being',
#    'proposed',
#    'for',
#    'public',
#    'and',
#    'commercial',
#    'use',
#    'this',
#    'route',
#    'covers',
#    '179',
#    '8',
#    'hectares',
#    'and',
#    'will',
#    'travel',
#    'for',
#    'approximately',
#    '12',
#    'kilometers',
#    'from',
#    'woody',
#    'point',
#    'to',
#    'trout',
#    'river',
#    'alongside',
#    'highway',
#    'route',
#    '431',
#    'trout',
#    'river',
#    'gulch',
#    'other',
#    'than',
#    'the',
#    'placement',
#    'of',
#    'signage',
#    'at',
#    'entrance',
#    'points',
#    'no',
#    'construction',
#    'activities',
#    'are',
#    'required',
#    'in',
#    'addition',
#    'to',
#    'this',
#    'access',
#    'route',
#    'a',
#    '1',
#    '541',
#    '5',
#    'hectare',
#    'snowmobile',
#    'exclusion',
#    'zone',
#    'will',
#    'be',
#    'created',
#    'on',
#    'the',
#    'northwest',
#    'facing',
#    'slope',
#    'of',
#    'the',
#    'tablelands',
#    'therefore',
#    'there',
#    'will',
#    'be',
#    'a',
#    'significant',
#    'net',
#    'reduction',
#    'in',
#    'areas',
#    'open',
#    'to',
#    'snowmobiling',
#    'most',
#    'of',
#    'the',
#    'new',
#    'snowmobile',
#    'corridor',
#    '134',
#    '8',
#    'hectares',
#    'passes',
#    'through',
#    'areas',
#    'designated',
#    'as',
#    'zone',
#    'iii',
#    'natural',
#    'environment',
#    'whereas',
#    'the',
#    'majority',
#    'of',
#    'the',
#    'expanded',
#    'exclusion',
#    'area',
#    '1',
#    '195',
#    '3',
#    'hectares',
#    'is',
#    'designated',
#    'as',
#    'zone',
#    'ii',
#    'wilderness']),
#  (250,
#   ['the',
#    'existing',
#    'culvert',
#    'was',
#    'originally',
#    'constructed',
#    'in',
#    '1957',
#    'and',
#    'is',
#    'in',
#    'poor',
#    'condition',
#    'with',
#    'spalls',
#    'exposed',
#    'rebar',
#    'and',
#    'wide',
#    'cracks',
#    'the',
#    'existing',
#    'culvert',
#    'is',
#    '5',
#    '5',
#    'm',
#    'wide',
#    'by',
#    '1',
#    '8',
#    'm',
#    'high',
#    'and',
#    'is',
#    'a',
#    'combination',
#    'of',
#    'concrete',
#    'open',
#    'footing',
#    'culvert',
#    'and',
#    'concrete',
#    'box',
#    'culvert',
#    'the',
#    'proposed',
#    'replacement',
#    'consists',
#    'of',
#    'a',
#    '6',
#    'm',
#    'x',
#    '2',
#    '5',
#    'm',
#    'cast',
#    'in',
#    'place',
#    'concrete',
#    'open',
#    'footing',
#    'culvert',
#    'supported',
#    'on',
#    'steel',
#    'h',
#    'piles',
#    'on',
#    'the',
#    'existing',
#    'alignment',
#    'the',
#    'culvert',
#    'will',
#    'include',
#    'cast',
#    'in',
#    'place',
#    'concrete',
#    'wingwalls',
#    'supported',
#    'on',
#    'steel',
#    'h',
#    'piles',
#    'the',
#    'proposed',
#    'culvert',
#    'has',
#    'adequate',
#    'capacity',
#    'to',
#    'convey',
#    'the',
#    '25',
#    'year',
#    'design',
#    'storm',
#    'and',
#    'check',
#    'flood',
#    'without',
#    'overtopping',
#    'the',
#    'roadway',
#    'during',
#    'the',
#    'replacement',
#    'the',
#    'flow',
#    'will',
#    'be',
#    'maintained',
#    'through',
#    'a',
#    'temporary',
#    'bypass',
#    'pipe',
#    'the',
#    'work',
#    'has',
#    'been',
#    'divided',
#    'into',
#    'two',
#    'phases',
#    'phase',
#    '1',
#    'in',
#    'fall',
#    '2019',
#    'involves',
#    'installation',
#    'of',
#    'the',
#    'bypass',
#    'system',
#    'and',
#    'phase',
#    '2',
#    'in',
#    '2020',
#    'involves',
#    'the',
#    'culvert',
#    'replacement',
#    'the',
#    'work',
#    'has',
#    'been',
#    'classified',
#    'as',
#    'a',
#    'group',
#    'c',
#    'project',
#    'under',
#    'the',
#    'mto',
#    'class',
#    'ea',
#    'in',
#    'which',
#    'an',
#    'environmental',
#    'screening',
#    'document',
#    'has',
#    'been',
#    'prepared',
#    'this',
#    'provincial',
#    'level',
#    'ea',
#    'will',
#    'be',
#    'evaluated',
#    'against',
#    'federal',
#    'requirements',
#    'and',
#    'any',
#    'gaps',
#    'will',
#    'be',
#    'filled',
#    'within',
#    'the',
#    'bia']),
#  (264,
#   ['parks',
#    'canada',
#    'fire',
#    'management',
#    'team',
#    'in',
#    'waterton',
#    'lakes',
#    'national',
#    'park',
#    'has',
#    'proposed',
#    'the',
#    'implementation',
#    'of',
#    'a',
#    'prescribed',
#    'fire',
#    'in',
#    'the',
#    'y',
#    'camp',
#    'wishbone',
#    'area',
#    'of',
#    'the',
#    'park',
#    'the',
#    'ecological',
#    'objective',
#    'of',
#    'the',
#    'fire',
#    'is',
#    'to',
#    'reverse',
#    'the',
#    'trend',
#    'of',
#    'aspen',
#    'tree',
#    'encroachment',
#    'onto',
#    'what',
#    'was',
#    'historically',
#    'fescue',
#    'grassland',
#    'and',
#    'to',
#    'restore',
#    'the',
#    'mean',
#    'fire',
#    'interval',
#    'of',
#    '5',
#    'years',
#    'to',
#    'the',
#    'fescue',
#    'grassland',
#    'and',
#    'aspen',
#    'parkland',
#    'ecoregions',
#    'of',
#    'the',
#    'park',
#    'the',
#    'fescue',
#    'grassland',
#    'provides',
#    'critical',
#    'habitat',
#    'for',
#    'a',
#    'variety',
#    'of',
#    'species',
#    'in',
#    'and',
#    'outside',
#    'of',
#    'the',
#    'park',
#    'the',
#    'burn',
#    'unit',
#    'is',
#    'located',
#    'on',
#    'the',
#    'east',
#    'side',
#    'of',
#    'lower',
#    'waterton',
#    'lake',
#    'and',
#    'waterton',
#    'river',
#    'just',
#    'south',
#    'of',
#    'highway',
#    '6',
#    'and',
#    'encompasses',
#    'an',
#    'area',
#    'of',
#    '1',
#    '170',
#    'ha',
#    'fire',
#    'operations',
#    'would',
#    'take',
#    'place',
#    'in',
#    'the',
#    'winter',
#    'pre',
#    'guard',
#    'burning',
#    'and',
#    'spring',
#    'main',
#    'unit',
#    'burning',
#    'of',
#    '2020',
#    'before',
#    'leaf',
#    'out',
#    'execution',
#    'of',
#    'this',
#    'burn',
#    'would',
#    'take',
#    'place',
#    'every',
#    '5',
#    'years',
#    'thereafter',
#    'under',
#    'the',
#    'same',
#    'conditions',
#    'to',
#    'continue',
#    'with',
#    'the',
#    'trend',
#    'of',
#    'the',
#    'reduction',
#    'of',
#    'aspen',
#    'parkland',
#    'encroachment',
#    'into',
#    'the',
#    'fescue',
#    'grasslands',
#    'ecoregion']),
#  (139,
#   ['grasslands',
#    'national',
#    'park',
#    'is',
#    'partnering',
#    'with',
#    'saskpower',
#    'to',
#    'remove',
#    '10',
#    'km',
#    'of',
#    'overhead',
#    'service',
#    'line',
#    'in',
#    'the',
#    'west',
#    'block',
#    'of',
#    'the',
#    'park',
#    'replacing',
#    'it',
#    'with',
#    'a',
#    'partially',
#    'buried',
#    'service',
#    'line',
#    'the',
#    'existing',
#    'overhead',
#    'line',
#    'crosses',
#    'through',
#    'prairie',
#    'while',
#    'the',
#    'replacement',
#    'line',
#    'will',
#    'follow',
#    'the',
#    'existing',
#    'public',
#    'access',
#    'road',
#    'the',
#    'public',
#    'access',
#    'road',
#    'intersects',
#    'a',
#    'black',
#    'tailed',
#    'prairie',
#    'dog',
#    'colony',
#    'and',
#    'work',
#    'will',
#    'occur',
#    'on',
#    'lands',
#    'protected',
#    'by',
#    'the',
#    'emergency',
#    'order',
#    'for',
#    'the',
#    'protection',
#    'of',
#    'the',
#    'greater',
#    'sage',
#    'grouse',
#    '2013',
#    'the',
#    'proposed',
#    'project',
#    'will',
#    'work',
#    'towards',
#    'conservation',
#    'goals',
#    'for',
#    'the',
#    'greater',
#    'sage',
#    'grouse',
#    'by',
#    'removing',
#    'power',
#    'poles',
#    'in',
#    'critical',
#    'habitat',
#    'tall',
#    'vertical',
#    'structures',
#    'in',
#    'critical',
#    'habitat',
#    'are',
#    'identified',
#    'by',
#    'the',
#    'recovery',
#    'strategy',
#    'for',
#    'this',
#    'species',
#    'as',
#    'a',
#    'chronic',
#    'disturbance',
#    'that',
#    'threatens',
#    'their',
#    'recovery',
#    'and',
#    'survival',
#    'this',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (112,
#   ['many',
#    'decades',
#    'of',
#    'high',
#    'intensity',
#    'browsing',
#    'by',
#    'deer',
#    'on',
#    'sidney',
#    'island',
#    'has',
#    'greatly',
#    'reduced',
#    'the',
#    'abundance',
#    'and',
#    'diversity',
#    'of',
#    'plants',
#    'in',
#    'the',
#    'forest',
#    'understory',
#    'the',
#    'result',
#    'of',
#    'this',
#    'pressure',
#    'is',
# ...
#    'and',
#    'adding',
#    '7',
#    'new',
#    'buoys',
#    'to',
#    'the',
#    'existing',
#    'mooring',
#    'field',
#    'the',
#    'second',
#    'portion',
#    'of',
#    'the',
#    'project',
#    'seeks',
#    'to',
#    'improve',
#    'the',
#    'existing',
#    'closure',
#    'at',
#    'the',
#    'sidney',
#    'lagoon',
#    'by',
#    'adding',
#    'regulatory',
#    'signage',
#    'and',
#    'closure',
#    'notices',
#    'at',
#    'the',
#    'entrance',
#    'and',
#    'replacing',
#    'one',
#    'special',
#    'purpose',
#    'buoy',
#    'the',
#    'sidney',
#    'lagoon',
#    'is',
#    'classified',
#    'as',
#    'a',
#    'zone',
#    'one',
#    'special',
#    'preservation',
#    'area',
#    'and',
#    'has',
#    'been',
#    'closed',
#    'to',
#    'the',
#    'public',
#    'since',
#    '2008',
#    'this',
#    'project',
#    'seeks',
#    'to',
#    'replace',
#    'one',
#    'missing',
#    'special',
#    'purpose',
#    'closure',
#    'buoy',
#    'at',
#    'the',
#    'entrance',
#    'of',
#    'the',
#    'lagoon',
#    'and',
#    'add',
#    'additional',
#    'signage',
#    'to',
#    'ensure',
#    'visitors',
#    'are',
#    'informed',
#    'of',
#    'the',
#    'lagoon',
#    'closure']),
#  (235,
#   ['the',
#    'wildfire',
#    'risk',
#    'reduction',
#    'project',
#    'entails',
#    'the',
#    'selective',
#    'removal',
#    'thinning',
#    'and',
#    'pruning',
#    'of',
#    'trees',
#    'using',
#    'fuel',
#    'management',
#    'and',
#    'firesmart',
#    'principles',
#    'to',
#    'reduce',
#    'fuel',
#    'loading',
#    'proposed',
#    'treatment',
#    'areas',
#    'are',
#    'strategically',
#    'located',
#    'within',
#    'the',
#    'gulf',
#    'islands',
#    'national',
#    'park',
#    'reserve',
#    'in',
#    'order',
#    'to',
#    'reduce',
#    'the',
#    'wildfire',
#    'risk',
#    'to',
#    'park',
#    'properties',
#    'adjacent',
#    'residents',
#    'and',
#    'island',
#    'communities',
#    'while',
#    'also',
#    'providing',
#    'safer',
#    'work',
#    'areas',
#    'for',
#    'firefighters',
#    'in',
#    'the',
#    'event',
#    'of',
#    'an',
#    'wildland',
#    'urban',
#    'interface',
#    'fire',
#    'project',
#    'locations',
#    'include',
#    'tumbo',
#    'island',
#    'north',
#    'edge',
#    'of',
#    'wetland',
#    'saturna',
#    'island',
#    'mt',
#    'warburton',
#    'pike',
#    'summit',
#    'parking',
#    'lot',
#    'area',
#    'and',
#    'north',
#    'pender',
#    'island',
#    'south',
#    'of',
#    'roe',
#    'lake',
#    'adjacent',
#    'to',
#    'the',
#    'park',
#    'reserve',
#    'boundary',
#    'project',
#    'work',
#    'is',
#    'proposed',
#    'for',
#    'mid',
#    'january',
#    'to',
#    'mid',
#    'march',
#    '2020',
#    'location',
#    'latitude',
#    'and',
#    'longitude',
#    'are',
#    'for',
#    'the',
#    'pender',
#    'island',
#    'site']),
#  (161,
#   ['the',
#    'parks',
#    'canada',
#    'agency',
#    'pca',
#    'has',
#    'proposed',
#    'to',
#    'construct',
#    'a',
#    'new',
#    'segment',
#    'of',
#    'approximately',
#    '10',
#    'km',
#    'linear',
#    'trail',
#    'that',
#    'will',
#    'connect',
#    'two',
#    'existing',
#    'trail',
#    'segments',
#    'bob',
#    'hunter',
#    'memorial',
#    'park',
#    'and',
#    'boyle',
#    's',
#    'cemetery',
#    'the',
#    'trail',
#    'is',
#    'intended',
#    'to',
#    'be',
#    'multi',
#    'use',
#    'and',
#    'primarily',
#    'aggregate',
#    'surface',
#    'with',
#    'boardwalk',
#    'where',
#    'required',
#    'in',
#    'wet',
#    'areas',
#    'and',
#    'crossings',
#    'over',
#    'the',
#    'little',
#    'rouge',
#    'river',
#    'it',
#    'will',
#    'also',
#    'connect',
#    'with',
#    'the',
#    'proposed',
#    'markham',
#    'gateway',
#    'welcome',
#    'area',
#    'fencing',
#    'will',
#    'be',
#    'used',
#    'to',
#    'separate',
#    'the',
#    'trail',
#    'from',
#    'active',
#    'farming',
#    'operations',
#    'pedestrian',
#    'road',
#    'crossings',
#    'will',
#    'occur',
#    'at',
#    'major',
#    'mackenzie',
#    '16th',
#    'avenue',
#    'highway',
#    '7',
#    '407',
#    'and',
#    '14th',
#    'avenue',
#    'routing',
#    'options',
#    'around',
#    'or',
#    'through',
#    'private',
#    'property',
#    'with',
#    'owner',
#    's',
#    'permission',
#    'and',
#    'a',
#    'small',
#    'capacity',
#    'parking',
#    'lot',
#    'on',
#    'major',
#    'mac',
#    'or',
#    '16th',
#    'ave',
#    'will',
#    'be',
#    'investigated']),
#  (59,
#   ['grasslands',
#    'national',
#    'park',
#    'is',
#    'proposing',
#    'to',
#    'install',
#    'a',
#    'weather',
#    'station',
#    'in',
#    'the',
#    'west',
#    'block',
#    'of',
#    'the',
#    'park',
#    'the',
#    'station',
#    'will',
#    'provide',
#    'real',
#    'time',
#    'weather',
#    'information',
#    'in',
#    'an',
#    'area',
#    'that',
#    'otherwise',
#    'has',
#    'little',
#    'coverage',
#    'and',
#    'this',
#    'information',
#    'will',
#    'be',
#    'used',
#    'to',
#    'support',
#    'the',
#    'fire',
#    'and',
#    'visitor',
#    'safety',
#    'programs',
#    'the',
#    'station',
#    'itself',
#    'is',
#    '3',
#    'm',
#    'tall',
#    'with',
#    'a',
#    '1',
#    'm2',
#    'tripod',
#    'base',
#    'requires',
#    'anchors',
#    'to',
#    'secure',
#    'and',
#    'will',
#    'also',
#    'require',
#    'a',
#    'cattle',
#    'exclusion',
#    'typically',
#    'a',
#    'fence',
#    'to',
#    'prevent',
#    'damage',
#    'from',
#    'cattle',
#    'the',
#    'weather',
#    'station',
#    'needs',
#    'to',
#    'be',
#    'sited',
#    'strategically',
#    'to',
#    'avoid',
#    'obstructions',
#    'or',
#    'other',
#    'features',
#    'that',
#    'might',
#    'bias',
#    'weather',
#    'readings',
#    'but',
#    'must',
#    'also',
#    'take',
#    'into',
#    'account',
#    'other',
#    'sensitive',
#    'features',
#    'such',
#    'as',
#    'critical',
#    'habitat',
#    'for',
#    'species',
#    'at',
#    'risk',
#    'and',
#    'cultural',
#    'resources',
#    'this',
#    'project',
#    'will',
#    'be',
#    'assessed',
#    'with',
#    'a',
#    'basic',
#    'impact',
#    'assessment']),
#  (160,
#   ['in',
#    'an',
#    'effort',
#    'to',
#    'manage',
#    'the',
#    'impacts',
#    'of',
#    'deer',
#    'browse',
#    'in',
#    'sensitive',
#    'areas',
#    'of',
#    'rnup',
#    'and',
#    'to',
#    'study',
#    'differences',
#    'in',
#    'browse',
#    'levels',
#    'when',
#    'deer',
#    'are',
#    'excluded',
#    'from',
#    'these',
#    'areas',
#    'approximately',
#    '600',
#    'metres',
#    'of',
#    'deer',
#    'exclusion',
#    'fencing',
#    'will',
#    'be',
#    'installed',
#    'in',
#    'a',
#    'forested',
#    'plot',
#    'in',
#    'rnup',
#    'the',
#    'fencing',
#    'will',
#    'be',
#    'installed',
#    'about',
#    '25',
#    'meters',
#    'off',
#    'of',
#    'a',
#    'main',
#    'road',
#    'and',
#    'continue',
#    'about',
#    '145',
#    'meters',
#    'into',
#    'the',
#    'interior',
#    'of',
#    'the',
#    'forest',
#    'a',
#    'city',
#    'of',
#    'toronto',
#    'road',
#    'closure',
#    'permit',
#    'will',
#    'be',
#    'required',
#    'for',
#    'the',
#    'duration',
#    'of',
#    'this',
#    'project',
#    'the',
#    'area',
#    'surrounding',
#    'the',
#    'site',
#    'is',
#    'a',
#    'densely',
#    'forested',
#    'area',
#    'with',
#    'a',
#    'healthy',
#    'understory',
#    'there',
#    'are',
#    'few',
#    'social',
#    'trails',
#    'through',
#    'the',
#    'area',
#    'that',
#    'should',
#    'be',
#    'used',
#    'as',
#    'access',
#    'routes',
#    'where',
#    'possible',
#    'to',
#    'minimize',
#    'disturbance']),
#  (114,
#   ['parks',
#    'canada',
#    'is',
#    'proposing',
#    'to',
#    'install',
#    'four',
#    'remote',
#    'avalanche',
#    'control',
#    'system',
#    'racs',
#    'units',
#    'on',
#    'mt',
#    'whymper',
#    'currently',
#    'parks',
#    'canada',
#    'agency',
#    'performs',
#    'avalanche',
#    'control',
#    'by',
#    'placing',
#    'explosives',
#    'from',
#    'helicopters',
#    'in',
#    'starting',
#    'zones',
#    'of',
#    'mt',
#    'whymper',
#    'however',
#    'control',
#    'by',
#    'helicopter',
#    'is',
#    'often',
#    'limited',
#    'by',
#    'poor',
#    'visibility',
#    'and',
#    'wind',
#    'in',
#    'the',
#    'starting',
#    'zones',
#    'effecting',
#    'timing',
#    'and',
#    'efficiency',
#    'of',
#    'avalanche',
#    'control',
#    'and',
#    'exposing',
#    'workers',
#    'to',
#    'challenging',
#    'flying',
#    'conditions',
#    'and',
#    'explosives',
#    'use',
#    'the',
#    'rationale',
#    'for',
#    'racs',
#    'in',
#    'these',
#    'paths',
#    'is',
#    'to',
#    'reduce',
#    'impacts',
#    'to',
#    'highway',
#    '93',
#    'south',
#    'highway',
#    'closure',
#    'time',
#    'and',
#    'gains',
#    'in',
#    'operational',
#    'efficiency',
#    'and',
#    'worker',
#    'safety',
#    'the',
#    'total',
#    'footprint',
#    'for',
#    'four',
#    'gazex',
#    'racs',
#    'units',
#    'including',
#    'foundations',
#    'shelters',
#    'and',
#    'pipelines',
#    'is',
#    '230',
#    'm',
#    'a',
#    'maximum',
#    'of',
#    'three',
#    'leveled',
#    'work',
#    'pads',
#    'will',
#    'be',
#    'required',
#    'per',
#    'site',
#    '72',
#    'm²',
#    'footprint',
#    'one',
#    'or',
#    'two',
#    'permanent',
#    'helipads',
#    'may',
#    'also',
#    'be',
#    'required',
#    '50',
#    'm²',
#    'maximum',
#    'footprint']),
#  (272,
#   ['hunters',
#    'lake',
#    'is',
#    'a',
#    'one',
#    'way',
#    'trail',
#    'that',
#    'incorporates',
#    'various',
#    'landscape',
#    'features',
#    'including',
#    'jack',
#    'pine',
#    'ridges',
#    'aspen',
#    'forest',
#    'and',
#    'aquatic',
#    'ecosytems',
#    'during',
#    'a',
#    'large',
#    'fire',
#    'that',
#    'burnt',
#    'throught',
#    'the',
#    'area',
#    'in',
#    '2018',
#    'heavy',
#    'equipment',
#    'was',
#    'brought',
#    'in',
#    'to',
#    'create',
#    'fire',
#    'breaks',
#    'and',
#    'the',
#    'trail',
#    'sustained',
#    'major',
#    'damage',
#    'a',
#    'reroute',
#    'was',
#    'cut',
#    'around',
#    'a',
#    'waterbody',
#    'trees',
#    'were',
#    'felled',
#    'and',
#    'left',
#    'on',
#    'site',
#    'causing',
#    'a',
#    'public',
#    'safety',
#    'hazard',
#    'the',
#    'project',
#    'involves',
#    'bringing',
#    'in',
#    'a',
#    'heavy',
#    'duty',
#    'mulcher',
#    'to',
#    'mulch',
#    'the',
#    'trees',
#    'on',
#    'site',
#    'at',
#    'the',
#    'trail',
#    'reroute',
#    'location',
#    'as',
#    'well',
#    'as',
#    'to',
#    'the',
#    'end',
#    'of',
#    'the',
#    'trail',
#    'where',
#    'regrowth',
#    'is',
#    'now',
#    'too',
#    'heavy',
#    'to',
#    'be',
#    'mown',
#    'with',
#    'traditional',
#    'equipment',
#    'aggregate',
#    'gravel',
#    'will',
#    'be',
#    'hauled',
#    'into',
#    'the',
#    'site',
#    'to',
#    'build',
#    'up',
#    'a',
#    'trail',
#    'tread',
#    'on',
#    'the',
#    'reroute',
#    'and',
#    'any',
#    'other',
#    'areas',
#    'that',
#    'need',
#    'to',
#    'be',
#    'resurfaced',
#    'a',
#    'culvert',
#    'will',
#    'be',
#    'installed',
#    'at',
#    'a',
#    'low',
#    'spot',
#    'on',
#    'the',
#    'trail']),
#  (260,
#   ['parks',
#    'canada',
#    'proposes',
#    'to',
#    'remove',
#    'and',
#    'decommission',
#    'three',
#    'structures',
#    'that',
#    'are',
#    'no',
#    'longer',
#    'operationally',
#    'viable',
#    'including',
#    'a',
#    'horse',
#    'barn',
#    'a',
#    'tack',
#    'shed',
#    'and',
#    'a',
#    'pump',
#    'house',
#    'located',
#    'at',
#    'kootenay',
#    'crossing',
#    'in',
#    'kootenay',
#    'national',
#    'park',
#    'all',
#    'materials',
#    'being',
#    'stored',
#    'on',
#    'site',
#    'will',
#    'also',
#    'be',
#    'removed',
#    'a',
#    'second',
#    'phase',
#    'of',
#    'this',
#    'project',
#    'may',
#    'occur',
#    'and',
#    'will',
#    'involve',
#    'the',
#    'rehabilitation',
#    'of',
#    'the',
#    'area',
#    'involving',
#    'the',
#    're',
#    'contouring',
#    'reclamation',
#    'and',
#    're',
#    'vegetation',
#    'of',
#    'the',
#    'site',
#    'the',
#    'project',
#    'is',
#    'located',
#    '43',
#    'kilometres',
#    'km',
#    'north',
#    'of',
#    'the',
#    'intersection',
#    'of',
#    'highway',
#    '93',
#    'and',
#    'highway',
#    '95',
#    'in',
#    'the',
#    'village',
#    'of',
#    'radium',
#    'hot',
#    'springs',
#    'it',
#    'is',
#    'on',
#    'the',
#    'west',
#    'side',
#    'of',
#    'highway',
#    '93',
#    'south',
#    'in',
#    'kootenay',
#    'national',
#    'park',
#    'and',
#    'past',
#    'parks',
#    'canada',
#    'fire',
#    'operations',
#    'facilities',
#    'which',
#    'are',
#    'currently',
#    'in',
#    'use',
#    'this',
#    'project',
#    'will',
#    'reduce',
#    'infrastructure',
#    'no',
#    'longer',
#    'required',
#    'in',
#    'the',
#    'park',
#    'reduce',
#    'operational',
#    'and',
#    'maintenance',
#    'cost',
#    'restore',
#    'the',
#    'area',
#    'to',
#    'its',
#    'natural',
#    'condition',
#    'and',
#    'improve',
#    'important',
#    'wildlife',
#    'habitat',
#    'and',
#    'corridors',
#    'in',
#    'the',
#    'kootenay',
#    'crossing',
#    'area',
#    'removal',
#    'of',
#    'these',
#    'facilities',
#    'restoration',
#    'of',
#    'the',
#    'area',
#    'and',
#    'reduction',
#    'in',
#    'human',
#    'use',
#    'will',
#    'contribute',
#    'to',
#    'park',
#    's',
#    'canada',
#    'general',
#    'objective',
#    'to',
#    'maintain',
#    'or',
#    'improve',
#    'ecological',
#    'integrity']),
#  (243,
#   ['saskpower',
#    'is',
#    'proposing',
#    'to',
#    'replace',
#    'an',
#    'urban',
#    'power',
#    'pole',
#    'transformer',
#    'and',
#    'take',
#    'off',
#    'equipment',
#    'then',
#    'trench',
#    'and',
#    'lay',
#    'approximately',
#    '30',
#    'metres',
#    'm',
#    'of',
#    'secondary',
#    'cable',
#    'to',
#    'a',
#    'customer',
#    'owned',
#    'splitter',
#    'at',
#    'which',
#    'point',
#    'the',
#    'customer',
#    'will',
#    'be',
#    'responsible',
#    'to',
#    'connections',
#    'ground',
#    'disturbance',
#    'will',
#    'be',
#    'limited',
#    'to',
#    'the',
#    'base',
#    'of',
#    'the',
#    'pole',
#    'and',
#    'the',
#    'short',
#    'run',
#    'of',
#    'trenching',
#    'the',
#    'work',
#    'will',
#    'take',
#    'place',
#    'near',
#    'an',
#    'existing',
#    'underground',
#    'cable',
#    'within',
#    'a',
#    'developed',
#    'area',
#    'and',
#    'existing',
#    'roadways',
#    'in',
#    'nw',
#    '10',
#    '057',
#    '01',
#    'w3m',
#    'within',
#    'the',
#    'waskesiu',
#    'townsite',
#    'in',
#    'prince',
#    'albert',
#    'national',
#    'park',
#    'the',
#    'project',
#    'the',
#    'project',
#    'is',
#    'required',
#    'to',
#    'provide',
#    'an',
#    'additional',
#    'service',
#    'point',
#    'near',
#    'the',
#    'library',
#    'recreation',
#    'hall',
#    'equipment',
#    'that',
#    'is',
#    'expected',
#    'to',
#    'be',
#    'used',
#    'for',
#    'completion',
#    'of',
#    'the',
#    'project',
#    'includes',
#    'a',
#    'digger',
#    'truck',
#    'back',
#    'hoe',
#    'trenching',
#    'equipment',
#    'and',
#    'crew',
#    'trucks',
#    'access',
#    'to',
#    'components',
#    'of',
#    'the',
#    'project',
#    'will',
#    'make',
#    'use',
#    'of',
#    'existing',
#    'roads',
#    'and',
#    'trails',
#    'surface',
#    'disturbance',
#    'is',
#    'expected',
#    'to',
#    'be',
#    'minimized',
#    'to',
#    'the',
#    'base',
#    'of',
#    'the',
#    'pole',
#    'and',
#    '30',
#    'm',
#    'of',
#    'trenching']),
#  (274,
#   ['in',
#    'an',
#    'effort',
#    'to',
#    'reduce',
#    'road',
#    'mortality',
#    'and',
#    'nest',
#    'predation',
#    'for',
#    'rare',
#    'turtles',
#    'thousand',
#    'islands',
#    'national',
#    'park',
#    'is',
#    'planning',
#    'to',
#    'build',
#    'a',
#    'small',
#    'artificial',
#    'nesting',
#    'site',
#    'near',
#    'polly',
#    'creek',
#    'the',
#    'site',
#    'will',
#    'be',
#    'approximately',
#    '5m',
#    'x',
#    '5m',
#    'large',
#    'and',
#    '1m',
#    'deep',
#    'consisting',
#    'of',
#    'sand',
#    'and',
#    'gravel',
#    'surrounded',
#    'by',
#    'cedar',
#    'logs',
#    'turtles',
#    'in',
#    'the',
#    'area',
#    'are',
#    'experiencing',
#    'significant',
#    'road',
#    'mortality',
#    'and',
#    'are',
#    'primarily',
#    'nesting',
#    'on',
#    'road',
#    'shoulders',
#    'where',
#    'near',
#    'complete',
#    'nest',
#    'predation',
#    'has',
#    'been',
#    'documented',
#    'the',
#    'artificial',
#    'nest',
#    'site',
#    'should',
#    'reduce',
#    'the',
#    'number',
#    'of',
#    'turtles',
#    'coming',
#    'onto',
#    'and',
#    'alongside',
#    'the',
#    'road',
#    'materials',
#    'will',
#    'be',
#    'brought',
#    'to',
#    'the',
#    'site',
#    'using',
#    'a',
#    'small',
#    'tractor',
#    'and',
#    'or',
#    'a',
#    'motorised',
#    'wheelbarrow',
#    'and',
#    'construction',
#    'is',
#    'planned',
#    'for',
#    'october',
#    '10',
#    'before',
#    'turtle',
#    'hibernation',
#    'begins'])]

# %% [markdown]
# #### Remove stopwords

# %%
stop_words = set(stopwords.words('english')) # set stopwords

filtered_words = [ (ID, [word for word in words if word not in stop_words]) for ID, words in datawords]
pprint(filtered_words)
# Out:
# [(87,
#   ['purpose',
#    'project',
#    'reduce',
#    'risk',
#    'wildfire',
#    'fort',
#    'walsh',
#    'national',
#    'historic',
#    'site',
#    'thinning',
#    'pockets',
#    'fuel',
#    'two',
#    'forested',
#    'areas',
#    'near',
#    'fort',
#    'site',
#    'total',
#    'area',
#    'treated',
#    '25',
#    'ha',
#    'absence',
#    'fire',
#    'maturity',
#    'forest',
#    'around',
#    'fort',
#    'site',
#    'resulted',
#    'accumulation',
#    'ladder',
#    'fuels',
#    'old',
#    'dying',
#    'mature',
#    'trees',
#    'downed',
#    'woody',
#    'material',
#    'reducing',
#    'fuel',
#    'load',
#    'site',
#    'removing',
#    'trees',
#    'administering',
#    'various',
#    'firesmart',
#    'techniques',
#    'stand',
#    'thinning',
#    'ladder',
#    'fuel',
#    'removal',
#    'etc',
#    'impact',
#    'wildfire',
#    'site',
#    'reduced',
#    'ladder',
#    'fuels',
#    'removed',
#    'tree',
#    'limbs',
#    'pruned',
#    'height',
#    '2m',
#    'using',
#    'chainsaws',
#    'various',
#    'hand',
#    'tools',
#    'dense',
#    'areas',
#    'thinned',
#    'hand',
#    'felling',
#    'deadfall',
#    'also',
#    'removed',
#    'hand',
#    'project',
#    'assessed',
#    'basic',
#    'impact',
#    'assessment']),
#  (110,
#   ['armoured',
#    'stone',
#    'seawall',
#    'located',
#    'around',
#    'perimeter',
#    'shoreline',
#    'adjacent',
#    'st',
#    'andrews',
#    'blockhouse',
#    'national',
#    'historic',
#    'site',
#    'provides',
#    'protection',
#    'erosion',
#    'water',
#    'wave',
#    'action',
#    'passamaquoddy',
#    'bay',
#    'recent',
#    'inspection',
#    'seawall',
#    'identified',
#    'number',
#    'deficiencies',
#    'could',
#    'result',
#    'potential',
#    'failure',
#    'structure',
#    'cause',
#    'erosion',
#    'site',
#    'shoreline',
#    'protection',
#    'seawall',
#    'repairs',
#    'project',
#    'intends',
#    'rehabilitate',
#    'stone',
#    'seawall',
#    'repairing',
#    'damaged',
#    'areas',
#    'along',
#    'structure',
#    'displaced',
#    'stones',
#    'temporary',
#    'removed',
#    'allow',
#    'necessary',
#    'work',
#    'repair',
#    'raise',
#    'degraded',
#    'bed',
#    'geotextile',
#    'fabric',
#    'installed',
#    'reinstating',
#    'stone',
#    'areas',
#    'displaced',
#    'stones',
#    'currently',
#    'sitting',
#    'ocean',
#    'floor',
#    'collected',
#    'fitted',
#    'back',
#    'place',
#    'addition',
#    'previously',
#    'placed',
#    'concrete',
#    'pieces',
#    'removed',
#    'replaced',
#    'stone']),
#  (197,
#   ['fisheries',
#    'act',
#    'authorization',
#    'required',
#    'dfo',
#    'relation',
#    'impacts',
#    'fish',
#    'habitat',
#    'associated',
#    'dam',
#    'construction',
#    'projects',
#    'tsw',
#    'trenton',
#    'dam',
#    '1',
#    'glen',
#    'miller',
#    'dam',
#    '3',
#    'authorization',
#    'includes',
#    'provisions',
#    'offsetting',
#    'measures',
#    'construction',
#    'big',
#    'island',
#    'causeway',
#    '1950',
#    'decreased',
#    'water',
#    'flows',
#    'island',
#    'mainland',
#    'caused',
#    'channels',
#    'filled',
#    'silt',
#    'cattails',
#    'cover',
#    'entire',
#    'area',
#    'island',
#    'mainland',
#    'parks',
#    'canada',
#    'proposing',
#    'expand',
#    'existing',
#    'fish',
#    'habitat',
#    'enhancements',
#    'big',
#    'island',
#    'marsh',
#    'constructing',
#    'new',
#    'channel',
#    'widening',
#    'deepening',
#    '2',
#    'existing',
#    'channels',
#    'cattail',
#    'marsh',
#    'vegetation',
#    'removed',
#    'width',
#    '10',
#    'depths',
#    '3',
#    '0',
#    'order',
#    'ensure',
#    'areas',
#    'stay',
#    'open',
#    'future',
#    'fisheries',
#    'offset',
#    'plan',
#    'expected',
#    'result',
#    'enhancement',
#    'fish',
#    'habitat',
#    'big',
#    'island',
#    'marsh']),
#  (111,
#   ['may',
#    '2018',
#    'rabbit',
#    'creek',
#    'wildfire',
#    'occurred',
#    'prince',
#    'albert',
#    'national',
#    'park',
#    'spread',
#    'within',
#    'outside',
#    'park',
#    'heavy',
#    'equipment',
#    'used',
#    'create',
#    'fire',
#    'control',
#    'lines',
#    'improve',
#    'ground',
#    'aerial',
#    'access',
#    'strategic',
#    'areas',
#    'addition',
#    'dozer',
#    'lines',
#    'put',
#    'fire',
#    'heavy',
#    'equipment',
#    'used',
#    'along',
#    'border',
#    'south',
#    'boundary',
#    'park',
#    'cookson',
#    'community',
#    'pasture',
#    'push',
#    'back',
#    'forested',
#    'edge',
#    'protect',
#    'newly',
#    'repaired',
#    'fence',
#    'damaged',
#    'fire',
#    'prince',
#    'albert',
#    'national',
#    'park',
#    'fire',
#    'management',
#    'takes',
#    'responsibility',
#    'reclamation',
#    'impacts',
#    'heavy',
#    'equipment',
#    'two',
#    'areas',
#    'work',
#    'south',
#    'boundary',
#    'trail',
#    'elk',
#    'trail',
#    'following',
#    '2018',
#    'rabbit',
#    'fire',
#    'approximately',
#    '13',
#    '5',
#    'km',
#    'fence',
#    'replaced',
#    'northern',
#    'boundary',
#    'cookson',
#    'community',
#    'pasture',
#    'approximately',
#    '6',
#    'km',
#    'fence',
#    'directly',
#    'adjacent',
#    'panp',
#    'boundary',
#    'area',
#    'cleared',
#    'vegetation',
#    'long',
#    'linear',
#    'berms',
#    'soil',
#    'wood',
#    'restricting',
#    'efforts',
#    'weed',
#    'control',
#    'seeding',
#    'along',
#    'boundary',
#    'also',
#    'increase',
#    'long',
#    'term',
#    'fire',
#    'hazard',
#    'left',
#    'piles',
#    'berms',
#    'need',
#    'spread',
#    'across',
#    'opening',
#    'section',
#    'area',
#    'need',
#    'flat',
#    'debris',
#    'free',
#    'surface',
#    'left',
#    'used',
#    'trail',
#    'road',
#    'vehicles',
#    'elk',
#    'trail',
#    'maintained',
#    'trail',
#    'within',
#    'park',
#    'section',
#    'elk',
#    'trail',
#    'closed',
#    'since',
#    '2018',
#    'due',
#    'impacts',
#    'heavy',
#    'equipment',
#    'wildfire',
#    'operations',
#    'main',
#    'area',
#    'concern',
#    'approximately',
#    '700',
#    'meters',
#    'forest',
#    'cleared',
#    'average',
#    '40',
#    'meters',
#    'wide',
#    '2',
#    '8',
#    'ha',
#    'reclaimed',
#    'fireguard',
#    'put',
#    'maintained',
#    'trail',
#    'new',
#    'trail',
#    'surface',
#    'need',
#    'developed',
#    'reclamation',
#    'within',
#    'area',
#    'bridge',
#    'crossed',
#    'small',
#    'stream',
#    'destroyed',
#    'heavy',
#    'equipment',
#    'shallow',
#    'water',
#    'ford',
#    'crossing',
#    'developed',
#    'near',
#    'area',
#    'also',
#    'helipad',
#    'approximately',
#    '0',
#    '5',
#    'ha',
#    'also',
#    'reclaimed',
#    'midway',
#    'trailhead',
#    'section',
#    'trail',
#    'culvert',
#    'washed',
#    'need',
#    'repaired',
#    'well']),
#  (149,
#   ['project',
#    'involve',
#    'construction',
#    'lake',
#    'superior',
#    'national',
#    'marine',
#    'conservation',
#    'area',
#    'discovery',
#    'centre',
#    'nipigon',
#    'project',
#    'site',
#    '1',
#    '4',
#    'hectare',
#    'lot',
#    'nipigon',
#    'waterfront',
#    'west',
#    'side',
#    'brennan',
#    'drive',
#    'project',
#    'include',
#    'construction',
#    'discovery',
#    'centre',
#    'detached',
#    'garage',
#    'parking',
#    'area',
#    'outdoor',
#    'interpretive',
#    'elements',
#    'landscaping',
#    'discovery',
#    'centre',
#    'approximately',
#    '1',
#    '300',
#    'square',
#    'meters',
#    'single',
#    'story',
#    'multiuse',
#    'building',
#    'include',
#    'exhibit',
#    'space',
#    'interpretive',
#    'elements',
#    'interior',
#    'exterior',
#    'administrative',
#    'space',
#    'serve',
#    'main',
#    'hub',
#    'visitors',
#    'lake',
#    'superior',
#    'national',
#    'marine',
#    'conservation',
#    'area',
#    'site',
#    'administration',
#    'operations',
#    'construction',
#    'phase',
#    'project',
#    'involve',
#    'use',
#    'heavy',
#    'machinery',
#    'excavation',
#    'backfilling',
#    'landscaping',
#    'vegetation',
#    'removal',
#    'project',
#    'assessed',
#    'basic',
#    'impact',
#    'assessment']),
#  (214,
#   ['yellow',
#    'toadflax',
#    'widely',
#    'distributed',
#    'perennial',
#    'invasive',
#    'plant',
#    'reproduces',
#    'seed',
#    'extensive',
#    'creeping',
#    'rhizome',
#    'plant',
#    'extremely',
#    'hardy',
#    'ability',
#    'densely',
#    'infest',
#    'large',
#    'areas',
#    'crowd',
#    'native',
#    'vegetation',
#    'making',
#    'threat',
#    'ecological',
#    'integrity',
#    'prince',
#    'albert',
#    'national',
#    'park',
#    'herbicide',
#    'spraying',
#    'yellow',
#    'toadflax',
#    'occurred',
#    'several',
#    'locations',
#    'prince',
#    'albert',
#    'national',
#    'park',
#    'limited',
#    'success',
#    'using',
#    'biological',
#    'control',
#    'agent',
#    'offers',
#    'additional',
#    'option',
#    'control',
#    'species',
#    'manner',
#    'nearly',
#    'labour',
#    'intensive',
#    'prince',
#    'albert',
#    'national',
#    'park',
#    'working',
#    'agriculture',
#    'agri',
#    'food',
#    'canada',
#    'carry',
#    'trials',
#    'rhinusa',
#    'pilosa',
#    'three',
#    'affected',
#    'locations',
#    'prospect',
#    'point',
#    'rabbit',
#    'cabin',
#    'area',
#    '12',
#    'mile',
#    'meadow',
#    'weevils',
#    'obtained',
#    'agriculture',
#    'agri',
#    'foods',
#    'canada',
#    'charge',
#    'released',
#    'sites',
#    'late',
#    'summer']),
#  (257,
#   ['hyperabundant',
#    'populations',
#    'white',
#    'tailed',
#    'deer',
#    'threaten',
#    'ecological',
#    'value',
#    'varied',
#    'forest',
#    'communities',
#    'hill',
#    'island',
#    'park',
#    'islands',
#    'intensive',
#    'browsing',
#    'led',
#    'distinct',
#    'lack',
#    'understory',
#    'vegetation',
#    'changing',
#    'forest',
#    'composition',
#    'parks',
#    'canada',
#    'developed',
#    'deer',
#    'management',
#    'strategy',
#    'response',
#    'ecological',
#    'impacts',
#    'proposing',
#    'restore',
#    'native',
#    'vegetation',
#    'area',
#    'reducing',
#    'deer',
#    'numbers',
#    'deer',
#    'herd',
#    'reduction',
#    'conducted',
#    'outlined',
#    'hill',
#    'island',
#    'hyperabundant',
#    'deer',
#    'management',
#    'plan',
#    '2012',
#    'goal',
#    'project',
#    'restore',
#    'integrity',
#    'forest',
#    'ecosystem',
#    'hill',
#    'island',
#    'processes',
#    'protect',
#    'habitat',
#    'plant',
#    'species',
#    'conservation',
#    'concern',
#    'eg',
#    'pitch',
#    'pine',
#    'deer',
#    'herd',
#    'reduction',
#    'began',
#    '2007',
#    'effort',
#    'reduce',
#    'populations',
#    'level',
#    '4',
#    'deer',
#    'per',
#    'km2',
#    'allow',
#    'healthy',
#    'forest',
#    'regeneration',
#    'efforts',
#    'continue',
#    'attain',
#    'population',
#    'density',
#    'reduction',
#    'deer',
#    'numbers',
#    'achieved',
#    'partnering',
#    'mohawks',
#    'akwesasne',
#    'harvest',
#    'white',
#    'tailed',
#    'deer',
#    'island',
#    'monitoring',
#    'program',
#    'continue',
#    'track',
#    'effectiveness',
#    'deer',
#    'reduction',
#    'strategy',
#    'recovery',
#    'forest',
#    'ecosystem',
#    'project',
#    'assessed',
#    'basic',
#    'impact',
#    'assessment']),
#  (63,
#   ['project',
#    'entail',
#    'installation',
#    'approximately',
#    '330',
#    'grid',
#    'tied',
#    'photovoltaic',
#    'solar',
#    'panels',
#    'site',
#    'former',
#    'environment',
#    'climate',
#    'change',
#    'canada',
#    'capmon',
#    'weather',
#    'station',
#    'located',
#    'within',
#    'kejimkujik',
#    'national',
#    'park',
#    'national',
#    'historic',
#    'site',
#    'frontcountry',
#    'goal',
#    'project',
#    'generate',
#    'renewable',
#    'electricity',
#    'contribute',
#    'reduction',
#    'greenhouse',
#    'gases',
#    'associated',
#    'park',
#    'operations',
#    'solar',
#    'panels',
#    'mounted',
#    'racking',
#    'system',
#    'anchored',
#    'screw',
#    'piles',
#    'poured',
#    'concrete',
#    'foundations',
#    'trenching',
#    'required',
#    'installation',
#    'electrical',
#    'wiring',
#    'connect',
#    'array',
#    'existing',
#    'nova',
#    'scotia',
#    'power',
#    'grid',
#    'site',
#    'project',
#    'reviewed',
#    'via',
#    'basic',
#    'impact',
#    'assessment']),
#  (273,
#   ['saskpower',
#    'proposing',
#    'replace',
#    'pole',
#    'mount',
#    'transformer',
#    'existing',
#    'wooden',
#    'pole',
#    'directionally',
#    'drill',
#    '65',
#    'customer',
#    'supplied',
#    'metering',
#    'point',
#    'se',
#    '16',
#    '57',
#    '01',
#    'w3m',
#    'within',
#    'prince',
#    'albert',
#    'national',
#    'park',
#    'project',
#    'required',
#    'increase',
#    'capacity',
#    'line',
#    'maintain',
#    'quality',
#    'service',
#    'existing',
#    'customer',
#    'equipment',
#    'expected',
#    'used',
#    'completion',
#    'project',
#    'includes',
#    'digger',
#    'truck',
#    'back',
#    'hoe',
#    'bucket',
#    'truck',
#    'directional',
#    'boring',
#    'equipment',
#    'crew',
#    'trucks',
#    'access',
#    'components',
#    'project',
#    'make',
#    'use',
#    'existing',
#    'roads',
#    'trails',
#    'surface',
#    'disturbance',
#    'expected',
#    'minimized',
#    'bell',
#    'holes',
#    'existing',
#    'pole',
#    'metering',
#    'point']),
#  (203,
#   ['project',
#    'involve',
#    'dock',
#    'work',
#    'multiple',
#    'locations',
#    'throughout',
#    'thousand',
#    'islands',
#    'national',
#    'park',
#    'specifically',
#    'work',
#    'include',
#    'installation',
#    'floating',
#    'docks',
#    'replace',
#    'docks',
#    'damaged',
#    'due',
#    'recent',
#    'high',
#    'water',
#    'levels',
#    'replace',
#    'docks',
#    'end',
#    'life',
#    'cycle',
#    'new',
#    'docks',
#    'designed',
#    'accommodate',
#    'higher',
#    'water',
#    'levels',
#    'associated',
#    'work',
#    'includes',
#    'installation',
#    'water',
#    'shoreline',
#    'anchoring',
#    'systems',
#    'installation',
#    'boardwalks',
#    'kiosks',
#    'shore',
#    'landing',
#    'points',
#    'replacements',
#    'minor',
#    'location',
#    'adjustments',
#    'mooring',
#    'buoy',
#    'anchors',
#    'may',
#    'also',
#    'carried',
#    'necessary',
#    'dock',
#    'project',
#    'locations',
#    'include',
#    'adelaide',
#    'island',
#    'east',
#    'grenadier',
#    'island',
#    'georgina',
#    'island',
#    'constance',
#    'island',
#    'mulcaster',
#    'island',
#    'milton',
#    'island',
#    'hill',
#    'island',
#    'stovin',
#    'island',
#    'project',
#    'work',
#    'planned',
#    'commence',
#    'april',
#    '2020',
#    'conclude',
#    'november',
#    '2020',
#    'project',
#    'assessed',
#    'basic',
#    'impact',
#    'assessment']),
#  (271,
#   ['new',
#    'culvert',
#    'needs',
#    'installed',
#    'boundary',
#    'road',
#    'north',
#    'osten',
#    'lake',
#    'camping',
#    'access',
#    'rr',
#    '205',
#    'culvert',
#    'collapsed',
#    'completely',
#    'rusted',
#    'site',
#    'currently',
#    'flooded',
#    'due',
#    'beaver',
#    'activity',
#    'strathcona',
#    'county',
#    'culvert',
#    'failure',
#    'rr',
#    '205',
#    'currently',
#    'beavers',
#    'deep',
#    'run',
#    'washout',
#    'boundary',
#    'road',
#    'making',
#    'impassable',
#    'new',
#    'culvert',
#    'larger',
#    'diameter',
#    '600mm',
#    'due',
#    'sizes',
#    'currently',
#    'kept',
#    'stock',
#    'replacements',
#    'old',
#    'culvert',
#    '450mm',
#    'work',
#    'take',
#    'place',
#    'water',
#    'flow',
#    'boundary',
#    'road',
#    'three',
#    'inch',
#    'minus',
#    'pit',
#    'run',
#    'gravel',
#    'used',
#    'fill',
#    'road',
#    'base',
#    'top',
#    'sides',
#    'new',
#    'culvert',
#    'strathcona',
#    'county',
#    'plans',
#    'repair',
#    'culvert',
#    'rr',
#    '205']),
#  (50,
#   ['red',
#    'bay',
#    '2011',
#    'management',
#    'plan',
#    'identified',
#    'strategies',
#    'develop',
#    'menu',
#    'visitor',
#    'experience',
#    'opportunities',
#    'enhance',
#    'canadians',
#    'discover',
#    'enjoy',
#    'connect',
#    'historic',
#    'site',
#    'site',
#    'management',
#    'proposed',
#    'escape',
#    'game',
#    'developed',
#    'fetch',
#    'quest',
#    'based',
#    'history',
#    'red',
#    'bay',
#    'basque',
#    'whaling',
#    'station',
#    'game',
#    'requires',
#    'participants',
#    'complete',
#    'number',
#    'puzzles',
#    'trivial',
#    'tasks',
#    'props',
#    'equipment',
#    'order',
#    'successfully',
#    'solve',
#    'game',
#    'facilitate',
#    'placement',
#    'props',
#    'site',
#    'management',
#    'proposing',
#    'small',
#    'addition',
#    'island',
#    'existing',
#    'trail',
#    'board',
#    'walk',
#    'approximately',
#    '5',
#    'feet',
#    'length',
#    'extend',
#    'existing',
#    'trail',
#    'allow',
#    'participants',
#    'step',
#    'main',
#    'trail',
#    'unto',
#    '8',
#    'x',
#    '12',
#    'meter',
#    'wooden',
#    'platform',
#    'placed',
#    'upon',
#    'gravel',
#    'bedding']),
#  (51,
#   ['objective',
#    'project',
#    'complete',
#    'second',
#    'phase',
#    'decommission',
#    'reclamation',
#    'redstreak',
#    'wastewater',
#    'lagoon',
#    'first',
#    'phase',
#    'project',
#    'completed',
#    'summer',
#    'fall',
#    '2020',
#    'fence',
#    'surrounding',
#    'lagoon',
#    'large',
#    'woody',
#    'debris',
#    'pile',
#    'removed',
#    'furthermore',
#    'soil',
#    'samples',
#    'collected',
#    'analyzed',
#    'confirm',
#    'site',
#    'contaminated',
#    'meets',
#    'federal',
#    'provincial',
#    'guidelines',
#    'bc',
#    'omrr',
#    'bc',
#    'csr',
#    'ccme',
#    'lagoon',
#    'adjacent',
#    'redstreak',
#    'restoration',
#    'area',
#    'within',
#    'subunit',
#    'called',
#    'provincial',
#    'block',
#    'harvested',
#    'thinned',
#    '2002',
#    'redstreak',
#    'restoration',
#    'area',
#    'created',
#    'multi',
#    'year',
#    'ecosystem',
#    'based',
#    'management',
#    'project',
#    'parks',
#    'canada',
#    'restored',
#    'historical',
#    'fire',
#    'regime',
#    'brought',
#    'back',
#    'native',
#    'grasses',
#    'provide',
#    'better',
#    'grazing',
#    'habitat',
#    'forest',
#    'thinning',
#    'maintenance',
#    'prescribed',
#    'fire',
#    '2021',
#    'parks',
#    'canada',
#    'targeting',
#    'complete',
#    'full',
#    'decommission',
#    'reclamation',
#    'old',
#    'wastewater',
#    'lagoon',
#    'site',
#    'main',
#    'objective',
#    'project',
#    'second',
#    'phase',
#    'reduce',
#    'human',
#    'footprint',
#    'left',
#    'site',
#    'removing',
#    'infrastructure',
#    'remains',
#    'lagoon',
#    'prepare',
#    'site',
#    'start',
#    'natural',
#    'revegetation',
#    'phase',
#    'reclamation']),
#  (123,
#   ['cedar',
#    'shingle',
#    'roofing',
#    'watchmen',
#    'accommodations',
#    'cabin',
#    'hotspring',
#    'island',
#    'compromised',
#    'requires',
#    'replacement',
#    'known',
#    'bat',
#    'maternity',
#    'roost',
#    'area',
#    'roughly',
#    '100m',
#    'away',
#    'bats',
#    'may',
#    'possibly',
#    'using',
#    'roof',
#    'soffits',
#    'attic',
#    'etc',
#    'roosting',
#    'unknown',
#    'point',
#    'physical',
#    'inspection',
#    'pending',
#    'metal',
#    'roofing',
#    'ellen',
#    'island',
#    'operations',
#    'station',
#    'leaks',
#    'requires',
#    'replacement',
#    'bats',
#    'observed',
#    'area',
#    'past',
#    'bats',
#    'may',
#    'possibly',
#    'using',
#    'roof',
#    'soffits',
#    'attic',
#    'etc',
#    'roosting',
#    'unknown',
#    'point',
#    'physical',
#    'inspection',
#    'pending',
#    'roofs',
#    'redone',
#    'using',
#    'metal',
#    'roofing',
#    'possibility',
#    'bats',
#    'may',
#    'using',
#    'cabins',
#    'residence',
#    'project',
#    'assessed',
#    'basic',
#    'impact',
#    'assessment']),
#  (205,
#   ['grasslands',
#    'national',
#    'park',
#    'proposes',
#    'issue',
#    'license',
#    'occupation',
#    'graze',
#    'cattle',
#    '8',
#    'sections',
#    'former',
#    'mankota',
#    'community',
#    'pasture',
#    'area',
#    'east',
#    'block',
#    'park',
#    'cattle',
#    'grazing',
#    'occurred',
#    'area',
#    'previously',
#    'grazing',
#    'permit',
#    'acquisition',
#    'parks',
#    'canada',
#    'used',
#    'grazing',
#    'livestock',
#    'domestic',
#    'livestock',
#    'grazing',
#    'used',
#    'area',
#    'maintain',
#    'disturbance',
#    'regime',
#    'supporting',
#    'habitat',
#    'maintenance',
#    'species',
#    'risk',
#    'prairie',
#    'ecosystem',
#    'function',
#    'new',
#    'infrastructure',
#    'constructed',
#    'part',
#    'program',
#    'activities',
#    'include',
#    'moving',
#    'cattle',
#    'grazing',
#    'paddocks',
#    'maintaining',
#    'repairing',
#    'fences',
#    'watering',
#    'systems',
#    'checking',
#    'cattle',
#    'project',
#    'assessed',
#    'basic',
#    'impact',
#    'assessment']),
#  (82,
#   ['existing',
#    'main',
#    'road',
#    'south',
#    'beach',
#    'sable',
#    'island',
#    'main',
#    'station',
#    'traverses',
#    'active',
#    'tern',
#    'colony',
#    'may',
#    'august',
#    'vehicle',
#    'movements',
#    'along',
#    'corridor',
#    'creates',
#    'disturbance',
#    'nesting',
#    'birds',
#    'contribute',
#    'nest',
#    'failure',
#    'chick',
#    'mortality',
#    'reduce',
#    'impacts',
#    'proposed',
#    'seasonal',
#    'temporary',
#    'crossing',
#    'developed',
#    'allow',
#    'access',
#    'south',
#    'beach',
#    'main',
#    'station',
#    'proposed',
#    'location',
#    'located',
#    'approximately',
#    '1',
#    '8',
#    'km',
#    'east',
#    'main',
#    'station',
#    'passes',
#    'one',
#    'narrowest',
#    'sections',
#    'dunes',
#    '100m',
#    'long',
#    'currently',
#    'almost',
#    'devoid',
#    'vegetation',
#    'easily',
#    'navigable',
#    'sinpr',
#    'vehicles',
#    'project',
#    'assessed',
#    'basic',
#    'impact',
#    'assessment']),
#  (49,
#   ['impact',
#    'assessment',
#    'required',
#    'address',
#    'potential',
#    'impacts',
#    'resulting',
#    'repair',
#    'class',
#    'a2',
#    'pedestrian',
#    'bridge',
#    'west',
#    'coast',
#    'trail',
#    'pacific',
#    'rim',
#    'national',
#    'park',
#    'reserve',
#    'bridge',
#    'repairs',
#    'required',
#    'ensure',
#    'safety',
#    'visitors',
#    'staff',
#    'traversing',
#    'maintaining',
#    'trail',
#    'limited',
#    'ground',
#    'disturbance',
#    'within',
#    'riparian',
#    'habitat',
#    'required',
#    'upgrade',
#    'mid',
#    'span',
#    'bridge',
#    'support',
#    'structure',
#    'work',
#    'within',
#    'riparian',
#    'zone',
#    'meet',
#    'dfo',
#    'measures',
#    'reduce',
#    'harm',
#    'fish',
#    'including',
#    'project',
#    'completion',
#    'least',
#    'risk',
#    'summer',
#    'window',
#    'adjacent',
#    'creek',
#    'expected',
#    'completely',
#    'dry',
#    'water',
#    'works',
#    'occur',
#    'part',
#    'project',
#    'anticipated',
#    'effects',
#    'mitigation',
#    'scope',
#    'work',
#    'limited',
#    'well',
#    'understood',
#    'thus',
#    'basic',
#    'impact',
#    'assessment',
#    'undertaken']),
#  (156,
#   ['previous',
#    'cavendish',
#    'campground',
#    'staff',
#    'room',
#    'experienced',
#    'devastating',
#    'fire',
#    'last',
#    'fall',
#    'burned',
#    'beyond',
#    'repair',
#    'national',
#    'park',
#    'staff',
#    'require',
#    'lunchroom',
#    'wash',
#    'area',
#    'bathroom',
#    'daily',
#    'personal',
#    'needs',
#    'site',
#    'design',
#    'drawings',
#    'completed',
#    'new',
#    'site',
#    'staff',
#    'room',
#    'designated',
#    'within',
#    'rehabilitated',
#    'dumping',
#    'station',
#    'cavendish',
#    'campground',
#    'new',
#    'staff',
#    'room',
#    'situated',
#    'northeast',
#    'corner',
#    'former',
#    'dumping',
#    'station',
#    'site',
#    'partially',
#    'constructed',
#    'old',
#    'agricultural',
#    'field',
#    '100',
#    'years',
#    'ago',
#    'since',
#    'grown',
#    'old',
#    'field',
#    'regenerative',
#    'forest',
#    'stand',
#    'white',
#    'spruce',
#    'paved',
#    'parking',
#    'lot',
#    'covering',
#    'large',
#    'portion',
#    'remaining',
#    'graded',
#    'site',
#    'also',
#    'proposed',
#    'within',
#    'site',
#    'design',
#    'services',
#    'electrical',
#    'water',
#    'sewage',
#    'communications',
#    'routed',
#    'new',
#    'lunchroom',
#    'travel',
#    'corridors',
#    'identified',
#    'site',
#    'drawing',
#    'corridors',
#    'previously',
#    'disturbed',
#    'either',
#    'road',
#    'construction',
#    'electrical',
#    'corridors',
#    'construction',
#    'expected',
#    'begin',
#    'june',
#    '2020',
#    'completed',
#    'october',
#    '2020',
#    'campground',
#    'entrance',
#    'designed',
#    'reconstructed',
#    '2017',
#    'time',
#    'old',
#    'dumping',
#    'station',
#    'removed',
#    'site',
#    'rehabilitated',
#    'grass',
#    'field',
#    'last',
#    'fall',
#    'hurricane',
#    'dorian',
#    'made',
#    'landfall',
#    'pei',
#    'devastated',
#    'cavendish',
#    'campground',
#    'felling',
#    'majority',
#    'trees',
#    'area',
#    'softwood',
#    'trees',
#    'remaining',
#    'standing',
#    'removed',
#    'due',
#    'safety',
#    'reasons',
#    'therefore',
#    'almost',
#    'trees',
#    'remaining',
#    'area',
#    'lunch',
#    'room',
#    'constructed',
#    'work',
#    'tendered',
#    'contract',
#    'may',
#    '2020',
#    'work',
#    'beginning',
#    'june',
#    '2020',
#    'expected',
#    'completed',
#    'october',
#    '2020',
#    'history',
#    'site',
#    'originally',
#    'agricultural',
#    'crops',
#    'hay',
#    'potato',
#    'grain',
#    'clover',
#    'project',
#    'site',
#    'since',
#    'heavily',
#    'landscaped',
#    'facilitate',
#    'construction',
#    'campground',
#    'entrance',
#    'supporting',
#    'infrastructure',
#    'access',
#    'roads',
#    'grahams',
#    'lane',
#    'parking',
#    'lots',
#    'walking',
#    'trails',
#    'entrance',
#    'campground',
#    'majorly',
#    'reconfigured',
#    'least',
#    'three',
#    'times',
#    'past',
#    '70',
#    'years',
#    'evident',
#    'aerial',
#    'photos',
#    'roadways',
#    'would',
#    'major',
#    'amounts',
#    'fill',
#    'trucked',
#    'build',
#    'road',
#    'surfaces',
#    'back',
#    'ditches',
#    'would',
#    'heavily',
#    'landscaped',
#    'heavy',
#    'machinery',
#    'disturbing',
#    'anything',
#    'found',
#    'site',
#    'campground',
#    'eia',
#    'completed',
#    '2015',
#    'encompassed',
#    'developing',
#    'additional',
#    'camping',
#    'sites',
#    'throughout',
#    'campground',
#    'archaeological',
#    'test',
#    'pits',
#    'dug',
#    'area',
#    'assessed',
#    'cultural',
#    'impacts']),
#  (221,
#   ['parks',
#    'canada',
#    'proposing',
#    'construct',
#    'new',
#    'facility',
#    'conduct',
#    'watercraft',
#    'inspections',
#    'aquatic',
#    'invasive',
#    'species',
#    'inspection',
#    'station',
#    'constructed',
#    'existing',
#    'disturbed',
#    'footprint',
#    'near',
#    'park',
#    'entrance',
#    'gate',
#    'scope',
#    'work',
#    'may',
#    'include',
#    'minor',
#    'roadway',
#    'work',
#    'including',
#    'realignment',
#    'facilitate',
#    'vehicle',
#    'access',
#    'site',
#    'site',
#    'preparation',
#    'work',
#    'including',
#    'grading',
#    'paving',
#    'installation',
#    'washroom',
#    'facility',
#    'utility',
#    'work',
#    'installation',
#    'inspection',
#    'building',
#    'parks',
#    'canada',
#    'undertaking',
#    'basic',
#    'impact',
#    'assessment',
#    'assess',
#    'potential',
#    'project',
#    'related',
#    'impacts',
#    'natural',
#    'cultural',
#    'resources',
#    'project',
#    'assessment',
#    'pathway',
#    'changed',
#    'bia',
#    'pria',
#    'amendment',
#    'signed',
#    'august',
#    '12',
#    '2020',
#    'design',
#    'finalized',
#    'determined',
#    'footprint',
#    'remained',
#    'fully',
#    'zone',
#    'iv',
#    'enter',
#    'zone',
#    'ii']),
#  (238,
#   ['project',
#    'includes',
#    'mobilizing',
#    'staging',
#    'equipment',
#    'moose',
#    'island',
#    'fuel',
#    'heavy',
#    'equipment',
#    'flooding',
#    'pumps',
#    'chainsaws',
#    'etc',
#    'construction',
#    'ice',
#    'bridge',
#    'peace',
#    'river',
#    'ice',
#    'depth',
#    'measurements',
#    'removal',
#    'pack',
#    'ice',
#    'north',
#    'south',
#    'shore',
#    'peace',
#    'river',
#    'flooding',
#    'river',
#    'adequate',
#    'ice',
#    'depth',
#    'achieved',
#    'winter',
#    'road',
#    'continues',
#    'forest',
#    'requires',
#    'snow',
#    'removal',
#    'brushing',
#    'fallen',
#    'trees',
#    'willows',
#    'removal',
#    'large',
#    'rocks',
#    'tree',
#    'stumps',
#    'etc',
#    'coordination',
#    'required',
#    'southern',
#    'crew',
#    'working',
#    'fort',
#    'chipewyan',
#    'rocher',
#    'river',
#    'ice',
#    'crossing',
#    'maintenance',
#    'ice',
#    'bridge',
#    'winter',
#    'road',
#    'required',
#    'throughout',
#    'season',
#    'brushing',
#    'plowing',
#    'grading',
#    'ice',
#    'bridge',
#    'winter',
#    'road',
#    'ice',
#    'depth',
#    'measurements',
#    'take',
#    'place',
#    'peace',
#    'river',
#    'quatre',
#    'forche']),
#  (251,
#   ['snowmobiling',
#    'permitted',
#    'activity',
#    'designated',
#    'areas',
#    'gros',
#    'morne',
#    'national',
#    'park',
#    'snowmobile',
#    'access',
#    'route',
#    'used',
#    'local',
#    'residents',
#    'proposed',
#    'public',
#    'commercial',
#    'use',
#    'route',
#    'covers',
#    '179',
#    '8',
#    'hectares',
#    'travel',
#    'approximately',
#    '12',
#    'kilometers',
#    'woody',
#    'point',
#    'trout',
#    'river',
#    'alongside',
#    'highway',
#    'route',
#    '431',
#    'trout',
#    'river',
#    'gulch',
#    'placement',
#    'signage',
#    'entrance',
#    'points',
#    'construction',
#    'activities',
#    'required',
#    'addition',
#    'access',
#    'route',
#    '1',
#    '541',
#    '5',
#    'hectare',
#    'snowmobile',
#    'exclusion',
#    'zone',
#    'created',
#    'northwest',
#    'facing',
#    'slope',
#    'tablelands',
#    'therefore',
#    'significant',
#    'net',
#    'reduction',
#    'areas',
#    'open',
#    'snowmobiling',
#    'new',
#    'snowmobile',
#    'corridor',
#    '134',
#    '8',
#    'hectares',
#    'passes',
#    'areas',
#    'designated',
#    'zone',
#    'iii',
#    'natural',
#    'environment',
#    'whereas',
#    'majority',
#    'expanded',
#    'exclusion',
#    'area',
#    '1',
#    '195',
#    '3',
#    'hectares',
#    'designated',
#    'zone',
#    'ii',
#    'wilderness']),
#  (250,
#   ['existing',
#    'culvert',
#    'originally',
#    'constructed',
#    '1957',
#    'poor',
#    'condition',
#    'spalls',
#    'exposed',
#    'rebar',
#    'wide',
#    'cracks',
#    'existing',
#    'culvert',
#    '5',
#    '5',
#    'wide',
#    '1',
#    '8',
#    'high',
#    'combination',
#    'concrete',
#    'open',
#    'footing',
#    'culvert',
#    'concrete',
#    'box',
#    'culvert',
#    'proposed',
#    'replacement',
#    'consists',
#    '6',
#    'x',
#    '2',
#    '5',
#    'cast',
#    'place',
#    'concrete',
#    'open',
#    'footing',
#    'culvert',
#    'supported',
#    'steel',
#    'h',
#    'piles',
#    'existing',
#    'alignment',
#    'culvert',
#    'include',
#    'cast',
#    'place',
#    'concrete',
#    'wingwalls',
#    'supported',
#    'steel',
#    'h',
#    'piles',
#    'proposed',
#    'culvert',
#    'adequate',
#    'capacity',
#    'convey',
#    '25',
#    'year',
#    'design',
#    'storm',
#    'check',
#    'flood',
#    'without',
#    'overtopping',
#    'roadway',
#    'replacement',
#    'flow',
#    'maintained',
#    'temporary',
#    'bypass',
#    'pipe',
#    'work',
#    'divided',
#    'two',
#    'phases',
#    'phase',
#    '1',
#    'fall',
#    '2019',
#    'involves',
#    'installation',
#    'bypass',
#    'system',
#    'phase',
#    '2',
#    '2020',
#    'involves',
#    'culvert',
#    'replacement',
#    'work',
#    'classified',
#    'group',
#    'c',
#    'project',
#    'mto',
#    'class',
#    'ea',
#    'environmental',
#    'screening',
#    'document',
#    'prepared',
#    'provincial',
#    'level',
#    'ea',
#    'evaluated',
#    'federal',
#    'requirements',
#    'gaps',
#    'filled',
#    'within',
#    'bia']),
#  (264,
#   ['parks',
#    'canada',
#    'fire',
#    'management',
#    'team',
#    'waterton',
#    'lakes',
#    'national',
#    'park',
#    'proposed',
#    'implementation',
#    'prescribed',
#    'fire',
#    'camp',
#    'wishbone',
#    'area',
#    'park',
#    'ecological',
#    'objective',
#    'fire',
#    'reverse',
#    'trend',
#    'aspen',
#    'tree',
#    'encroachment',
#    'onto',
#    'historically',
#    'fescue',
#    'grassland',
#    'restore',
#    'mean',
#    'fire',
#    'interval',
#    '5',
#    'years',
#    'fescue',
#    'grassland',
#    'aspen',
#    'parkland',
#    'ecoregions',
#    'park',
#    'fescue',
#    'grassland',
#    'provides',
#    'critical',
#    'habitat',
#    'variety',
#    'species',
#    'outside',
#    'park',
#    'burn',
#    'unit',
#    'located',
#    'east',
#    'side',
#    'lower',
#    'waterton',
#    'lake',
#    'waterton',
#    'river',
#    'south',
#    'highway',
#    '6',
#    'encompasses',
#    'area',
#    '1',
#    '170',
#    'ha',
#    'fire',
#    'operations',
#    'would',
#    'take',
#    'place',
#    'winter',
#    'pre',
#    'guard',
#    'burning',
#    'spring',
#    'main',
#    'unit',
#    'burning',
#    '2020',
#    'leaf',
#    'execution',
#    'burn',
#    'would',
#    'take',
#    'place',
#    'every',
#    '5',
#    'years',
#    'thereafter',
#    'conditions',
#    'continue',
#    'trend',
#    'reduction',
#    'aspen',
#    'parkland',
#    'encroachment',
#    'fescue',
#    'grasslands',
#    'ecoregion']),
#  (139,
#   ['grasslands',
#    'national',
#    'park',
#    'partnering',
#    'saskpower',
#    'remove',
#    '10',
#    'km',
#    'overhead',
#    'service',
#    'line',
#    'west',
#    'block',
#    'park',
#    'replacing',
#    'partially',
#    'buried',
#    'service',
#    'line',
#    'existing',
#    'overhead',
#    'line',
#    'crosses',
#    'prairie',
#    'replacement',
#    'line',
#    'follow',
#    'existing',
#    'public',
#    'access',
#    'road',
#    'public',
#    'access',
#    'road',
#    'intersects',
#    'black',
#    'tailed',
#    'prairie',
#    'dog',
#    'colony',
#    'work',
#    'occur',
#    'lands',
#    'protected',
#    'emergency',
#    'order',
#    'protection',
#    'greater',
#    'sage',
#    'grouse',
#    '2013',
#    'proposed',
#    'project',
#    'work',
#    'towards',
#    'conservation',
#    'goals',
#    'greater',
#    'sage',
#    'grouse',
#    'removing',
#    'power',
#    'poles',
#    'critical',
#    'habitat',
#    'tall',
#    'vertical',
#    'structures',
#    'critical',
#    'habitat',
#    'identified',
#    'recovery',
#    'strategy',
#    'species',
#    'chronic',
#    'disturbance',
#    'threatens',
#    'recovery',
#    'survival',
#    'project',
#    'assessed',
#    'basic',
#    'impact',
#    'assessment']),
#  (112,
#   ['many',
#    'decades',
#    'high',
#    'intensity',
#    'browsing',
#    'deer',
#    'sidney',
#    'island',
#    'greatly',
#    'reduced',
#    'abundance',
#    'diversity',
#    'plants',
#    'forest',
#    'understory',
#    'result',
#    'pressure',
#    'forest',
#    'sidney',
#    'island',
#    'lost',
#    'much',
#    'species',
#    'diversity',
#    'structural',
#    'diversity',
#    'fewer',
#    'tree',
#    'species',
#    'able',
#    'grow',
#    'saplings',
#    'replace',
#    'older',
#    'trees',
#    'die',
#    'understorey',
#    'nearly',
#    'disappeared',
#    'forest',
#    'continue',
#    'trajectory',
#    'unless',
#    'effective',
#    'restoration',
#    'work',
#    'done',
#    'therefore',
#    'objective',
#    'project',
#    'establish',
#    'pockets',
#    'native',
#    'shrubs',
#    'park',
#    'reserve',
#    'would',
#    'rejuvenate',
#    'forest',
#    'understorey',
#    'planted',
#    'also',
#    'throughout',
#    'forest',
#    'producing',
#    'seeds',
#    'accomplish',
#    'objective',
#    'propose',
#    'building',
#    'ten',
#    'small',
#    'fenced',
#    'areas',
#    '10',
#    'meter',
#    '10',
#    'meter',
#    'prevent',
#    'deer',
#    'browsing',
#    'planting',
#    'native',
#    'shrubs',
#    'within',
#    'fencing',
#    'permanent',
#    'fenced',
#    'areas',
#    'constructed',
#    'last',
#    'several',
#    'years',
#    '3',
#    '10',
#    'give',
#    'shrubs',
#    'time',
#    'become',
#    'well',
#    'established',
#    'time',
#    'fences',
#    'removed',
#    'work',
#    'occur',
#    'seasonally',
#    '2021',
#    '2023',
#    'project',
#    'assessed',
#    'basic',
#    'impact',
#    'assessment']),
#  (126,
#   ['parks',
#    'canada',
#    'responsible',
#    'overseeing',
#    'management',
#    'maintenance',
#    'tenanted',
#    'properties',
#    'including',
#    'associated',
#    'assets',
#    'within',
#    'rouge',
#    'national',
#    'urban',
#    'park',
#    'purpose',
#    'project',
#    'decommission',
#    'existing',
#    'residential',
#    'sewage',
#    'disposal',
#    'systems',
#    'install',
#    'new',
#    'residential',
#    'sewage',
#    'disposal',
#    'systems',
#    'septic',
#    'systems',
#    'prevent',
#    'potential',
#    'risk',
#    'ground',
#    'water',
#    'human',
#    'health',
#    'order',
#    'install',
#    'new',
#    'systems',
#    'pits',
#    'excavated',
#    'contain',
#    'septic',
#    'tanks',
#    'pump',
#    'tanks',
#    'approximately',
#    '2',
#    '0',
#    'ground',
#    'level',
#    'trenches',
#    'excavated',
#    'dwelling',
#    'septic',
#    'tank',
#    'pump',
#    'tank',
#    'leaching',
#    'bed',
#    'contain',
#    'underground',
#    'pipe',
#    'system',
#    'area',
#    'leaching',
#    'beds',
#    'excavated',
#    'various',
#    'depths',
#    'depending',
#    'site',
#    'excavations',
#    'larger',
#    'area',
#    'final',
#    'septic',
#    'system',
#    'allow',
#    'room',
#    'installation',
#    'work',
#    'temporary',
#    'silt',
#    'fence',
#    'barrier',
#    'installed',
#    'site',
#    'necessary',
#    'equipment',
#    'driven',
#    'area',
#    'around',
#    'excavations',
#    'topsoil',
#    'stockpiled',
#    'site',
#    'new',
#    'septic',
#    'systems',
#    'compliance',
#    '2012',
#    'ontario',
#    'building',
#    'code',
#    'amended',
#    'septic',
#    'systems',
#    'expected',
#    'minimum',
#    'service',
#    'life',
#    '25',
#    'years',
#    'provided',
#    'trees',
#    'shrubs',
#    'vegetation',
#    'deep',
#    'roots',
#    'controlled']),
#  (171,
#   ['purpose',
#    'project',
#    'replace',
#    'distribution',
#    'water',
#    'main',
#    'services',
#    'sanitary',
#    'sewer',
#    'main',
#    'services',
#    'including',
#    'septic',
#    'fields',
#    'within',
#    'various',
#    'sections',
#    'newman',
#    'sound',
#    'malady',
#    'head',
#    'campgrounds',
#    'within',
#    'terra',
#    'nova',
#    'national',
#    'park',
#    'project',
#    'areas',
#    'include',
#    'distribution',
#    'main',
#    'leaving',
#    'water',
#    'treatment',
#    'plant',
#    'pump',
#    'house',
#    'replacement',
#    'existing',
#    'wood',
#    'stave',
#    'tank',
#    'water',
#    'distribution',
#    'mains',
#    'sanitary',
#    'sewers',
#    'newman',
#    'sound',
#    'campground',
#    'loops',
#    'h',
#    'j',
#    'k',
#    'l',
#    'dumping',
#    'station',
#    'area',
#    'loops',
#    'e',
#    'f',
#    'g',
#    'well',
#    'water',
#    'main',
#    'fire',
#    'hose',
#    'boxes',
#    'loops',
#    'r',
#    'f',
#    'q',
#    'septic',
#    'fields',
#    '3',
#    'installed',
#    'vicinity',
#    'loop',
#    'e',
#    'h',
#    'respectively',
#    'project',
#    'works',
#    'also',
#    'include',
#    'water',
#    'services',
#    'kitchen',
#    'shelters',
#    'replacement',
#    'sanitary',
#    'sewer',
#    'services',
#    'existing',
#    'washrooms',
#    'water',
#    'bottling',
#    'filling',
#    'stations',
#    'replacement',
#    'water',
#    'distribution',
#    'mains',
#    'sanitary',
#    'sewer',
#    'system',
#    'including',
#    '3',
#    'septic',
#    'fields',
#    'malady',
#    'head',
#    'campground',
#    'septic',
#    'fields',
#    'located',
#    'near',
#    'existing',
#    'trickling',
#    'plant',
#    'group',
#    'tenting',
#    'day',
#    'use',
#    'area',
#    'respectively']),
#  (115,
#   ['recapitalization',
#    'junior',
#    'commissariat',
#    'officers',
#    'quarters',
#    'federally',
#    'recognized',
#    'heritage',
#    'building',
#    'part',
#    'series',
#    'federal',
#    'infrastructure',
#    'initiative',
#    'projects',
#    'initiated',
#    '2015',
#    'butler',
#    'barracks',
#    'national',
#    'historic',
#    'site',
#    'junior',
#    'commissariat',
#    'officers',
#    'quarters',
#    'structurally',
#    'unsound',
#    'certain',
#    'areas',
#    'renovations',
#    'structure',
#    'substantial',
#    'including',
#    'replacement',
#    'roofing',
#    'system',
#    'stabilization',
#    'repointing',
#    'chimneys',
#    'reconstruction',
#    'walls',
#    'improvements',
#    'drainage',
#    'around',
#    'exterior',
#    'building',
#    'installation',
#    'upgrading',
#    'utilities',
#    'project',
#    'allow',
#    'parks',
#    'canada',
#    'explore',
#    'future',
#    'uses',
#    'important',
#    'heritage',
#    'building']),
#  (209,
#   ['invasive',
#    'english',
#    'hawthorn',
#    'crataegus',
#    'monogyna',
#    'identified',
#    'key',
#    'threat',
#    'meadow',
#    'plant',
#    'communities',
#    'sidney',
#    'island',
#    'parks',
#    'canada',
#    'sidney',
#    'island',
#    'community',
#    'academic',
#    'researchers',
#    'management',
#    'english',
#    'hawthorn',
#    'ongoing',
#    'since',
#    '2008',
#    'english',
#    'hawthorn',
#    'population',
#    'progressively',
#    'expanding',
#    'open',
#    'meadows',
#    'english',
#    'hawthorn',
#    'shrubs',
#    'able',
#    'aggressively',
#    'resprout',
#    'untreated',
#    'stumps',
#    'root',
#    'fragments',
#    'rendering',
#    'traditional',
#    'control',
#    'methods',
#    'hand',
#    'pulling',
#    'clipping',
#    'ineffective',
#    'continued',
#    'english',
#    'hawthorn',
#    'invasion',
#    'degrade',
#    'ecosystem',
#    'health',
#    'supplanting',
#    'native',
#    'species',
#    'changing',
#    'local',
#    'environmental',
#    'conditions',
#    'favor',
#    'shrubs',
#    'trees',
#    'rather',
#    'meadow',
#    'species',
#    'experimental',
#    'approach',
#    'taken',
#    'compare',
#    'efficacy',
#    'several',
#    'physical',
#    'chemical',
#    'removal',
#    'methods',
#    'order',
#    'determine',
#    'best',
#    'practices',
#    'english',
#    'hawthorn',
#    'control',
#    'english',
#    'hawthorn',
#    'shrubs',
#    'cut',
#    'using',
#    'hand',
#    'saws',
#    'power',
#    'tools',
#    'eg',
#    'brush',
#    'cutters',
#    'chainsaws',
#    'garlon',
#    'brand',
#    'herbicide',
#    'applied',
#    'directly',
#    'remaining',
#    'stumps',
#    'control',
#    'regrowth',
#    'garlon',
#    'triclopyr',
#    'herbicide',
#    'selected',
#    'trial',
#    'specifically',
#    'targets',
#    'broadleaf',
#    'species',
#    'successfully',
#    'controls',
#    'resprouting',
#    'little',
#    'long',
#    'term',
#    'effects',
#    'grasses',
#    'sedges',
#    'documented',
#    'peer',
#    'reviewed',
#    'academic',
#    'research',
#    'garlon',
#    'applied',
#    'manner',
#    'avoid',
#    'leaching',
#    'aerial',
#    'drift',
#    'surface',
#    'runoff',
#    'proposed',
#    'use',
#    'garlon',
#    'herbicide',
#    'consistent',
#    'parks',
#    'canada',
#    'integrated',
#    'pest',
#    'management',
#    'plan',
#    'gulf',
#    'islands',
#    'national',
#    'park',
#    'reserve',
#    'treatment',
#    'occur',
#    'sidney',
#    'island',
#    'march',
#    'april',
#    'october',
#    'december',
#    '2020']),
#  (39,
#   ['fundy',
#    'national',
#    'park',
#    'intends',
#    'initiate',
#    'vegetation',
#    'management',
#    'plan',
#    'reduce',
#    'potential',
#    'hazards',
#    'excessive',
#    'vegetation',
#    'growth',
#    'seepage',
#    'caused',
#    'deep',
#    'roots',
#    'cavities',
#    'created',
#    'decaying',
#    'roots',
#    'erosion',
#    'caused',
#    'uprooted',
#    'trees',
#    'competition',
#    'undesired',
#    'vegetation',
#    'dense',
#    'vegetation',
#    'obscure',
#    'ability',
#    'observe',
#    'deficiencies',
#    'etc',
#    'bennett',
#    'lake',
#    'dam',
#    'wolfe',
#    'lake',
#    'water',
#    'retaining',
#    'structure',
#    'left',
#    'unchecked',
#    'existing',
#    'vegetation',
#    'could',
#    'pose',
#    'serious',
#    'threat',
#    'strength',
#    'stabilize',
#    'structures',
#    'proposed',
#    'vegetation',
#    'management',
#    'activities',
#    'conducted',
#    'periodically',
#    'growing',
#    'season',
#    'repeated',
#    'annually',
#    'basic',
#    'impact',
#    'assessment',
#    'required',
#    'investigate',
#    'potential',
#    'impacts',
#    'proposed',
#    'vegetation',
#    'management',
#    'activities']),
#  (138,
#   ['proposed',
#    'project',
#    'see',
#    'construction',
#    'new',
#    'pedestrian',
#    'bridge',
#    'across',
#    'mersey',
#    'river',
#    'near',
#    'mills',
#    'falls',
#    'new',
#    'bridge',
#    'replace',
#    'nearby',
#    'existing',
#    'pontoon',
#    'floating',
#    'bridge',
#    'damaged',
#    'hurricane',
#    'dorian',
#    'september',
#    '2019',
#    'new',
#    'single',
#    'span',
#    'bridge',
#    '30',
#    '5m',
#    'length',
#    '1',
#    '8m',
#    'wide',
#    'cast',
#    'place',
#    'concrete',
#    'abutments',
#    'established',
#    'either',
#    'bank',
#    'total',
#    'surface',
#    'area',
#    '20m2',
#    'short',
#    'sections',
#    'new',
#    'trail',
#    '30m',
#    'total',
#    'length',
#    'also',
#    'required',
#    'north',
#    'south',
#    'banks',
#    'connect',
#    'bridge',
#    'adjacent',
#    'existing',
#    'trail',
#    'networks',
#    'project',
#    'assessed',
#    'basic',
#    'impact',
#    'assessment']),
#  (113,
#   ['grasslands',
#    'national',
#    'park',
#    'proposing',
#    'upgrade',
#    'low',
#    'level',
#    'stream',
#    'crossings',
#    'east',
#    'block',
#    'grasslands',
#    'national',
#    'park',
#    'crossings',
#    'located',
#    'along',
#    'vehicle',
#    'access',
#    'routes',
#    'maintained',
#    'local',
#    'access',
#    'emergency',
#    'response',
#    'operational',
#    'purposes',
#    'current',
#    'condition',
#    'stream',
#    'crossings',
#    'assessed',
#    'upgrade',
#    'options',
#    'evaluated',
#    'implemented',
#    'rock',
#    'creek',
#    'east',
#    'block',
#    'habitat',
#    'plains',
#    'minnow',
#    'species',
#    'listed',
#    'schedule',
#    '1',
#    'species',
#    'risk',
#    'act',
#    'possible',
#    'work',
#    'occur',
#    'tributary',
#    'rock',
#    'creek',
#    'rock',
#    'creek',
#    'project',
#    'assessed',
#    'basic',
#    'impact',
#    'assessment']),
#  (277,
#   ['work',
#    'involves',
#    'installing',
#    'cofferdam',
#    'structures',
#    'upstream',
#    'downstream',
#    'lock',
#    'dewatering',
#    'lock',
#    'approaches',
#    'removal',
#    'damaged',
#    'concrete',
#    'concrete',
#    'repair',
#    'landscaping',
#    'upon',
#    'project',
#    'completion',
#    'related',
#    'project',
#    'activities',
#    'creating',
#    'staging',
#    'areas',
#    'use',
#    'machinery',
#    'lock',
#    'work',
#    'take',
#    'place',
#    'fall',
#    'winter',
#    'navigation',
#    'season',
#    'thanksgiving',
#    'weekend',
#    'october',
#    'prior',
#    'victoria',
#    'day',
#    'weekend',
#    'may',
#    'project',
#    'complete',
#    'replacement',
#    'steel',
#    'bridge',
#    'structure',
#    'spans',
#    'canal',
#    'repairs',
#    'concrete',
#    'piers',
#    'completely',
#    'water',
#    'work',
#    'also',
#    'taking',
#    'place',
#    'fall',
#    'winter',
#    'navigation',
#    'season',
#    'interfere',
#    'navigation',
#    'lock',
#    '42']),
#  (210,
#   ['crean',
#    'lake',
#    'channel',
#    'joins',
#    '3rd',
#    'heart',
#    'lake',
#    'crean',
#    'lake',
#    'periodically',
#    'hazard',
#    'boaters',
#    'due',
#    'submerged',
#    'rocks',
#    'damage',
#    'boat',
#    'props',
#    'motor',
#    'legs',
#    'partial',
#    'modification',
#    'carried',
#    'volunteers',
#    '2003',
#    'hazardous',
#    'rocks',
#    'removed',
#    'hand',
#    'relocated',
#    'edge',
#    'channel',
#    'lower',
#    'water',
#    'levels',
#    'recent',
#    'years',
#    'channel',
#    'safety',
#    'issue',
#    'group',
#    'concerned',
#    'lake',
#    'users',
#    'approached',
#    'park',
#    'proposal',
#    'permanently',
#    'rectify',
#    'issue',
#    'removing',
#    'hazardous',
#    'rocks',
#    'boulders',
#    'using',
#    'small',
#    'backhoe',
#    'thumb',
#    'attachment',
#    'working',
#    'park',
#    'barge',
#    'rocks',
#    'would',
#    'picked',
#    'boat',
#    'channel',
#    'moved',
#    'edge',
#    'channel',
#    'way',
#    'passing',
#    'boats']),
#  (266,
#   ['project',
#    'entail',
#    'campground',
#    'kiosk',
#    'replacement',
#    'established',
#    'campground',
#    'north',
#    'saanich',
#    'within',
#    'gulf',
#    'islands',
#    'national',
#    'park',
#    'reserve',
#    'work',
#    'involves',
#    'removing',
#    'replacing',
#    'structure',
#    'cement',
#    'footing',
#    'approximately',
#    '2m',
#    'x',
#    '5m',
#    'structure',
#    'replacing',
#    'new',
#    'footing',
#    'structure',
#    'new',
#    'kiosk',
#    'incorporate',
#    'culturally',
#    'appropriate',
#    'content',
#    'selected',
#    'consultation',
#    'local',
#    'nations',
#    'include',
#    'coast',
#    'salish',
#    'carving',
#    'equipment',
#    'includes',
#    'small',
#    'excavator',
#    'cement',
#    'mixer',
#    'hand',
#    'tools',
#    'proposed',
#    'mitigations',
#    'include',
#    'local',
#    'cultural',
#    'workers',
#    'site',
#    'excavation',
#    'work',
#    'work',
#    'site',
#    'planned',
#    'occur',
#    'april',
#    '15',
#    '2020',
#    'kiosk',
#    'replacement',
#    'planned',
#    'coincide',
#    'campground',
#    'revitalization',
#    'activities',
#    'undertaken',
#    'first',
#    'nations',
#    'program',
#    'gulf',
#    'islands',
#    'national',
#    'park',
#    'reserve']),
#  (144,
#   ['existing',
#    'decking',
#    'thomas',
#    'meadow',
#    'brook',
#    'bridge',
#    'degraded',
#    'end',
#    'service',
#    'life',
#    'thomas',
#    'meadow',
#    'brook',
#    'bridge',
#    'forms',
#    'part',
#    'kejimkujik',
#    'national',
#    'park',
#    'national',
#    'historic',
#    'site',
#    'backcountry',
#    'liberty',
#    'lake',
#    'trail',
#    'provides',
#    'asset',
#    'maintenance',
#    'staff',
#    'access',
#    'northern',
#    'portion',
#    'park',
#    'essential',
#    'visitor',
#    'safety',
#    'purposes',
#    'proposed',
#    'work',
#    'involves',
#    'removing',
#    'deteriorated',
#    'decking',
#    '6',
#    '2m',
#    'x',
#    '3',
#    '7m',
#    'bridge',
#    'replacement',
#    'pressure',
#    'treated',
#    'timbers',
#    'replacement',
#    'bridge',
#    'stringers',
#    'abutments',
#    'anticipated',
#    'construction',
#    'waste',
#    'disposed',
#    'site',
#    'proposed',
#    'work',
#    'occur',
#    'august',
#    'september',
#    '2020',
#    'project',
#    'assessed',
#    'basic',
#    'impact',
#    'assessment']),
#  (247,
#   ['two',
#    'outcomes',
#    'sought',
#    'project',
#    'first',
#    'outcome',
#    'seeks',
#    'increase',
#    'number',
#    'visitor',
#    'mooring',
#    'buoys',
#    'sidney',
#    'spit',
#    '14',
#    '21',
#    'order',
#    'provide',
#    'better',
#    'quality',
#    'visitor',
#    'experience',
#    'also',
#    'protecting',
#    'critical',
#    'eelgrass',
#    'habitat',
#    'buoys',
#    'attached',
#    'chains',
#    '1m',
#    'cubed',
#    'cement',
#    'gravity',
#    'anchors',
#    'set',
#    'ocean',
#    'floor',
#    'project',
#    'seeks',
#    'return',
#    'number',
#    'visitor',
#    'mooring',
#    'buoys',
#    '21',
#    'installing',
#    '4',
#    'additional',
#    'anchors',
#    'ocean',
#    'floor',
#    'adding',
#    '7',
#    'new',
#    'buoys',
#    'existing',
#    'mooring',
#    'field',
#    'second',
#    'portion',
#    'project',
#    'seeks',
#    'improve',
#    'existing',
#    'closure',
#    'sidney',
#    'lagoon',
#    'adding',
#    'regulatory',
#    'signage',
#    'closure',
#    'notices',
#    'entrance',
#    'replacing',
#    'one',
#    'special',
#    'purpose',
#    'buoy',
#    'sidney',
#    'lagoon',
#    'classified',
#    'zone',
#    'one',
#    'special',
#    'preservation',
#    'area',
#    'closed',
#    'public',
#    'since',
#    '2008',
#    'project',
#    'seeks',
#    'replace',
#    'one',
#    'missing',
#    'special',
#    'purpose',
#    'closure',
#    'buoy',
#    'entrance',
#    'lagoon',
#    'add',
#    'additional',
#    'signage',
#    'ensure',
#    'visitors',
#    'informed',
#    'lagoon',
#    'closure']),
#  (235,
#   ['wildfire',
#    'risk',
#    'reduction',
#    'project',
#    'entails',
#    'selective',
#    'removal',
#    'thinning',
#    'pruning',
#    'trees',
#    'using',
#    'fuel',
#    'management',
#    'firesmart',
#    'principles',
#    'reduce',
#    'fuel',
#    'loading',
#    'proposed',
#    'treatment',
#    'areas',
#    'strategically',
#    'located',
#    'within',
#    'gulf',
#    'islands',
#    'national',
#    'park',
#    'reserve',
#    'order',
#    'reduce',
#    'wildfire',
#    'risk',
#    'park',
#    'properties',
#    'adjacent',
#    'residents',
#    'island',
#    'communities',
#    'also',
#    'providing',
#    'safer',
#    'work',
#    'areas',
#    'firefighters',
#    'event',
#    'wildland',
#    'urban',
#    'interface',
#    'fire',
#    'project',
#    'locations',
#    'include',
#    'tumbo',
#    'island',
#    'north',
#    'edge',
#    'wetland',
#    'saturna',
#    'island',
#    'mt',
#    'warburton',
#    'pike',
#    'summit',
#    'parking',
#    'lot',
#    'area',
#    'north',
#    'pender',
#    'island',
#    'south',
#    'roe',
#    'lake',
#    'adjacent',
#    'park',
#    'reserve',
#    'boundary',
#    'project',
#    'work',
#    'proposed',
#    'mid',
#    'january',
#    'mid',
#    'march',
#    '2020',
#    'location',
#    'latitude',
#    'longitude',
#    'pender',
#    'island',
#    'site']),
#  (161,
#   ['parks',
#    'canada',
#    'agency',
#    'pca',
#    'proposed',
#    'construct',
#    'new',
#    'segment',
#    'approximately',
#    '10',
#    'km',
#    'linear',
#    'trail',
#    'connect',
#    'two',
#    'existing',
#    'trail',
#    'segments',
#    'bob',
#    'hunter',
#    'memorial',
#    'park',
#    'boyle',
#    'cemetery',
#    'trail',
#    'intended',
#    'multi',
#    'use',
#    'primarily',
#    'aggregate',
#    'surface',
#    'boardwalk',
#    'required',
#    'wet',
#    'areas',
#    'crossings',
#    'little',
#    'rouge',
#    'river',
#    'also',
#    'connect',
#    'proposed',
#    'markham',
#    'gateway',
#    'welcome',
#    'area',
#    'fencing',
#    'used',
#    'separate',
#    'trail',
#    'active',
#    'farming',
#    'operations',
#    'pedestrian',
#    'road',
#    'crossings',
#    'occur',
#    'major',
#    'mackenzie',
#    '16th',
#    'avenue',
#    'highway',
#    '7',
#    '407',
#    '14th',
#    'avenue',
#    'routing',
#    'options',
#    'around',
#    'private',
#    'property',
#    'owner',
#    'permission',
#    'small',
#    'capacity',
#    'parking',
#    'lot',
#    'major',
#    'mac',
#    '16th',
#    'ave',
#    'investigated']),
#  (59,
#   ['grasslands',
#    'national',
#    'park',
#    'proposing',
#    'install',
#    'weather',
#    'station',
#    'west',
#    'block',
#    'park',
#    'station',
#    'provide',
#    'real',
#    'time',
#    'weather',
#    'information',
#    'area',
#    'otherwise',
#    'little',
#    'coverage',
#    'information',
#    'used',
#    'support',
#    'fire',
#    'visitor',
#    'safety',
#    'programs',
#    'station',
#    '3',
#    'tall',
#    '1',
#    'm2',
#    'tripod',
#    'base',
#    'requires',
#    'anchors',
#    'secure',
#    'also',
#    'require',
#    'cattle',
#    'exclusion',
#    'typically',
#    'fence',
#    'prevent',
#    'damage',
#    'cattle',
#    'weather',
#    'station',
#    'needs',
#    'sited',
#    'strategically',
#    'avoid',
#    'obstructions',
#    'features',
#    'might',
#    'bias',
#    'weather',
#    'readings',
#    'must',
#    'also',
#    'take',
#    'account',
#    'sensitive',
#    'features',
#    'critical',
#    'habitat',
#    'species',
#    'risk',
#    'cultural',
#    'resources',
#    'project',
#    'assessed',
#    'basic',
#    'impact',
#    'assessment']),
#  (160,
#   ['effort',
#    'manage',
#    'impacts',
#    'deer',
#    'browse',
#    'sensitive',
#    'areas',
#    'rnup',
#    'study',
#    'differences',
#    'browse',
#    'levels',
#    'deer',
#    'excluded',
#    'areas',
#    'approximately',
#    '600',
#    'metres',
#    'deer',
#    'exclusion',
#    'fencing',
#    'installed',
#    'forested',
#    'plot',
#    'rnup',
#    'fencing',
#    'installed',
#    '25',
#    'meters',
#    'main',
#    'road',
#    'continue',
#    '145',
#    'meters',
#    'interior',
#    'forest',
#    'city',
#    'toronto',
#    'road',
#    'closure',
#    'permit',
#    'required',
#    'duration',
#    'project',
#    'area',
#    'surrounding',
#    'site',
#    'densely',
#    'forested',
#    'area',
#    'healthy',
#    'understory',
#    'social',
#    'trails',
#    'area',
#    'used',
#    'access',
#    'routes',
#    'possible',
#    'minimize',
#    'disturbance']),
#  (114,
#   ['parks',
#    'canada',
#    'proposing',
#    'install',
#    'four',
#    'remote',
#    'avalanche',
#    'control',
#    'system',
#    'racs',
#    'units',
#    'mt',
#    'whymper',
#    'currently',
#    'parks',
#    'canada',
#    'agency',
#    'performs',
#    'avalanche',
#    'control',
#    'placing',
#    'explosives',
#    'helicopters',
#    'starting',
#    'zones',
#    'mt',
#    'whymper',
#    'however',
#    'control',
#    'helicopter',
#    'often',
#    'limited',
#    'poor',
#    'visibility',
#    'wind',
#    'starting',
#    'zones',
#    'effecting',
#    'timing',
#    'efficiency',
#    'avalanche',
#    'control',
#    'exposing',
#    'workers',
#    'challenging',
#    'flying',
#    'conditions',
#    'explosives',
#    'use',
#    'rationale',
#    'racs',
#    'paths',
#    'reduce',
#    'impacts',
#    'highway',
#    '93',
#    'south',
#    'highway',
#    'closure',
#    'time',
#    'gains',
#    'operational',
#    'efficiency',
#    'worker',
#    'safety',
#    'total',
#    'footprint',
#    'four',
#    'gazex',
#    'racs',
#    'units',
#    'including',
#    'foundations',
#    'shelters',
#    'pipelines',
#    '230',
#    'maximum',
#    'three',
#    'leveled',
#    'work',
#    'pads',
#    'required',
#    'per',
#    'site',
#    '72',
#    'm²',
#    'footprint',
#    'one',
#    'two',
#    'permanent',
#    'helipads',
#    'may',
#    'also',
#    'required',
#    '50',
#    'm²',
#    'maximum',
#    'footprint']),
#  (272,
#   ['hunters',
#    'lake',
#    'one',
#    'way',
#    'trail',
#    'incorporates',
#    'various',
#    'landscape',
#    'features',
#    'including',
#    'jack',
#    'pine',
#    'ridges',
#    'aspen',
#    'forest',
#    'aquatic',
#    'ecosytems',
#    'large',
#    'fire',
#    'burnt',
#    'throught',
#    'area',
#    '2018',
#    'heavy',
#    'equipment',
#    'brought',
#    'create',
#    'fire',
#    'breaks',
#    'trail',
#    'sustained',
#    'major',
#    'damage',
#    'reroute',
#    'cut',
#    'around',
#    'waterbody',
#    'trees',
#    'felled',
#    'left',
#    'site',
#    'causing',
#    'public',
#    'safety',
#    'hazard',
#    'project',
#    'involves',
#    'bringing',
#    'heavy',
#    'duty',
#    'mulcher',
#    'mulch',
#    'trees',
#    'site',
#    'trail',
#    'reroute',
#    'location',
#    'well',
#    'end',
#    'trail',
#    'regrowth',
#    'heavy',
#    'mown',
#    'traditional',
#    'equipment',
#    'aggregate',
#    'gravel',
#    'hauled',
#    'site',
#    'build',
#    'trail',
#    'tread',
#    'reroute',
#    'areas',
#    'need',
#    'resurfaced',
#    'culvert',
#    'installed',
#    'low',
#    'spot',
#    'trail']),
#  (260,
#   ['parks',
#    'canada',
#    'proposes',
#    'remove',
#    'decommission',
#    'three',
#    'structures',
#    'longer',
#    'operationally',
#    'viable',
#    'including',
#    'horse',
#    'barn',
#    'tack',
#    'shed',
#    'pump',
#    'house',
#    'located',
#    'kootenay',
#    'crossing',
#    'kootenay',
#    'national',
#    'park',
#    'materials',
#    'stored',
#    'site',
#    'also',
#    'removed',
#    'second',
#    'phase',
#    'project',
#    'may',
#    'occur',
#    'involve',
#    'rehabilitation',
#    'area',
#    'involving',
#    'contouring',
#    'reclamation',
#    'vegetation',
#    'site',
#    'project',
#    'located',
#    '43',
#    'kilometres',
#    'km',
#    'north',
#    'intersection',
#    'highway',
#    '93',
#    'highway',
#    '95',
#    'village',
#    'radium',
#    'hot',
#    'springs',
#    'west',
#    'side',
#    'highway',
#    '93',
#    'south',
#    'kootenay',
#    'national',
#    'park',
#    'past',
#    'parks',
#    'canada',
#    'fire',
#    'operations',
#    'facilities',
#    'currently',
#    'use',
#    'project',
#    'reduce',
#    'infrastructure',
#    'longer',
#    'required',
#    'park',
#    'reduce',
#    'operational',
#    'maintenance',
#    'cost',
#    'restore',
#    'area',
#    'natural',
#    'condition',
#    'improve',
#    'important',
#    'wildlife',
#    'habitat',
#    'corridors',
#    'kootenay',
#    'crossing',
#    'area',
#    'removal',
#    'facilities',
#    'restoration',
#    'area',
#    'reduction',
#    'human',
#    'use',
#    'contribute',
#    'park',
#    'canada',
#    'general',
#    'objective',
#    'maintain',
#    'improve',
#    'ecological',
#    'integrity']),
#  (243,
#   ['saskpower',
#    'proposing',
#    'replace',
#    'urban',
#    'power',
#    'pole',
#    'transformer',
#    'take',
#    'equipment',
#    'trench',
#    'lay',
#    'approximately',
#    '30',
#    'metres',
#    'secondary',
#    'cable',
#    'customer',
#    'owned',
#    'splitter',
#    'point',
#    'customer',
#    'responsible',
#    'connections',
#    'ground',
#    'disturbance',
#    'limited',
#    'base',
#    'pole',
#    'short',
#    'run',
#    'trenching',
#    'work',
#    'take',
#    'place',
#    'near',
#    'existing',
#    'underground',
#    'cable',
#    'within',
#    'developed',
#    'area',
#    'existing',
#    'roadways',
#    'nw',
#    '10',
#    '057',
#    '01',
#    'w3m',
#    'within',
#    'waskesiu',
#    'townsite',
#    'prince',
#    'albert',
#    'national',
#    'park',
#    'project',
#    'project',
#    'required',
#    'provide',
#    'additional',
#    'service',
#    'point',
#    'near',
#    'library',
#    'recreation',
#    'hall',
#    'equipment',
#    'expected',
#    'used',
#    'completion',
#    'project',
#    'includes',
#    'digger',
#    'truck',
#    'back',
#    'hoe',
#    'trenching',
#    'equipment',
#    'crew',
#    'trucks',
#    'access',
#    'components',
#    'project',
#    'make',
#    'use',
#    'existing',
#    'roads',
#    'trails',
#    'surface',
#    'disturbance',
#    'expected',
#    'minimized',
#    'base',
#    'pole',
#    '30',
#    'trenching']),
#  (274,
#   ['effort',
#    'reduce',
#    'road',
#    'mortality',
#    'nest',
#    'predation',
#    'rare',
#    'turtles',
#    'thousand',
#    'islands',
#    'national',
#    'park',
#    'planning',
#    'build',
#    'small',
#    'artificial',
#    'nesting',
#    'site',
#    'near',
#    'polly',
#    'creek',
#    'site',
#    'approximately',
#    '5m',
#    'x',
#    '5m',
#    'large',
#    '1m',
#    'deep',
#    'consisting',
#    'sand',
#    'gravel',
#    'surrounded',
#    'cedar',
#    'logs',
#    'turtles',
#    'area',
#    'experiencing',
#    'significant',
#    'road',
#    'mortality',
#    'primarily',
#    'nesting',
#    'road',
#    'shoulders',
#    'near',
#    'complete',
#    'nest',
#    'predation',
#    'documented',
#    'artificial',
#    'nest',
#    'site',
#    'reduce',
#    'number',
#    'turtles',
#    'coming',
#    'onto',
#    'alongside',
#    'road',
#    'materials',
#    'brought',
#    'site',
#    'using',
#    'small',
#    'tractor',
#    'motorised',
#    'wheelbarrow',
#    'construction',
#    'planned',
#    'october',
#    '10',
#    'turtle',
#    'hibernation',
#    'begins'])]

# %% [markdown]
# #### Create master list of all words

# %%
# extract words from tuples
words_only = []

for project in filtered_words:
    
    words_only.append(project[1])

# create master list from list of lists
master_wordlist = []

for sublist in words_only:
    for word in sublist:
        master_wordlist.append(word)
        
print(len(master_wordlist))
# Out:
# 4397

# %% [markdown]
# ### Step 2 : Count the frequency of words in the master word list (project descriptions)

# %%
from collections import Counter

# %%
wordcounts = Counter(master_wordlist)
pprint(wordcounts)
# Out:
# Counter({'project': 68,
#          'site': 52,
#          'park': 50,
#          'area': 46,
#          'national': 36,
#          'work': 35,
#          'island': 32,
#          'existing': 30,
#          'trail': 27,
#          'new': 23,
#          'areas': 22,
#          'fire': 21,
#          'canada': 21,
#          'water': 20,
#          'road': 20,
#          'proposed': 20,
#          'impact': 19,
#          'assessment': 19,
#          'within': 19,
#          'forest': 17,
#          'also': 17,
#          'basic': 17,
#          'required': 17,
#          'parks': 17,
#          'equipment': 17,
#          'bridge': 17,
#          'culvert': 17,
#          'vegetation': 16,
#          'assessed': 15,
#          'access': 15,
#          'management': 15,
#          'approximately': 15,
#          'deer': 15,
#          'station': 15,
#          '2020': 15,
#          'replacement': 15,
#          'habitat': 14,
#          'main': 14,
#          'species': 14,
#          'reduce': 13,
#          'trees': 13,
#          'construction': 13,
#          'lake': 13,
#          'campground': 13,
#          '1': 12,
#          'used': 12,
#          'include': 12,
#          'removed': 11,
#          'place': 11,
#          'impacts': 11,
#          'may': 11,
#          'heavy': 11,
#          'control': 11,
#          'use': 11,
#          'using': 10,
#          'concrete': 10,
#          'south': 10,
#          'installation': 10,
#          'including': 10,
#          'river': 10,
#          'septic': 10,
#          'near': 9,
#          'removal': 9,
#          'located': 9,
#          'structure': 9,
#          'proposing': 9,
#          'expected': 9,
#          'boundary': 9,
#          '5': 9,
#          'reduction': 9,
#          'lagoon': 9,
#          'occur': 9,
#          'risk': 8,
#          '3': 8,
#          '10': 8,
#          'small': 8,
#          'phase': 8,
#          'point': 8,
#          'replace': 8,
#          'disturbance': 8,
#          'systems': 8,
#          'take': 8,
#          'ice': 8,
#          'highway': 8,
#          'sidney': 8,
#          'hand': 7,
#          'adjacent': 7,
#          'installed': 7,
#          'currently': 7,
#          'order': 7,
#          'prince': 7,
#          'albert': 7,
#          'surface': 7,
#          'operations': 7,
#          '8': 7,
#          'building': 7,
#          'islands': 7,
#          'system': 7,
#          'north': 7,
#          'reserve': 7,
#          'safety': 7,
#          'zone': 7,
#          'years': 7,
#          'entrance': 7,
#          'shrubs': 7,
#          'english': 7,
#          'hawthorn': 7,
#          'wildfire': 6,
#          'historic': 6,
#          'fuel': 6,
#          'two': 6,
#          'around': 6,
#          'old': 6,
#          'removing': 6,
#          'etc': 6,
#          'potential': 6,
#          'allow': 6,
#          'back': 6,
#          'includes': 6,
#          'channel': 6,
#          'creek': 6,
#          'fence': 6,
#          'reclamation': 6,
#          'km': 6,
#          'due': 6,
#          'developed': 6,
#          'plant': 6,
#          'large': 6,
#          'native': 6,
#          'pole': 6,
#          'service': 6,
#          'east': 6,
#          'visitor': 6,
#          'objective': 6,
#          'fall': 6,
#          'block': 6,
#          'grazing': 6,
#          'maintenance': 6,
#          'footprint': 6,
#          'grasslands': 6,
#          'cattle': 6,
#          'constructed': 6,
#          'activities': 6,
#          'one': 6,
#          'staff': 6,
#          'would': 6,
#          'winter': 6,
#          'involves': 6,
#          'closure': 6,
#          'purpose': 5,
#          'various': 5,
#          'inspection': 5,
#          'identified': 5,
#          'number': 5,
#          'damaged': 5,
#          'along': 5,
#          'repair': 5,
#          '2': 5,
#          'open': 5,
#          'plan': 5,
#          'ground': 5,
#          'left': 5,
#          'need': 5,
#          'since': 5,
#          'meters': 5,
#          'crossing': 5,
#          'well': 5,
#          'west': 5,
#          'parking': 5,
#          'ecological': 5,
#          'locations': 5,
#          'limited': 5,
#          'additional': 5,
#          'three': 5,
#          'meadow': 5,
#          'ecosystem': 5,
#          'continue': 5,
#          'weather': 5,
#          'connect': 5,
#          'line': 5,
#          'requires': 5,
#          'complete': 5,
#          'x': 5,
#          'completed': 5,
#          'infrastructure': 5,
#          'room': 5,
#          'services': 5,
#          'october': 5,
#          'time': 5,
#          'rocks': 5,
#          'local': 5,
#          'public': 5,
#          'critical': 5,
#          'crossings': 5,
#          'fort': 4,
#          'thinning': 4,
#          'forested': 4,
#          'total': 4,
#          '25': 4,
#          'ha': 4,
#          'tree': 4,
#          'stone': 4,
#          'seawall': 4,
#          'temporary': 4,
#          'addition': 4,
#          'fish': 4,
#          'associated': 4,
#          'dam': 4,
#          '2018': 4,
#          'improve': 4,
#          'community': 4,
#          'edge': 4,
#          '6': 4,
#          'long': 4,
#          'piles': 4,
#          'maintained': 4,
#          'wide': 4,
#          'involve': 4,
#          'conservation': 4,
#          'lot': 4,
#          'herbicide': 4,
#          '12': 4,
#          'hill': 4,
#          'restore': 4,
#          'level': 4,
#          'trenching': 4,
#          'power': 4,
#          'customer': 4,
#          'completion': 4,
#          'trails': 4,
#          'throughout': 4,
#          'docks': 4,
#          'levels': 4,
#          'location': 4,
#          'mooring': 4,
#          'anchors': 4,
#          'planned': 4,
#          'deep': 4,
#          'gravel': 4,
#          'base': 4,
#          'second': 4,
#          'decommission': 4,
#          'restoration': 4,
#          'provide': 4,
#          'natural': 4,
#          'roofing': 4,
#          'bats': 4,
#          'sections': 4,
#          'part': 4,
#          'nest': 4,
#          'design': 4,
#          'designated': 4,
#          'dumping': 4,
#          'field': 4,
#          'remaining': 4,
#          'corridors': 4,
#          'major': 4,
#          'cultural': 4,
#          'season': 4,
#          'route': 4,
#          'exclusion': 4,
#          'footing': 4,
#          'h': 4,
#          'aspen': 4,
#          'fescue': 4,
#          'replacing': 4,
#          'structures': 4,
#          'fencing': 4,
#          'install': 4,
#          'pump': 4,
#          'distribution': 4,
#          'sanitary': 4,
#          'fields': 4,
#          'garlon': 4,
#          'gulf': 4,
#          '5m': 4,
#          'lock': 4,
#          'seeks': 4,
#          'buoys': 4,
#          'kootenay': 4,
#          'ladder': 3,
#          'woody': 3,
#          '2m': 3,
#          'chainsaws': 3,
#          'tools': 3,
#          'shoreline': 3,
#          'provides': 3,
#          'protection': 3,
#          'erosion': 3,
#          'bay': 3,
#          'recent': 3,
#          'result': 3,
#          'failure': 3,
#          'repairs': 3,
#          'necessary': 3,
#          'ocean': 3,
#          'floor': 3,
#          'previously': 3,
#          'big': 3,
#          'caused': 3,
#          'marsh': 3,
#          '0': 3,
#          'ensure': 3,
#          'rabbit': 3,
#          'occurred': 3,
#          'aerial': 3,
#          'pasture': 3,
#          'elk': 3,
#          'increase': 3,
#          'hazard': 3,
#          'section': 3,
#          'stream': 3,
#          'discovery': 3,
#          'centre': 3,
#          '4': 3,
#          'side': 3,
#          'landscaping': 3,
#          'visitors': 3,
#          'machinery': 3,
#          'invasive': 3,
#          'threat': 3,
#          'integrity': 3,
#          'several': 3,
#          'working': 3,
#          'summer': 3,
#          'white': 3,
#          'tailed': 3,
#          'communities': 3,
#          'browsing': 3,
#          'understory': 3,
#          'strategy': 3,
#          'effort': 3,
#          'program': 3,
#          'recovery': 3,
#          'former': 3,
#          'contribute': 3,
#          'electrical': 3,
#          'saskpower': 3,
#          'capacity': 3,
#          'maintain': 3,
#          'truck': 3,
#          'crew': 3,
#          'roads': 3,
#          'high': 3,
#          'end': 3,
#          'life': 3,
#          'buoy': 3,
#          'april': 3,
#          'needs': 3,
#          'rr': 3,
#          '205': 3,
#          'completely': 3,
#          'run': 3,
#          'game': 3,
#          'props': 3,
#          'facilitate': 3,
#          'length': 3,
#          'meter': 3,
#          'redstreak': 3,
#          'first': 3,
#          'federal': 3,
#          'provincial': 3,
#          'created': 3,
#          'brought': 3,
#          'human': 3,
#          'physical': 3,
#          'past': 3,
#          'issue': 3,
#          'prairie': 3,
#          'august': 3,
#          'vehicle': 3,
#          'nesting': 3,
#          'mortality': 3,
#          'pedestrian': 3,
#          'upgrade': 3,
#          'mid': 3,
#          'cavendish': 3,
#          'last': 3,
#          'portion': 3,
#          'sewage': 3,
#          'therefore': 3,
#          'build': 3,
#          'peace': 3,
#          'depth': 3,
#          'stumps': 3,
#          'snowmobile': 3,
#          'hectares': 3,
#          'signage': 3,
#          'condition': 3,
#          'cast': 3,
#          'steel': 3,
#          'group': 3,
#          'waterton': 3,
#          'grassland': 3,
#          'conditions': 3,
#          'diversity': 3,
#          'prevent': 3,
#          'established': 3,
#          'urban': 3,
#          'excavated': 3,
#          'tank': 3,
#          'leaching': 3,
#          'roots': 3,
#          'sewer': 3,
#          'treatment': 3,
#          'loops': 3,
#          'little': 3,
#          '30': 3,
#          'operational': 3,
#          'rock': 3,
#          'navigation': 3,
#          'damage': 3,
#          'kiosk': 3,
#          'cement': 3,
#          'special': 3,
#          'mt': 3,
#          'features': 3,
#          'avalanche': 3,
#          'racs': 3,
#          '93': 3,
#          'reroute': 3,
#          'turtles': 3,
#          'pockets': 2,
#          'treated': 2,
#          'fuels': 2,
#          'reducing': 2,
#          'firesmart': 2,
#          'stand': 2,
#          'reduced': 2,
#          'dense': 2,
#          'thinned': 2,
#          'felling': 2,
#          'deficiencies': 2,
#          'could': 2,
#          'intends': 2,
#          'repairing': 2,
#          'displaced': 2,
#          'stones': 2,
#          'degraded': 2,
#          'bed': 2,
#          'collected': 2,
#          'placed': 2,
#          'replaced': 2,
#          'fisheries': 2,
#          'act': 2,
#          'authorization': 2,
#          'dfo': 2,
#          'projects': 2,
#          'measures': 2,
#          'mainland': 2,
#          'channels': 2,
#          'filled': 2,
#          'silt': 2,
#          'depths': 2,
#          'future': 2,
#          'spread': 2,
#          'outside': 2,
#          'create': 2,
#          'lines': 2,
#          'put': 2,
#          'cookson': 2,
#          'protect': 2,
#          'repaired': 2,
#          'northern': 2,
#          'directly': 2,
#          'cleared': 2,
#          'linear': 2,
#          'berms': 2,
#          'soil': 2,
#          'wood': 2,
#          'efforts': 2,
#          'term': 2,
#          'across': 2,
#          'debris': 2,
#          'vehicles': 2,
#          'closed': 2,
#          'concern': 2,
#          'reclaimed': 2,
#          'superior': 2,
#          'marine': 2,
#          'nipigon': 2,
#          'hectare': 2,
#          'interpretive': 2,
#          'elements': 2,
#          'single': 2,
#          'space': 2,
#          'interior': 2,
#          'exterior': 2,
#          'excavation': 2,
#          'yellow': 2,
#          'toadflax': 2,
#          'ability': 2,
#          'densely': 2,
#          'making': 2,
#          'manner': 2,
#          'nearly': 2,
#          'intensive': 2,
#          'agriculture': 2,
#          'agri': 2,
#          'cabin': 2,
#          'sites': 2,
#          'hyperabundant': 2,
#          'populations': 2,
#          'changing': 2,
#          'response': 2,
#          'numbers': 2,
#          'herd': 2,
#          'conducted': 2,
#          '2012': 2,
#          'goal': 2,
#          'eg': 2,
#          'pine': 2,
#          'per': 2,
#          'healthy': 2,
#          'population': 2,
#          'achieved': 2,
#          'partnering': 2,
#          'entail': 2,
#          'grid': 2,
#          'solar': 2,
#          'panels': 2,
#          'environment': 2,
#          'kejimkujik': 2,
#          'foundations': 2,
#          'nova': 2,
#          'reviewed': 2,
#          'transformer': 2,
#          'wooden': 2,
#          'metering': 2,
#          '01': 2,
#          'w3m': 2,
#          'quality': 2,
#          'digger': 2,
#          'hoe': 2,
#          'trucks': 2,
#          'components': 2,
#          'make': 2,
#          'minimized': 2,
#          'dock': 2,
#          'thousand': 2,
#          'specifically': 2,
#          'floating': 2,
#          'designed': 2,
#          'shore': 2,
#          'points': 2,
#          'replacements': 2,
#          'minor': 2,
#          'carried': 2,
#          'camping': 2,
#          'activity': 2,
#          'strathcona': 2,
#          'county': 2,
#          'larger': 2,
#          'flow': 2,
#          'fill': 2,
#          'red': 2,
#          'experience': 2,
#          'based': 2,
#          'history': 2,
#          'participants': 2,
#          'successfully': 2,
#          'placement': 2,
#          'upon': 2,
#          'wastewater': 2,
#          'surrounding': 2,
#          'bc': 2,
#          'multi': 2,
#          'year': 2,
#          'regime': 2,
#          'grasses': 2,
#          'better': 2,
#          'prescribed': 2,
#          '2021': 2,
#          'cedar': 2,
#          '100m': 2,
#          'possibly': 2,
#          'roof': 2,
#          'soffits': 2,
#          'attic': 2,
#          'roosting': 2,
#          'unknown': 2,
#          'pending': 2,
#          'metal': 2,
#          'proposes': 2,
#          'permit': 2,
#          'livestock': 2,
#          'supporting': 2,
#          'maintaining': 2,
#          'fences': 2,
#          'beach': 2,
#          'active': 2,
#          'colony': 2,
#          'corridor': 2,
#          'passes': 2,
#          'almost': 2,
#          'class': 2,
#          'coast': 2,
#          'riparian': 2,
#          'span': 2,
#          'support': 2,
#          'least': 2,
#          'works': 2,
#          'anticipated': 2,
#          'effects': 2,
#          'scope': 2,
#          'undertaken': 2,
#          'require': 2,
#          'lunchroom': 2,
#          'rehabilitated': 2,
#          'partially': 2,
#          'agricultural': 2,
#          'travel': 2,
#          'disturbed': 2,
#          'either': 2,
#          'june': 2,
#          'hurricane': 2,
#          'dorian': 2,
#          'majority': 2,
#          'originally': 2,
#          'heavily': 2,
#          'landscaped': 2,
#          'roadways': 2,
#          '2015': 2,
#          'pits': 2,
#          'construct': 2,
#          'facility': 2,
#          'aquatic': 2,
#          'roadway': 2,
#          'grading': 2,
#          'related': 2,
#          'resources': 2,
#          'bia': 2,
#          'ii': 2,
#          'staging': 2,
#          'flooding': 2,
#          'measurements': 2,
#          'adequate': 2,
#          'brushing': 2,
#          'snowmobiling': 2,
#          'residents': 2,
#          'trout': 2,
#          'alongside': 2,
#          'significant': 2,
#          'poor': 2,
#          'supported': 2,
#          'bypass': 2,
#          'pipe': 2,
#          '2019': 2,
#          'classified': 2,
#          'ea': 2,
#          'environmental': 2,
#          'evaluated': 2,
#          'trend': 2,
#          'encroachment': 2,
#          'onto': 2,
#          'parkland': 2,
#          'burn': 2,
#          'unit': 2,
#          'lower': 2,
#          'burning': 2,
#          'remove': 2,
#          'overhead': 2,
#          'emergency': 2,
#          'greater': 2,
#          'sage': 2,
#          'grouse': 2,
#          'tall': 2,
#          'pressure': 2,
#          'able': 2,
#          'understorey': 2,
#          'fenced': 2,
#          'permanent': 2,
#          'responsible': 2,
#          'properties': 2,
#          'rouge': 2,
#          'residential': 2,
#          'disposal': 2,
#          'health': 2,
#          'contain': 2,
#          'tanks': 2,
#          'underground': 2,
#          'excavations': 2,
#          'newman': 2,
#          'sound': 2,
#          'malady': 2,
#          'head': 2,
#          'house': 2,
#          'mains': 2,
#          'e': 2,
#          'f': 2,
#          'respectively': 2,
#          'shelters': 2,
#          'day': 2,
#          'junior': 2,
#          'commissariat': 2,
#          'officers': 2,
#          'quarters': 2,
#          'heritage': 2,
#          'important': 2,
#          'academic': 2,
#          '2008': 2,
#          'traditional': 2,
#          'methods': 2,
#          'cut': 2,
#          'applied': 2,
#          'regrowth': 2,
#          'selected': 2,
#          'documented': 2,
#          'avoid': 2,
#          'march': 2,
#          'periodically': 2,
#          'september': 2,
#          'abutments': 2,
#          'short': 2,
#          'low': 2,
#          'routes': 2,
#          'purposes': 2,
#          'options': 2,
#          'possible': 2,
#          'installing': 2,
#          'weekend': 2,
#          'crean': 2,
#          'boat': 2,
#          'hazardous': 2,
#          'way': 2,
#          'nations': 2,
#          'workers': 2,
#          'decking': 2,
#          'thomas': 2,
#          'brook': 2,
#          '21': 2,
#          '1m': 2,
#          'adding': 2,
#          '7': 2,
#          'strategically': 2,
#          'pender': 2,
#          'agency': 2,
#          'primarily': 2,
#          'aggregate': 2,
#          '16th': 2,
#          'avenue': 2,
#          'information': 2,
#          'sensitive': 2,
#          'browse': 2,
#          'rnup': 2,
#          'metres': 2,
#          'four': 2,
#          'units': 2,
#          'whymper': 2,
#          'explosives': 2,
#          'starting': 2,
#          'zones': 2,
#          'efficiency': 2,
#          'maximum': 2,
#          'm²': 2,
#          'longer': 2,
#          'materials': 2,
#          'facilities': 2,
#          'cable': 2,
#          'predation': 2,
#          'artificial': 2,
#          'walsh': 1,
#          'absence': 1,
#          'maturity': 1,
#          'resulted': 1,
#          'accumulation': 1,
#          'dying': 1,
#          'mature': 1,
#          'downed': 1,
#          'material': 1,
#          'load': 1,
#          'administering': 1,
#          'techniques': 1,
#          'limbs': 1,
#          'pruned': 1,
#          'height': 1,
#          'deadfall': 1,
#          'armoured': 1,
#          'perimeter': 1,
#          'st': 1,
#          'andrews': 1,
#          'blockhouse': 1,
#          'wave': 1,
#          'action': 1,
#          'passamaquoddy': 1,
#          'cause': 1,
#          'rehabilitate': 1,
#          'raise': 1,
#          'geotextile': 1,
#          'fabric': 1,
#          'reinstating': 1,
#          'sitting': 1,
#          'fitted': 1,
#          'pieces': 1,
#          'relation': 1,
#          'tsw': 1,
#          'trenton': 1,
#          'glen': 1,
#          'miller': 1,
#          'provisions': 1,
#          'offsetting': 1,
#          'causeway': 1,
#          '1950': 1,
#          'decreased': 1,
#          'flows': 1,
#          'cattails': 1,
#          'cover': 1,
#          'entire': 1,
#          'expand': 1,
#          'enhancements': 1,
#          'constructing': 1,
#          'widening': 1,
#          'deepening': 1,
#          'cattail': 1,
#          'width': 1,
#          'stay': 1,
#          'offset': 1,
#          'enhancement': 1,
#          'strategic': 1,
#          'dozer': 1,
#          'border': 1,
#          'push': 1,
#          'newly': 1,
#          'takes': 1,
#          'responsibility': 1,
#          'following': 1,
#          '13': 1,
#          'panp': 1,
#          'restricting': 1,
#          'weed': 1,
#          'seeding': 1,
#          'opening': 1,
#          'flat': 1,
#          'free': 1,
#          '700': 1,
#          'average': 1,
#          '40': 1,
#          'fireguard': 1,
#          'crossed': 1,
#          'destroyed': 1,
#          'shallow': 1,
#          'ford': 1,
#          'helipad': 1,
#          'midway': 1,
#          'trailhead': 1,
#          'washed': 1,
#          'waterfront': 1,
#          'brennan': 1,
#          'drive': 1,
#          'detached': 1,
#          'garage': 1,
#          'outdoor': 1,
#          '300': 1,
#          'square': 1,
#          'story': 1,
#          'multiuse': 1,
#          'exhibit': 1,
#          'administrative': 1,
#          'serve': 1,
#          'hub': 1,
#          'administration': 1,
#          'backfilling': 1,
#          'widely': 1,
#          'distributed': 1,
#          'perennial': 1,
#          'reproduces': 1,
#          'seed': 1,
#          'extensive': 1,
#          'creeping': 1,
#          'rhizome': 1,
#          'extremely': 1,
#          'hardy': 1,
#          'infest': 1,
#          'crowd': 1,
#          'spraying': 1,
#          'success': 1,
#          'biological': 1,
#          'agent': 1,
#          'offers': 1,
#          'option': 1,
#          'labour': 1,
#          'food': 1,
#          'carry': 1,
#          'trials': 1,
#          'rhinusa': 1,
#          'pilosa': 1,
#          'affected': 1,
#          'prospect': 1,
#          'mile': 1,
#          'weevils': 1,
#          'obtained': 1,
#          'foods': 1,
#          'charge': 1,
#          'released': 1,
#          'late': 1,
#          'threaten': 1,
#          'value': 1,
#          'varied': 1,
#          'led': 1,
#          'distinct': 1,
#          'lack': 1,
#          'composition': 1,
#          'outlined': 1,
#          'processes': 1,
#          'pitch': 1,
#          'began': 1,
#          '2007': 1,
#          'km2': 1,
#          'regeneration': 1,
#          'attain': 1,
#          'density': 1,
#          'mohawks': 1,
#          'akwesasne': 1,
#          'harvest': 1,
#          'monitoring': 1,
#          'track': 1,
#          'effectiveness': 1,
#          '330': 1,
#          'tied': 1,
#          'photovoltaic': 1,
#          'climate': 1,
#          'change': 1,
#          'capmon': 1,
#          'frontcountry': 1,
#          'generate': 1,
#          'renewable': 1,
#          'electricity': 1,
#          'greenhouse': 1,
#          'gases': 1,
#          'mounted': 1,
#          'racking': 1,
#          'anchored': 1,
#          'screw': 1,
#          'poured': 1,
#          'wiring': 1,
#          'array': 1,
#          'scotia': 1,
#          'via': 1,
#          'mount': 1,
#          'directionally': 1,
#          'drill': 1,
#          '65': 1,
#          'supplied': 1,
#          'se': 1,
#          '16': 1,
#          '57': 1,
#          'bucket': 1,
#          'directional': 1,
#          'boring': 1,
#          'bell': 1,
#          'holes': 1,
#          'multiple': 1,
#          'cycle': 1,
#          'accommodate': 1,
#          'higher': 1,
#          'anchoring': 1,
#          'boardwalks': 1,
#          'kiosks': 1,
#          'landing': 1,
#          'adjustments': 1,
#          'adelaide': 1,
#          'grenadier': 1,
#          'georgina': 1,
#          'constance': 1,
#          'mulcaster': 1,
#          'milton': 1,
#          'stovin': 1,
#          'commence': 1,
#          'conclude': 1,
#          'november': 1,
#          'osten': 1,
#          'collapsed': 1,
#          'rusted': 1,
#          'flooded': 1,
#          'beaver': 1,
#          'beavers': 1,
#          'washout': 1,
#          'impassable': 1,
#          'diameter': 1,
#          '600mm': 1,
#          'sizes': 1,
#          'kept': 1,
#          'stock': 1,
#          '450mm': 1,
#          'inch': 1,
#          'minus': 1,
#          'pit': 1,
#          'top': 1,
#          'sides': 1,
#          'plans': 1,
#          '2011': 1,
#          'strategies': 1,
#          'develop': 1,
#          'menu': 1,
#          'opportunities': 1,
#          'enhance': 1,
#          'canadians': 1,
#          'discover': 1,
#          'enjoy': 1,
#          'escape': 1,
#          'fetch': 1,
#          'quest': 1,
#          'basque': 1,
#          'whaling': 1,
#          'puzzles': 1,
#          'trivial': 1,
#          'tasks': 1,
#          'solve': 1,
#          'board': 1,
#          'walk': 1,
#          'feet': 1,
#          'extend': 1,
#          'step': 1,
#          'unto': 1,
#          'platform': 1,
#          'bedding': 1,
#          'pile': 1,
#          'furthermore': 1,
#          'samples': 1,
#          'analyzed': 1,
#          'confirm': 1,
#          'contaminated': 1,
#          'meets': 1,
#          'guidelines': 1,
#          'omrr': 1,
#          'csr': 1,
#          'ccme': 1,
#          'subunit': 1,
#          'called': 1,
#          'harvested': 1,
#          '2002': 1,
#          'restored': 1,
#          'historical': 1,
#          'targeting': 1,
#          'full': 1,
#          'remains': 1,
#          'prepare': 1,
#          'start': 1,
#          'revegetation': 1,
#          'shingle': 1,
#          'watchmen': 1,
#          'accommodations': 1,
#          'hotspring': 1,
#          'compromised': 1,
#          'known': 1,
#          'bat': 1,
#          'maternity': 1,
#          'roost': 1,
#          'roughly': 1,
#          'away': 1,
#          'ellen': 1,
#          'leaks': 1,
#          'observed': 1,
#          'roofs': 1,
#          'redone': 1,
#          'possibility': 1,
#          'cabins': 1,
#          'residence': 1,
#          'license': 1,
#          'occupation': 1,
#          'graze': 1,
#          'mankota': 1,
#          'acquisition': 1,
#          'domestic': 1,
#          'function': 1,
#          'moving': 1,
#          'paddocks': 1,
#          'watering': 1,
#          'checking': 1,
#          'sable': 1,
#          'traverses': 1,
#          'tern': 1,
#          'movements': 1,
#          'creates': 1,
#          'birds': 1,
#          'chick': 1,
#          'seasonal': 1,
#          'narrowest': 1,
#          'dunes': 1,
#          'devoid': 1,
#          'easily': 1,
#          'navigable': 1,
#          'sinpr': 1,
#          'address': 1,
#          'resulting': 1,
#          'a2': 1,
#          'pacific': 1,
#          'rim': 1,
#          'traversing': 1,
#          'meet': 1,
#          'harm': 1,
#          'window': 1,
#          'dry': 1,
#          'mitigation': 1,
#          'understood': 1,
#          'thus': 1,
#          'previous': 1,
#          'experienced': 1,
#          'devastating': 1,
#          'burned': 1,
#          'beyond': 1,
#          'wash': 1,
#          'bathroom': 1,
#          'daily': 1,
#          'personal': 1,
#          'drawings': 1,
#          'situated': 1,
#          'northeast': 1,
#          'corner': 1,
#          '100': 1,
#          'ago': 1,
#          'grown': 1,
#          'regenerative': 1,
#          'spruce': 1,
#          'paved': 1,
#          'covering': 1,
#          'graded': 1,
#          'communications': 1,
#          'routed': 1,
#          'drawing': 1,
#          'begin': 1,
#          'reconstructed': 1,
#          '2017': 1,
#          'grass': 1,
#          'made': 1,
#          'landfall': 1,
#          'pei': 1,
#          'devastated': 1,
#          'softwood': 1,
#          'standing': 1,
#          'reasons': 1,
#          'lunch': 1,
#          'tendered': 1,
#          'contract': 1,
#          'beginning': 1,
#          'crops': 1,
#          'hay': 1,
#          'potato': 1,
#          'grain': 1,
#          'clover': 1,
#          'grahams': 1,
#          'lane': 1,
#          'lots': 1,
#          'walking': 1,
#          'majorly': 1,
#          'reconfigured': 1,
#          'times': 1,
#          '70': 1,
#          'evident': 1,
#          'photos': 1,
#          'amounts': 1,
#          'trucked': 1,
#          'surfaces': 1,
#          'ditches': 1,
#          'disturbing': 1,
#          'anything': 1,
#          'found': 1,
#          'eia': 1,
#          'encompassed': 1,
#          'developing': 1,
#          'archaeological': 1,
#          'test': 1,
#          'dug': 1,
#          'conduct': 1,
#          'watercraft': 1,
#          'inspections': 1,
#          'gate': 1,
#          'realignment': 1,
#          'preparation': 1,
#          'paving': 1,
#          'washroom': 1,
#          'utility': 1,
#          'undertaking': 1,
#          'assess': 1,
#          'pathway': 1,
#          'changed': 1,
#          'pria': 1,
#          'amendment': 1,
#          'signed': 1,
#          'finalized': 1,
#          'determined': 1,
#          'remained': 1,
#          'fully': 1,
#          'iv': 1,
#          'enter': 1,
#          'mobilizing': 1,
#          'moose': 1,
#          'pumps': 1,
#          'pack': 1,
#          'continues': 1,
#          'snow': 1,
#          'fallen': 1,
#          'willows': 1,
#          'coordination': 1,
#          'southern': 1,
#          'chipewyan': 1,
#          'rocher': 1,
#          'plowing': 1,
#          'quatre': 1,
#          'forche': 1,
#          'permitted': 1,
#          'gros': 1,
#          'morne': 1,
#          'commercial': 1,
#          'covers': 1,
#          '179': 1,
#          'kilometers': 1,
#          '431': 1,
#          'gulch': 1,
#          '541': 1,
#          'northwest': 1,
#          'facing': 1,
#          'slope': 1,
#          'tablelands': 1,
#          'net': 1,
#          '134': 1,
#          'iii': 1,
#          'whereas': 1,
#          'expanded': 1,
#          '195': 1,
#          'wilderness': 1,
#          '1957': 1,
#          'spalls': 1,
#          'exposed': 1,
#          'rebar': 1,
#          'cracks': 1,
#          'combination': 1,
#          'box': 1,
#          'consists': 1,
#          'alignment': 1,
#          'wingwalls': 1,
#          'convey': 1,
#          'storm': 1,
#          'check': 1,
#          'flood': 1,
#          'without': 1,
#          'overtopping': 1,
#          'divided': 1,
#          'phases': 1,
#          'c': 1,
#          'mto': 1,
#          'screening': 1,
#          'document': 1,
#          'prepared': 1,
#          'requirements': 1,
#          'gaps': 1,
#          'team': 1,
#          'lakes': 1,
#          'implementation': 1,
#          'camp': 1,
#          'wishbone': 1,
#          'reverse': 1,
#          'historically': 1,
#          'mean': 1,
#          'interval': 1,
#          'ecoregions': 1,
#          'variety': 1,
#          'encompasses': 1,
#          '170': 1,
#          'pre': 1,
#          'guard': 1,
#          'spring': 1,
#          'leaf': 1,
#          'execution': 1,
#          'every': 1,
#          'thereafter': 1,
#          'ecoregion': 1,
#          'buried': 1,
#          'crosses': 1,
#          'follow': 1,
#          'intersects': 1,
#          'black': 1,
#          'dog': 1,
#          'lands': 1,
#          'protected': 1,
#          '2013': 1,
#          'towards': 1,
#          'goals': 1,
#          'poles': 1,
#          'vertical': 1,
#          'chronic': 1,
#          'threatens': 1,
#          'survival': 1,
#          'many': 1,
#          'decades': 1,
#          'intensity': 1,
#          'greatly': 1,
#          'abundance': 1,
#          'plants': 1,
#          'lost': 1,
#          'much': 1,
#          'structural': 1,
#          'fewer': 1,
#          'grow': 1,
#          'saplings': 1,
#          'older': 1,
#          'die': 1,
#          'disappeared': 1,
#          'trajectory': 1,
#          'unless': 1,
#          'effective': 1,
#          'done': 1,
#          'establish': 1,
#          'rejuvenate': 1,
#          'planted': 1,
#          'producing': 1,
#          'seeds': 1,
#          'accomplish': 1,
#          'propose': 1,
#          'ten': 1,
#          'planting': 1,
#          'give': 1,
#          'become': 1,
#          'seasonally': 1,
#          '2023': 1,
#          'overseeing': 1,
#          'tenanted': 1,
#          'assets': 1,
#          'trenches': 1,
#          'dwelling': 1,
#          'beds': 1,
#          'depending': 1,
#          'final': 1,
#          'barrier': 1,
#          'driven': 1,
#          'topsoil': 1,
#          'stockpiled': 1,
#          'compliance': 1,
#          'ontario': 1,
#          'code': 1,
#          'amended': 1,
#          'minimum': 1,
#          'provided': 1,
#          'controlled': 1,
#          'campgrounds': 1,
#          'terra': 1,
#          'leaving': 1,
#          'stave': 1,
#          'sewers': 1,
#          'j': 1,
#          'k': 1,
#          'l': 1,
#          'g': 1,
#          'hose': 1,
#          'boxes': 1,
#          'r': 1,
#          'q': 1,
#          'vicinity': 1,
#          'loop': 1,
#          'kitchen': 1,
#          'washrooms': 1,
#          'bottling': 1,
#          'filling': 1,
#          'stations': 1,
#          'trickling': 1,
#          'tenting': 1,
#          'recapitalization': 1,
#          'federally': 1,
#          'recognized': 1,
#          'series': 1,
#          'initiative': 1,
#          'initiated': 1,
#          'butler': 1,
#          'barracks': 1,
#          'structurally': 1,
#          'unsound': 1,
#          'certain': 1,
#          'renovations': 1,
#          'substantial': 1,
#          'stabilization': 1,
#          'repointing': 1,
#          'chimneys': 1,
#          'reconstruction': 1,
#          'walls': 1,
#          'improvements': 1,
#          'drainage': 1,
#          'upgrading': 1,
#          'utilities': 1,
#          'explore': 1,
#          'uses': 1,
#          'crataegus': 1,
#          'monogyna': 1,
#          'key': 1,
#          'researchers': 1,
#          'ongoing': 1,
#          'progressively': 1,
#          'expanding': 1,
#          'meadows': 1,
#          'aggressively': 1,
#          'resprout': 1,
#          'untreated': 1,
#          'root': 1,
#          'fragments': 1,
#          'rendering': 1,
#          'pulling': 1,
#          'clipping': 1,
#          'ineffective': 1,
#          'continued': 1,
#          'invasion': 1,
#          'degrade': 1,
#          'supplanting': 1,
#          'favor': 1,
#          'rather': 1,
#          'experimental': 1,
#          'approach': 1,
#          'taken': 1,
#          'compare': 1,
#          'efficacy': 1,
#          'chemical': 1,
#          'determine': 1,
#          'best': 1,
#          'practices': 1,
#          'saws': 1,
#          'brush': 1,
#          'cutters': 1,
#          'brand': 1,
#          'triclopyr': 1,
#          'trial': 1,
#          'targets': 1,
#          'broadleaf': 1,
#          'controls': 1,
#          'resprouting': 1,
#          'sedges': 1,
#          'peer': 1,
#          'research': 1,
#          'drift': 1,
#          'runoff': 1,
#          'consistent': 1,
#          'integrated': 1,
#          'pest': 1,
#          'december': 1,
#          'fundy': 1,
#          'initiate': 1,
#          'hazards': 1,
#          'excessive': 1,
#          'growth': 1,
#          'seepage': 1,
#          'cavities': 1,
#          'decaying': 1,
#          'uprooted': 1,
#          'competition': 1,
#          'undesired': 1,
#          'obscure': 1,
#          'observe': 1,
#          'bennett': 1,
#          'wolfe': 1,
#          'retaining': 1,
#          'unchecked': 1,
#          'pose': 1,
#          'serious': 1,
#          'strength': 1,
#          'stabilize': 1,
#          'growing': 1,
#          'repeated': 1,
#          'annually': 1,
#          'investigate': 1,
#          'see': 1,
#          'mersey': 1,
#          'mills': 1,
#          'falls': 1,
#          'nearby': 1,
#          'pontoon': 1,
#          '8m': 1,
#          'bank': 1,
#          '20m2': 1,
#          '30m': 1,
#          'banks': 1,
#          'networks': 1,
#          'current': 1,
#          'implemented': 1,
#          'plains': 1,
#          'minnow': 1,
#          'listed': 1,
#          'schedule': 1,
#          'tributary': 1,
#          'cofferdam': 1,
#          'upstream': 1,
#          'downstream': 1,
#          'dewatering': 1,
#          'approaches': 1,
#          'creating': 1,
#          'thanksgiving': 1,
#          'prior': 1,
#          'victoria': 1,
#          'spans': 1,
#          'canal': 1,
#          'piers': 1,
#          'taking': 1,
#          'interfere': 1,
#          '42': 1,
#          'joins': 1,
#          '3rd': 1,
#          'heart': 1,
#          'boaters': 1,
#          'submerged': 1,
#          'motor': 1,
#          'legs': 1,
#          'partial': 1,
#          'modification': 1,
#          'volunteers': 1,
#          '2003': 1,
#          'relocated': 1,
#          'concerned': 1,
#          'users': 1,
#          'approached': 1,
#          'proposal': 1,
#          'permanently': 1,
#          'rectify': 1,
#          'boulders': 1,
#          'backhoe': 1,
#          'thumb': 1,
#          'attachment': 1,
#          'barge': 1,
#          'picked': 1,
#          'moved': 1,
#          'passing': 1,
#          'boats': 1,
#          'saanich': 1,
#          'incorporate': 1,
#          'culturally': 1,
#          'appropriate': 1,
#          'content': 1,
#          'consultation': 1,
#          'salish': 1,
#          'carving': 1,
#          'excavator': 1,
#          'mixer': 1,
#          'mitigations': 1,
#          '15': 1,
#          'coincide': 1,
#          'revitalization': 1,
#          'forms': 1,
#          'backcountry': 1,
#          'liberty': 1,
#          'asset': 1,
#          'essential': 1,
#          'deteriorated': 1,
#          '7m': 1,
#          'timbers': 1,
#          'stringers': 1,
#          'waste': 1,
#          'disposed': 1,
#          'outcomes': 1,
#          'sought': 1,
#          'outcome': 1,
#          'spit': 1,
#          '14': 1,
#          'protecting': 1,
#          'eelgrass': 1,
#          'attached': 1,
#          'chains': 1,
#          'cubed': 1,
#          'gravity': 1,
#          'set': 1,
#          'return': 1,
#          'regulatory': 1,
#          'notices': 1,
#          'preservation': 1,
#          'missing': 1,
#          'add': 1,
#          'informed': 1,
#          'entails': 1,
#          'selective': 1,
#          'pruning': 1,
#          'principles': 1,
#          'loading': 1,
#          'providing': 1,
#          'safer': 1,
#          'firefighters': 1,
#          'event': 1,
#          'wildland': 1,
#          'interface': 1,
#          'tumbo': 1,
#          'wetland': 1,
#          'saturna': 1,
#          'warburton': 1,
#          'pike': 1,
#          'summit': 1,
#          'roe': 1,
#          'january': 1,
#          'latitude': 1,
#          'longitude': 1,
#          'pca': 1,
#          'segment': 1,
#          'segments': 1,
#          'bob': 1,
#          'hunter': 1,
#          'memorial': 1,
#          'boyle': 1,
#          'cemetery': 1,
#          'intended': 1,
#          'boardwalk': 1,
#          'wet': 1,
#          'markham': 1,
#          'gateway': 1,
#          'welcome': 1,
#          'separate': 1,
#          'farming': 1,
#          'mackenzie': 1,
#          '407': 1,
#          '14th': 1,
#          'routing': 1,
#          'private': 1,
#          'property': 1,
#          'owner': 1,
#          'permission': 1,
#          'mac': 1,
#          'ave': 1,
#          'investigated': 1,
#          'real': 1,
#          'otherwise': 1,
#          'coverage': 1,
#          'programs': 1,
#          'm2': 1,
#          'tripod': 1,
#          'secure': 1,
#          'typically': 1,
#          'sited': 1,
#          'obstructions': 1,
#          'might': 1,
#          'bias': 1,
#          'readings': 1,
#          'must': 1,
#          'account': 1,
#          'manage': 1,
#          'study': 1,
#          'differences': 1,
#          'excluded': 1,
#          '600': 1,
#          'plot': 1,
#          '145': 1,
#          'city': 1,
#          'toronto': 1,
#          'duration': 1,
#          'social': 1,
#          'minimize': 1,
#          'remote': 1,
#          'performs': 1,
#          'placing': 1,
#          'helicopters': 1,
#          'however': 1,
#          'helicopter': 1,
#          'often': 1,
#          'visibility': 1,
#          'wind': 1,
#          'effecting': 1,
#          'timing': 1,
#          'exposing': 1,
#          'challenging': 1,
#          'flying': 1,
#          'rationale': 1,
#          'paths': 1,
#          'gains': 1,
#          'worker': 1,
#          'gazex': 1,
#          'pipelines': 1,
#          '230': 1,
#          'leveled': 1,
#          'pads': 1,
#          '72': 1,
#          'helipads': 1,
#          '50': 1,
#          'hunters': 1,
#          'incorporates': 1,
#          'landscape': 1,
#          'jack': 1,
#          'ridges': 1,
#          'ecosytems': 1,
#          'burnt': 1,
#          'throught': 1,
#          'breaks': 1,
#          'sustained': 1,
#          'waterbody': 1,
#          'felled': 1,
#          'causing': 1,
#          'bringing': 1,
#          'duty': 1,
#          'mulcher': 1,
#          'mulch': 1,
#          'mown': 1,
#          'hauled': 1,
#          'tread': 1,
#          'resurfaced': 1,
#          'spot': 1,
#          'operationally': 1,
#          'viable': 1,
#          'horse': 1,
#          'barn': 1,
#          'tack': 1,
#          'shed': 1,
#          'stored': 1,
#          'rehabilitation': 1,
#          'involving': 1,
#          'contouring': 1,
#          '43': 1,
#          'kilometres': 1,
#          'intersection': 1,
#          '95': 1,
#          'village': 1,
#          'radium': 1,
#          'hot': 1,
#          'springs': 1,
#          'cost': 1,
#          'wildlife': 1,
#          'general': 1,
#          'trench': 1,
#          'lay': 1,
#          'secondary': 1,
#          'owned': 1,
#          'splitter': 1,
#          'connections': 1,
#          'nw': 1,
#          '057': 1,
#          'waskesiu': 1,
#          'townsite': 1,
#          'library': 1,
#          'recreation': 1,
#          'hall': 1,
#          'rare': 1,
#          'planning': 1,
#          'polly': 1,
#          'consisting': 1,
#          'sand': 1,
#          'surrounded': 1,
#          'logs': 1,
#          'experiencing': 1,
#          'shoulders': 1,
#          'coming': 1,
#          'tractor': 1,
#          'motorised': 1,
#          'wheelbarrow': 1,
#          'turtle': 1,
#          'hibernation': 1,
#          'begins': 1})

# %% [markdown]
# #### Refine count to words with 3 syllables or more

# %%
# Import a library for counting syllables

nltk.download('cmudict')
from nltk.corpus import cmudict
d = cmudict.dict()
# Out:
# [nltk_data] Downloading package cmudict to
# [nltk_data]     /Users/whitneylight/nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!

# %%
# define function that returns the number of syllables

def nsyl(word): 
    try:
        return [len(list(y for y in x if y[-1].isdigit())) for x in d[word.lower()]]
    except KeyError:
        return syllables(word) # helper function

# %%
# define helper function to count sylls in words that are not in the dictionary

def syllables(word):
    #referred from stackoverflow.com/questions/14541303/count-the-number-of-syllables-in-a-word
    count = 0
    vowels = 'aeiouy'
    word = word.lower()
    if word[0] in vowels:
        count +=1
    for index in range(1,len(word)):
        if word[index] in vowels and word[index-1] not in vowels:
            count +=1
    if word.endswith('e'):
        count -= 1
    if word.endswith('le'):
        count += 1
    if count == 0:
        count += 1
    return [count]

# %%
print(nsyl("fire"))
print(nsyl("firesmart"))
# Out:
# [2, 1]
# [3]

# %%
# Get rid of numbers in the word list

wordlist_clean = [word for word in master_wordlist if word.isdigit() == False]

print(wordlist_clean)
# Out:
# ['purpose', 'project', 'reduce', 'risk', 'wildfire', 'fort', 'walsh', 'national', 'historic', 'site', 'thinning', 'pockets', 'fuel', 'two', 'forested', 'areas', 'near', 'fort', 'site', 'total', 'area', 'treated', 'ha', 'absence', 'fire', 'maturity', 'forest', 'around', 'fort', 'site', 'resulted', 'accumulation', 'ladder', 'fuels', 'old', 'dying', 'mature', 'trees', 'downed', 'woody', 'material', 'reducing', 'fuel', 'load', 'site', 'removing', 'trees', 'administering', 'various', 'firesmart', 'techniques', 'stand', 'thinning', 'ladder', 'fuel', 'removal', 'etc', 'impact', 'wildfire', 'site', 'reduced', 'ladder', 'fuels', 'removed', 'tree', 'limbs', 'pruned', 'height', '2m', 'using', 'chainsaws', 'various', 'hand', 'tools', 'dense', 'areas', 'thinned', 'hand', 'felling', 'deadfall', 'also', 'removed', 'hand', 'project', 'assessed', 'basic', 'impact', 'assessment', 'armoured', 'stone', 'seawall', 'located', 'around', 'perimeter', 'shoreline', 'adjacent', 'st', 'andrews', 'blockhouse', 'national', 'historic', 'site', 'provides', 'protection', 'erosion', 'water', 'wave', 'action', 'passamaquoddy', 'bay', 'recent', 'inspection', 'seawall', 'identified', 'number', 'deficiencies', 'could', 'result', 'potential', 'failure', 'structure', 'cause', 'erosion', 'site', 'shoreline', 'protection', 'seawall', 'repairs', 'project', 'intends', 'rehabilitate', 'stone', 'seawall', 'repairing', 'damaged', 'areas', 'along', 'structure', 'displaced', 'stones', 'temporary', 'removed', 'allow', 'necessary', 'work', 'repair', 'raise', 'degraded', 'bed', 'geotextile', 'fabric', 'installed', 'reinstating', 'stone', 'areas', 'displaced', 'stones', 'currently', 'sitting', 'ocean', 'floor', 'collected', 'fitted', 'back', 'place', 'addition', 'previously', 'placed', 'concrete', 'pieces', 'removed', 'replaced', 'stone', 'fisheries', 'act', 'authorization', 'required', 'dfo', 'relation', 'impacts', 'fish', 'habitat', 'associated', 'dam', 'construction', 'projects', 'tsw', 'trenton', 'dam', 'glen', 'miller', 'dam', 'authorization', 'includes', 'provisions', 'offsetting', 'measures', 'construction', 'big', 'island', 'causeway', 'decreased', 'water', 'flows', 'island', 'mainland', 'caused', 'channels', 'filled', 'silt', 'cattails', 'cover', 'entire', 'area', 'island', 'mainland', 'parks', 'canada', 'proposing', 'expand', 'existing', 'fish', 'habitat', 'enhancements', 'big', 'island', 'marsh', 'constructing', 'new', 'channel', 'widening', 'deepening', 'existing', 'channels', 'cattail', 'marsh', 'vegetation', 'removed', 'width', 'depths', 'order', 'ensure', 'areas', 'stay', 'open', 'future', 'fisheries', 'offset', 'plan', 'expected', 'result', 'enhancement', 'fish', 'habitat', 'big', 'island', 'marsh', 'may', 'rabbit', 'creek', 'wildfire', 'occurred', 'prince', 'albert', 'national', 'park', 'spread', 'within', 'outside', 'park', 'heavy', 'equipment', 'used', 'create', 'fire', 'control', 'lines', 'improve', 'ground', 'aerial', 'access', 'strategic', 'areas', 'addition', 'dozer', 'lines', 'put', 'fire', 'heavy', 'equipment', 'used', 'along', 'border', 'south', 'boundary', 'park', 'cookson', 'community', 'pasture', 'push', 'back', 'forested', 'edge', 'protect', 'newly', 'repaired', 'fence', 'damaged', 'fire', 'prince', 'albert', 'national', 'park', 'fire', 'management', 'takes', 'responsibility', 'reclamation', 'impacts', 'heavy', 'equipment', 'two', 'areas', 'work', 'south', 'boundary', 'trail', 'elk', 'trail', 'following', 'rabbit', 'fire', 'approximately', 'km', 'fence', 'replaced', 'northern', 'boundary', 'cookson', 'community', 'pasture', 'approximately', 'km', 'fence', 'directly', 'adjacent', 'panp', 'boundary', 'area', 'cleared', 'vegetation', 'long', 'linear', 'berms', 'soil', 'wood', 'restricting', 'efforts', 'weed', 'control', 'seeding', 'along', 'boundary', 'also', 'increase', 'long', 'term', 'fire', 'hazard', 'left', 'piles', 'berms', 'need', 'spread', 'across', 'opening', 'section', 'area', 'need', 'flat', 'debris', 'free', 'surface', 'left', 'used', 'trai ...

# %%
# Get rid of things that aren't words (e.g. 2m or m2 or km)

notwords = []

wordlist2 = []

def containsNumber(value): # define function that checks if a string contains a number
    return any([char.isdigit() for char in value])

for word in wordlist_clean: # iterate through the wordlist
        if containsNumber(word) == True: # if it contains a number, put it in a separate list of notwords
            notwords.append(word)
        else:
            wordlist2.append(word)
            
print(notwords)
# Out:
# ['2m', 'km2', 'w3m', '600mm', '450mm', '100m', '100m', 'a2', '5m', '8m', '20m2', '30m', '3rd', '2m', '5m', '2m', '7m', '1m', '16th', '14th', '16th', 'm2', 'm²', 'm²', 'w3m', '5m', '5m', '1m']

# %%
# Get syllables for each word in the master list

syl_list = []

for word in wordlist2:
    count = nsyl(word)
    syl_list.append(count)

# Zip together words and syllable counts

pair_list = list(zip(wordlist2, syl_list))

pair_list[0]
# Out:
# ('purpose', [2])

# %%
# Look at the words where nysl() has given more than one syllable count

for pair in pair_list:
    if len(pair[1]) > 1:
        print (pair)
# Out:
# ('project', [2, 2])
# ('reduce', [2, 2, 2])
# ('national', [3, 2])
# ('fuel', [2, 1])
# ('treated', [2, 2])
# ('ha', [1, 2])
# ('fire', [2, 1])
# ('maturity', [4, 4])
# ('forest', [2, 2])
# ('around', [2, 2])
# ('resulted', [3, 3, 3])
# ('mature', [2, 2])
# ('reducing', [3, 3, 3])
# ('fuel', [2, 1])
# ('fuel', [2, 1])
# ('impact', [2, 2])
# ('reduced', [2, 2, 2])
# ('project', [2, 2])
# ('impact', [2, 2])
# ('located', [3, 2])
# ('around', [2, 2])
# ('st', [1, 1])
# ('national', [3, 2])
# ('protection', [3, 3])
# ('identified', [4, 4])
# ('result', [2, 2])
# ('potential', [3, 3])
# ('cause', [1, 1])
# ('protection', [3, 3])
# ('repairs', [2, 2])
# ('project', [2, 2])
# ('rehabilitate', [5, 5])
# ('repairing', [3, 3])
# ('damaged', [2, 2])
# ('degraded', [3, 3])
# ('fitted', [2, 2])
# ('concrete', [2, 2])
# ('pieces', [2, 2])
# ('required', [3, 2])
# ('impacts', [2, 2, 2, 2])
# ('associated', [5, 5])
# ('projects', [2, 2, 2, 2])
# ('offsetting', [3, 3])
# ('causeway', [2, 2])
# ('decreased', [2, 2])
# ('mainland', [2, 2])
# ('caused', [1, 1])
# ('mainland', [2, 2])
# ('new', [1, 1])
# ('deepening', [3, 2])
# ('ensure', [2, 2])
# ('offset', [2, 2])
# ('expected', [3, 3])
# ('result', [2, 2])
# ('rabbit', [2, 2])
# ('national', [3, 2])
# ('within', [2, 2])
# ('fire', [2, 1])
# ('fire', [2, 1])
# ('boundary', [3, 2])
# ('community', [4, 4])
# ('protect', [2, 2])
# ('repaired', [2, 2])
# ('damaged', [2, 2])
# ('fire', [2, 1])
# ('national', [3, 2])
# ('fire', [2, 1])
# ('management', [3, 3])
# ('impacts', [2, 2, 2, 2])
# ('boundary', [3, 2])
# ('rabbit', [2, 2])
# ('fire', [2, 1])
# ('boundary', [3, 2])
# ('community', [4, 4])
# ('directly', [3, 3, 3, 3])
# ('boundary', [3, 2])
# ('boundary', [3, 2])
# ('increase', [2, 2])
# ('fire', [2, 1])
# ('vehicles', [3, 3])
# ('within', [2, 2])
# ('due', [1, 1])
# ('impacts', [2, 2, 2, 2])
# ('forest', [2, 2])
# ('average', [3, 2, 2])
# ('ha', [1, 2])
# ('new', [1, 1])
# ('within', [2, 2])
# ('ha', [1, 2])
# ('repaired', [2, 2])
# ('project', [2, 2])
# ('national', [3, 2])
# ('discovery', [4, 3, 3])
# ('project', [2, 2])
# ('lot', [1, 1])
# ('project', [2, 2])
# ('discovery', [4, 3, 3])
# ('detached', [2, 2])
# ('landscaping', [3, 3])
# ('discovery', [4, 3, 3])
# ('visitors', [3, 3])
# ('national', [3, 2])
# ('project', [2, 2])
# ('use', [1, 1])
# ('machinery', [4, 3])
# ('landscaping', [3, 3])
# ('project', [2, 2])
# ('impact', [2, 2])
# ('ecological', [5, 5])
# ('integrity', [4, 4])
# ('national', [3, 2])
# ('herbicide', [3, 3])
# ('several', [2, 3])
# ('national', [3, 2])
# ('limited', [3, 3])
# ('additional', [4, 3])
# ('option', [2, 2])
# ('labour', [2, 2])
# ('national', [3, 2])
# ('carry', [2, 2])
# ('trials', [2, 1])
# ('affected', [3, 3])
# ('rabbit', [2, 2])
# ('white', [1, 1])
# ('ecological', [5, 5])
# ('forest', [2, 2])
# ('communities', [4, 4])
# ('forest', [2, 2])
# ('management', [3, 3])
# ('response', [2, 2])
# ('ecological', [5, 5])
# ('impacts', [2, 2, 2, 2])
# ('reducing', [3, 3, 3])
# ('reduction', [3, 3])
# ('management', [3, 3])
# ('project', [2, 2])
# ('integrity', [4, 4])
# ('forest', [2, 2])
# ('protect', [2, 2])
# ('reduction', [3, 3])
# ('began', [2, 2])
# ('reduce', [2, 2, 2])
# ('forest', [2, 2])
# ('density', [3, 3])
# ('reduction', [3, 3])
# ('white', [1, 1])
# ('effectiveness', [4, 4])
# ('reduction', [3, 3])
# ('recovery', [3, 4])
# ('forest', [2, 2])
# ('project', [2, 2])
# ('impact', [2, 2])
# ('project', [2, 2])
# ('climate', [2, 2])
# ('located', [3, 2])
# ('within', [2, 2])
# ('national', [3, 2])
# ('national', [3, 2])
# ('project', [2, 2])
# ('reduction', [3, 3])
# ('gases', [2, 2])
# ('associated', [5, 5])
# ('mounted', [2, 2, 2])
# ('concrete', [2, 2])
# ('required', [3, 2])
# ('project', [2, 2])
# ('via', [2, 2])
# ('impact', [2, 2])
# ('replace', [2, 2])
# ('se', [2, 1, 2])
# ('within', [2, 2])
# ('national', [3, 2])
# ('project', [2, 2])
# ('required', [3, 2])
# ('increase', [2, 2])
# ('capacity', [4, 4])
# ('service', [2, 2])
# ('expected', [3, 3])
# ('project', [2, 2])
# ('bucket', [2, 2])
# ('directional', [4, 4, 4, 4])
# ('project', [2, 2])
# ('use', [1, 1])
# ('expected', [3, 3])
# ('project', [2, 2])
# ('thousand', [2, 2])
# ('national', [3, 2])
# ('replace', [2, 2])
# ('damaged', [2, 2])
# ('due', [1, 1])
# ('replace', [2, 2])
# ('new', [1, 1])
# ('associated', [5, 5])
# ('carried', [2, 2])
# ('project', [2, 2])
# ('project', [2, 2])
# ('project', [2, 2])
# ('impact', [2, 2])
# ('new', [1, 1])
# ('boundary', [3, 2])
# ('rusted', [2, 2])
# ('flooded', [2, 2])
# ('due', [1, 1])
# ('activity', [4, 4])
# ('county', [2, 2])
# ('boundary', [3, 2])
# ('new', [1, 1])
# ('due', [1, 1])
# ('sizes', [2, 2])
# ('kept', [1, 1])
# ('boundary', [3, 2])
# ('top', [1, 1])
# ('new', [1, 1])
# ('county', [2, 2])
# ('management', [3, 3])
# ('identified', [4, 4])
# ('visitor', [3, 3])
# ('enjoy', [2, 2])
# ('management', [3, 3])
# ('history', [3, 2])
# ('whaling', [2, 2])
# ('requires', [3, 2])
# ('management', [3, 3])
# ('walk', [1, 1])
# ('length', [1, 1])
# ('project', [2, 2])
# ('second', [2, 2])
# ('project', [2, 2])
# ('completed', [3, 3])
# ('fall', [1, 1])
# ('contaminated', [5, 5])
# ('federal', [3, 2])
# ('within', [2, 2])
# ('harvested', [3, 3])
# ('created', [3, 3])
# ('management', [3, 3])
# ('project', [2, 2])
# ('fire', [2, 1])
# ('regime', [2, 2])
# ('grasses', [2, 2])
# ('forest', [2, 2])
# ('maintenance', [3, 2])
# ('fire', [2, 1])
# ('project', [2, 2])
# ('second', [2, 2])
# ('reduce', [2, 2, 2])
# ('human', [2, 2])
# ('remains', [2, 2])
# ('natural', [3, 2])
# ('requires', [3, 2])
# ('roof', [1, 1])
# ('requires', [3, 2])
# ('roof', [1, 1])
# ('project', [2, 2])
# ('impact', [2, 2])
# ('national', [3, 2])
# ('community', [4, 4])
# ('permit', [2, 2])
# ('regime', [2, 2])
# ('maintenance', [3, 2])
# ('new', [1, 1])
# ('constructed', [3, 3])
# ('activities', [4, 4])
# ('repairing', [3, 3])
# ('fences', [2, 2])
# ('project', [2, 2])
# ('impact', [2, 2])
# ('august', [2, 2])
# ('vehicle', [3, 3])
# ('corridor', [3, 3])
# ('reduce', [2, 2, 2])
# ('impacts', [2, 2, 2, 2])
# ('located', [3, 2])
# ('passes', [2, 2])
# ('one', [1, 1])
# ('vehicles', [3, 3])
# ('project', [2, 2])
# ('impact', [2, 2])
# ('impact', [2, 2])
# ('required', [3, 2])
# ('address', [2, 2])
# ('potential', [3, 3])
# ('impacts', [2, 2, 2, 2])
# ('resulting', [3, 3])
# ('national', [3, 2])
# ('reserve', [2, 2])
# ('repairs', [2, 2])
# ('required', [3, 2])
# ('ensure', [2, 2])
# ('visitors', [3, 3])
# ('limited', [3, 3])
# ('within', [2, 2])
# ('required', [3, 2])
# ('upgrade', [2, 2])
# ('within', [2, 2])
# ('reduce', [2, 2, 2])
# ('project', [2, 2])
# ('expected', [3, 3])
# ('project', [2, 2])
# ('anticipated', [5, 5])
# ('effects', [2, 2, 2, 2])
# ('limited', [3, 3])
# ('impact', [2, 2])
# ('fire', [2, 1])
# ('last', [1, 1, 1])
# ('fall', [1, 1])
# ('beyond', [2, 2, 2])
# ('national', [3, 2])
# ('require', [3, 2, 3])
# ('wash', [1, 1])
# ('completed', [3, 3])
# ('new', [1, 1])
# ('within', [2, 2])
# ('rehabilitated', [6, 6])
# ('new', [1, 1])
# ('partially', [3, 2])
# ('constructed', [3, 3])
# ('agricultural', [5, 5])
# ('years', [1, 1])
# ('forest', [2, 2])
# ('white', [1, 1])
# ('lot', [1, 1])
# ('covering', [3, 2])
# ('remaining', [3, 3])
# ('graded', [2, 2])
# ('within', [2, 2])
# ('services', [3, 3])
# ('sewage', [2, 2])
# ('routed', [2, 2])
# ('new', [1, 1])
# ('corridors', [3, 3])
# ('identified', [4, 4])
# ('corridors', [3, 3])
# ('either', [2, 2])
# ('corridors', [3, 3])
# ('expected', [3, 3])
# ('completed', [3, 3])
# ('rehabilitated', [6, 6])
# ('last', [1, 1, 1])
# ('fall', [1, 1])
# ('hurricane', [3, 3])
# ('devastated', [4, 4])
# ('remaining', [3, 3])
# ('due', [1, 1])
# ('remaining', [3, 3])
# ('constructed', [3, 3])
# ('contract', [2, 2])
# ('expected', [3, 3])
# ('completed', [3, 3])
# ('history', [3, 2])
# ('originally', [5, 4])
# ('agricultural', [5, 5])
# ('project', [2, 2])
# ('grahams', [1, 2])
# ('years', [1, 1])
# ('surfaces', [3, 3])
# ('ditches', [2, 2])
# ('machinery', [4, 3])
# ('completed', [3, 3])
# ('additional', [4, 3])
# ('impacts', [2, 2, 2, 2])
# ('construct', [2, 2])
# ('new', [1, 1])
# ('conduct', [2, 2])
# ('aquatic', [3, 3])
# ('constructed', [3, 3])
# ('vehicle', [3, 3])
# ('impact', [2, 2])
# ('potential', [3, 3])
# ('project', [2, 2])
# ('related', [3, 3, 3])
# ('impacts', [2, 2, 2, 2])
# ('natural', [3, 2])
# ('project', [2, 2])
# ('august', [2, 2])
# ('remained', [2, 2])
# ('enter', [2, 2])
# ('project', [2, 2])
# ('fuel', [2, 1])
# ('adequate', [3, 3])
# ('forest', [2, 2])
# ('requires', [3, 2])
# ('required', [3, 2])
# ('rocher', [2, 2])
# ('maintenance', [3, 2])
# ('required', [3, 2])
# ('permitted', [3, 3])
# ('activity', [4, 4])
# ('national', [3, 2])
# ('route', [1, 1])
# ('use', [1, 1])
# ('route', [1, 1])
# ('kilometers', [4, 4])
# ('route', [1, 1])
# ('activities', [4, 4])
# ('required', [3, 2])
# ('route', [1, 1])
# ('created', [3, 3])
# ('significant', [4, 4])
# ('reduction', [3, 3])
# ('new', [1, 1])
# ('corridor', [3, 3])
# ('passes', [2, 2])
# ('natural', [3, 2])
# ('whereas', [2, 2])
# ('expanded', [3, 3])
# ('originally', [5, 4])
# ('constructed', [3, 3])
# ('concrete', [2, 2])
# ('concrete', [2, 2])
# ('consists', [2, 2, 2])
# ('concrete', [2, 2])
# ('supported', [3, 3])
# ('concrete', [2, 2])
# ('supported', [3, 3])
# ('adequate', [3, 3])
# ('capacity', [4, 4])
# ('without', [2, 2])
# ('phases', [2, 2])
# ('fall', [1, 1])
# ('project', [2, 2])
# ('environmental', [5, 5])
# ('document', [3, 3])
# ('evaluated', [5, 5])
# ('federal', [3, 2])
# ('within', [2, 2])
# ('fire', [2, 1])
# ('management', [3, 3])
# ('national', [3, 2])
# ('fire', [2, 1])
# ('ecological', [5, 5])
# ('fire', [2, 1])
# ('reverse', [2, 2])
# ('onto', [2, 2])
# ('historically', [5, 4])
# ('fire', [2, 1])
# ('interval', [3, 3])
# ('years', [1, 1])
# ('unit', [2, 2])
# ('located', [3, 2])
# ('ha', [1, 2])
# ('fire', [2, 1])
# ('spring', [1, 2])
# ('unit', [2, 2])
# ('every', [3, 2])
# ('years', [1, 1])
# ('reduction', [3, 3])
# ('national', [3, 2])
# ('service', [2, 2])
# ('partially', [3, 2])
# ('service', [2, 2])
# ('intersects', [3, 3, 3, 3])
# ('protected', [3, 3, 3])
# ('emergency', [4, 4])
# ('protection', [3, 3])
# ('project', [2, 2])
# ('towards', [2, 1])
# ('identified', [4, 4])
# ('recovery', [3, 4])
# ('recovery', [3, 4])
# ('project', [2, 2])
# ('impact', [2, 2])
# ('decades', [2, 2])
# ('intensity', [4, 4])
# ('reduced', [2, 2, 2])
# ('diversity', [4, 4, 4, 4])
# ('forest', [2, 2])
# ('result', [2, 2])
# ('forest', [2, 2])
# ('diversity', [4, 4, 4, 4])
# ('diversity', [4, 4, 4, 4])
# ('replace', [2, 2])
# ('disappeared', [3, 3])
# ('forest', [2, 2])
# ('effective', [3, 3])
# ('project', [2, 2])
# ('establish', [3, 3])
# ('reserve', [2, 2])
# ('forest', [2, 2])
# ('planted', [2, 2, 2, 2])
# ('forest', [2, 2])
# ('prevent', [2, 2])
# ('within', [2, 2])
# ('constructed', [3, 3])
# ('last', [1, 1, 1])
# ('several', [2, 3])
# ('years', [1, 1])
# ('established', [3, 3])
# ('fences', [2, 2])
# ('seasonally', [4, 3])
# ('project', [2, 2])
# ('impact', [2, 2])
# ('management', [3, 3])
# ('maintenance', [3, 2])
# ('associated', [5, 5])
# ('within', [2, 2])
# ('national', [3, 2])
# ('project', [2, 2])
# ('sewage', [2, 2])
# ('new', [1, 1])
# ('sewage', [2, 2])
# ('prevent', [2, 2])
# ('potential', [3, 3])
# ('human', [2, 2])
# ('new', [1, 1])
# ('barrier', [3, 3])
# ('around', [2, 2])
# ('new', [1, 1])
# ('amended', [3, 3])
# ('expected', [3, 3])
# ('service', [2, 2])
# ('years', [1, 1])
# ('provided', [3, 3])
# ('project', [2, 2])
# ('replace', [2, 2])
# ('services', [3, 3])
# ('services', [3, 3])
# ('within', [2, 2])
# ('within', [2, 2])
# ('national', [3, 2])
# ('project', [2, 2])
# ('fire', [2, 1])
# ('boxes', [2, 2])
# ('vicinity', [4, 4])
# ('project', [2, 2])
# ('services', [3, 3])
# ('services', [3, 3])
# ('bottling', [3, 2])
# ('located', [3, 2])
# ('use', [1, 1])
# ('officers', [3, 3])
# ('federally', [4, 3])
# ('heritage', [3, 3])
# ('federal', [3, 2])
# ('initiative', [4, 4])
# ('projects', [2, 2, 2, 2])
# ('initiated', [5, 5])
# ('barracks', [2, 2])
# ('national', [3, 2])
# ('officers', [3, 3])
# ('substantial', [3, 3])
# ('drainage', [2, 2])
# ('around', [2, 2])
# ('upgrading', [3, 3])
# ('project', [2, 2])
# ('uses', [2, 2, 2, 2])
# ('heritage', [3, 3])
# ('english', [2, 2])
# ('identified', [4, 4])
# ('communities', [4, 4])
# ('community', [4, 4])
# ('management', [3, 3])
# ('english', [2, 2])
# ('ongoing', [3, 3])
# ('english', [2, 2])
# ('english', [2, 2])
# ('english', [2, 2])
# ('environmental', [5, 5])
# ('rather', [2, 2])
# ('experimental', [5, 4, 5, 4])
# ('several', [2, 3])
# ('chemical', [3, 3])
# ('determine', [3, 3])
# ('practices', [3, 3])
# ('english', [2, 2])
# ('english', [2, 2])
# ('herbicide', [3, 3])
# ('directly', [3, 3, 3, 3])
# ('remaining', [3, 3])
# ('herbicide', [3, 3])
# ('selected', [3, 3])
# ('trial', [2, 1])
# ('effects', [2, 2, 2, 2])
# ('grasses', [2, 2])
# ('documented', [4, 4, 4, 4])
# ('research', [2, 2])
# ('use', [1, 1])
# ('herbicide', [3, 3])
# ('integrated', [4, 4, 4, 4])
# ('management', [3, 3])
# ('national', [3, 2])
# ('reserve', [2, 2])
# ('national', [3, 2])
# ('management', [3, 3])
# ('reduce', [2, 2, 2])
# ('potential', [3, 3])
# ('caused', [1, 1])
# ('created', [3, 3])
# ('decaying', [3, 3])
# ('caused', [1, 1])
# ('bennett', [2, 2])
# ('retaining', [3, 3])
# ('strength', [1, 1])
# ('management', [3, 3])
# ('activities', [4, 4])
# ('periodically', [6, 5])
# ('repeated', [3, 3, 3])
# ('impact', [2, 2])
# ('required', [3, 2])
# ('potential', [3, 3])
# ('impacts', [2, 2, 2, 2])
# ('management', [3, 3])
# ('activities', [4, 4])
# ('project', [2, 2])
# ('new', [1, 1])
# ('new', [1, 1])
# ('replace', [2, 2])
# ('damaged', [2, 2])
# ('hurricane', [3, 3])
# ('new', [1, 1])
# ('length', [1, 1])
# ('concrete', [2, 2])
# ('established', [3, 3])
# ('either', [2, 2])
# ('new', [1, 1])
# ('length', [1, 1])
# ('required', [3, 2])
# ('project', [2, 2])
# ('impact', [2, 2])
# ('national', [3, 2])
# ('upgrade', [2, 2])
# ('national', [3, 2])
# ('located', [3, 2])
# ('vehicle', [3, 3])
# ('routes', [1, 1, 1])
# ('emergency', [4, 4])
# ('response', [2, 2])
# ('purposes', [3, 3])
# ('current', [2, 1, 2])
# ('upgrade', [2, 2])
# ('options', [2, 2])
# ('evaluated', [5, 5])
# ('implemented', [4, 4])
# ('listed', [2, 2])
# ('schedule', [2, 2])
# ('project', [2, 2])
# ('impact', [2, 2])
# ('approaches', [3, 3])
# ('damaged', [2, 2])
# ('concrete', [2, 2])
# ('concrete', [2, 2])
# ('landscaping', [3, 3])
# ('project', [2, 2])
# ('related', [3, 3, 3])
# ('project', [2, 2])
# ('activities', [4, 4])
# ('use', [1, 1])
# ('machinery', [4, 3])
# ('fall', [1, 1])
# ('navigation', [4, 4])
# ('weekend', [2, 2])
# ('weekend', [2, 2])
# ('project', [2, 2])
# ('repairs', [2, 2])
# ('concrete', [2, 2])
# ('fall', [1, 1])
# ('navigation', [4, 4])
# ('interfere', [3, 3])
# ('navigation', [4, 4])
# ('periodically', [6, 5])
# ('due', [1, 1])
# ('damage', [2, 2])
# ('carried', [2, 2])
# ('years', [1, 1])
# ('project', [2, 2])
# ('established', [3, 3])
# ('within', [2, 2])
# ('national', [3, 2])
# ('reserve', [2, 2])
# ('cement', [2, 2])
# ('new', [1, 1])
# ('new', [1, 1])
# ('appropriate', [4, 4])
# ('content', [2, 2])
# ('selected', [3, 3])
# ('cement', [2, 2])
# ('activities', [4, 4])
# ('national', [3, 2])
# ('reserve', [2, 2])
# ('degraded', [3, 3])
# ('service', [2, 2])
# ('national', [3, 2])
# ('national', [3, 2])
# ('maintenance', [3, 2])
# ('essential', [3, 3, 3, 3])
# ('visitor', [3, 3])
# ('purposes', [3, 3])
# ('treated', [2, 2])
# ('anticipated', [5, 5])
# ('august', [2, 2])
# ('project', [2, 2])
# ('impact', [2, 2])
# ('project', [2, 2])
# ('increase', [2, 2])
# ('visitor', [3, 3])
# ('visitor', [3, 3])
# ('protecting', [3, 3])
# ('cement', [2, 2])
# ('gravity', [3, 3])
# ('project', [2, 2])
# ('return', [2, 2])
# ('visitor', [3, 3])
# ('additional', [4, 3])
# ('new', [1, 1])
# ('second', [2, 2])
# ('project', [2, 2])
# ('notices', [3, 3])
# ('one', [1, 1])
# ('one', [1, 1])
# ('project', [2, 2])
# ('replace', [2, 2])
# ('one', [1, 1])
# ('additional', [4, 3])
# ('ensure', [2, 2])
# ('visitors', [3, 3])
# ('reduction', [3, 3])
# ('project', [2, 2])
# ('fuel', [2, 1])
# ('management', [3, 3])
# ('reduce', [2, 2, 2])
# ('fuel', [2, 1])
# ('located', [3, 2])
# ('within', [2, 2])
# ('national', [3, 2])
# ('reserve', [2, 2])
# ('reduce', [2, 2, 2])
# ('communities', [4, 4])
# ('event', [2, 2])
# ('interface', [3, 3])
# ('fire', [2, 1])
# ('project', [2, 2])
# ('mt', [1, 2])
# ('summit', [2, 2])
# ('lot', [1, 1])
# ('reserve', [2, 2])
# ('boundary', [3, 2])
# ('project', [2, 2])
# ('construct', [2, 2])
# ('new', [1, 1])
# ('segment', [2, 2])
# ('segments', [2, 2])
# ('cemetery', [4, 4])
# ('intended', [3, 3])
# ('use', [1, 1])
# ('aggregate', [3, 3, 3])
# ('required', [3, 2])
# ('separate', [3, 3, 2])
# ('routing', [2, 2])
# ('options', [2, 2])
# ('around', [2, 2])
# ('capacity', [4, 4])
# ('lot', [1, 1])
# ('ave', [3, 2])
# ('investigated', [5, 5])
# ('national', [3, 2])
# ('information', [4, 4])
# ('coverage', [3, 3, 2])
# ('information', [4, 4])
# ('fire', [2, 1])
# ('visitor', [3, 3])
# ('requires', [3, 2])
# ('require', [3, 2, 3])
# ('typically', [3, 4])
# ('prevent', [2, 2])
# ('damage', [2, 2])
# ('readings', [2, 2])
# ('sensitive', [3, 3])
# ('project', [2, 2])
# ('impact', [2, 2])
# ('manage', [2, 2])
# ('impacts', [2, 2, 2, 2])
# ('sensitive', [3, 3])
# ('differences', [4, 3])
# ('excluded', [3, 3])
# ('forest', [2, 2])
# ('toronto', [3, 3])
# ('permit', [2, 2])
# ('required', [3, 2])
# ('project', [2, 2])
# ('routes', [1, 1, 1])
# ('remote', [2, 2])
# ('units', [2, 2])
# ('mt', [1, 2])
# ('mt', [1, 2])
# ('often', [2, 2])
# ('limited', [3, 3])
# ('wind', [1, 1])
# ('effecting', [3, 3])
# ('use', [1, 1])
# ('paths', [1, 1])
# ('reduce', [2, 2, 2])
# ('impacts', [2, 2, 2, 2])
# ('units', [2, 2])
# ('required', [3, 2])
# ('one', [1, 1])
# ('required', [3, 2])
# ('one', [1, 1])
# ('landscape', [2, 2])
# ('ridges', [2, 2])
# ('forest', [2, 2])
# ('aquatic', [3, 3])
# ('fire', [2, 1])
# ('fire', [2, 1])
# ('damage', [2, 2])
# ('reroute', [2, 2])
# ('around', [2, 2])
# ('causing', [2, 2])
# ('project', [2, 2])
# ('duty', [2, 2])
# ('reroute', [2, 2])
# ('aggregate', [3, 3, 3])
# ('reroute', [2, 2])
# ('operationally', [6, 5])
# ('located', [3, 2])
# ('national', [3, 2])
# ('second', [2, 2])
# ('project', [2, 2])
# ('rehabilitation', [6, 6])
# ('project', [2, 2])
# ('located', [3, 2])
# ('intersection', [4, 4])
# ('village', [2, 2])
# ('springs', [1, 2])
# ('national', [3, 2])
# ('fire', [2, 1])
# ('facilities', [4, 4])
# ('use', [1, 1])
# ('project', [2, 2])
# ('reduce', [2, 2, 2])
# ('required', [3, 2])
# ('reduce', [2, 2, 2])
# ('maintenance', [3, 2])
# ('cost', [1, 1])
# ('natural', [3, 2])
# ('corridors', [3, 3])
# ('facilities', [4, 4])
# ('reduction', [3, 3])
# ('human', [2, 2])
# ('use', [1, 1])
# ('general', [3, 2])
# ('ecological', [5, 5])
# ('integrity', [4, 4])
# ('replace', [2, 2])
# ('limited', [3, 3])
# ('within', [2, 2])
# ('within', [2, 2])
# ('national', [3, 2])
# ('project', [2, 2])
# ('project', [2, 2])
# ('required', [3, 2])
# ('additional', [4, 3])
# ('service', [2, 2])
# ('expected', [3, 3])
# ('project', [2, 2])
# ('project', [2, 2])
# ('use', [1, 1])
# ('expected', [3, 3])
# ('reduce', [2, 2, 2])
# ('thousand', [2, 2])
# ('national', [3, 2])
# ('surrounded', [3, 3])
# ('significant', [4, 4])
# ('documented', [4, 4, 4, 4])
# ('reduce', [2, 2, 2])
# ('onto', [2, 2])
# ('wheelbarrow', [3, 3])

# %%
# It appears that the first number in the list reliably indicates the number of syllables
# Edit the list so every word has only one syllable count

new_list = []

for pair in pair_list:
    word = pair[0]
    syl = pair[1][0]
    new_pair = (word, syl)
    new_list.append(new_pair)

new_list
# Out:
# [('purpose', 2),
#  ('project', 2),
#  ('reduce', 2),
#  ('risk', 1),
#  ('wildfire', 3),
#  ('fort', 1),
#  ('walsh', 1),
#  ('national', 3),
#  ('historic', 3),
#  ('site', 1),
#  ('thinning', 2),
#  ('pockets', 2),
#  ('fuel', 2),
#  ('two', 1),
#  ('forested', 3),
#  ('areas', 3),
#  ('near', 1),
#  ('fort', 1),
#  ('site', 1),
#  ('total', 2),
#  ('area', 3),
#  ('treated', 2),
#  ('ha', 1),
#  ('absence', 2),
#  ('fire', 2),
#  ('maturity', 4),
#  ('forest', 2),
#  ('around', 2),
#  ('fort', 1),
#  ('site', 1),
#  ('resulted', 3),
#  ('accumulation', 5),
#  ('ladder', 2),
#  ('fuels', 2),
#  ('old', 1),
#  ('dying', 2),
#  ('mature', 2),
#  ('trees', 1),
#  ('downed', 1),
#  ('woody', 2),
#  ('material', 4),
#  ('reducing', 3),
#  ('fuel', 2),
#  ('load', 1),
#  ('site', 1),
#  ('removing', 3),
#  ('trees', 1),
#  ('administering', 5),
#  ('various', 3),
#  ('firesmart', 3),
#  ('techniques', 2),
#  ('stand', 1),
#  ('thinning', 2),
#  ('ladder', 2),
#  ('fuel', 2),
#  ('removal', 3),
#  ('etc', 4),
#  ('impact', 2),
#  ('wildfire', 3),
#  ('site', 1),
#  ('reduced', 2),
#  ('ladder', 2),
#  ('fuels', 2),
#  ('removed', 2),
#  ('tree', 1),
#  ('limbs', 1),
#  ('pruned', 1),
#  ('height', 1),
#  ('using', 2),
#  ('chainsaws', 2),
#  ('various', 3),
#  ('hand', 1),
#  ('tools', 1),
#  ('dense', 1),
#  ('areas', 3),
#  ('thinned', 1),
#  ('hand', 1),
#  ('felling', 2),
#  ('deadfall', 2),
#  ('also', 2),
#  ('removed', 2),
#  ('hand', 1),
#  ('project', 2),
#  ('assessed', 2),
#  ('basic', 2),
#  ('impact', 2),
#  ('assessment', 3),
#  ('armoured', 3),
#  ('stone', 1),
#  ('seawall', 2),
#  ('located', 3),
#  ('around', 2),
#  ('perimeter', 4),
#  ('shoreline', 2),
#  ('adjacent', 3),
#  ('st', 1),
#  ('andrews', 2),
#  ('blockhouse', 2),
#  ('national', 3),
#  ('historic', 3),
#  ('site', 1),
#  ('provides', 2),
#  ('protection', 3),
#  ('erosion', 3),
#  ('water', 2),
#  ('wave', 1),
#  ('action', 2),
#  ('passamaquoddy', 5),
#  ('bay', 1),
#  ('recent', 2),
#  ('inspection', 3),
#  ('seawall', 2),
#  ('identified', 4),
#  ('number', 2),
#  ('deficiencies', 4),
#  ('could', 1),
#  ('result', 2),
#  ('potential', 3),
#  ('failure', 2),
#  ('structure', 2),
#  ('cause', 1),
#  ('erosion', 3),
#  ('site', 1),
#  ('shoreline', 2),
#  ('protection', 3),
#  ('seawall', 2),
#  ('repairs', 2),
#  ('project', 2),
#  ('intends', 2),
#  ('rehabilitate', 5),
#  ('stone', 1),
#  ('seawall', 2),
#  ('repairing', 3),
#  ('damaged', 2),
#  ('areas', 3),
#  ('along', 2),
#  ('structure', 2),
#  ('displaced', 2),
#  ('stones', 1),
#  ('temporary', 4),
#  ('removed', 2),
#  ('allow', 2),
#  ('necessary', 4),
#  ('work', 1),
#  ('repair', 2),
#  ('raise', 1),
#  ('degraded', 3),
#  ('bed', 1),
#  ('geotextile', 4),
#  ('fabric', 2),
#  ('installed', 2),
#  ('reinstating', 4),
#  ('stone', 1),
#  ('areas', 3),
#  ('displaced', 2),
#  ('stones', 1),
#  ('currently', 3),
#  ('sitting', 2),
#  ('ocean', 2),
#  ('floor', 1),
#  ('collected', 3),
#  ('fitted', 2),
#  ('back', 1),
#  ('place', 1),
#  ('addition', 3),
#  ('previously', 4),
#  ('placed', 1),
#  ('concrete', 2),
#  ('pieces', 2),
#  ('removed', 2),
#  ('replaced', 2),
#  ('stone', 1),
#  ('fisheries', 3),
#  ('act', 1),
#  ('authorization', 5),
#  ('required', 3),
#  ('dfo', 1),
#  ('relation', 3),
#  ('impacts', 2),
#  ('fish', 1),
#  ('habitat', 3),
#  ('associated', 5),
#  ('dam', 1),
#  ('construction', 3),
#  ('projects', 2),
#  ('tsw', 1),
#  ('trenton', 2),
#  ('dam', 1),
#  ('glen', 1),
#  ('miller', 2),
#  ('dam', 1),
#  ('authorization', 5),
#  ('includes', 2),
#  ('provisions', 3),
#  ('offsetting', 3),
#  ('measures', 2),
#  ('construction', 3),
#  ('big', 1),
#  ('island', 2),
#  ('causeway', 2),
#  ('decreased', 2),
#  ('water', 2),
#  ('flows', 1),
#  ('island', 2),
#  ('mainland', 2),
#  ('caused', 1),
#  ('channels', 2),
#  ('filled', 1),
#  ('silt', 1),
#  ('cattails', 2),
#  ('cover', 2),
#  ('entire', 3),
#  ('area', 3),
#  ('island', 2),
#  ('mainland', 2),
#  ('parks', 1),
#  ('canada', 3),
#  ('proposing', 3),
#  ('expand', 2),
#  ('existing', 3),
#  ('fish', 1),
#  ('habitat', 3),
#  ('enhancements', 3),
#  ('big', 1),
#  ('island', 2),
#  ('marsh', 1),
#  ('constructing', 3),
#  ('new', 1),
#  ('channel', 2),
#  ('widening', 3),
#  ('deepening', 3),
#  ('existing', 3),
#  ('channels', 2),
#  ('cattail', 2),
#  ('marsh', 1),
#  ('vegetation', 4),
#  ('removed', 2),
#  ('width', 1),
#  ('depths', 1),
#  ('order', 2),
#  ('ensure', 2),
#  ('areas', 3),
#  ('stay', 1),
#  ('open', 2),
#  ('future', 2),
#  ('fisheries', 3),
#  ('offset', 2),
#  ('plan', 1),
#  ('expected', 3),
#  ('result', 2),
#  ('enhancement', 3),
#  ('fish', 1),
#  ('habitat', 3),
#  ('big', 1),
#  ('island', 2),
#  ('marsh', 1),
#  ('may', 1),
#  ('rabbit', 2),
#  ('creek', 1),
#  ('wildfire', 3),
#  ('occurred', 2),
#  ('prince', 1),
#  ('albert', 2),
#  ('national', 3),
#  ('park', 1),
#  ('spread', 1),
#  ('within', 2),
#  ('outside', 2),
#  ('park', 1),
#  ('heavy', 2),
#  ('equipment', 3),
#  ('used', 1),
#  ('create', 2),
#  ('fire', 2),
#  ('control', 2),
#  ('lines', 1),
#  ('improve', 2),
#  ('ground', 1),
#  ('aerial', 3),
#  ('access', 2),
#  ('strategic', 3),
#  ('areas', 3),
#  ('addition', 3),
#  ('dozer', 2),
#  ('lines', 1),
#  ('put', 1),
#  ('fire', 2),
#  ('heavy', 2),
#  ('equipment', 3),
#  ('used', 1),
#  ('along', 2),
#  ('border', 2),
#  ('south', 1),
#  ('boundary', 3),
#  ('park', 1),
#  ('cookson', 2),
#  ('community', 4),
#  ('pasture', 2),
#  ('push', 1),
#  ('back', 1),
#  ('forested', 3),
#  ('edge', 1),
#  ('protect', 2),
#  ('newly', 2),
#  ('repaired', 2),
#  ('fence', 1),
#  ('damaged', 2),
#  ('fire', 2),
#  ('prince', 1),
#  ('albert', 2),
#  ('national', 3),
#  ('park', 1),
#  ('fire', 2),
#  ('management', 3),
#  ('takes', 1),
#  ('responsibility', 6),
#  ('reclamation', 4),
#  ('impacts', 2),
#  ('heavy', 2),
#  ('equipment', 3),
#  ('two', 1),
#  ('areas', 3),
#  ('work', 1),
#  ('south', 1),
#  ('boundary', 3),
#  ('trail', 1),
#  ('elk', 1),
#  ('trail', 1),
#  ('following', 3),
#  ('rabbit', 2),
#  ('fire', 2),
#  ('approximately', 5),
#  ('km', 1),
#  ('fence', 1),
#  ('replaced', 2),
#  ('northern', 2),
#  ('boundary', 3),
#  ('cookson', 2),
#  ('community', 4),
#  ('pasture', 2),
#  ('approximately', 5),
#  ('km', 1),
#  ('fence', 1),
#  ('directly', 3),
#  ('adjacent', 3),
#  ('panp', 1),
#  ('boundary', 3),
#  ('area', 3),
#  ('cleared', 1),
#  ('vegetation', 4),
#  ('long', 1),
#  ('linear', 3),
#  ('berms', 1),
#  ('soil', 1),
#  ('wood', 1),
#  ('restricting', 3),
#  ('efforts', 2),
#  ('weed', 1),
#  ('control', 2),
#  ('seeding', 2),
#  ('along', 2),
#  ('boundary', 3),
#  ('also', 2),
#  ('increase', 2),
#  ('long', 1),
#  ('term', 1),
#  ('fire', 2),
#  ('hazard', 2),
#  ('left', 1),
#  ('piles', 1),
#  ('berms', 1),
#  ('need', 1),
#  ('spread', 1),
#  ('across', 2),
#  ('opening', 3),
#  ('section', 2),
#  ('area', 3),
#  ('need', 1),
#  ('flat', 1),
#  ('debris', 2),
#  ('free', 1),
#  ('surface', 2),
#  ('left', 1),
#  ('used', 1),
#  ('trail', 1),
#  ('road', 1),
#  ('vehicles', 3),
#  ('elk', 1),
#  ('trail', 1),
#  ('maintained', 2),
#  ('trail', 1),
#  ('within', 2),
#  ('park', 1),
#  ('section', 2),
#  ('elk', 1),
#  ('trail', 1),
#  ('closed', 1),
#  ('since', 1),
#  ('due', 1),
#  ('impacts', 2),
#  ('heavy', 2),
#  ('equipment', 3),
#  ('wildfire', 3),
#  ('operations', 4),
#  ('main', 1),
#  ('area', 3),
#  ('concern', 2),
#  ('approximately', 5),
#  ('meters', 2),
#  ('forest', 2),
#  ('cleared', 1),
#  ('average', 3),
#  ('meters', 2),
#  ('wide', 1),
#  ('ha', 1),
#  ('reclaimed', 2),
#  ('fireguard', 3),
#  ('put', 1),
#  ('maintained', 2),
#  ('trail', 1),
#  ('new', 1),
#  ('trail', 1),
#  ('surface', 2),
#  ('need', 1),
#  ('developed', 3),
#  ('reclamation', 4),
#  ('within', 2),
#  ('area', 3),
#  ('bridge', 1),
#  ('crossed', 1),
#  ('small', 1),
#  ('stream', 1),
#  ('destroyed', 2),
#  ('heavy', 2),
#  ('equipment', 3),
#  ('shallow', 2),
#  ('water', 2),
#  ('ford', 1),
#  ('crossing', 2),
#  ('developed', 3),
#  ('near', 1),
#  ('area', 3),
#  ('also', 2),
#  ('helipad', 3),
#  ('approximately', 5),
#  ('ha', 1),
#  ('also', 2),
#  ('reclaimed', 2),
#  ('midway', 2),
#  ('trailhead', 2),
#  ('section', 2),
#  ('trail', 1),
#  ('culvert', 2),
#  ('washed', 1),
#  ('need', 1),
#  ('repaired', 2),
#  ('well', 1),
#  ('project', 2),
#  ('involve', 2),
#  ('construction', 3),
#  ('lake', 1),
#  ('superior', 4),
#  ('national', 3),
#  ('marine', 2),
#  ('conservation', 4),
#  ('area', 3),
#  ('discovery', 4),
#  ('centre', 2),
#  ('nipigon', 3),
#  ('project', 2),
#  ('site', 1),
#  ('hectare', 2),
#  ('lot', 1),
#  ('nipigon', 3),
#  ('waterfront', 3),
#  ('west', 1),
#  ('side', 1),
#  ('brennan', 2),
#  ('drive', 1),
#  ('project', 2),
#  ('include', 2),
#  ('construction', 3),
#  ('discovery', 4),
#  ('centre', 2),
#  ('detached', 2),
#  ('garage', 2),
#  ('parking', 2),
#  ('area', 3),
#  ('outdoor', 2),
#  ('interpretive', 4),
#  ('elements', 3),
#  ('landscaping', 3),
#  ('discovery', 4),
#  ('centre', 2),
#  ('approximately', 5),
#  ('square', 1),
#  ('meters', 2),
#  ('single', 2),
#  ('story', 2),
#  ('multiuse', 2),
#  ('building', 2),
#  ('include', 2),
#  ('exhibit', 3),
#  ('space', 1),
#  ('interpretive', 4),
#  ('elements', 3),
#  ('interior', 4),
#  ('exterior', 4),
#  ('administrative', 5),
#  ('space', 1),
#  ('serve', 1),
#  ('main', 1),
#  ('hub', 1),
#  ('visitors', 3),
#  ('lake', 1),
#  ('superior', 4),
#  ('national', 3),
#  ('marine', 2),
#  ('conservation', 4),
#  ('area', 3),
#  ('site', 1),
#  ('administration', 5),
#  ('operations', 4),
#  ('construction', 3),
#  ('phase', 1),
#  ('project', 2),
#  ('involve', 2),
#  ('use', 1),
#  ('heavy', 2),
#  ('machinery', 4),
#  ('excavation', 4),
#  ('backfilling', 3),
#  ('landscaping', 3),
#  ('vegetation', 4),
#  ('removal', 3),
#  ('project', 2),
#  ('assessed', 2),
#  ('basic', 2),
#  ('impact', 2),
#  ('assessment', 3),
#  ('yellow', 2),
#  ('toadflax', 2),
#  ('widely', 2),
#  ('distributed', 4),
#  ('perennial', 4),
#  ('invasive', 3),
#  ('plant', 1),
#  ('reproduces', 4),
#  ('seed', 1),
#  ('extensive', 3),
#  ('creeping', 2),
#  ('rhizome', 2),
#  ('plant', 1),
#  ('extremely', 3),
#  ('hardy', 2),
#  ('ability', 4),
#  ('densely', 2),
#  ('infest', 2),
#  ('large', 1),
#  ('areas', 3),
#  ('crowd', 1),
#  ('native', 2),
#  ('vegetation', 4),
#  ('making', 2),
#  ('threat', 1),
#  ('ecological', 5),
#  ('integrity', 4),
#  ('prince', 1),
#  ('albert', 2),
#  ('national', 3),
#  ('park', 1),
#  ('herbicide', 3),
#  ('spraying', 2),
#  ('yellow', 2),
#  ('toadflax', 2),
#  ('occurred', 2),
#  ('several', 2),
#  ('locations', 3),
#  ('prince', 1),
#  ('albert', 2),
#  ('national', 3),
#  ('park', 1),
#  ('limited', 3),
#  ('success', 2),
#  ('using', 2),
#  ('biological', 5),
#  ('control', 2),
#  ('agent', 2),
#  ('offers', 2),
#  ('additional', 4),
#  ('option', 2),
#  ('control', 2),
#  ('species', 2),
#  ('manner', 2),
#  ('nearly', 2),
#  ('labour', 2),
#  ('intensive', 3),
#  ('prince', 1),
#  ('albert', 2),
#  ('national', 3),
#  ('park', 1),
#  ('working', 2),
#  ('agriculture', 4),
#  ('agri', 2),
#  ('food', 1),
#  ('canada', 3),
#  ('carry', 2),
#  ('trials', 2),
#  ('rhinusa', 3),
#  ('pilosa', 3),
#  ('three', 1),
#  ('affected', 3),
#  ('locations', 3),
#  ('prospect', 2),
#  ('point', 1),
#  ('rabbit', 2),
#  ('cabin', 2),
#  ('area', 3),
#  ('mile', 1),
#  ('meadow', 2),
#  ('weevils', 2),
#  ('obtained', 2),
#  ('agriculture', 4),
#  ('agri', 2),
#  ('foods', 1),
#  ('canada', 3),
#  ('charge', 1),
#  ('released', 2),
#  ('sites', 1),
#  ('late', 1),
#  ('summer', 2),
#  ('hyperabundant', 5),
#  ('populations', 4),
#  ('white', 1),
#  ('tailed', 1),
#  ('deer', 1),
#  ('threaten', 2),
#  ('ecological', 5),
#  ('value', 2),
#  ('varied', 2),
#  ('forest', 2),
#  ('communities', 4),
#  ('hill', 1),
#  ('island', 2),
#  ('park', 1),
#  ('islands', 2),
#  ('intensive', 3),
#  ('browsing', 2),
#  ('led', 1),
#  ('distinct', 2),
#  ('lack', 1),
#  ('understory', 4),
#  ('vegetation', 4),
#  ('changing', 2),
#  ('forest', 2),
#  ('composition', 4),
#  ('parks', 1),
#  ('canada', 3),
#  ('developed', 3),
#  ('deer', 1),
#  ('management', 3),
#  ('strategy', 3),
#  ('response', 2),
#  ('ecological', 5),
#  ('impacts', 2),
#  ('proposing', 3),
#  ('restore', 2),
#  ('native', 2),
#  ('vegetation', 4),
#  ('area', 3),
#  ('reducing', 3),
#  ('deer', 1),
#  ('numbers', 2),
#  ('deer', 1),
#  ('herd', 1),
#  ('reduction', 3),
#  ('conducted', 3),
#  ('outlined', 2),
#  ('hill', 1),
#  ('island', 2),
#  ('hyperabundant', 5),
#  ('deer', 1),
#  ('management', 3),
#  ('plan', 1),
#  ('goal', 1),
#  ('project', 2),
#  ('restore', 2),
#  ('integrity', 4),
#  ('forest', 2),
#  ('ecosystem', 4),
#  ('hill', 1),
#  ('island', 2),
#  ('processes', 3),
#  ('protect', 2),
#  ('habitat', 3),
#  ('plant', 1),
#  ('species', 2),
#  ('conservation', 4),
#  ('concern', 2),
#  ('eg', 1),
#  ('pitch', 1),
#  ('pine', 1),
#  ('deer', 1),
#  ('herd', 1),
#  ('reduction', 3),
#  ('began', 2),
#  ('effort', 2),
#  ('reduce', 2),
#  ('populations', 4),
#  ('level', 2),
#  ('deer', 1),
#  ('per', 1),
#  ('allow', 2),
#  ('healthy', 2),
#  ('forest', 2),
#  ('regeneration', 5),
#  ('efforts', 2),
#  ('continue', 3),
#  ('attain', 2),
#  ('population', 4),
#  ('density', 3),
#  ('reduction', 3),
#  ('deer', 1),
#  ('numbers', 2),
#  ('achieved', 2),
#  ('partnering', 3),
#  ('mohawks', 2),
#  ('akwesasne', 3),
#  ('harvest', 2),
#  ('white', 1),
#  ('tailed', 1),
#  ('deer', 1),
#  ('island', 2),
#  ('monitoring', 4),
#  ('program', 2),
#  ('continue', 3),
#  ('track', 1),
#  ('effectiveness', 4),
#  ('deer', 1),
#  ('reduction', 3),
#  ('strategy', 3),
#  ('recovery', 3),
#  ('forest', 2),
#  ('ecosystem', 4),
#  ('project', 2),
#  ('assessed', 2),
#  ('basic', 2),
#  ('impact', 2),
#  ('assessment', 3),
#  ('project', 2),
#  ('entail', 2),
#  ('installation', 4),
#  ('approximately', 5),
#  ('grid', 1),
#  ('tied', 1),
#  ('photovoltaic', 5),
#  ('solar', 2),
#  ('panels', 2),
#  ('site', 1),
#  ('former', 2),
#  ('environment', 4),
#  ('climate', 2),
#  ('change', 1),
#  ('canada', 3),
#  ('capmon', 2),
#  ('weather', 2),
#  ('station', 2),
#  ('located', 3),
#  ('within', 2),
#  ('kejimkujik', 4),
#  ('national', 3),
#  ('park', 1),
#  ('national', 3),
#  ('historic', 3),
#  ('site', 1),
#  ('frontcountry', 3),
#  ('goal', 1),
#  ('project', 2),
#  ('generate', 3),
#  ('renewable', 4),
#  ('electricity', 5),
#  ('contribute', 3),
#  ('reduction', 3),
#  ('greenhouse', 2),
#  ('gases', 2),
#  ('associated', 5),
#  ('park', 1),
#  ('operations', 4),
#  ('solar', 2),
#  ('panels', 2),
#  ('mounted', 2),
#  ('racking', 2),
#  ('system', 2),
#  ('anchored', 2),
#  ('screw', 1),
#  ('piles', 1),
#  ('poured', 1),
#  ('concrete', 2),
#  ('foundations', 3),
#  ('trenching', 2),
#  ('required', 3),
#  ('installation', 4),
#  ('electrical', 4),
#  ('wiring', 2),
#  ('connect', 2),
#  ('array', 2),
#  ('existing', 3),
#  ('nova', 2),
#  ('scotia', 2),
#  ('power', 2),
#  ('grid', 1),
#  ('site', 1),
#  ('project', 2),
#  ('reviewed', 2),
#  ('via', 2),
#  ('basic', 2),
#  ('impact', 2),
#  ('assessment', 3),
#  ('saskpower', 3),
#  ('proposing', 3),
#  ('replace', 2),
#  ('pole', 1),
#  ('mount', 1),
#  ('transformer', 3),
#  ('existing', 3),
#  ('wooden', 2),
#  ('pole', 1),
#  ('directionally', 5),
#  ('drill', 1),
#  ('customer', 3),
#  ('supplied', 2),
#  ('metering', 3),
#  ('point', 1),
#  ('se', 2),
#  ('within', 2),
#  ('prince', 1),
#  ('albert', 2),
#  ('national', 3),
#  ('park', 1),
#  ('project', 2),
#  ('required', 3),
#  ('increase', 2),
#  ('capacity', 4),
#  ('line', 1),
#  ('maintain', 2),
#  ('quality', 3),
#  ('service', 2),
#  ('existing', 3),
#  ('customer', 3),
#  ('equipment', 3),
#  ('expected', 3),
#  ('used', 1),
#  ('completion', 3),
#  ('project', 2),
#  ('includes', 2),
#  ('digger', 2),
#  ('truck', 1),
#  ('back', 1),
#  ('hoe', 1),
#  ('bucket', 2),
#  ('truck', 1),
#  ('directional', 4),
#  ('boring', 2),
#  ('equipment', 3),
#  ('crew', 1),
#  ('trucks', 1),
#  ('access', 2),
#  ('components', 3),
#  ('project', 2),
#  ('make', 1),
#  ('use', 1),
#  ('existing', 3),
#  ('roads', 1),
#  ('trails', 1),
#  ('surface', 2),
#  ('disturbance', 3),
#  ('expected', 3),
#  ('minimized', 3),
#  ('bell', 1),
#  ('holes', 1),
#  ('existing', 3),
#  ('pole', 1),
#  ('metering', 3),
#  ('point', 1),
#  ('project', 2),
#  ('involve', 2),
#  ('dock', 1),
#  ('work', 1),
#  ('multiple', 3),
#  ('locations', 3),
#  ('throughout', 2),
#  ('thousand', 2),
#  ('islands', 2),
#  ('national', 3),
#  ('park', 1),
#  ('specifically', 4),
#  ('work', 1),
#  ('include', 2),
#  ('installation', 4),
#  ('floating', 2),
#  ('docks', 1),
#  ('replace', 2),
#  ('docks', 1),
#  ('damaged', 2),
#  ('due', 1),
#  ('recent', 2),
#  ('high', 1),
#  ('water', 2),
#  ('levels', 2),
#  ('replace', 2),
#  ('docks', 1),
#  ('end', 1),
#  ('life', 1),
#  ('cycle', 2),
#  ('new', 1),
#  ('docks', 1),
#  ('designed', 2),
#  ('accommodate', 4),
#  ('higher', 2),
#  ('water', 2),
#  ('levels', 2),
#  ('associated', 5),
#  ('work', 1),
#  ('includes', 2),
#  ('installation', 4),
#  ('water', 2),
#  ('shoreline', 2),
#  ('anchoring', 3),
#  ('systems', 2),
#  ('installation', 4),
#  ('boardwalks', 2),
#  ('kiosks', 2),
#  ('shore', 1),
#  ('landing', 2),
#  ('points', 1),
#  ('replacements', 3),
#  ('minor', 2),
#  ('location', 3),
#  ('adjustments', 3),
#  ('mooring', 2),
#  ('buoy', 2),
#  ('anchors', 2),
#  ('may', 1),
#  ('also', 2),
#  ('carried', 2),
#  ('necessary', 4),
#  ('dock', 1),
#  ('project', 2),
#  ('locations', 3),
#  ('include', 2),
#  ('adelaide', 3),
#  ('island', 2),
#  ('east', 1),
#  ('grenadier', 3),
#  ('island', 2),
#  ('georgina', 3),
#  ('island', 2),
#  ('constance', 2),
#  ('island', 2),
#  ('mulcaster', 3),
#  ('island', 2),
#  ('milton', 2),
#  ('island', 2),
#  ('hill', 1),
#  ('island', 2),
#  ('stovin', 2),
#  ('island', 2),
#  ('project', 2),
#  ('work', 1),
#  ('planned', 1),
#  ('commence', 2),
#  ('april', 2),
#  ('conclude', 2),
#  ('november', 3),
#  ('project', 2),
#  ('assessed', 2),
#  ('basic', 2),
#  ('impact', 2),
#  ('assessment', 3),
#  ('new', 1),
#  ('culvert', 2),
#  ('needs', 1),
#  ('installed', 2),
#  ('boundary', 3),
#  ('road', 1),
#  ('north', 1),
#  ('osten', 2),
#  ('lake', 1),
#  ('camping', 2),
#  ('access', 2),
#  ('rr', 1),
#  ('culvert', 2),
#  ('collapsed', 2),
#  ('completely', 3),
#  ('rusted', 2),
#  ('site', 1),
#  ('currently', 3),
#  ('flooded', 2),
#  ('due', 1),
#  ('beaver', 2),
#  ...]

# %%
# Count occurrence of words with 3 or more syllables

long_words = []

for pair in new_list:
    if pair[1] >= 3:
        long_words.append(pair)

print(len(new_list)) # count all words
print(len(long_words))    # count all long words
# Out:
# 4221
# 1314

# %%
# Percentage of long words in all words

1314/4221 * 100
# Out:
# 31.13006396588486

# %% [markdown]
# About 30% of the meaningful words in the project description text are 3 syllables or longer.

# %%
# Frequency of long words

# isolate the words from syl counts so they can be counted
long = [] 
for pair in long_words:
    long.append(pair[0])

long_count = Counter(long)
pprint(long_count)
# Out:
# Counter({'area': 46,
#          'national': 36,
#          'existing': 30,
#          'areas': 22,
#          'canada': 21,
#          'assessment': 19,
#          'required': 17,
#          'equipment': 17,
#          'vegetation': 16,
#          'management': 15,
#          'approximately': 15,
#          'replacement': 15,
#          'habitat': 14,
#          'construction': 13,
#          'installation': 10,
#          'including': 10,
#          'removal': 9,
#          'located': 9,
#          'proposing': 9,
#          'expected': 9,
#          'boundary': 9,
#          'reduction': 9,
#          'disturbance': 8,
#          'adjacent': 7,
#          'currently': 7,
#          'operations': 7,
#          'wildfire': 6,
#          'historic': 6,
#          'removing': 6,
#          'etc': 6,
#          'potential': 6,
#          'reclamation': 6,
#          'developed': 6,
#          'visitor': 6,
#          'objective': 6,
#          'maintenance': 6,
#          'constructed': 6,
#          'activities': 6,
#          'various': 5,
#          'inspection': 5,
#          'identified': 5,
#          'ecological': 5,
#          'locations': 5,
#          'limited': 5,
#          'additional': 5,
#          'ecosystem': 5,
#          'continue': 5,
#          'requires': 5,
#          'completed': 5,
#          'infrastructure': 5,
#          'services': 5,
#          'october': 5,
#          'critical': 5,
#          'forested': 4,
#          'temporary': 4,
#          'addition': 4,
#          'associated': 4,
#          'community': 4,
#          'conservation': 4,
#          'herbicide': 4,
#          'customer': 4,
#          'completion': 4,
#          'location': 4,
#          'decommission': 4,
#          'restoration': 4,
#          'natural': 4,
#          'designated': 4,
#          'remaining': 4,
#          'corridors': 4,
#          'cultural': 4,
#          'exclusion': 4,
#          'replacing': 4,
#          'distribution': 4,
#          'sanitary': 4,
#          'kootenay': 4,
#          'protection': 3,
#          'erosion': 3,
#          'necessary': 3,
#          'previously': 3,
#          'aerial': 3,
#          'discovery': 3,
#          'landscaping': 3,
#          'visitors': 3,
#          'machinery': 3,
#          'invasive': 3,
#          'integrity': 3,
#          'communities': 3,
#          'understory': 3,
#          'strategy': 3,
#          'recovery': 3,
#          'contribute': 3,
#          'electrical': 3,
#          'saskpower': 3,
#          'capacity': 3,
#          'completely': 3,
#          'facilitate': 3,
#          'federal': 3,
#          'provincial': 3,
#          'created': 3,
#          'physical': 3,
#          'vehicle': 3,
#          'mortality': 3,
#          'pedestrian': 3,
#          'cavendish': 3,
#          'snowmobile': 3,
#          'condition': 3,
#          'waterton': 3,
#          'conditions': 3,
#          'diversity': 3,
#          'established': 3,
#          'excavated': 3,
#          'operational': 3,
#          'navigation': 3,
#          'avalanche': 3,
#          'reducing': 2,
#          'firesmart': 2,
#          'deficiencies': 2,
#          'repairing': 2,
#          'degraded': 2,
#          'collected': 2,
#          'fisheries': 2,
#          'authorization': 2,
#          'directly': 2,
#          'linear': 2,
#          'vehicles': 2,
#          'superior': 2,
#          'nipigon': 2,
#          'interpretive': 2,
#          'elements': 2,
#          'interior': 2,
#          'exterior': 2,
#          'excavation': 2,
#          'ability': 2,
#          'intensive': 2,
#          'agriculture': 2,
#          'hyperabundant': 2,
#          'populations': 2,
#          'conducted': 2,
#          'population': 2,
#          'partnering': 2,
#          'environment': 2,
#          'kejimkujik': 2,
#          'foundations': 2,
#          'transformer': 2,
#          'metering': 2,
#          'quality': 2,
#          'components': 2,
#          'minimized': 2,
#          'specifically': 2,
#          'replacements': 2,
#          'activity': 2,
#          'strathcona': 2,
#          'experience': 2,
#          'history': 2,
#          'participants': 2,
#          'successfully': 2,
#          'wastewater': 2,
#          'surrounding': 2,
#          'possibly': 2,
#          'proposes': 2,
#          'supporting': 2,
#          'maintaining': 2,
#          'colony': 2,
#          'corridor': 2,
#          'riparian': 2,
#          'anticipated': 2,
#          'undertaken': 2,
#          'require': 2,
#          'rehabilitated': 2,
#          'partially': 2,
#          'agricultural': 2,
#          'hurricane': 2,
#          'dorian': 2,
#          'majority': 2,
#          'originally': 2,
#          'heavily': 2,
#          'facility': 2,
#          'aquatic': 2,
#          'related': 2,
#          'resources': 2,
#          'measurements': 2,
#          'adequate': 2,
#          'snowmobiling': 2,
#          'residents': 2,
#          'alongside': 2,
#          'significant': 2,
#          'supported': 2,
#          'classified': 2,
#          'environmental': 2,
#          'evaluated': 2,
#          'encroachment': 2,
#          'overhead': 2,
#          'emergency': 2,
#          'understorey': 2,
#          'permanent': 2,
#          'responsible': 2,
#          'properties': 2,
#          'residential': 2,
#          'disposal': 2,
#          'underground': 2,
#          'excavations': 2,
#          'malady': 2,
#          'respectively': 2,
#          'commissariat': 2,
#          'officers': 2,
#          'heritage': 2,
#          'important': 2,
#          'academic': 2,
#          'traditional': 2,
#          'selected': 2,
#          'documented': 2,
#          'periodically': 2,
#          'september': 2,
#          'abutments': 2,
#          'purposes': 2,
#          'possible': 2,
#          'installing': 2,
#          'hazardous': 2,
#          'strategically': 2,
#          'agency': 2,
#          'primarily': 2,
#          'aggregate': 2,
#          'avenue': 2,
#          'information': 2,
#          'sensitive': 2,
#          'explosives': 2,
#          'efficiency': 2,
#          'maximum': 2,
#          'materials': 2,
#          'facilities': 2,
#          'predation': 2,
#          'artificial': 2,
#          'maturity': 1,
#          'resulted': 1,
#          'accumulation': 1,
#          'material': 1,
#          'administering': 1,
#          'armoured': 1,
#          'perimeter': 1,
#          'passamaquoddy': 1,
#          'rehabilitate': 1,
#          'geotextile': 1,
#          'reinstating': 1,
#          'relation': 1,
#          'provisions': 1,
#          'offsetting': 1,
#          'entire': 1,
#          'enhancements': 1,
#          'constructing': 1,
#          'widening': 1,
#          'deepening': 1,
#          'enhancement': 1,
#          'strategic': 1,
#          'responsibility': 1,
#          'following': 1,
#          'restricting': 1,
#          'opening': 1,
#          'average': 1,
#          'fireguard': 1,
#          'helipad': 1,
#          'waterfront': 1,
#          'exhibit': 1,
#          'administrative': 1,
#          'administration': 1,
#          'backfilling': 1,
#          'distributed': 1,
#          'perennial': 1,
#          'reproduces': 1,
#          'extensive': 1,
#          'extremely': 1,
#          'biological': 1,
#          'rhinusa': 1,
#          'pilosa': 1,
#          'affected': 1,
#          'composition': 1,
#          'processes': 1,
#          'regeneration': 1,
#          'density': 1,
#          'akwesasne': 1,
#          'monitoring': 1,
#          'effectiveness': 1,
#          'photovoltaic': 1,
#          'frontcountry': 1,
#          'generate': 1,
#          'renewable': 1,
#          'electricity': 1,
#          'directionally': 1,
#          'directional': 1,
#          'multiple': 1,
#          'accommodate': 1,
#          'anchoring': 1,
#          'adjustments': 1,
#          'adelaide': 1,
#          'grenadier': 1,
#          'georgina': 1,
#          'mulcaster': 1,
#          'november': 1,
#          'impassable': 1,
#          'diameter': 1,
#          'strategies': 1,
#          'develop': 1,
#          'opportunities': 1,
#          'canadians': 1,
#          'discover': 1,
#          'trivial': 1,
#          'furthermore': 1,
#          'analyzed': 1,
#          'contaminated': 1,
#          'subunit': 1,
#          'harvested': 1,
#          'historical': 1,
#          'targeting': 1,
#          'revegetation': 1,
#          'accommodations': 1,
#          'compromised': 1,
#          'maternity': 1,
#          'possibility': 1,
#          'residence': 1,
#          'occupation': 1,
#          'mankota': 1,
#          'acquisition': 1,
#          'domestic': 1,
#          'watering': 1,
#          'traverses': 1,
#          'seasonal': 1,
#          'narrowest': 1,
#          'easily': 1,
#          'navigable': 1,
#          'resulting': 1,
#          'pacific': 1,
#          'traversing': 1,
#          'mitigation': 1,
#          'understood': 1,
#          'previous': 1,
#          'experienced': 1,
#          'devastating': 1,
#          'personal': 1,
#          'situated': 1,
#          'regenerative': 1,
#          'covering': 1,
#          'communications': 1,
#          'reconstructed': 1,
#          'devastated': 1,
#          'beginning': 1,
#          'potato': 1,
#          'majorly': 1,
#          'reconfigured': 1,
#          'evident': 1,
#          'surfaces': 1,
#          'disturbing': 1,
#          'anything': 1,
#          'encompassed': 1,
#          'developing': 1,
#          'archaeological': 1,
#          'watercraft': 1,
#          'inspections': 1,
#          'realignment': 1,
#          'preparation': 1,
#          'utility': 1,
#          'undertaking': 1,
#          'amendment': 1,
#          'finalized': 1,
#          'determined': 1,
#          'mobilizing': 1,
#          'continues': 1,
#          'coordination': 1,
#          'chipewyan': 1,
#          'permitted': 1,
#          'commercial': 1,
#          'kilometers': 1,
#          'tablelands': 1,
#          'expanded': 1,
#          'wilderness': 1,
#          'combination': 1,
#          'alignment': 1,
#          'overtopping': 1,
#          'divided': 1,
#          'document': 1,
#          'requirements': 1,
#          'implementation': 1,
#          'historically': 1,
#          'interval': 1,
#          'ecoregions': 1,
#          'variety': 1,
#          'encompasses': 1,
#          'execution': 1,
#          'every': 1,
#          'thereafter': 1,
#          'ecoregion': 1,
#          'intersects': 1,
#          'protected': 1,
#          'vertical': 1,
#          'survival': 1,
#          'intensity': 1,
#          'abundance': 1,
#          'structural': 1,
#          'disappeared': 1,
#          'trajectory': 1,
#          'effective': 1,
#          'establish': 1,
#          'rejuvenate': 1,
#          'producing': 1,
#          'accomplish': 1,
#          'seasonally': 1,
#          'overseeing': 1,
#          'tenanted': 1,
#          'depending': 1,
#          'barrier': 1,
#          'compliance': 1,
#          'ontario': 1,
#          'amended': 1,
#          'minimum': 1,
#          'provided': 1,
#          'vicinity': 1,
#          'bottling': 1,
#          'recapitalization': 1,
#          'federally': 1,
#          'recognized': 1,
#          'initiative': 1,
#          'initiated': 1,
#          'structurally': 1,
#          'renovations': 1,
#          'substantial': 1,
#          'stabilization': 1,
#          'repointing': 1,
#          'reconstruction': 1,
#          'improvements': 1,
#          'upgrading': 1,
#          'utilities': 1,
#          'crataegus': 1,
#          'monogyna': 1,
#          'researchers': 1,
#          'ongoing': 1,
#          'progressively': 1,
#          'expanding': 1,
#          'aggressively': 1,
#          'untreated': 1,
#          'rendering': 1,
#          'ineffective': 1,
#          'continued': 1,
#          'invasion': 1,
#          'supplanting': 1,
#          'experimental': 1,
#          'efficacy': 1,
#          'chemical': 1,
#          'determine': 1,
#          'practices': 1,
#          'triclopyr': 1,
#          'resprouting': 1,
#          'consistent': 1,
#          'integrated': 1,
#          'december': 1,
#          'initiate': 1,
#          'excessive': 1,
#          'cavities': 1,
#          'decaying': 1,
#          'uprooted': 1,
#          'competition': 1,
#          'undesired': 1,
#          'retaining': 1,
#          'serious': 1,
#          'stabilize': 1,
#          'repeated': 1,
#          'annually': 1,
#          'investigate': 1,
#          'implemented': 1,
#          'tributary': 1,
#          'cofferdam': 1,
#          'dewatering': 1,
#          'approaches': 1,
#          'creating': 1,
#          'thanksgiving': 1,
#          'victoria': 1,
#          'interfere': 1,
#          'modification': 1,
#          'volunteers': 1,
#          'relocated': 1,
#          'proposal': 1,
#          'permanently': 1,
#          'rectify': 1,
#          'attachment': 1,
#          'incorporate': 1,
#          'culturally': 1,
#          'appropriate': 1,
#          'consultation': 1,
#          'excavator': 1,
#          'mitigations': 1,
#          'coincide': 1,
#          'revitalization': 1,
#          'backcountry': 1,
#          'liberty': 1,
#          'essential': 1,
#          'deteriorated': 1,
#          'protecting': 1,
#          'gravity': 1,
#          'regulatory': 1,
#          'notices': 1,
#          'preservation': 1,
#          'selective': 1,
#          'principles': 1,
#          'providing': 1,
#          'firefighters': 1,
#          'interface': 1,
#          'saturna': 1,
#          'warburton': 1,
#          'january': 1,
#          'latitude': 1,
#          'longitude': 1,
#          'memorial': 1,
#          'cemetery': 1,
#          'intended': 1,
#          'separate': 1,
#          'mackenzie': 1,
#          'property': 1,
#          'permission': 1,
#          'ave': 1,
#          'investigated': 1,
#          'otherwise': 1,
#          'coverage': 1,
#          'typically': 1,
#          'obstructions': 1,
#          'differences': 1,
#          'excluded': 1,
#          'toronto': 1,
#          'duration': 1,
#          'minimize': 1,
#          'helicopters': 1,
#          'however': 1,
#          'helicopter': 1,
#          'visibility': 1,
#          'effecting': 1,
#          'exposing': 1,
#          'challenging': 1,
#          'rationale': 1,
#          'helipads': 1,
#          'incorporates': 1,
#          'ecosytems': 1,
#          'waterbody': 1,
#          'resurfaced': 1,
#          'operationally': 1,
#          'viable': 1,
#          'rehabilitation': 1,
#          'involving': 1,
#          'contouring': 1,
#          'kilometres': 1,
#          'intersection': 1,
#          'radium': 1,
#          'general': 1,
#          'secondary': 1,
#          'connections': 1,
#          'waskesiu': 1,
#          'library': 1,
#          'recreation': 1,
#          'consisting': 1,
#          'surrounded': 1,
#          'experiencing': 1,
#          'motorised': 1,
#          'wheelbarrow': 1,
#          'hibernation': 1})
